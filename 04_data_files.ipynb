# %% [markdown]
# # Форматы данных (1)

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 4: Форматы данных"
# * https://docs.python.org/3/library/json.html
# * https://docs.python.org/3/library/pickle.html
# * https://www.crummy.com/software/BeautifulSoup/bs4/doc.ru/bs4ru.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Вывести все адреса электронной почты, содержащиеся в адресной книге `addres-book.json`

# %%
import json

with open('addres-book.json', 'r', encoding = 'utf8') as fp:
    data = json.load(fp)

# %%
data
# Out:
# [{'name': 'Faina Lee',
#   'email': 'faina@mail.ru',
#   'birthday': '22.08.1994',
#   'phones': [{'phone': '232-19-55'}, {'phone': '+7 (916) 232-19-55'}]},
#  {'name': 'Robert Lee',
#   'email': 'robert@mail.ru',
#   'birthday': '22.08.1994',
#   'phones': [{'phone': '111-19-55'}, {'phone': '+7 (916) 445-19-55'}]}]

# %%
for person in data:
    print(person['email'])
# Out:
# faina@mail.ru
# robert@mail.ru

# %% [markdown]
# 2. Вывести телефоны, содержащиеся в адресной книге `addres-book.json`

# %%
for person in data:
    for number in person['phones']:
        print(number)
# Out:
# {'phone': '232-19-55'}
# {'phone': '+7 (916) 232-19-55'}
# {'phone': '111-19-55'}
# {'phone': '+7 (916) 445-19-55'}

# %% [markdown]
# 3. По данным из файла `addres-book-q.xml` сформировать список словарей с телефонами каждого из людей.

# %%
from bs4 import BeautifulSoup

with open('addres-book-q.xml', 'r', encoding = 'utf8') as fp:
    data = BeautifulSoup(fp, 'xml')

# %%
data.address
# Out:
# <address id="1">
# <gender>m</gender>
# <name>Aicha Barki</name>
# <email>aiqraa.asso@caramail.com</email>
# <position>Presidente</position>
# <company>Association Algerienne d'Alphabetisation Iqraa</company>
# <phones>
# <phone type="work">+ (213) 6150 4015</phone>
# <phone type="personal">+ (213) 2173 5247</phone>
# </phones>
# </address>

# %%
for address in data.find_all('address'):
    for phone in address.find_all('phone'):
        print(phone.text, phone.attrs['type'])
# Out:
# + (213) 6150 4015 work
# + (213) 2173 5247 personal
# + (244-2) 325 023 work
# + (244-2) 325 023 personal
# + (244) 4232 2836 personal
# + (244-2) 325 023 work
# + (244-2) 325 023 personal
# + (54-11) 4784 1159 work
# + (61-2) 6274 9500 work
# + (61-2) 6274 9513 personal
# + (61-3) 9807 4702 work

# %%
data.find_all('address')
# Out:
# [<address id="1">
#  <gender>m</gender>
#  <name>Aicha Barki</name>
#  <email>aiqraa.asso@caramail.com</email>
#  <position>Presidente</position>
#  <company>Association Algerienne d'Alphabetisation Iqraa</company>
#  <phones>
#  <phone type="work">+ (213) 6150 4015</phone>
#  <phone type="personal">+ (213) 2173 5247</phone>
#  </phones>
#  </address>,
#  <address id="2">
#  <gender>m</gender>
#  <name>Francisco Domingos</name>
#  <email>frandomingos@hotmail.com</email>
#  <position>Directeur General</position>
#  <company>Institut National de Education des Adultes</company>
#  <phones>
#  <phone type="work">+ (244-2) 325 023</phone>
#  <phone type="personal">+ (244-2) 325 023</phone>
#  </phones>
#  </address>,
#  <address id="3">
#  <gender>f</gender>
#  <name>Maria Luisa</name>
#  <email>luisagrilo@ebonet.net</email>
#  <position>Directrice Nationale</position>
#  <company>Institut National de Education des Adultes</company>
#  <phones>
#  <phone type="personal">+ (244) 4232 2836</phone>
#  </phones>
#  </address>,
#  <address id="4">
#  <gender>m</gender>
#  <name>Abraao Chanda</name>
#  <email>ineda@snet.co.ao</email>
#  <position>Chef</position>
#  <company>Institut National de Education des Adultes</company>
#  <phones>
#  <phone type="work">+ (244-2) 325 023</phone>
#  <phone type="personal">+ (244-2) 325 023</phone>
#  </phones>
#  </address>,
#  <address id="5">
#  <gender>m</gender>
#  <name>Beatriz Busaniche</name>
#  <email>busaniche@caminandoutopias.org.ar</email>
#  <position>Executive Director</position>
#  <company>Universidad de Buenos Aires</company>
#  <phones>
#  <phone type="work">+ (54-11) 4784 1159</phone>
#  </phones>
#  </address>,
#  <address id="6">
#  <gender>f</gender>
#  <name>Francesca Beddie</name>
#  <email>f.beddie@ala.asn.au</email>
#  <position>Executive Director</position>
#  <company>Adult Learning Australia</company>
#  <phones>
#  <phone type="work">+ (61-2) 6274 9500</phone>
#  <phone type="personal">+ (61-2) 6274 9513</phone>
#  </phones>
#  </address>,
#  <address id="7">
#  <gender>m</gender>
#  <name>Graham John Smith</name>
#  <email>grasm@connexus.net.au</email>
#  <position>Secretary</position>
#  <company>Disability Australia Ltd</company>
#  <phones>
#  <phone type="work">+ (61-3) 9807 4702</phone>
#  </phones>
#  </address>]

# %% [markdown]
# ## Лабораторная работа №4

# %% [markdown]
# ### JSON

# %% [markdown]
# 1.1 Считайте файл `contributors_sample.json`. Воспользовавшись модулем `json`, преобразуйте содержимое файла в соответствующие объекты python. Выведите на экран информацию о первых 3 пользователях.

# %%
with open('contributors_sample.json', 'r', encoding = 'utf8') as fp:
    contributors_sample = json.load(fp)

# %%
contributors_sample[:3]
# Out:
# [{'username': 'uhebert',
#   'name': 'Lindsey Nguyen',
#   'sex': 'F',
#   'address': '01261 Cameron Spring\nTaylorfurt, AK 97791',
#   'mail': 'jsalazar@gmail.com',
#   'jobs': ['Energy engineer',
#    'Engineer, site',
#    'Environmental health practitioner',
#    'Biomedical scientist',
#    'Jewellery designer'],
#   'id': 35193},
#  {'username': 'vickitaylor',
#   'name': 'Cheryl Lewis',
#   'sex': 'F',
#   'address': '66992 Welch Brooks\nMarshallshire, ID 56004',
#   'mail': 'bhudson@gmail.com',
#   'jobs': ['Music therapist',
#    'Volunteer coordinator',
#    'Designer, interior/spatial'],
#   'id': 91970},
#  {'username': 'sheilaadams',
#   'name': 'Julia Allen',
#   'sex': 'F',
#   'address': 'Unit 1632 Box 2971\nDPO AE 23297',
#   'mail': 'darren44@yahoo.com',
#   'jobs': ['Management consultant',
#    'Engineer, structural',
#    'Lecturer, higher education',
#    'Theatre manager',
#    'Designer, textile'],
#   'id': 1848091}]

# %% [markdown]
# 1.2 Выведите уникальные почтовые домены, содержащиеся в почтовых адресах людей

# %%
import numpy as np

# %%
f = set()
for person in contributors_sample:
    f.add(person['mail'].split('@')[1])

f
# Out:
# {'gmail.com', 'hotmail.com', 'yahoo.com'}

# %% [markdown]
# 1.3 Напишите функцию, которая по `username` ищет человека и выводит информацию о нем. Если пользователь с заданным `username` отсутствует, возбудите исключение `ValueError`

# %%
contributors_sample
# Out:
# [{'username': 'uhebert',
#   'name': 'Lindsey Nguyen',
#   'sex': 'F',
#   'address': '01261 Cameron Spring\nTaylorfurt, AK 97791',
#   'mail': 'jsalazar@gmail.com',
#   'jobs': ['Energy engineer',
#    'Engineer, site',
#    'Environmental health practitioner',
#    'Biomedical scientist',
#    'Jewellery designer'],
#   'id': 35193},
#  {'username': 'vickitaylor',
#   'name': 'Cheryl Lewis',
#   'sex': 'F',
#   'address': '66992 Welch Brooks\nMarshallshire, ID 56004',
#   'mail': 'bhudson@gmail.com',
#   'jobs': ['Music therapist',
#    'Volunteer coordinator',
#    'Designer, interior/spatial'],
#   'id': 91970},
#  {'username': 'sheilaadams',
#   'name': 'Julia Allen',
#   'sex': 'F',
#   'address': 'Unit 1632 Box 2971\nDPO AE 23297',
#   'mail': 'darren44@yahoo.com',
#   'jobs': ['Management consultant',
#    'Engineer, structural',
#    'Lecturer, higher education',
#    'Theatre manager',
#    'Designer, textile'],
#   'id': 1848091},
#  {'username': 'nicole82',
#   'name': 'Gina Stevens',
#   'sex': 'F',
#   'address': '9880 Michelle Bridge\nNew Kimberlybury, WY 02583',
#   'mail': 'stevensonsarah@hotmail.com',
#   'jobs': ['Mechanical engineer', 'Retail banker', 'Barrister'],
#   'id': 50969},
#  {'username': 'jean67',
#   'name': 'Nicholas Harrington',
#   'sex': 'M',
#   'address': '9080 Monica Crescent Suite 820\nNorth Deanbury, HI 28977',
#   'mail': 'denise42@gmail.com',
#   'jobs': ['Network engineer',
#    'Youth worker',
#    'Primary school teacher',
#    'Engineer, broadcasting (operations)'],
#   'id': 676820},
#  {'username': 'james67',
#   'name': 'Allison Gomez',
#   'sex': 'F',
#   'address': '635 Kenneth Ways Suite 172\nHancockfort, AZ 50544',
#   'mail': 'monique02@hotmail.com',
#   'jobs': ['Designer, ceramics/pottery',
#    'Engineer, energy',
#    'Engineer, manufacturing'],
#   'id': 64918},
#  {'username': 'woodmarissa',
#   'name': 'Michael Jackson',
#   'sex': 'M',
#   'address': '4531 Phillips Underpass\nMartinezport, MA 82685',
#   'mail': 'dustin32@hotmail.com',
#   'jobs': ['Designer, furniture',
#    'Designer, furniture',
#    'Lecturer, higher education'],
#   'id': 113941},
#  {'username': 'sampsontammy',
#   'name': 'David Cruz',
#   'sex': 'M',
#   'address': '81737 Amy Grove Apt. 471\nJoannaport, IA 95575',
#   'mail': 'josephpowell@gmail.com',
#   'jobs': ['Sport and exercise psychologist',
#    'Hospital pharmacist',
#    'Surveyor, minerals',
#    'Geochemist',
#    'Restaurant manager'],
#   'id': 398160},
#  {'username': 'jonathan18',
#   'name': 'Mr. Matthew Robinson',
#   'sex': 'M',
#   'address': '01262 Dunn Ranch Apt. 256\nWest Jay, CO 99010',
#   'mail': 'oclark@hotmail.com',
#   'jobs': ['Clinical psychologist',
#    'Retail banker',
#    'Sports development officer',
#    'Firefighter',
#    'Charity fundraiser'],
#   'id': 35635},
#  {'username': 'michael53',
#   'name': 'Michael Kelly',
#   'sex': 'M',
#   'address': '75339 Jeremy Ford\nVictoriamouth, WV 22856',
#   'mail': 'danielsjessica@gmail.com',
#   'jobs': ['Insurance underwriter',
#    'Analytical chemist',
#    'Holiday representative'],
#   'id': 718054},
#  {'username': 'mcmahondavid',
#   'name': 'Christina Cowan',
#   'sex': 'F',
#   'address': '3829 Scott Prairie Apt. 614\nLoweland, CA 60640',
#   'mail': 'tinabrown@gmail.com',
#   'jobs': ['Network engineer',
#    'Scientist, research (physical sciences)',
#    'Financial planner'],
#   'id': 817632},
#  {'username': 'thomas96',
#   'name': 'Laura Trujillo',
#   'sex': 'F',
#   'address': '2573 Mahoney Shore Suite 323\nWest Briannaside, FL 13733',
#   'mail': 'patrickrodgers@gmail.com',
#   'jobs': ['Psychiatric nurse',
#    'Audiological scientist',
#    'Programmer, applications',
#    'Phytotherapist',
#    'Records manager'],
#   'id': 2406227},
#  {'username': 'martindonald',
#   'name': 'Diane Bell',
#   'sex': 'F',
#   'address': '565 Vazquez Spurs\nNew Richard, IA 19952',
#   'mail': 'makayla88@hotmail.com',
#   'jobs': ['Secondary school teacher',
#    'Futures trader',
#    'Programmer, multimedia',
#    'Public affairs consultant'],
#   'id': 239808},
#  {'username': 'ljohnson',
#   'name': 'Stephen Hull',
#   'sex': 'M',
#   'address': '9821 Patton Roads\nPort Scott, OH 39878',
#   'mail': 'jonescrystal@hotmail.com',
#   'jobs': ['Therapeutic radiographer', 'IT trainer', 'Location manager'],
#   'id': 66448},
#  {'username': 'wendycross',
#   'name': 'William Morris',
#   'sex': 'M',
#   'address': '97846 Stephens Ford\nWest Mary, DC 76913',
#   'mail': 'joseph72@yahoo.com',
#   'jobs': ['Production engineer',
#    'Chief Operating Officer',
#    'Hospital doctor',
#    'Radiation protection practitioner'],
#   'id': 27643},
#  {'username': 'wsmith',
#   'name': 'Matthew Ewing',
#   'sex': 'M',
#   'address': '1436 Wilson Stream Suite 801\nIantown, IL 27715',
#   'mail': 'ymorgan@gmail.com',
#   'jobs': ['Printmaker',
#    'Publishing copy',
#    'Research scientist (life sciences)'],
#   'id': 797706},
#  {'username': 'ashlee22',
#   'name': 'Dylan Rodriguez',
#   'sex': 'M',
#   'address': '8542 Navarro Ports\nTravisborough, SD 62180',
#   'mail': 'andersonrobert@gmail.com',
#   'jobs': ['Chief Technology Officer',
#    'Call centre manager',
#    'Chief Executive Officer',
#    'Purchasing manager'],
#   'id': 40493},
#  {'username': 'swoodward',
#   'name': 'David Brown',
#   'sex': 'M',
#   'address': '9359 Snyder Creek\nBruceview, SD 54485',
#   'mail': 'bonnie99@hotmail.com',
#   'jobs': ['Engineer, petroleum',
#    'Social researcher',
#    'Publishing rights manager'],
#   'id': 727055},
#  {'username': 'donald28',
#   'name': 'Taylor Byrd',
#   'sex': 'M',
#   'address': '16804 Terry Wall\nPort Haileyville, WY 58276',
#   'mail': 'kimberly45@yahoo.com',
#   'jobs': ['Tax adviser',
#    'Customer service manager',
#    'Forensic psychologist',
#    'Financial adviser',
#    'Photographer'],
#   'id': 1292969},
#  {'username': 'moodydavid',
#   'name': 'John Morton',
#   'sex': 'M',
#   'address': '408 Townsend Island Apt. 258\nPaulashire, GA 79680',
#   'mail': 'ericdavis@hotmail.com',
#   'jobs': ['Health and safety adviser',
#    'Product/process development scientist',
#    'Ceramics designer',
#    'Secretary/administrator',
#    'Patent attorney'],
#   'id': 31364},
#  {'username': 'edwardszachary',
#   'name': 'Rachel Newman',
#   'sex': 'F',
#   'address': '847 Brian Park Apt. 089\nEast Michaelstad, FL 85845',
#   'mail': 'xsmith@gmail.com',
#   'jobs': ['Hotel manager',
#    'Quantity surveyor',
#    'Scientist, research (physical sciences)'],
#   'id': 814629},
#  {'username': 'ashley92',
#   'name': 'Christopher Decker',
#   'sex': 'M',
#   'address': '50944 Jennifer Union Suite 411\nBrittanyfurt, OR 99825',
#   'mail': 'gardnerjason@yahoo.com',
#   'jobs': ['Forest/woodland manager',
#    'Administrator, education',
#    'Nurse, adult',
#    'Multimedia programmer'],
#   'id': 209747},
#  {'username': 'tamara08',
#   'name': 'Kelly Atkins',
#   'sex': 'F',
#   'address': '3641 Justin Estates Suite 613\nWest Rubenland, OH 42410',
#   'mail': 'pmartinez@hotmail.com',
#   'jobs': ['Civil Service fast streamer',
#    'Psychologist, prison and probation services',
#    'Armed forces training and education officer',
#    'Glass blower/designer',
#    'Pharmacist, hospital'],
#   'id': 37636},
#  {'username': 'richardsstephen',
#   'name': 'Jordan Pittman',
#   'sex': 'M',
#   'address': '268 Richard Club\nNew Jasonland, MA 43402',
#   'mail': 'kochmichael@hotmail.com',
#   'jobs': ['Holiday representative',
#    'Warehouse manager',
#    'Psychologist, counselling',
#    'Pensions consultant'],
#   'id': 13483},
#  {'username': 'davidreynolds',
#   'name': 'Jerry Salazar',
#   'sex': 'M',
#   'address': '627 Mason Mill Apt. 896\nDonaldtown, LA 85040',
#   'mail': 'skane@yahoo.com',
#   'jobs': ['Trade mark attorney',
#    'Psychotherapist, child',
#    'Engineer, energy',
#    'Bonds trader',
#    'Journalist, broadcasting'],
#   'id': 21752},
#  {'username': 'nburnett',
#   'name': 'Heather Larson',
#   'sex': 'F',
#   'address': '236 Hernandez Vista\nAnthonyberg, MI 51576',
#   'mail': 'robert58@hotmail.com',
#   'jobs': ['Advice worker', 'Geologist, wellsite', 'Toxicologist'],
#   'id': 29291},
#  {'username': 'kimberly63',
#   'name': 'Adam Atkinson',
#   'sex': 'M',
#   'address': '27804 David Pine\nDeannashire, OH 45920',
#   'mail': 'perrylaura@hotmail.com',
#   'jobs': ['Media buyer',
#    'Engineer, civil (consulting)',
#    'Corporate treasurer'],
#   'id': 424680},
#  {'username': 'lindsey03',
#   'name': 'William Bennett',
#   'sex': 'M',
#   'address': '7707 Miller Locks Suite 144\nGlennchester, GA 21253',
#   'mail': 'keith76@yahoo.com',
#   'jobs': ['Nature conservation officer',
#    'Neurosurgeon',
#    'Special effects artist',
#    'Professor Emeritus',
#    'Rural practice surveyor'],
#   'id': 166642},
#  {'username': 'patrick77',
#   'name': 'John Bender',
#   'sex': 'M',
#   'address': '158 Oconnell Hollow\nJasonville, CA 51906',
#   'mail': 'donna95@yahoo.com',
#   'jobs': ['Education administrator', 'Arboriculturist', 'Facilities manager'],
#   'id': 29782},
#  {'username': 'christine79',
#   'name': 'Kenneth Love',
#   'sex': 'M',
#   'address': 'Unit 4345 Box 3747\nDPO AP 52811',
#   'mail': 'carrmichael@yahoo.com',
#   'jobs': ['Water engineer', 'Cabin crew', 'Radiographer, diagnostic'],
#   'id': 891449},
#  {'username': 'beanangela',
#   'name': 'Anthony Wilson',
#   'sex': 'M',
#   'address': '9677 Franco Camp\nEast Matthewport, KS 01648',
#   'mail': 'myoung@hotmail.com',
#   'jobs': ['Chief Operating Officer',
#    'Chemist, analytical',
#    'Engineer, civil (consulting)',
#    'Product/process development scientist',
#    'Osteopath'],
#   'id': 167849},
#  {'username': 'johnsonashley',
#   'name': 'Denise Dixon',
#   'sex': 'F',
#   'address': '115 Brady Port Apt. 682\nSandyside, VT 54365',
#   'mail': 'williamsmichelle@yahoo.com',
#   'jobs': ['Insurance claims handler',
#    'Quality manager',
#    'Designer, exhibition/display',
#    'Sub',
#    'Records manager'],
#   'id': 1926889},
#  {'username': 'alexander89',
#   'name': 'Kaitlin Lopez',
#   'sex': 'F',
#   'address': '3885 Derek River Suite 436\nNew Debraville, TX 56047',
#   'mail': 'angela69@yahoo.com',
#   'jobs': ['Market researcher',
#    'Colour technologist',
#    'Emergency planning/management officer'],
#   'id': 47892},
#  {'username': 'vincent02',
#   'name': 'Rebecca Casey',
#   'sex': 'F',
#   'address': '92862 Zachary Forge Apt. 896\nEricksonmouth, VA 70050',
#   'mail': 'riosrichard@hotmail.com',
#   'jobs': ['Lexicographer', 'Hospital doctor', 'Water quality scientist'],
#   'id': 47549},
#  {'username': 'lopezantonio',
#   'name': 'Adam Watson',
#   'sex': 'M',
#   'address': '90456 Justin Wells Apt. 266\nStacyberg, FL 37938',
#   'mail': 'lauren19@hotmail.com',
#   'jobs': ['Engineer, water',
#    'Jewellery designer',
#    'Surveyor, insurance',
#    'Environmental manager'],
#   'id': 454149},
#  {'username': 'powersemily',
#   'name': 'Stacy Wood',
#   'sex': 'F',
#   'address': '6862 Eric Shoal Apt. 336\nNew Sheila, IL 41723',
#   'mail': 'tmiller@yahoo.com',
#   'jobs': ['Maintenance engineer',
#    'Charity fundraiser',
#    "Nurse, children's",
#    'Astronomer'],
#   'id': 1299206},
#  {'username': 'joseconley',
#   'name': 'Brooke Higgins',
#   'sex': 'F',
#   'address': '71018 Henson Mews\nGregoryhaven, ME 68359',
#   'mail': 'cummingsjared@gmail.com',
#   'jobs': ['Archaeologist',
#    'Journalist, newspaper',
#    'Accountant, chartered',
#    'Computer games developer'],
#   'id': 498271},
#  {'username': 'leslie69',
#   'name': 'Olivia Johnson',
#   'sex': 'F',
#   'address': '6878 James Tunnel Apt. 770\nWest Keith, IL 97125',
#   'mail': 'jamie80@yahoo.com',
#   'jobs': ['Drilling engineer',
#    'Scientist, research (physical sciences)',
#    'Environmental manager',
#    'Librarian, academic',
#    'Biomedical engineer'],
#   'id': 37449},
#  {'username': 'james03',
#   'name': 'Alison Smith',
#   'sex': 'F',
#   'address': '87793 Livingston Estate Apt. 513\nNew Rachel, NY 40946',
#   'mail': 'kerri43@gmail.com',
#   'jobs': ['Psychologist, prison and probation services',
#    'Haematologist',
#    'Presenter, broadcasting'],
#   'id': 1375473},
#  {'username': 'calhounchristopher',
#   'name': 'Juan Miller',
#   'sex': 'M',
#   'address': '044 Johnny Track Apt. 543\nKathrynview, ID 67020',
#   'mail': 'alexanderdouglas@yahoo.com',
#   'jobs': ['Lexicographer',
#    'Surveyor, commercial/residential',
#    'Engineer, electronics'],
#   'id': 2247203},
#  {'username': 'wgray',
#   'name': 'Patrick Johnson',
#   'sex': 'M',
#   'address': 'Unit 0962 Box 0438\nDPO AA 87836',
#   'mail': 'uchavez@gmail.com',
#   'jobs': ['Maintenance engineer',
#    'Surveyor, land/geomatics',
#    'Accountant, chartered management'],
#   'id': 94189},
#  {'username': 'laura87',
#   'name': 'Justin Barron',
#   'sex': 'M',
#   'address': '6288 Franklin Villages Suite 093\nNorth Elizabeth, VA 76953',
#   'mail': 'renee68@hotmail.com',
#   'jobs': ['Broadcast engineer',
#    'Engineer, building services',
#    'Patent examiner',
#    'Media planner'],
#   'id': 279496},
#  {'username': 'bethany97',
#   'name': 'David Kirk',
#   'sex': 'M',
#   'address': '722 Jennifer Estates Suite 046\nPort Kennethfurt, GA 36698',
#   'mail': 'vgonzalez@hotmail.com',
#   'jobs': ['Ecologist',
#    'Astronomer',
#    'Chief Operating Officer',
#    'Geographical information systems officer',
#    'Paramedic'],
#   'id': 57042},
#  {'username': 'tyroneglass',
#   'name': 'Sydney Cisneros',
#   'sex': 'F',
#   'address': '1276 Katie Stream Suite 648\nDouglasburgh, HI 24784',
#   'mail': 'toddgarcia@hotmail.com',
#   'jobs': ['Designer, television/film set',
#    'Public librarian',
#    'Petroleum engineer',
#    'Cabin crew',
#    'Sales professional, IT'],
#   'id': 205983},
#  {'username': 'blanchardjackie',
#   'name': 'Blake Fletcher',
#   'sex': 'M',
#   'address': '7744 Ray Way Apt. 856\nNew Ray, SD 70899',
#   'mail': 'clarkkrista@hotmail.com',
#   'jobs': ['Clinical molecular geneticist',
#    'Commercial art gallery manager',
#    'Scientist, research (physical sciences)'],
#   'id': 379836},
#  {'username': 'annmoore',
#   'name': 'Richard Brown',
#   'sex': 'M',
#   'address': '5793 Hart Unions\nWest Tonyville, WA 85226',
#   'mail': 'briankennedy@yahoo.com',
#   'jobs': ['Energy engineer',
#    'Television/film/video producer',
#    'Dispensing optician',
#    'Buyer, industrial',
#    'Energy manager'],
#   'id': 210965},
#  {'username': 'wwinters',
#   'name': 'Crystal Blair',
#   'sex': 'F',
#   'address': '1434 Matthew Locks\nKeithmouth, IL 03520',
#   'mail': 'flopez@gmail.com',
#   'jobs': ['Publishing copy', 'Ecologist', 'Structural engineer'],
#   'id': 126687},
#  {'username': 'richard91',
#   'name': 'Kenneth Wright',
#   'sex': 'M',
#   'address': '22129 Donna Coves\nLake Douglasside, NJ 54596',
#   'mail': 'ronald61@gmail.com',
#   'jobs': ['Chief Strategy Officer',
#    'Building control surveyor',
#    'Product designer'],
#   'id': 63855},
#  {'username': 'christina73',
#   'name': 'Karina Miller',
#   'sex': 'F',
#   'address': 'USCGC Stanley\nFPO AP 62480',
#   'mail': 'anthony91@yahoo.com',
#   'jobs': ['Archaeologist',
#    'Analytical chemist',
#    'Surveyor, planning and development',
#    'Architect'],
#   'id': 189030},
#  {'username': 'zmartin',
#   'name': 'Kyle Harrison',
#   'sex': 'M',
#   'address': '35728 George Harbors\nPalmerhaven, NY 19496',
#   'mail': 'kfoster@gmail.com',
#   'jobs': ['Social researcher', 'Dietitian', 'Engineer, chemical'],
#   'id': 524879},
#  {'username': 'richard14',
#   'name': 'Carla Miller',
#   'sex': 'F',
#   'address': '0975 Patton Points Suite 520\nGutierrezburgh, MI 89035',
#   'mail': 'jermaine23@yahoo.com',
#   'jobs': ['Transport planner',
#    'Radiographer, diagnostic',
#    'Therapist, sports',
#    'Facilities manager'],
#   'id': 470110},
#  {'username': 'amy62',
#   'name': 'Nicole Smith',
#   'sex': 'F',
#   'address': '798 Torres Circles\nComptonmouth, AL 88224',
#   'mail': 'fcharles@hotmail.com',
#   'jobs': ['Scientist, audiological',
#    'Learning mentor',
#    'Air broker',
#    'Oceanographer'],
#   'id': 131674},
#  {'username': 'sstrickland',
#   'name': 'Sandra Clark',
#   'sex': 'F',
#   'address': '909 William Springs Apt. 438\nRhondaport, WY 17145',
#   'mail': 'chavezrobert@yahoo.com',
#   'jobs': ['Psychotherapist, dance movement',
#    'Physicist, medical',
#    'Equities trader',
#    'Radiation protection practitioner'],
#   'id': 303454},
#  {'username': 'icervantes',
#   'name': 'Deborah Conrad',
#   'sex': 'F',
#   'address': '75565 Parrish Skyway Apt. 904\nMurphyhaven, OR 23100',
#   'mail': 'maldonadocourtney@yahoo.com',
#   'jobs': ['Dance movement psychotherapist',
#    'Theatre manager',
#    'Electrical engineer',
#    'Site engineer'],
#   'id': 1618462},
#  {'username': 'ydavis',
#   'name': 'Judith Richardson',
#   'sex': 'F',
#   'address': '027 Pamela Parkway Suite 059\nWhiteton, WV 30405',
#   'mail': 'turnerkathryn@hotmail.com',
#   'jobs': ['Phytotherapist',
#    'Occupational psychologist',
#    'Librarian, academic',
#    'Physicist, medical',
#    'Merchandiser, retail'],
#   'id': 789314},
#  {'username': 'luceroashley',
#   'name': 'Molly Mooney',
#   'sex': 'F',
#   'address': '6371 Robert Corners\nEast Michaelland, ND 55885',
#   'mail': 'lharrington@gmail.com',
#   'jobs': ['Planning and development surveyor',
#    'Environmental education officer',
#    'Arts development officer',
#    'Surveyor, land/geomatics'],
#   'id': 205783},
#  {'username': 'mariaporter',
#   'name': 'Michael Johnson',
#   'sex': 'M',
#   'address': '65191 Sarah Islands Apt. 215\nLisaborough, VA 81648',
#   'mail': 'davidshah@yahoo.com',
#   'jobs': ['Horticultural therapist',
#    'Recruitment consultant',
#    'Financial planner',
#    'Energy manager',
#    'Editor, magazine features'],
#   'id': 63098},
#  {'username': 'kristen66',
#   'name': 'Christy Jones DDS',
#   'sex': 'F',
#   'address': '9705 Christopher Crossing\nNew Matthewland, ND 15813',
#   'mail': 'carlareed@yahoo.com',
#   'jobs': ['Nature conservation officer',
#    'Scientist, forensic',
#    'Geologist, engineering'],
#   'id': 193516},
#  {'username': 'nunezjeffrey',
#   'name': 'Albert Richards',
#   'sex': 'M',
#   'address': '056 Davis Ways Apt. 530\nNicolebury, OK 84769',
#   'mail': 'ncox@gmail.com',
#   'jobs': ['Architect',
#    'IT sales professional',
#    'Psychologist, educational',
#    'Risk analyst'],
#   'id': 107135},
#  {'username': 'rwilliams',
#   'name': 'Alexandria Myers',
#   'sex': 'F',
#   'address': 'USNS Hanson\nFPO AE 27071',
#   'mail': 'thomasmary@yahoo.com',
#   'jobs': ['Scientist, research (life sciences)',
#    'Designer, exhibition/display',
#    'Technical sales engineer'],
#   'id': 613457},
#  {'username': 'hmata',
#   'name': 'Crystal Parks',
#   'sex': 'F',
#   'address': '947 Michael Heights\nBrowntown, WI 08542',
#   'mail': 'ronald80@yahoo.com',
#   'jobs': ['Haematologist',
#    'Insurance claims handler',
#    'Restaurant manager',
#    'Publishing copy',
#    'Network engineer'],
#   'id': 69474},
#  {'username': 'davidsondouglas',
#   'name': 'Jennifer Hicks',
#   'sex': 'F',
#   'address': '101 Dominguez Overpass Apt. 644\nNew Linda, WY 27449',
#   'mail': 'stuartjackson@hotmail.com',
#   'jobs': ['Adult nurse',
#    'Animal nutritionist',
#    'English as a foreign language teacher',
#    'Product/process development scientist',
#    'Publishing copy'],
#   'id': 6357},
#  {'username': 'ocurry',
#   'name': 'Ashley Stout',
#   'sex': 'F',
#   'address': '706 John Mountains\nLake Jennifer, OK 37366',
#   'mail': 'peter52@hotmail.com',
#   'jobs': ['Manufacturing systems engineer',
#    'Orthoptist',
#    'Financial trader',
#    'Clinical cytogeneticist'],
#   'id': 528468},
#  {'username': 'orobles',
#   'name': 'Renee Bennett',
#   'sex': 'F',
#   'address': '5657 Green Corners\nTimothymouth, MO 39130',
#   'mail': 'hillelizabeth@yahoo.com',
#   'jobs': ['Nurse, learning disability',
#    'Chief of Staff',
#    'Financial planner'],
#   'id': 136726},
#  {'username': 'anna17',
#   'name': 'Colleen Scott',
#   'sex': 'F',
#   'address': '0510 Anderson Orchard\nNelsonstad, KY 92537',
#   'mail': 'james20@hotmail.com',
#   'jobs': ['Child psychotherapist', 'Seismic interpreter', 'Retail manager'],
#   'id': 37026},
#  {'username': 'waltonhannah',
#   'name': 'William Bernard',
#   'sex': 'M',
#   'address': 'PSC 2462, Box 5852\nAPO AA 43271',
#   'mail': 'millergail@yahoo.com',
#   'jobs': ['Logistics and distribution manager',
#    'Merchant navy officer',
#    'Microbiologist'],
#   'id': 77146},
#  {'username': 'jamesmckenzie',
#   'name': 'Howard Blankenship',
#   'sex': 'M',
#   'address': 'PSC 1853, Box 6104\nAPO AE 61953',
#   'mail': 'huntsarah@gmail.com',
#   'jobs': ['Professor Emeritus',
#    'Librarian, public',
#    'Learning mentor',
#    'Education officer, community'],
#   'id': 407338},
#  {'username': 'michael28',
#   'name': 'Dr. Charles Jones',
#   'sex': 'M',
#   'address': '03999 Mckinney Stream\nWilliamsland, VT 98324',
#   'mail': 'annachristian@gmail.com',
#   'jobs': ['Fitness centre manager',
#    'Gaffer',
#    'Theatre director',
#    'Music therapist',
#    'Aeronautical engineer'],
#   'id': 83093},
#  {'username': 'christina19',
#   'name': 'Melanie Hess',
#   'sex': 'F',
#   'address': '7650 Megan Forges Apt. 648\nElizabethton, NE 19614',
#   'mail': 'dturner@hotmail.com',
#   'jobs': ['Geologist, wellsite',
#    'Accountant, chartered',
#    'Customer service manager',
#    'Research officer, government'],
#   'id': 153866},
#  {'username': 'helenhall',
#   'name': 'Angela Baker',
#   'sex': 'F',
#   'address': '9489 Gregory Union\nJohnville, DE 39395',
#   'mail': 'nancy36@hotmail.com',
#   'jobs': ['Chemist, analytical',
#    'Television camera operator',
#    'Location manager',
#    'Administrator',
#    'Dealer'],
#   'id': 1562},
#  {'username': 'ryanphillips',
#   'name': 'Miguel Cuevas',
#   'sex': 'M',
#   'address': '471 Pittman Shoals\nPort Eric, NC 43612',
#   'mail': 'richardsseth@hotmail.com',
#   'jobs': ['Surveyor, building',
#    'Broadcast presenter',
#    'Patent attorney',
#    'Engineer, manufacturing',
#    'Nurse, mental health'],
#   'id': 188744},
#  {'username': 'harrissandra',
#   'name': 'Thomas Cisneros',
#   'sex': 'M',
#   'address': '08137 Robert Hollow\nHallfort, ND 02186',
#   'mail': 'amybrown@yahoo.com',
#   'jobs': ['Curator', 'Aid worker', 'Press sub'],
#   'id': 679759},
#  {'username': 'kimberlybrock',
#   'name': 'Tim Parker',
#   'sex': 'M',
#   'address': '40794 Hill Stream\nBryanberg, KS 12602',
#   'mail': 'cassandra35@yahoo.com',
#   'jobs': ['Conservation officer, historic buildings',
#    'Insurance account manager',
#    'Public relations officer'],
#   'id': 1003473},
#  {'username': 'trujilloashley',
#   'name': 'Charles Butler',
#   'sex': 'M',
#   'address': '515 Harrison Lake Apt. 800\nTammyside, NE 99899',
#   'mail': 'leewilliam@yahoo.com',
#   'jobs': ['Teaching laboratory technician',
#    'Air traffic controller',
#    'Designer, exhibition/display',
#    'Professor Emeritus'],
#   'id': 94996},
#  {'username': 'alexanderkelly',
#   'name': 'Lucas Lowe',
#   'sex': 'M',
#   'address': '23908 Angela Ways\nTiffanyview, NY 07087',
#   'mail': 'rebeccamcfarland@yahoo.com',
#   'jobs': ['Occupational hygienist', 'Surgeon', 'Civil engineer, consulting'],
#   'id': 97901},
#  {'username': 'privera',
#   'name': 'Stephanie Noble',
#   'sex': 'F',
#   'address': '6753 Bell Hill\nFlemingchester, MA 29669',
#   'mail': 'jacob65@yahoo.com',
#   'jobs': ['Insurance broker', 'Magazine journalist', 'Chartered accountant'],
#   'id': 516406},
#  {'username': 'nancy12',
#   'name': 'Jesus Thomas',
#   'sex': 'M',
#   'address': '200 Thomas Gateway Suite 323\nDebraland, MI 79080',
#   'mail': 'crichardson@gmail.com',
#   'jobs': ['Counsellor',
#    'Newspaper journalist',
#    'Engineer, site',
#    'Surveyor, rural practice',
#    'Occupational therapist'],
#   'id': 90628},
#  {'username': 'robertrichardson',
#   'name': 'Mary Cooper',
#   'sex': 'F',
#   'address': '75146 Nathan Plaza\nMichaelville, PA 55349',
#   'mail': 'samuel01@gmail.com',
#   'jobs': ['Educational psychologist',
#    'Retail buyer',
#    'Management consultant'],
#   'id': 288146},
#  {'username': 'teresaballard',
#   'name': 'Ronald Ortega',
#   'sex': 'M',
#   'address': '301 Amanda Square Apt. 088\nAnthonyton, MD 57214',
#   'mail': 'meganferguson@hotmail.com',
#   'jobs': ['Mining engineer',
#    'Sports development officer',
#    'Investment banker, corporate',
#    'Journalist, magazine'],
#   'id': 8688},
#  {'username': 'prattjoseph',
#   'name': 'Karen Smith',
#   'sex': 'F',
#   'address': '59347 Stacey Mountain Suite 888\nPort Richard, NM 55056',
#   'mail': 'michelleparker@gmail.com',
#   'jobs': ['Child psychotherapist',
#    'Graphic designer',
#    'Medical sales representative',
#    'Sports administrator'],
#   'id': 61388},
#  {'username': 'stokescheryl',
#   'name': 'Peter Wilson',
#   'sex': 'M',
#   'address': '77204 Salinas Mountain Apt. 045\nKeytown, IA 55371',
#   'mail': 'wendy82@gmail.com',
#   'jobs': ['Engineer, broadcasting (operations)',
#    'Stage manager',
#    'Broadcast journalist',
#    'Development worker, community',
#    'Rural practice surveyor'],
#   'id': 235468},
#  {'username': 'richardwhite',
#   'name': 'Charles Martin',
#   'sex': 'M',
#   'address': '021 Nichole Forge\nSusanstad, CT 70685',
#   'mail': 'hcamacho@hotmail.com',
#   'jobs': ['Cabin crew',
#    'Surveyor, hydrographic',
#    'Customer service manager',
#    'Estate agent'],
#   'id': 898589},
#  {'username': 'mistyzavala',
#   'name': 'Mary Flynn',
#   'sex': 'F',
#   'address': '85359 Taylor Square Apt. 022\nEast Kenneth, HI 15693',
#   'mail': 'kristenreyes@hotmail.com',
#   'jobs': ['Scientist, physiological',
#    'Event organiser',
#    'Public relations officer',
#    'Housing manager/officer'],
#   'id': 4439},
#  {'username': 'marissa26',
#   'name': 'Lisa Lopez',
#   'sex': 'F',
#   'address': '3290 Johnson Island Apt. 180\nEast Suzanneton, OR 42494',
#   'mail': 'kmccullough@hotmail.com',
#   'jobs': ['Sports development officer',
#    'Lawyer',
#    'Chief Operating Officer',
#    'Systems developer',
#    'Dance movement psychotherapist'],
#   'id': 482933},
#  {'username': 'xzamora',
#   'name': 'Henry Alvarez',
#   'sex': 'M',
#   'address': '9866 Henry Mill Apt. 882\nNorth Jonathon, AZ 19201',
#   'mail': 'shanerobinson@yahoo.com',
#   'jobs': ['Engineer, aeronautical',
#    'Exhibition designer',
#    'Brewing technologist'],
#   'id': 10649},
#  {'username': 'jessecowan',
#   'name': 'Margaret Turner',
#   'sex': 'F',
#   'address': '5140 Smith Mountains\nWest Glennstad, WV 56346',
#   'mail': 'johnathansavage@gmail.com',
#   'jobs': ['Television production assistant',
#    'Embryologist, clinical',
#    'Trading standards officer'],
#   'id': 813515},
#  {'username': 'michaelriddle',
#   'name': 'Chloe Wagner',
#   'sex': 'F',
#   'address': '297 Melissa Way\nBlakeshire, TN 16412',
#   'mail': 'maurice76@hotmail.com',
#   'jobs': ['Actuary',
#    'Restaurant manager, fast food',
#    'Market researcher',
#    'Quality manager'],
#   'id': 37779},
#  {'username': 'cassandra63',
#   'name': 'Christopher Byrd',
#   'sex': 'M',
#   'address': '74243 Harris Rue Apt. 569\nRamirezfort, IA 44390',
#   'mail': 'allisonsanchez@gmail.com',
#   'jobs': ['International aid/development worker',
#    "Politician's assistant",
#    'Environmental consultant'],
#   'id': 461834},
#  {'username': 'andrew58',
#   'name': 'Jesse Ortiz',
#   'sex': 'M',
#   'address': '64119 Matthew Pines\nShanefort, NY 31686',
#   'mail': 'andrea91@gmail.com',
#   'jobs': ['Sports therapist',
#    'Engineer, energy',
#    'Biochemist, clinical',
#    'Microbiologist'],
#   'id': 121686},
#  {'username': 'zflores',
#   'name': 'Jessica Watson',
#   'sex': 'F',
#   'address': 'PSC 9514, Box 2974\nAPO AE 57694',
#   'mail': 'mnelson@yahoo.com',
#   'jobs': ['Newspaper journalist', 'Biomedical engineer', 'Sports coach'],
#   'id': 262200},
#  {'username': 'karenhuang',
#   'name': 'Patrick Hawkins',
#   'sex': 'M',
#   'address': '55740 Gutierrez Plains Suite 123\nNew Jeffreyhaven, WA 78759',
#   'mail': 'zsimpson@hotmail.com',
#   'jobs': ['Airline pilot',
#    'Engineer, structural',
#    'Health and safety inspector',
#    'Cytogeneticist'],
#   'id': 20754},
#  {'username': 'johnnystrickland',
#   'name': 'Robert Robinson',
#   'sex': 'M',
#   'address': 'Unit 4104 Box 6047\nDPO AE 77206',
#   'mail': 'renee82@hotmail.com',
#   'jobs': ['Furniture designer',
#    'Paediatric nurse',
#    'Osteopath',
#    'Engineer, civil (consulting)',
#    'Journalist, magazine'],
#   'id': 575052},
#  {'username': 'edward61',
#   'name': 'Jennifer Stewart',
#   'sex': 'F',
#   'address': '73943 Anthony Park Suite 424\nNguyenport, VA 30960',
#   'mail': 'earellano@gmail.com',
#   'jobs': ['Sports therapist', 'Tax inspector', 'Scientist, forensic'],
#   'id': 882465},
#  {'username': 'stacey31',
#   'name': 'Anthony Ramirez',
#   'sex': 'M',
#   'address': '320 Raymond Shoal Suite 059\nHollowayhaven, KY 52769',
#   'mail': 'stephen22@hotmail.com',
#   'jobs': ['Bookseller',
#    'English as a foreign language teacher',
#    'Set designer',
#    'Counsellor',
#    'Meteorologist'],
#   'id': 39547},
#  {'username': 'millervincent',
#   'name': 'Jonathan Callahan',
#   'sex': 'M',
#   'address': '90193 Barnes Cliffs\nFranklinside, GA 25602',
#   'mail': 'andrew10@gmail.com',
#   'jobs': ['Community development worker',
#    'Television camera operator',
#    'Control and instrumentation engineer'],
#   'id': 964093},
#  {'username': 'christine57',
#   'name': 'Angel Williams',
#   'sex': 'F',
#   'address': '581 Garcia Roads Apt. 477\nSouth Holly, RI 91473',
#   'mail': 'marylozano@gmail.com',
#   'jobs': ['Producer, television/film/video',
#    'Broadcast engineer',
#    'Charity officer',
#    'Haematologist',
#    'Historic buildings inspector/conservation officer'],
#   'id': 630984},
#  {'username': 'wdavis',
#   'name': 'April Howard',
#   'sex': 'F',
#   'address': '19892 Tran Course Apt. 775\nLake Karenstad, AK 69688',
#   'mail': 'keithamanda@hotmail.com',
#   'jobs': ['Lighting technician, broadcasting/film/video',
#    'Surveyor, planning and development',
#    'Teaching laboratory technician'],
#   'id': 50509},
#  {'username': 'smithkatherine',
#   'name': 'Alexander Smith',
#   'sex': 'M',
#   'address': '6060 Barry Dale\nChristopherside, OH 92094',
#   'mail': 'laura62@yahoo.com',
#   'jobs': ['Careers adviser',
#    'Careers adviser',
#    'Product manager',
#    'Research scientist (life sciences)',
#    'Designer, multimedia'],
#   'id': 672534},
#  {'username': 'abrown',
#   'name': 'Kimberly Simmons',
#   'sex': 'F',
#   'address': '16634 David Freeway Suite 821\nPort Edward, DE 92982',
#   'mail': 'brandon84@gmail.com',
#   'jobs': ['Licensed conveyancer', 'Archivist', 'Ship broker'],
#   'id': 214991},
#  {'username': 'edwin87',
#   'name': 'Anthony Thompson',
#   'sex': 'M',
#   'address': '8165 Martinez Lodge\nWest Anthonyburgh, TN 18279',
#   'mail': 'mgarcia@gmail.com',
#   'jobs': ['Copywriter, advertising',
#    'Surveyor, commercial/residential',
#    'Hydrogeologist'],
#   'id': 1360982},
#  {'username': 'robert24',
#   'name': 'David Kelley',
#   'sex': 'M',
#   'address': '262 Michelle Streets Apt. 670\nChristinestad, OH 72142',
#   'mail': 'tdoyle@gmail.com',
#   'jobs': ['Risk analyst', 'Hydrographic surveyor', 'Financial controller'],
#   'id': 278639},
#  {'username': 'rhodesmary',
#   'name': 'Jacob Harvey',
#   'sex': 'M',
#   'address': 'PSC 8379, Box 6667\nAPO AA 18327',
#   'mail': 'whiteheadsherry@gmail.com',
#   'jobs': ['Fashion designer',
#    'Cartographer',
#    'Scientist, water quality',
#    'Graphic designer'],
#   'id': 537937},
#  {'username': 'andradecourtney',
#   'name': 'Scott Alvarado',
#   'sex': 'M',
#   'address': '60827 Michael Parkways Suite 266\nBrandonstad, NM 88527',
#   'mail': 'natalietaylor@yahoo.com',
#   'jobs': ['Furniture conservator/restorer',
#    'Public relations account executive',
#    'Research officer, trade union'],
#   'id': 461283},
#  {'username': 'wellsjesse',
#   'name': 'Jamie Tran',
#   'sex': 'F',
#   'address': '3032 Johnson Points\nChristinamouth, NE 78248',
#   'mail': 'johnsonderrick@yahoo.com',
#   'jobs': ['Surveyor, hydrographic',
#    'Museum/gallery curator',
#    'Manufacturing systems engineer',
#    'Print production planner'],
#   'id': 811431},
#  {'username': 'gilljohn',
#   'name': 'Sara Hickman',
#   'sex': 'F',
#   'address': '706 Parker Locks\nLongborough, NE 06076',
#   'mail': 'jacobcrawford@hotmail.com',
#   'jobs': ['Public relations account executive',
#    'Musician',
#    'Insurance account manager'],
#   'id': 932620},
#  {'username': 'tramsey',
#   'name': 'Candace Wong',
#   'sex': 'F',
#   'address': '8207 Hunt Fall\nPort Gregory, TN 78905',
#   'mail': 'hodgecrystal@gmail.com',
#   'jobs': ['Child psychotherapist',
#    'Education officer, museum',
#    'Psychologist, prison and probation services',
#    'Commercial art gallery manager'],
#   'id': 10113},
#  {'username': 'rstanley',
#   'name': 'Sandra Hill',
#   'sex': 'F',
#   'address': '6652 Roy Way Suite 642\nEast Sheilaville, OR 50681',
#   'mail': 'jeremy89@gmail.com',
#   'jobs': ['Energy manager',
#    'Building control surveyor',
#    'Games developer',
#    'IT trainer',
#    'Rural practice surveyor'],
#   'id': 428885},
#  {'username': 'ievans',
#   'name': 'Ethan Morales',
#   'sex': 'M',
#   'address': '9300 Phillips Way Apt. 948\nNew Aliceburgh, GA 70575',
#   'mail': 'markmarks@yahoo.com',
#   'jobs': ['Counselling psychologist',
#    'Surveyor, commercial/residential',
#    'Event organiser',
#    'Logistics and distribution manager',
#    'Museum/gallery conservator'],
#   'id': 1329782},
#  {'username': 'rickyvaughn',
#   'name': 'Nicole Johnston',
#   'sex': 'F',
#   'address': '137 Cisneros Path Apt. 601\nChaneyland, NJ 95831',
#   'mail': 'whunter@hotmail.com',
#   'jobs': ['Environmental manager',
#    'Marketing executive',
#    'Production designer, theatre/television/film',
#    'Translator'],
#   'id': 80353},
#  {'username': 'bakerlisa',
#   'name': 'Walter Wallace',
#   'sex': 'M',
#   'address': '3319 Craig Bridge\nWest Courtney, ME 20802',
#   'mail': 'allisonheather@hotmail.com',
#   'jobs': ['Chief Financial Officer',
#    'Claims inspector/assessor',
#    'Radio broadcast assistant'],
#   'id': 1891},
#  {'username': 'walkerpaul',
#   'name': 'Matthew Hinton',
#   'sex': 'M',
#   'address': '562 Carter Road Apt. 110\nWest Michaelview, KY 87911',
#   'mail': 'amygraham@yahoo.com',
#   'jobs': ['Insurance risk surveyor',
#    'Seismic interpreter',
#    'Secretary/administrator',
#    'Magazine journalist'],
#   'id': 242729},
#  {'username': 'amorales',
#   'name': 'Matthew Shepherd',
#   'sex': 'M',
#   'address': '928 Kimberly Rapids\nWilliamstad, ME 98726',
#   'mail': 'scottbrown@gmail.com',
#   'jobs': ['Curator',
#    'Government social research officer',
#    'Special educational needs teacher',
#    'Horticultural consultant',
#    'Biochemist, clinical'],
#   'id': 2549237},
#  {'username': 'harrismegan',
#   'name': 'Teresa Torres',
#   'sex': 'F',
#   'address': '4083 Smith Gateway Suite 857\nNorth Michaelville, FL 47530',
#   'mail': 'devonlloyd@hotmail.com',
#   'jobs': ['Copywriter, advertising',
#    'Scientist, audiological',
#    'Administrator, arts',
#    'Legal secretary'],
#   'id': 262129},
#  {'username': 'edwardsaustin',
#   'name': 'Gregory Huffman',
#   'sex': 'M',
#   'address': '54989 Madeline Mill Suite 534\nNorth Rebecca, MO 71519',
#   'mail': 'andrewrowland@gmail.com',
#   'jobs': ['Aid worker',
#    'Chemist, analytical',
#    'Corporate treasurer',
#    'Charity officer',
#    'Ship broker'],
#   'id': 567959},
#  {'username': 'nicholas86',
#   'name': 'Amber Jacobs',
#   'sex': 'F',
#   'address': '147 Little Spur\nJordanfurt, UT 51171',
#   'mail': 'brucethomas@yahoo.com',
#   'jobs': ['Occupational psychologist',
#    'Legal executive',
#    'Therapist, drama',
#    'Insurance risk surveyor',
#    'Investment banker, operational'],
#   'id': 47858},
#  {'username': 'ortizsteven',
#   'name': 'Brittney Lee',
#   'sex': 'F',
#   'address': '05048 Young Key Apt. 245\nWest Heidimouth, AK 81874',
#   'mail': 'tgarcia@yahoo.com',
#   'jobs': ['Advertising account planner',
#    'Nurse, mental health',
#    'Higher education careers adviser',
#    'Marketing executive'],
#   'id': 465056},
#  {'username': 'miguelwolf',
#   'name': 'Sharon Walsh',
#   'sex': 'F',
#   'address': '559 Jeremiah Mills Apt. 488\nKnighttown, NM 07761',
#   'mail': 'vanessa10@hotmail.com',
#   'jobs': ['Scientist, product/process development',
#    'Housing manager/officer',
#    'Audiological scientist',
#    'Government social research officer'],
#   'id': 144205},
#  {'username': 'penningtonalicia',
#   'name': 'Vicki Short',
#   'sex': 'F',
#   'address': '05267 Miles Mall Apt. 769\nVictoriamouth, DC 17554',
#   'mail': 'timothy26@hotmail.com',
#   'jobs': ['Risk analyst',
#    'Diagnostic radiographer',
#    'Scientific laboratory technician',
#    'Psychotherapist, dance movement',
#    'Teacher, special educational needs'],
#   'id': 213139},
#  {'username': 'douglas33',
#   'name': 'Theresa Wilson',
#   'sex': 'F',
#   'address': 'PSC 7664, Box 1154\nAPO AA 24551',
#   'mail': 'salazarwilliam@yahoo.com',
#   'jobs': ['Clinical psychologist',
#    'Engineer, petroleum',
#    'Lexicographer',
#    'Psychologist, counselling',
#    'Accountant, chartered'],
#   'id': 177443},
#  {'username': 'cmolina',
#   'name': 'Travis Wallace',
#   'sex': 'M',
#   'address': '6205 Brandy Unions Apt. 432\nMichaelberg, NJ 91136',
#   'mail': 'reginarobinson@gmail.com',
#   'jobs': ['Proofreader',
#    'Clinical scientist, histocompatibility and immunogenetics',
#    'Network engineer'],
#   'id': 2200921},
#  {'username': 'huntterri',
#   'name': 'Austin Ward',
#   'sex': 'M',
#   'address': '53485 Robert Parks\nWademouth, WI 12513',
#   'mail': 'jdavis@hotmail.com',
#   'jobs': ['Psychotherapist',
#    'Horticultural therapist',
#    'Animal technologist',
#    'Psychotherapist',
#    'Insurance risk surveyor'],
#   'id': 437294},
#  {'username': 'toconnor',
#   'name': 'Travis Martin',
#   'sex': 'M',
#   'address': '096 Murphy Locks Apt. 192\nNorth Louis, VA 55432',
#   'mail': 'hunterjacob@gmail.com',
#   'jobs': ['Company secretary',
#    'Retail banker',
#    'Animal nutritionist',
#    'Senior tax professional/tax inspector',
#    'Producer, radio'],
#   'id': 143318},
#  {'username': 'tanderson',
#   'name': 'Sarah Stevenson',
#   'sex': 'F',
#   'address': '8790 Powell Mission\nDeniseburgh, CO 82821',
#   'mail': 'sheltonstacey@hotmail.com',
#   'jobs': ['Retail merchandiser',
#    'Psychiatric nurse',
#    'Learning disability nurse',
#    'Designer, graphic',
#    'Tourism officer'],
#   'id': 116740},
#  {'username': 'sawyerjames',
#   'name': 'Kendra Cook',
#   'sex': 'F',
#   'address': '4652 Rodriguez Courts\nSouth Robert, OK 57460',
#   'mail': 'uanderson@yahoo.com',
#   'jobs': ['Scientist, physiological',
#    "Barrister's clerk",
#    'Education officer, museum'],
#   'id': 323731},
#  {'username': 'hensleybrittney',
#   'name': 'Robin Lambert',
#   'sex': 'F',
#   'address': '21418 Wallace Inlet Suite 018\nPort Calvinland, OH 99864',
#   'mail': 'fwoods@hotmail.com',
#   'jobs': ['Research officer, political party',
#    'Heritage manager',
#    'Engineer, manufacturing'],
#   'id': 804550},
#  {'username': 'beankatelyn',
#   'name': 'Anne Miller',
#   'sex': 'F',
#   'address': '412 Reid Lakes\nPort Jerome, ME 55491',
#   'mail': 'clarkkirsten@yahoo.com',
#   'jobs': ['Conservation officer, historic buildings',
#    'Consulting civil engineer',
#    'Conservator, furniture',
#    'Software engineer',
#    'Nurse, adult'],
#   'id': 125356},
#  {'username': 'barbaramacias',
#   'name': 'Julia Flores',
#   'sex': 'F',
#   'address': 'PSC 7729, Box 9222\nAPO AE 75822',
#   'mail': 'jimmygeorge@yahoo.com',
#   'jobs': ['Dietitian',
#    'Outdoor activities/education manager',
#    'Clothing/textile technologist',
#    'Industrial buyer'],
#   'id': 865936},
#  {'username': 'qwade',
#   'name': 'Caitlin Benton',
#   'sex': 'F',
#   'address': '355 William Underpass\nNew Crystalview, WA 80512',
#   'mail': 'lauren72@yahoo.com',
#   'jobs': ['Location manager',
#    'Newspaper journalist',
#    'Surveyor, rural practice',
#    'Outdoor activities/education manager'],
#   'id': 440869},
#  {'username': 'raymond30',
#   'name': 'Lynn Diaz MD',
#   'sex': 'F',
#   'address': '62592 Todd Groves Apt. 433\nWest Grace, NJ 78278',
#   'mail': 'awilliams@yahoo.com',
#   'jobs': ['Exhibition designer',
#    'Fashion designer',
#    'Health physicist',
#    'Proofreader',
#    'Programmer, multimedia'],
#   'id': 464080},
#  {'username': 'btownsend',
#   'name': 'Robert Mcconnell',
#   'sex': 'M',
#   'address': '1397 Perez Corner\nNew Brandishire, AZ 28855',
#   'mail': 'cwilkerson@hotmail.com',
#   'jobs': ['Producer, radio',
#    'Secondary school teacher',
#    'Operations geologist'],
#   'id': 52282},
#  {'username': 'dmoore',
#   'name': 'Diana Martin',
#   'sex': 'F',
#   'address': '67428 Timothy Path\nPort Mary, MN 59354',
#   'mail': 'kyle80@hotmail.com',
#   'jobs': ['Scientist, research (medical)',
#    'Conservator, museum/gallery',
#    'Occupational hygienist'],
#   'id': 335718},
#  {'username': 'kelsey73',
#   'name': 'Robert Brown',
#   'sex': 'M',
#   'address': '069 Rivera Mall Suite 975\nCopelandfurt, CT 71574',
#   'mail': 'rcook@yahoo.com',
#   'jobs': ['Health service manager',
#    'Garment/textile technologist',
#    'Engineer, biomedical',
#    'Agricultural engineer',
#    'Soil scientist'],
#   'id': 311003},
#  {'username': 'shawnrobinson',
#   'name': 'Jennifer Myers',
#   'sex': 'F',
#   'address': '4169 Anna Fall Apt. 611\nPhillipsmouth, AK 32472',
#   'mail': 'brittany57@yahoo.com',
#   'jobs': ['Merchandiser, retail', 'Clinical cytogeneticist', 'Advice worker'],
#   'id': 542159},
#  {'username': 'angelasmith',
#   'name': 'Lisa Yoder',
#   'sex': 'F',
#   'address': '938 Amber Tunnel Suite 546\nAngelachester, TX 20390',
#   'mail': 'charris@yahoo.com',
#   'jobs': ['Engineer, electronics',
#    'Secondary school teacher',
#    'Transport planner',
#    'Secretary, company',
#    'Maintenance engineer'],
#   'id': 730126},
#  {'username': 'wilsonjonathan',
#   'name': 'Christopher Anderson',
#   'sex': 'M',
#   'address': '62887 White Ferry\nJordanstad, MN 65726',
#   'mail': 'hallkeith@hotmail.com',
#   'jobs': ['Scientific laboratory technician',
#    'Agricultural engineer',
#    'Advice worker',
#    'Geologist, wellsite',
#    'Wellsite geologist'],
#   'id': 124614},
#  {'username': 'pbaird',
#   'name': 'Kevin Schwartz',
#   'sex': 'M',
#   'address': '5423 Johnson Squares Apt. 927\nNicoletown, ME 73397',
#   'mail': 'carolyn77@gmail.com',
#   'jobs': ['Conference centre manager',
#    'Nutritional therapist',
#    'Fast food restaurant manager',
#    'Warehouse manager'],
#   'id': 48263},
#  {'username': 'moraleshayley',
#   'name': 'Michael Graham',
#   'sex': 'M',
#   'address': '09936 Sabrina Centers\nWest Brianhaven, OK 80507',
#   'mail': 'heidi60@gmail.com',
#   'jobs': ['Copywriter, advertising',
#    'Management consultant',
#    'Equality and diversity officer',
#    'Public house manager',
#    'Designer, graphic'],
#   'id': 505183},
#  {'username': 'staceynguyen',
#   'name': 'Terry Hunt',
#   'sex': 'M',
#   'address': 'Unit 3162 Box 2350\nDPO AP 79305',
#   'mail': 'wdavis@gmail.com',
#   'jobs': ['Scientist, marine',
#    'Therapist, horticultural',
#    'Engineer, structural',
#    'Merchant navy officer',
#    'Commissioning editor'],
#   'id': 321078},
#  {'username': 'martincrystal',
#   'name': 'Andre Gilbert',
#   'sex': 'M',
#   'address': '822 Lopez Plain\nWest Kelly, WV 13180',
#   'mail': 'andrewsingh@hotmail.com',
#   'jobs': ['Clinical research associate',
#    'Immunologist',
#    'Personnel officer',
#    'Bonds trader',
#    'Chiropractor'],
#   'id': 1108700},
#  {'username': 'dmartinez',
#   'name': 'Sergio Stewart',
#   'sex': 'M',
#   'address': '2676 Brian Pines Apt. 514\nNorth Amanda, AZ 53317',
#   'mail': 'mharris@gmail.com',
#   'jobs': ['Information systems manager',
#    'Location manager',
#    'Artist',
#    'Medical secretary',
#    'Media buyer'],
#   'id': 422893},
#  {'username': 'kreynolds',
#   'name': 'Maria Williamson',
#   'sex': 'F',
#   'address': '574 Rhonda Lodge Apt. 382\nAnthonyside, ME 08310',
#   'mail': 'murraymichael@gmail.com',
#   'jobs': ['Health physicist',
#    'Engineer, chemical',
#    'Public affairs consultant',
#    'Civil engineer, consulting'],
#   'id': 121690},
#  {'username': 'lindawhite',
#   'name': 'Eric Novak',
#   'sex': 'M',
#   'address': '56090 Julie Inlet Suite 641\nWest Leslie, AL 46584',
#   'mail': 'jonestroy@yahoo.com',
#   'jobs': ['Retail buyer',
#    'Graphic designer',
#    'Engineer, biomedical',
#    'Administrator, charities/voluntary organisations'],
#   'id': 283251},
#  {'username': 'danielamanda',
#   'name': 'Jessica Gutierrez',
#   'sex': 'F',
#   'address': 'USNS Alexander\nFPO AE 29331',
#   'mail': 'rhonda90@gmail.com',
#   'jobs': ['Armed forces operational officer',
#    'Clinical molecular geneticist',
#    'Best boy',
#    'Geographical information systems officer',
#    'Insurance risk surveyor'],
#   'id': 515278},
#  {'username': 'walterwilliams',
#   'name': 'Carrie Mccall',
#   'sex': 'F',
#   'address': '097 Christina Course Apt. 518\nThompsonburgh, LA 83538',
#   'mail': 'lisa82@yahoo.com',
#   'jobs': ['Consulting civil engineer',
#    'Production designer, theatre/television/film',
#    'Learning mentor'],
#   'id': 211184},
#  {'username': 'frankerin',
#   'name': 'Christopher Perez',
#   'sex': 'M',
#   'address': '95310 David Spring\nAllenmouth, NJ 81978',
#   'mail': 'stephenssusan@gmail.com',
#   'jobs': ['Ophthalmologist',
#    'Administrator, sports',
#    'Clinical cytogeneticist',
#    'Counselling psychologist'],
#   'id': 526666},
#  {'username': 'william18',
#   'name': 'Troy Barker',
#   'sex': 'M',
#   'address': '139 Lindsay Lock Apt. 967\nSharonberg, CA 47097',
#   'mail': 'matthew87@yahoo.com',
#   'jobs': ['Pathologist', 'Chief of Staff', 'Engineering geologist'],
#   'id': 386585},
#  {'username': 'perezmichael',
#   'name': 'Cynthia Grant',
#   'sex': 'F',
#   'address': '44772 Kara Inlet Suite 000\nWhitakerborough, DE 79229',
#   'mail': 'epaul@gmail.com',
#   'jobs': ['Tour manager',
#    'Air cabin crew',
#    'Retail banker',
#    'Further education lecturer'],
#   'id': 356062},
#  {'username': 'christopherdyer',
#   'name': 'Mary Hubbard',
#   'sex': 'F',
#   'address': '157 Jennifer Trail Suite 955\nWest Victoria, MI 04238',
#   'mail': 'ritterclaire@yahoo.com',
#   'jobs': ['Claims inspector/assessor', 'Minerals surveyor', 'Firefighter'],
#   'id': 327115},
#  {'username': 'hlee',
#   'name': 'Wanda Bradley',
#   'sex': 'F',
#   'address': '519 Lane Bridge\nEast William, HI 23530',
#   'mail': 'markpark@yahoo.com',
#   'jobs': ['Actuary',
#    'Surveyor, rural practice',
#    'Education officer, museum',
#    'Buyer, retail'],
#   'id': 171790},
#  {'username': 'barbara76',
#   'name': 'Jacqueline Hunter',
#   'sex': 'F',
#   'address': '3796 Carson Mews Apt. 928\nWarnerfurt, OK 50490',
#   'mail': 'ltyler@gmail.com',
#   'jobs': ['Warehouse manager',
#    'Information officer',
#    'Chief Operating Officer'],
#   'id': 247473},
#  {'username': 'gabriel80',
#   'name': 'Susan Conner',
#   'sex': 'F',
#   'address': '21575 Catherine Centers Suite 892\nVincenthaven, DE 21289',
#   'mail': 'kevinpetersen@gmail.com',
#   'jobs': ['Research scientist (life sciences)',
#    'Physiological scientist',
#    'Historic buildings inspector/conservation officer'],
#   'id': 145352},
#  {'username': 'qaustin',
#   'name': 'Julie Wagner',
#   'sex': 'F',
#   'address': '7075 Reynolds Port\nJoseside, NY 92892',
#   'mail': 'cruzolivia@yahoo.com',
#   'jobs': ['Video editor',
#    'Building control surveyor',
#    'Scientist, research (medical)',
#    'Minerals surveyor',
#    'Chief Marketing Officer'],
#   'id': 573325},
#  {'username': 'amygray',
#   'name': 'Mark Gregory',
#   'sex': 'M',
#   'address': '88099 Yolanda Highway Suite 090\nCookborough, MN 37304',
#   'mail': 'cheryl35@gmail.com',
#   'jobs': ['Legal executive',
#    'Secondary school teacher',
#    'Engineering geologist',
#    'Human resources officer'],
#   'id': 222139},
#  {'username': 'evanswanson',
#   'name': 'Taylor Fisher',
#   'sex': 'F',
#   'address': '2904 Johnson Summit\nNew Brianaside, NY 18948',
#   'mail': 'jessicawilson@hotmail.com',
#   'jobs': ['Biochemist, clinical',
#    'Air broker',
#    'Investment banker, corporate'],
#   'id': 1925885},
#  {'username': 'katherine59',
#   'name': 'Kenneth Burns',
#   'sex': 'M',
#   'address': '944 Woodard Plaza Apt. 360\nPort Amandaton, SD 67613',
#   'mail': 'pstevens@hotmail.com',
#   'jobs': ['Therapist, drama',
#    'Psychotherapist, child',
#    'Television production assistant'],
#   'id': 1364641},
#  {'username': 'bridgetjones',
#   'name': 'David Mccarty',
#   'sex': 'M',
#   'address': '142 Jessica Ports Suite 519\nEast Josephburgh, NH 28541',
#   'mail': 'barbaraparker@hotmail.com',
#   'jobs': ['Theatre stage manager',
#    'Engineering geologist',
#    'Embryologist, clinical'],
#   'id': 121684},
#  {'username': 'amanda04',
#   'name': 'Elizabeth Wolfe',
#   'sex': 'F',
#   'address': 'USS Banks\nFPO AE 64420',
#   'mail': 'leachrachael@hotmail.com',
#   'jobs': ['Surveyor, building', 'Mining engineer', 'Mudlogger'],
#   'id': 292175},
#  {'username': 'williamsdawn',
#   'name': 'Tammy Rodriguez',
#   'sex': 'F',
#   'address': '9675 Lawrence Heights\nNorth Patrickburgh, MS 11282',
#   'mail': 'ewebb@yahoo.com',
#   'jobs': ['Retail merchandiser',
#    'Civil Service fast streamer',
#    'Youth worker',
#    'IT trainer'],
#   'id': 685866},
#  {'username': 'rhood',
#   'name': 'Denise Brown',
#   'sex': 'F',
#   'address': '2344 Randall Mews\nRobinland, WI 07389',
#   'mail': 'fmitchell@hotmail.com',
#   'jobs': ['Editor, film/video', 'Arboriculturist', 'Statistician'],
#   'id': 64780},
#  {'username': 'michael68',
#   'name': 'Michael Figueroa',
#   'sex': 'M',
#   'address': '48891 Anthony Dale\nPort Jeff, MN 54280',
#   'mail': 'alicia11@hotmail.com',
#   'jobs': ['Chartered management accountant',
#    'Video editor',
#    'Engineer, electronics',
#    'Engineer, maintenance'],
#   'id': 47510},
#  {'username': 'rosssusan',
# ...
#   'id': 97825},
#  {'username': 'hornsherry',
#   'name': 'Mr. Bryan Freeman',
#   'sex': 'M',
#   'address': '9125 Craig Dam\nWest Stevenside, ID 18249',
#   'mail': 'aaronwagner@yahoo.com',
#   'jobs': ['Forensic scientist',
#    'Sales executive',
#    'Chartered legal executive (England and Wales)',
#    'Engineer, production',
#    'Financial risk analyst'],
#   'id': 204116},
#  {'username': 'stewartmichael',
#   'name': 'Thomas Conway',
#   'sex': 'M',
#   'address': '4582 Steele Radial Apt. 107\nAntoniofort, OR 08464',
#   'mail': 'earias@hotmail.com',
#   'jobs': ['Local government officer',
#    'Visual merchandiser',
#    'Clinical cytogeneticist',
#    'Midwife'],
#   'id': 28460},
#  {'username': 'shannonmiller',
#   'name': 'Charles Hill',
#   'sex': 'M',
#   'address': '27932 Cameron Meadow Suite 830\nLake Michaelborough, MD 02004',
#   'mail': 'yharris@gmail.com',
#   'jobs': ['Horticultural consultant',
#    'Historic buildings inspector/conservation officer',
#    'Agricultural consultant'],
#   'id': 956207},
#  {'username': 'nashwilliam',
#   'name': 'Richard Perkins',
#   'sex': 'M',
#   'address': '1017 Jimmy Inlet Suite 225\nGonzalesfort, DC 75744',
#   'mail': 'csmith@hotmail.com',
#   'jobs': ['Production engineer',
#    'Social worker',
#    'Records manager',
#    'Bonds trader',
#    'Engineer, maintenance (IT)'],
#   'id': 1271506},
#  {'username': 'wendy88',
#   'name': 'Rachel Moore',
#   'sex': 'F',
#   'address': '12875 Powell Rest\nEast John, NM 96032',
#   'mail': 'mclaughlinkathryn@yahoo.com',
#   'jobs': ['Tourist information centre manager',
#    'Physicist, medical',
#    'Glass blower/designer'],
#   'id': 55392},
#  {'username': 'vazquezmitchell',
#   'name': 'Daniel Jacobs',
#   'sex': 'M',
#   'address': 'PSC 3016, Box 1659\nAPO AA 81027',
#   'mail': 'erika73@gmail.com',
#   'jobs': ['Senior tax professional/tax inspector',
#    'Teacher, primary school',
#    'Careers adviser',
#    'Trade mark attorney',
#    'Programmer, multimedia'],
#   'id': 164368},
#  {'username': 'simmonslisa',
#   'name': 'Stephen Gonzales',
#   'sex': 'M',
#   'address': '92960 Carter Ford Apt. 028\nLynnfurt, ID 50908',
#   'mail': 'christina55@gmail.com',
#   'jobs': ['Site engineer',
#    'Geographical information systems officer',
#    'Health visitor'],
#   'id': 255057},
#  {'username': 'joshua29',
#   'name': 'James Hernandez',
#   'sex': 'M',
#   'address': '822 Stephenson Creek Suite 112\nJeffreyside, TN 00698',
#   'mail': 'kellie32@gmail.com',
#   'jobs': ['Medical technical officer',
#    'Teacher, English as a foreign language',
#    'Community development worker'],
#   'id': 832773},
#  {'username': 'daniellemcguire',
#   'name': 'Laurie Johnson',
#   'sex': 'F',
#   'address': '05197 Hartman Loop\nAmyville, ME 69883',
#   'mail': 'kevin47@yahoo.com',
#   'jobs': ['Set designer',
#    'Therapist, sports',
#    'Economist',
#    'Theatre stage manager'],
#   'id': 29229},
#  {'username': 'walkerjulie',
#   'name': 'Jeremy Cortez',
#   'sex': 'M',
#   'address': 'USS Burns\nFPO AE 66947',
#   'mail': 'meghanparker@yahoo.com',
#   'jobs': ['Manufacturing engineer',
#    'Engineer, civil (consulting)',
#    'Psychologist, clinical',
#    'Surveyor, hydrographic',
#    'Video editor'],
#   'id': 382464},
#  {'username': 'amorrison',
#   'name': 'Lauren Ramirez',
#   'sex': 'F',
#   'address': '21206 Brian Gardens Suite 254\nEast Kennethside, NV 18092',
#   'mail': 'jacksonlarry@yahoo.com',
#   'jobs': ['Office manager',
#    'Pharmacist, community',
#    'Chiropodist',
#    'Speech and language therapist'],
#   'id': 335614},
#  {'username': 'juanhall',
#   'name': 'Lorraine Martinez',
#   'sex': 'F',
#   'address': '70904 Gonzalez Rue\nScottmouth, DE 96694',
#   'mail': 'mmontoya@hotmail.com',
#   'jobs': ['Private music teacher',
#    'Field trials officer',
#    'Engineer, water',
#    'Film/video editor'],
#   'id': 391008},
#  {'username': 'danielle79',
#   'name': 'Alex Medina',
#   'sex': 'M',
#   'address': '46558 Adams Light\nGomezport, NC 96906',
#   'mail': 'schmidtcarolyn@hotmail.com',
#   'jobs': ['English as a second language teacher',
#    'Surveyor, hydrographic',
#    'Surveyor, building control',
#    'Sports therapist',
#    'Manufacturing systems engineer'],
#   'id': 65573},
#  {'username': 'jamiegreen',
#   'name': 'Amber Rivera',
#   'sex': 'F',
#   'address': '734 Welch Bypass\nNew James, NH 31687',
#   'mail': 'barnettjimmy@yahoo.com',
#   'jobs': ['Operational investment banker',
#    'Psychologist, prison and probation services',
#    'Nurse, learning disability',
#    'Psychotherapist, dance movement'],
#   'id': 121786},
#  {'username': 'feliciadominguez',
#   'name': 'Kathryn Deleon',
#   'sex': 'F',
#   'address': '8996 Sanders Drive Apt. 625\nEast Savannahshire, OK 05047',
#   'mail': 'scottchristopher@gmail.com',
#   'jobs': ['Therapist, sports',
#    'Designer, graphic',
#    'Advice worker',
#    'Energy manager',
#    'Secretary/administrator'],
#   'id': 90611},
#  {'username': 'nlee',
#   'name': 'Gail Caldwell',
#   'sex': 'F',
#   'address': '9878 David Highway Apt. 456\nNicolefurt, ID 03190',
#   'mail': 'udennis@gmail.com',
#   'jobs': ['Engineer, maintenance (IT)',
#    'Health service manager',
#    'Conservator, museum/gallery'],
#   'id': 111911},
#  {'username': 'jwilcox',
#   'name': 'Kristi Garcia',
#   'sex': 'F',
#   'address': '06752 Williams Drive\nNorth Julieville, AR 05337',
#   'mail': 'johnsonmichael@yahoo.com',
#   'jobs': ['Tax inspector',
#    'Corporate investment banker',
#    'Administrator, sports'],
#   'id': 196198},
#  {'username': 'walterreynolds',
#   'name': 'Martin Long',
#   'sex': 'M',
#   'address': '801 Matthew Mall Suite 732\nMarkhaven, CT 59330',
#   'mail': 'latoya35@yahoo.com',
#   'jobs': ['Site engineer',
#    'Sport and exercise psychologist',
#    'Research officer, trade union'],
#   'id': 69927},
#  {'username': 'bradley58',
#   'name': 'Laura Cline',
#   'sex': 'F',
#   'address': '370 Ashley Alley\nBarbarashire, RI 46983',
#   'mail': 'antoniowebb@yahoo.com',
#   'jobs': ['Therapist, horticultural',
#    'Development worker, community',
#    'Solicitor, Scotland',
#    'Pilot, airline'],
#   'id': 282737},
#  {'username': 'kgallegos',
#   'name': 'Mark Johnson',
#   'sex': 'M',
#   'address': '2606 Christina Wells\nMichaelshire, IN 30625',
#   'mail': 'uharrell@hotmail.com',
#   'jobs': ['Trade mark attorney',
#    'Pathologist',
#    'Higher education lecturer',
#    'Fashion designer',
#    'Teacher, secondary school'],
#   'id': 416409},
#  {'username': 'sharontucker',
#   'name': 'Anthony Matthews',
#   'sex': 'M',
#   'address': '303 Fuentes Lights Suite 838\nHarrisfurt, NM 70169',
#   'mail': 'lisasmith@hotmail.com',
#   'jobs': ['Chemist, analytical', 'Designer, television/film set', 'Actuary'],
#   'id': 221851},
#  {'username': 'fhall',
#   'name': 'Jasmine Byrd',
#   'sex': 'F',
#   'address': '0733 Lee Meadows Suite 916\nBriannaborough, NH 11902',
#   'mail': 'buckleykyle@hotmail.com',
#   'jobs': ['Research scientist (physical sciences)',
#    'Education officer, community',
#    'Product/process development scientist'],
#   'id': 86947},
#  {'username': 'victoriazamora',
#   'name': 'Brendan Leblanc',
#   'sex': 'M',
#   'address': 'Unit 1426 Box 3643\nDPO AP 35115',
#   'mail': 'rhopkins@hotmail.com',
#   'jobs': ['Sports administrator', 'Quarry manager', 'Psychologist, forensic'],
#   'id': 34280},
#  {'username': 'travis57',
#   'name': 'Angela Sandoval',
#   'sex': 'F',
#   'address': '2122 Webb Summit\nRichberg, KS 30110',
#   'mail': 'laura07@gmail.com',
#   'jobs': ['Textile designer',
#    'Insurance claims handler',
#    'Community arts worker',
#    'Theatre stage manager',
#    'Research scientist (life sciences)'],
#   'id': 438558},
#  {'username': 'mlopez',
#   'name': 'Melanie Torres',
#   'sex': 'F',
#   'address': '338 Alan Ferry\nWest Kimberlyland, AK 53455',
#   'mail': 'hchaney@hotmail.com',
#   'jobs': ['Software engineer',
#    'Occupational hygienist',
#    'Engineer, chemical'],
#   'id': 481494},
#  {'username': 'snyderandrew',
#   'name': 'Julie Murphy',
#   'sex': 'F',
#   'address': '804 Herrera Via\nEast James, NM 89957',
#   'mail': 'gibsonalyssa@gmail.com',
#   'jobs': ['Therapist, occupational',
#    'Chiropodist',
#    'Scientist, biomedical',
#    'Engineer, mining',
#    'Network engineer'],
#   'id': 63128},
#  {'username': 'colleendean',
#   'name': 'Sharon Lin',
#   'sex': 'F',
#   'address': '98571 White Manor\nReneeburgh, OK 86887',
#   'mail': 'jefferybell@yahoo.com',
#   'jobs': ['Event organiser',
#    'Medical illustrator',
#    'Surveyor, building control'],
#   'id': 511821},
#  {'username': 'coleandrea',
#   'name': 'Andrea Vasquez',
#   'sex': 'F',
#   'address': '291 Donna Fords\nNew Stacy, KS 03407',
#   'mail': 'annvaughn@gmail.com',
#   'jobs': ['Occupational psychologist',
#    'Development worker, international aid',
#    'Accountant, chartered certified'],
#   'id': 15572},
#  {'username': 'desiree85',
#   'name': 'Joseph Wade',
#   'sex': 'M',
#   'address': 'Unit 5375 Box 7243\nDPO AP 27470',
#   'mail': 'ojohnson@gmail.com',
#   'jobs': ['Public librarian',
#    'Therapist, speech and language',
#    'Surveyor, building'],
#   'id': 1123793},
#  {'username': 'ocollier',
#   'name': 'Joan Bailey',
#   'sex': 'F',
#   'address': 'USS Mercado\nFPO AE 61628',
#   'mail': 'jeff06@hotmail.com',
#   'jobs': ['Research officer, government',
#    'Equality and diversity officer',
#    'Surveyor, quantity',
#    'Futures trader'],
#   'id': 1687037},
#  {'username': 'buckleyrebecca',
#   'name': 'Katherine Dean',
#   'sex': 'F',
#   'address': 'USS Lowe\nFPO AA 29825',
#   'mail': 'suzannerussell@gmail.com',
#   'jobs': ['Nature conservation officer',
#    'Film/video editor',
#    'Ambulance person'],
#   'id': 235751},
#  {'username': 'peter97',
#   'name': 'Daniel Rodriguez',
#   'sex': 'M',
#   'address': '61242 Boyer Hill\nPort Robert, SC 02062',
#   'mail': 'amiller@gmail.com',
#   'jobs': ['Equality and diversity officer',
#    'Commercial/residential surveyor',
#    'Medical secretary',
#    'Probation officer'],
#   'id': 251499},
#  {'username': 'tsalas',
#   'name': 'Luke Hood',
#   'sex': 'M',
#   'address': '93027 Moore Vista\nNew Kaylaland, WY 76111',
#   'mail': 'claire15@gmail.com',
#   'jobs': ['Market researcher',
#    'Curator',
#    'Engineer, biomedical',
#    'Engineer, communications'],
#   'id': 168896},
#  {'username': 'stephaniesnyder',
#   'name': 'Jasmine Campbell',
#   'sex': 'F',
#   'address': '50923 Madeline Brook Suite 349\nWest Samanthafort, MO 05061',
#   'mail': 'carterjoseph@hotmail.com',
#   'jobs': ['Administrator, education',
#    'Careers information officer',
#    'Engineer, drilling'],
#   'id': 790231},
#  {'username': 'michelle21',
#   'name': 'Shawn Hale',
#   'sex': 'M',
#   'address': '87173 Brent Junctions Apt. 643\nWest Jacob, SC 24140',
#   'mail': 'dsanchez@hotmail.com',
#   'jobs': ['Aid worker',
#    'Operational investment banker',
#    'Accounting technician',
#    'Hotel manager',
#    'Nutritional therapist'],
#   'id': 192581},
#  {'username': 'jesus56',
#   'name': 'Jason White',
#   'sex': 'M',
#   'address': '37540 Nicholson Summit\nNew Brittany, NJ 17338',
#   'mail': 'zachary18@yahoo.com',
#   'jobs': ['Data processing manager',
#    'Research scientist (life sciences)',
#    'Best boy',
#    'Learning disability nurse'],
#   'id': 51664},
#  {'username': 'oliveraaron',
#   'name': 'Melissa Brown',
#   'sex': 'F',
#   'address': '412 Bird Spurs\nMichaelside, CA 10173',
#   'mail': 'amanda92@gmail.com',
#   'jobs': ['Water quality scientist',
#    'Financial risk analyst',
#    'Engineer, production'],
#   'id': 1129847},
#  {'username': 'vtaylor',
#   'name': 'Tara Kelly',
#   'sex': 'F',
#   'address': '2049 Schultz Terrace\nWilliamsland, SC 62184',
#   'mail': 'jeffreymccarthy@yahoo.com',
#   'jobs': ['Community pharmacist', 'Media buyer', 'IT sales professional'],
#   'id': 356222},
#  {'username': 'iwatkins',
#   'name': 'John Nelson',
#   'sex': 'M',
#   'address': '51164 Wu Ranch Apt. 320\nNorth Julie, NV 38976',
#   'mail': 'pattonmark@hotmail.com',
#   'jobs': ['Administrator, Civil Service',
#    'Production engineer',
#    'Journalist, magazine'],
#   'id': 91392},
#  {'username': 'fstanley',
#   'name': 'Victoria Russell',
#   'sex': 'F',
#   'address': '757 Martin Camp\nWest Christieview, TX 07318',
#   'mail': 'jonesmichele@hotmail.com',
#   'jobs': ['Hospital doctor',
#    'Volunteer coordinator',
#    'Engineer, electronics',
#    'Psychotherapist, child'],
#   'id': 876253},
#  {'username': 'bryan04',
#   'name': 'Jordan Burke',
#   'sex': 'M',
#   'address': '0626 Samuel Park\nNorth Mario, KS 16728',
#   'mail': 'patriciaross@hotmail.com',
#   'jobs': ['IT consultant', "Politician's assistant", 'Warden/ranger'],
#   'id': 65190},
#  {'username': 'robinsongordon',
#   'name': 'Susan Gardner',
#   'sex': 'F',
#   'address': 'Unit 3877 Box 4781\nDPO AE 57419',
#   'mail': 'cforbes@yahoo.com',
#   'jobs': ['Air traffic controller',
#    'Surveyor, quantity',
#    'Tourist information centre manager',
#    'Lobbyist',
#    'Pensions consultant'],
#   'id': 229137},
#  {'username': 'tayloraustin',
#   'name': 'Kirk Hicks',
#   'sex': 'M',
#   'address': '38851 Michelle Forges Apt. 231\nLake Sharichester, MI 30959',
#   'mail': 'jean83@yahoo.com',
#   'jobs': ['Air traffic controller',
#    'Television production assistant',
#    'Office manager'],
#   'id': 164913},
#  {'username': 'scott92',
#   'name': 'Anthony Reeves',
#   'sex': 'M',
#   'address': '099 Cuevas Hill Suite 438\nEdwardsfurt, DE 88265',
#   'mail': 'xharris@yahoo.com',
#   'jobs': ['Academic librarian',
#    'Public affairs consultant',
#    'Conservation officer, nature',
#    'Surveyor, mining'],
#   'id': 1445094},
#  {'username': 'wellsfrancisco',
#   'name': 'Sean Bennett',
#   'sex': 'M',
#   'address': '37777 William Trace Suite 348\nSouth Ronaldfurt, WV 78706',
#   'mail': 'cannoncameron@hotmail.com',
#   'jobs': ['Psychiatric nurse',
#    'Naval architect',
#    'Homeopath',
#    'Landscape architect'],
#   'id': 62997},
#  {'username': 'ogonzalez',
#   'name': 'Anthony Webb',
#   'sex': 'M',
#   'address': '3893 Elizabeth Row\nWrightville, DC 03541',
#   'mail': 'kathryn96@hotmail.com',
#   'jobs': ['Museum/gallery conservator',
#    'Chief Technology Officer',
#    'Mudlogger'],
#   'id': 470211},
#  {'username': 'ygordon',
#   'name': 'Aaron Taylor',
#   'sex': 'M',
#   'address': '674 Pamela Square Apt. 345\nNorth Julia, NV 46252',
#   'mail': 'brent59@yahoo.com',
#   'jobs': ['Editor, film/video',
#    'Telecommunications researcher',
#    'Furniture designer',
#    'Control and instrumentation engineer',
#    'Buyer, industrial'],
#   'id': 1655837},
#  {'username': 'elewis',
#   'name': 'Valerie Lee',
#   'sex': 'F',
#   'address': '235 Julie Summit Suite 460\nJadeport, MT 49806',
#   'mail': 'christinanguyen@hotmail.com',
#   'jobs': ['Loss adjuster, chartered',
#    'Scientist, product/process development',
#    'Engineer, water'],
#   'id': 90086},
#  {'username': 'jmiller',
#   'name': 'April Jones',
#   'sex': 'F',
#   'address': '191 Melanie Underpass Suite 350\nDorisshire, SC 61721',
#   'mail': 'garciaderek@yahoo.com',
#   'jobs': ['Communications engineer',
#    'Translator',
#    'Teacher, music',
#    'Journalist, newspaper'],
#   'id': 48902},
#  {'username': 'michaelhartman',
#   'name': 'Sarah Castaneda',
#   'sex': 'F',
#   'address': '4364 Jackson Locks Suite 991\nNorth Andrew, ND 68515',
#   'mail': 'justin28@hotmail.com',
#   'jobs': ['Geochemist',
#    'Loss adjuster, chartered',
#    'Herbalist',
#    'Advice worker'],
#   'id': 109353},
#  {'username': 'lopezderek',
#   'name': 'Tracy Brown',
#   'sex': 'F',
#   'address': '805 Taylor Roads\nMaryville, MS 32255',
#   'mail': 'james65@yahoo.com',
#   'jobs': ['Charity officer',
#    'Adult guidance worker',
#    'Leisure centre manager'],
#   'id': 1142473},
#  {'username': 'fzuniga',
#   'name': 'John Martinez',
#   'sex': 'M',
#   'address': '28262 Nancy Freeway\nStaffordton, MS 34983',
#   'mail': 'bruce58@yahoo.com',
#   'jobs': ['Television floor manager',
#    'Therapist, drama',
#    'Licensed conveyancer'],
#   'id': 54827},
#  {'username': 'amysmith',
#   'name': 'Jimmy Hendrix',
#   'sex': 'M',
#   'address': '399 Barry Wall\nPort Barbara, AZ 64144',
#   'mail': 'jenningswilliam@hotmail.com',
#   'jobs': ['Control and instrumentation engineer',
#    'Insurance risk surveyor',
#    'Theatre manager'],
#   'id': 1409727},
#  {'username': 'loweanthony',
#   'name': 'Tyler Wilson',
#   'sex': 'M',
#   'address': '527 Janet Ports Apt. 602\nNew Mathewville, MD 52703',
#   'mail': 'johnsondavid@yahoo.com',
#   'jobs': ['Exercise physiologist',
#    "Barrister's clerk",
#    'Scientist, water quality',
#    'Acupuncturist',
#    'Producer, television/film/video'],
#   'id': 64625},
#  ...]

# %%
def find_user(name, data):
    for person in data:
        if person['username'] == name:
            return person
    raise ValueError
       
find_user('ljohnson', contributors_sample)
# Out:
# {'username': 'ljohnson',
#  'name': 'Stephen Hull',
#  'sex': 'M',
#  'address': '9821 Patton Roads\nPort Scott, OH 39878',
#  'mail': 'jonescrystal@hotmail.com',
#  'jobs': ['Therapeutic radiographer', 'IT trainer', 'Location manager'],
#  'id': 66448}

# %% [markdown]
# 1.4 Посчитайте, сколько мужчин и женщин присутсвует в этом наборе данных.

# %%
male = 0
female = 0 
for person in contributors_sample:
    if person['sex'] == 'M':
        male += 1
    else:
        female += 1
print('Мужчин:', male)        
print('Женщин:', female)
# Out:
# Мужчин: 2064
# Женщин: 2136

# %% [markdown]
# 1.5 Создайте `pd.DataFrame` `contributors`, имеющий столбцы `id`, `username` и `sex`.

# %%
import pandas as pd

# %%
contributors = pd.read_json('contributors_sample.json')[['id', 'username', 'sex']]
contributors
# Out:
#            id       username sex
# 0       35193        uhebert   F
# 1       91970    vickitaylor   F
# 2     1848091    sheilaadams   F
# 3       50969       nicole82   F
# 4      676820         jean67   M
# ...       ...            ...  ..
# 4195   423555  stevenspencer   F
# 4196    35251      rwilliams   M
# 4197   135887      lmartinez   F
# 4198   212714     brendahill   M
# 4199   344321       mistyray   F
#
# [4200 rows x 3 columns]

# %% [markdown]
# 1.6 Загрузите данные из файла `recipes_sample.csv` (__ЛР2__) в таблицу `recipes`. Объедините `recipes` с таблицей `contributors` с сохранением строк в том случае, если информация о человеке отсутствует в JSON-файле. Для скольких человек информация отсутствует?

# %%
recipes = pd.read_csv('recipes_sample.csv', sep = ',', header = 0, parse_dates = ['submitted'])

# %%
recipes.head()
# Out:
#                                        name     id  minutes  contributor_id  \
# 0     george s at the cove  black bean soup  44123       90           35193
# 1        healthy for them  yogurt popsicles  67664       10           91970
# 2              i can t believe it s spinach  38798       30            1533
# 3                      italian  gut busters  35173       45           22724
# 4  love is in the air  beef fondue   sauces  84797       25            4470
#
#    submitted  n_steps                                        description  \
# 0 2002-10-25      NaN  an original recipe created by chef scott meska...
# 1 2003-07-26      NaN  my children and their friends ask for my homem...
# 2 2002-08-29      NaN            these were so go, it surprised even me.
# 3 2002-07-27      NaN  my sister-in-law made these for us at a family...
# 4 2004-02-23      4.0  i think a fondue is a very romantic casual din...
#
#    n_ingredients
# 0           18.0
# 1            NaN
# 2            8.0
# 3            NaN
# 4            NaN

# %%
contributors.head()
# Out:
#         id     username sex
# 0    35193      uhebert   F
# 1    91970  vickitaylor   F
# 2  1848091  sheilaadams   F
# 3    50969     nicole82   F
# 4   676820       jean67   M

# %%
contributors = contributors.rename(columns={'id': 'contributor_id'})

# %%
rec_cont = recipes.merge(contributors, how = 'left')
rec_cont.head()
# Out:
#                                        name     id  minutes  contributor_id  \
# 0     george s at the cove  black bean soup  44123       90           35193
# 1        healthy for them  yogurt popsicles  67664       10           91970
# 2              i can t believe it s spinach  38798       30            1533
# 3                      italian  gut busters  35173       45           22724
# 4  love is in the air  beef fondue   sauces  84797       25            4470
#
#    submitted  n_steps                                        description  \
# 0 2002-10-25      NaN  an original recipe created by chef scott meska...
# 1 2003-07-26      NaN  my children and their friends ask for my homem...
# 2 2002-08-29      NaN            these were so go, it surprised even me.
# 3 2002-07-27      NaN  my sister-in-law made these for us at a family...
# 4 2004-02-23      4.0  i think a fondue is a very romantic casual din...
#
#    n_ingredients     username  sex
# 0           18.0      uhebert    F
# 1            NaN  vickitaylor    F
# 2            8.0          NaN  NaN
# 3            NaN          NaN  NaN
# 4            NaN          NaN  NaN

# %%
print('В JSON-файле отсутствует информация о {} пользователях'.format(rec_cont.isnull().sum(axis = 0)['sex']))
# Out:
# В JSON-файле отсутствует информация о 15059 пользователях

# %% [markdown]
# ### pickle

# %% [markdown]
# 2.1 На основе файла `contributors_sample.json` создайте словарь следующего вида:
# ```
# {
#     должность: [список username людей, занимавших эту должность]
# }
# ```

# %%
contributors_sample
# Out:
# [{'username': 'uhebert',
#   'name': 'Lindsey Nguyen',
#   'sex': 'F',
#   'address': '01261 Cameron Spring\nTaylorfurt, AK 97791',
#   'mail': 'jsalazar@gmail.com',
#   'jobs': ['Energy engineer',
#    'Engineer, site',
#    'Environmental health practitioner',
#    'Biomedical scientist',
#    'Jewellery designer'],
#   'id': 35193},
#  {'username': 'vickitaylor',
#   'name': 'Cheryl Lewis',
#   'sex': 'F',
#   'address': '66992 Welch Brooks\nMarshallshire, ID 56004',
#   'mail': 'bhudson@gmail.com',
#   'jobs': ['Music therapist',
#    'Volunteer coordinator',
#    'Designer, interior/spatial'],
#   'id': 91970},
#  {'username': 'sheilaadams',
#   'name': 'Julia Allen',
#   'sex': 'F',
#   'address': 'Unit 1632 Box 2971\nDPO AE 23297',
#   'mail': 'darren44@yahoo.com',
#   'jobs': ['Management consultant',
#    'Engineer, structural',
#    'Lecturer, higher education',
#    'Theatre manager',
#    'Designer, textile'],
#   'id': 1848091},
#  {'username': 'nicole82',
#   'name': 'Gina Stevens',
#   'sex': 'F',
#   'address': '9880 Michelle Bridge\nNew Kimberlybury, WY 02583',
#   'mail': 'stevensonsarah@hotmail.com',
#   'jobs': ['Mechanical engineer', 'Retail banker', 'Barrister'],
#   'id': 50969},
#  {'username': 'jean67',
#   'name': 'Nicholas Harrington',
#   'sex': 'M',
#   'address': '9080 Monica Crescent Suite 820\nNorth Deanbury, HI 28977',
#   'mail': 'denise42@gmail.com',
#   'jobs': ['Network engineer',
#    'Youth worker',
#    'Primary school teacher',
#    'Engineer, broadcasting (operations)'],
#   'id': 676820},
#  {'username': 'james67',
#   'name': 'Allison Gomez',
#   'sex': 'F',
#   'address': '635 Kenneth Ways Suite 172\nHancockfort, AZ 50544',
#   'mail': 'monique02@hotmail.com',
#   'jobs': ['Designer, ceramics/pottery',
#    'Engineer, energy',
#    'Engineer, manufacturing'],
#   'id': 64918},
#  {'username': 'woodmarissa',
#   'name': 'Michael Jackson',
#   'sex': 'M',
#   'address': '4531 Phillips Underpass\nMartinezport, MA 82685',
#   'mail': 'dustin32@hotmail.com',
#   'jobs': ['Designer, furniture',
#    'Designer, furniture',
#    'Lecturer, higher education'],
#   'id': 113941},
#  {'username': 'sampsontammy',
#   'name': 'David Cruz',
#   'sex': 'M',
#   'address': '81737 Amy Grove Apt. 471\nJoannaport, IA 95575',
#   'mail': 'josephpowell@gmail.com',
#   'jobs': ['Sport and exercise psychologist',
#    'Hospital pharmacist',
#    'Surveyor, minerals',
#    'Geochemist',
#    'Restaurant manager'],
#   'id': 398160},
#  {'username': 'jonathan18',
#   'name': 'Mr. Matthew Robinson',
#   'sex': 'M',
#   'address': '01262 Dunn Ranch Apt. 256\nWest Jay, CO 99010',
#   'mail': 'oclark@hotmail.com',
#   'jobs': ['Clinical psychologist',
#    'Retail banker',
#    'Sports development officer',
#    'Firefighter',
#    'Charity fundraiser'],
#   'id': 35635},
#  {'username': 'michael53',
#   'name': 'Michael Kelly',
#   'sex': 'M',
#   'address': '75339 Jeremy Ford\nVictoriamouth, WV 22856',
#   'mail': 'danielsjessica@gmail.com',
#   'jobs': ['Insurance underwriter',
#    'Analytical chemist',
#    'Holiday representative'],
#   'id': 718054},
#  {'username': 'mcmahondavid',
#   'name': 'Christina Cowan',
#   'sex': 'F',
#   'address': '3829 Scott Prairie Apt. 614\nLoweland, CA 60640',
#   'mail': 'tinabrown@gmail.com',
#   'jobs': ['Network engineer',
#    'Scientist, research (physical sciences)',
#    'Financial planner'],
#   'id': 817632},
#  {'username': 'thomas96',
#   'name': 'Laura Trujillo',
#   'sex': 'F',
#   'address': '2573 Mahoney Shore Suite 323\nWest Briannaside, FL 13733',
#   'mail': 'patrickrodgers@gmail.com',
#   'jobs': ['Psychiatric nurse',
#    'Audiological scientist',
#    'Programmer, applications',
#    'Phytotherapist',
#    'Records manager'],
#   'id': 2406227},
#  {'username': 'martindonald',
#   'name': 'Diane Bell',
#   'sex': 'F',
#   'address': '565 Vazquez Spurs\nNew Richard, IA 19952',
#   'mail': 'makayla88@hotmail.com',
#   'jobs': ['Secondary school teacher',
#    'Futures trader',
#    'Programmer, multimedia',
#    'Public affairs consultant'],
#   'id': 239808},
#  {'username': 'ljohnson',
#   'name': 'Stephen Hull',
#   'sex': 'M',
#   'address': '9821 Patton Roads\nPort Scott, OH 39878',
#   'mail': 'jonescrystal@hotmail.com',
#   'jobs': ['Therapeutic radiographer', 'IT trainer', 'Location manager'],
#   'id': 66448},
#  {'username': 'wendycross',
#   'name': 'William Morris',
#   'sex': 'M',
#   'address': '97846 Stephens Ford\nWest Mary, DC 76913',
#   'mail': 'joseph72@yahoo.com',
#   'jobs': ['Production engineer',
#    'Chief Operating Officer',
#    'Hospital doctor',
#    'Radiation protection practitioner'],
#   'id': 27643},
#  {'username': 'wsmith',
#   'name': 'Matthew Ewing',
#   'sex': 'M',
#   'address': '1436 Wilson Stream Suite 801\nIantown, IL 27715',
#   'mail': 'ymorgan@gmail.com',
#   'jobs': ['Printmaker',
#    'Publishing copy',
#    'Research scientist (life sciences)'],
#   'id': 797706},
#  {'username': 'ashlee22',
#   'name': 'Dylan Rodriguez',
#   'sex': 'M',
#   'address': '8542 Navarro Ports\nTravisborough, SD 62180',
#   'mail': 'andersonrobert@gmail.com',
#   'jobs': ['Chief Technology Officer',
#    'Call centre manager',
#    'Chief Executive Officer',
#    'Purchasing manager'],
#   'id': 40493},
#  {'username': 'swoodward',
#   'name': 'David Brown',
#   'sex': 'M',
#   'address': '9359 Snyder Creek\nBruceview, SD 54485',
#   'mail': 'bonnie99@hotmail.com',
#   'jobs': ['Engineer, petroleum',
#    'Social researcher',
#    'Publishing rights manager'],
#   'id': 727055},
#  {'username': 'donald28',
#   'name': 'Taylor Byrd',
#   'sex': 'M',
#   'address': '16804 Terry Wall\nPort Haileyville, WY 58276',
#   'mail': 'kimberly45@yahoo.com',
#   'jobs': ['Tax adviser',
#    'Customer service manager',
#    'Forensic psychologist',
#    'Financial adviser',
#    'Photographer'],
#   'id': 1292969},
#  {'username': 'moodydavid',
#   'name': 'John Morton',
#   'sex': 'M',
#   'address': '408 Townsend Island Apt. 258\nPaulashire, GA 79680',
#   'mail': 'ericdavis@hotmail.com',
#   'jobs': ['Health and safety adviser',
#    'Product/process development scientist',
#    'Ceramics designer',
#    'Secretary/administrator',
#    'Patent attorney'],
#   'id': 31364},
#  {'username': 'edwardszachary',
#   'name': 'Rachel Newman',
#   'sex': 'F',
#   'address': '847 Brian Park Apt. 089\nEast Michaelstad, FL 85845',
#   'mail': 'xsmith@gmail.com',
#   'jobs': ['Hotel manager',
#    'Quantity surveyor',
#    'Scientist, research (physical sciences)'],
#   'id': 814629},
#  {'username': 'ashley92',
#   'name': 'Christopher Decker',
#   'sex': 'M',
#   'address': '50944 Jennifer Union Suite 411\nBrittanyfurt, OR 99825',
#   'mail': 'gardnerjason@yahoo.com',
#   'jobs': ['Forest/woodland manager',
#    'Administrator, education',
#    'Nurse, adult',
#    'Multimedia programmer'],
#   'id': 209747},
#  {'username': 'tamara08',
#   'name': 'Kelly Atkins',
#   'sex': 'F',
#   'address': '3641 Justin Estates Suite 613\nWest Rubenland, OH 42410',
#   'mail': 'pmartinez@hotmail.com',
#   'jobs': ['Civil Service fast streamer',
#    'Psychologist, prison and probation services',
#    'Armed forces training and education officer',
#    'Glass blower/designer',
#    'Pharmacist, hospital'],
#   'id': 37636},
#  {'username': 'richardsstephen',
#   'name': 'Jordan Pittman',
#   'sex': 'M',
#   'address': '268 Richard Club\nNew Jasonland, MA 43402',
#   'mail': 'kochmichael@hotmail.com',
#   'jobs': ['Holiday representative',
#    'Warehouse manager',
#    'Psychologist, counselling',
#    'Pensions consultant'],
#   'id': 13483},
#  {'username': 'davidreynolds',
#   'name': 'Jerry Salazar',
#   'sex': 'M',
#   'address': '627 Mason Mill Apt. 896\nDonaldtown, LA 85040',
#   'mail': 'skane@yahoo.com',
#   'jobs': ['Trade mark attorney',
#    'Psychotherapist, child',
#    'Engineer, energy',
#    'Bonds trader',
#    'Journalist, broadcasting'],
#   'id': 21752},
#  {'username': 'nburnett',
#   'name': 'Heather Larson',
#   'sex': 'F',
#   'address': '236 Hernandez Vista\nAnthonyberg, MI 51576',
#   'mail': 'robert58@hotmail.com',
#   'jobs': ['Advice worker', 'Geologist, wellsite', 'Toxicologist'],
#   'id': 29291},
#  {'username': 'kimberly63',
#   'name': 'Adam Atkinson',
#   'sex': 'M',
#   'address': '27804 David Pine\nDeannashire, OH 45920',
#   'mail': 'perrylaura@hotmail.com',
#   'jobs': ['Media buyer',
#    'Engineer, civil (consulting)',
#    'Corporate treasurer'],
#   'id': 424680},
#  {'username': 'lindsey03',
#   'name': 'William Bennett',
#   'sex': 'M',
#   'address': '7707 Miller Locks Suite 144\nGlennchester, GA 21253',
#   'mail': 'keith76@yahoo.com',
#   'jobs': ['Nature conservation officer',
#    'Neurosurgeon',
#    'Special effects artist',
#    'Professor Emeritus',
#    'Rural practice surveyor'],
#   'id': 166642},
#  {'username': 'patrick77',
#   'name': 'John Bender',
#   'sex': 'M',
#   'address': '158 Oconnell Hollow\nJasonville, CA 51906',
#   'mail': 'donna95@yahoo.com',
#   'jobs': ['Education administrator', 'Arboriculturist', 'Facilities manager'],
#   'id': 29782},
#  {'username': 'christine79',
#   'name': 'Kenneth Love',
#   'sex': 'M',
#   'address': 'Unit 4345 Box 3747\nDPO AP 52811',
#   'mail': 'carrmichael@yahoo.com',
#   'jobs': ['Water engineer', 'Cabin crew', 'Radiographer, diagnostic'],
#   'id': 891449},
#  {'username': 'beanangela',
#   'name': 'Anthony Wilson',
#   'sex': 'M',
#   'address': '9677 Franco Camp\nEast Matthewport, KS 01648',
#   'mail': 'myoung@hotmail.com',
#   'jobs': ['Chief Operating Officer',
#    'Chemist, analytical',
#    'Engineer, civil (consulting)',
#    'Product/process development scientist',
#    'Osteopath'],
#   'id': 167849},
#  {'username': 'johnsonashley',
#   'name': 'Denise Dixon',
#   'sex': 'F',
#   'address': '115 Brady Port Apt. 682\nSandyside, VT 54365',
#   'mail': 'williamsmichelle@yahoo.com',
#   'jobs': ['Insurance claims handler',
#    'Quality manager',
#    'Designer, exhibition/display',
#    'Sub',
#    'Records manager'],
#   'id': 1926889},
#  {'username': 'alexander89',
#   'name': 'Kaitlin Lopez',
#   'sex': 'F',
#   'address': '3885 Derek River Suite 436\nNew Debraville, TX 56047',
#   'mail': 'angela69@yahoo.com',
#   'jobs': ['Market researcher',
#    'Colour technologist',
#    'Emergency planning/management officer'],
#   'id': 47892},
#  {'username': 'vincent02',
#   'name': 'Rebecca Casey',
#   'sex': 'F',
#   'address': '92862 Zachary Forge Apt. 896\nEricksonmouth, VA 70050',
#   'mail': 'riosrichard@hotmail.com',
#   'jobs': ['Lexicographer', 'Hospital doctor', 'Water quality scientist'],
#   'id': 47549},
#  {'username': 'lopezantonio',
#   'name': 'Adam Watson',
#   'sex': 'M',
#   'address': '90456 Justin Wells Apt. 266\nStacyberg, FL 37938',
#   'mail': 'lauren19@hotmail.com',
#   'jobs': ['Engineer, water',
#    'Jewellery designer',
#    'Surveyor, insurance',
#    'Environmental manager'],
#   'id': 454149},
#  {'username': 'powersemily',
#   'name': 'Stacy Wood',
#   'sex': 'F',
#   'address': '6862 Eric Shoal Apt. 336\nNew Sheila, IL 41723',
#   'mail': 'tmiller@yahoo.com',
#   'jobs': ['Maintenance engineer',
#    'Charity fundraiser',
#    "Nurse, children's",
#    'Astronomer'],
#   'id': 1299206},
#  {'username': 'joseconley',
#   'name': 'Brooke Higgins',
#   'sex': 'F',
#   'address': '71018 Henson Mews\nGregoryhaven, ME 68359',
#   'mail': 'cummingsjared@gmail.com',
#   'jobs': ['Archaeologist',
#    'Journalist, newspaper',
#    'Accountant, chartered',
#    'Computer games developer'],
#   'id': 498271},
#  {'username': 'leslie69',
#   'name': 'Olivia Johnson',
#   'sex': 'F',
#   'address': '6878 James Tunnel Apt. 770\nWest Keith, IL 97125',
#   'mail': 'jamie80@yahoo.com',
#   'jobs': ['Drilling engineer',
#    'Scientist, research (physical sciences)',
#    'Environmental manager',
#    'Librarian, academic',
#    'Biomedical engineer'],
#   'id': 37449},
#  {'username': 'james03',
#   'name': 'Alison Smith',
#   'sex': 'F',
#   'address': '87793 Livingston Estate Apt. 513\nNew Rachel, NY 40946',
#   'mail': 'kerri43@gmail.com',
#   'jobs': ['Psychologist, prison and probation services',
#    'Haematologist',
#    'Presenter, broadcasting'],
#   'id': 1375473},
#  {'username': 'calhounchristopher',
#   'name': 'Juan Miller',
#   'sex': 'M',
#   'address': '044 Johnny Track Apt. 543\nKathrynview, ID 67020',
#   'mail': 'alexanderdouglas@yahoo.com',
#   'jobs': ['Lexicographer',
#    'Surveyor, commercial/residential',
#    'Engineer, electronics'],
#   'id': 2247203},
#  {'username': 'wgray',
#   'name': 'Patrick Johnson',
#   'sex': 'M',
#   'address': 'Unit 0962 Box 0438\nDPO AA 87836',
#   'mail': 'uchavez@gmail.com',
#   'jobs': ['Maintenance engineer',
#    'Surveyor, land/geomatics',
#    'Accountant, chartered management'],
#   'id': 94189},
#  {'username': 'laura87',
#   'name': 'Justin Barron',
#   'sex': 'M',
#   'address': '6288 Franklin Villages Suite 093\nNorth Elizabeth, VA 76953',
#   'mail': 'renee68@hotmail.com',
#   'jobs': ['Broadcast engineer',
#    'Engineer, building services',
#    'Patent examiner',
#    'Media planner'],
#   'id': 279496},
#  {'username': 'bethany97',
#   'name': 'David Kirk',
#   'sex': 'M',
#   'address': '722 Jennifer Estates Suite 046\nPort Kennethfurt, GA 36698',
#   'mail': 'vgonzalez@hotmail.com',
#   'jobs': ['Ecologist',
#    'Astronomer',
#    'Chief Operating Officer',
#    'Geographical information systems officer',
#    'Paramedic'],
#   'id': 57042},
#  {'username': 'tyroneglass',
#   'name': 'Sydney Cisneros',
#   'sex': 'F',
#   'address': '1276 Katie Stream Suite 648\nDouglasburgh, HI 24784',
#   'mail': 'toddgarcia@hotmail.com',
#   'jobs': ['Designer, television/film set',
#    'Public librarian',
#    'Petroleum engineer',
#    'Cabin crew',
#    'Sales professional, IT'],
#   'id': 205983},
#  {'username': 'blanchardjackie',
#   'name': 'Blake Fletcher',
#   'sex': 'M',
#   'address': '7744 Ray Way Apt. 856\nNew Ray, SD 70899',
#   'mail': 'clarkkrista@hotmail.com',
#   'jobs': ['Clinical molecular geneticist',
#    'Commercial art gallery manager',
#    'Scientist, research (physical sciences)'],
#   'id': 379836},
#  {'username': 'annmoore',
#   'name': 'Richard Brown',
#   'sex': 'M',
#   'address': '5793 Hart Unions\nWest Tonyville, WA 85226',
#   'mail': 'briankennedy@yahoo.com',
#   'jobs': ['Energy engineer',
#    'Television/film/video producer',
#    'Dispensing optician',
#    'Buyer, industrial',
#    'Energy manager'],
#   'id': 210965},
#  {'username': 'wwinters',
#   'name': 'Crystal Blair',
#   'sex': 'F',
#   'address': '1434 Matthew Locks\nKeithmouth, IL 03520',
#   'mail': 'flopez@gmail.com',
#   'jobs': ['Publishing copy', 'Ecologist', 'Structural engineer'],
#   'id': 126687},
#  {'username': 'richard91',
#   'name': 'Kenneth Wright',
#   'sex': 'M',
#   'address': '22129 Donna Coves\nLake Douglasside, NJ 54596',
#   'mail': 'ronald61@gmail.com',
#   'jobs': ['Chief Strategy Officer',
#    'Building control surveyor',
#    'Product designer'],
#   'id': 63855},
#  {'username': 'christina73',
#   'name': 'Karina Miller',
#   'sex': 'F',
#   'address': 'USCGC Stanley\nFPO AP 62480',
#   'mail': 'anthony91@yahoo.com',
#   'jobs': ['Archaeologist',
#    'Analytical chemist',
#    'Surveyor, planning and development',
#    'Architect'],
#   'id': 189030},
#  {'username': 'zmartin',
#   'name': 'Kyle Harrison',
#   'sex': 'M',
#   'address': '35728 George Harbors\nPalmerhaven, NY 19496',
#   'mail': 'kfoster@gmail.com',
#   'jobs': ['Social researcher', 'Dietitian', 'Engineer, chemical'],
#   'id': 524879},
#  {'username': 'richard14',
#   'name': 'Carla Miller',
#   'sex': 'F',
#   'address': '0975 Patton Points Suite 520\nGutierrezburgh, MI 89035',
#   'mail': 'jermaine23@yahoo.com',
#   'jobs': ['Transport planner',
#    'Radiographer, diagnostic',
#    'Therapist, sports',
#    'Facilities manager'],
#   'id': 470110},
#  {'username': 'amy62',
#   'name': 'Nicole Smith',
#   'sex': 'F',
#   'address': '798 Torres Circles\nComptonmouth, AL 88224',
#   'mail': 'fcharles@hotmail.com',
#   'jobs': ['Scientist, audiological',
#    'Learning mentor',
#    'Air broker',
#    'Oceanographer'],
#   'id': 131674},
#  {'username': 'sstrickland',
#   'name': 'Sandra Clark',
#   'sex': 'F',
#   'address': '909 William Springs Apt. 438\nRhondaport, WY 17145',
#   'mail': 'chavezrobert@yahoo.com',
#   'jobs': ['Psychotherapist, dance movement',
#    'Physicist, medical',
#    'Equities trader',
#    'Radiation protection practitioner'],
#   'id': 303454},
#  {'username': 'icervantes',
#   'name': 'Deborah Conrad',
#   'sex': 'F',
#   'address': '75565 Parrish Skyway Apt. 904\nMurphyhaven, OR 23100',
#   'mail': 'maldonadocourtney@yahoo.com',
#   'jobs': ['Dance movement psychotherapist',
#    'Theatre manager',
#    'Electrical engineer',
#    'Site engineer'],
#   'id': 1618462},
#  {'username': 'ydavis',
#   'name': 'Judith Richardson',
#   'sex': 'F',
#   'address': '027 Pamela Parkway Suite 059\nWhiteton, WV 30405',
#   'mail': 'turnerkathryn@hotmail.com',
#   'jobs': ['Phytotherapist',
#    'Occupational psychologist',
#    'Librarian, academic',
#    'Physicist, medical',
#    'Merchandiser, retail'],
#   'id': 789314},
#  {'username': 'luceroashley',
#   'name': 'Molly Mooney',
#   'sex': 'F',
#   'address': '6371 Robert Corners\nEast Michaelland, ND 55885',
#   'mail': 'lharrington@gmail.com',
#   'jobs': ['Planning and development surveyor',
#    'Environmental education officer',
#    'Arts development officer',
#    'Surveyor, land/geomatics'],
#   'id': 205783},
#  {'username': 'mariaporter',
#   'name': 'Michael Johnson',
#   'sex': 'M',
#   'address': '65191 Sarah Islands Apt. 215\nLisaborough, VA 81648',
#   'mail': 'davidshah@yahoo.com',
#   'jobs': ['Horticultural therapist',
#    'Recruitment consultant',
#    'Financial planner',
#    'Energy manager',
#    'Editor, magazine features'],
#   'id': 63098},
#  {'username': 'kristen66',
#   'name': 'Christy Jones DDS',
#   'sex': 'F',
#   'address': '9705 Christopher Crossing\nNew Matthewland, ND 15813',
#   'mail': 'carlareed@yahoo.com',
#   'jobs': ['Nature conservation officer',
#    'Scientist, forensic',
#    'Geologist, engineering'],
#   'id': 193516},
#  {'username': 'nunezjeffrey',
#   'name': 'Albert Richards',
#   'sex': 'M',
#   'address': '056 Davis Ways Apt. 530\nNicolebury, OK 84769',
#   'mail': 'ncox@gmail.com',
#   'jobs': ['Architect',
#    'IT sales professional',
#    'Psychologist, educational',
#    'Risk analyst'],
#   'id': 107135},
#  {'username': 'rwilliams',
#   'name': 'Alexandria Myers',
#   'sex': 'F',
#   'address': 'USNS Hanson\nFPO AE 27071',
#   'mail': 'thomasmary@yahoo.com',
#   'jobs': ['Scientist, research (life sciences)',
#    'Designer, exhibition/display',
#    'Technical sales engineer'],
#   'id': 613457},
#  {'username': 'hmata',
#   'name': 'Crystal Parks',
#   'sex': 'F',
#   'address': '947 Michael Heights\nBrowntown, WI 08542',
#   'mail': 'ronald80@yahoo.com',
#   'jobs': ['Haematologist',
#    'Insurance claims handler',
#    'Restaurant manager',
#    'Publishing copy',
#    'Network engineer'],
#   'id': 69474},
#  {'username': 'davidsondouglas',
#   'name': 'Jennifer Hicks',
#   'sex': 'F',
#   'address': '101 Dominguez Overpass Apt. 644\nNew Linda, WY 27449',
#   'mail': 'stuartjackson@hotmail.com',
#   'jobs': ['Adult nurse',
#    'Animal nutritionist',
#    'English as a foreign language teacher',
#    'Product/process development scientist',
#    'Publishing copy'],
#   'id': 6357},
#  {'username': 'ocurry',
#   'name': 'Ashley Stout',
#   'sex': 'F',
#   'address': '706 John Mountains\nLake Jennifer, OK 37366',
#   'mail': 'peter52@hotmail.com',
#   'jobs': ['Manufacturing systems engineer',
#    'Orthoptist',
#    'Financial trader',
#    'Clinical cytogeneticist'],
#   'id': 528468},
#  {'username': 'orobles',
#   'name': 'Renee Bennett',
#   'sex': 'F',
#   'address': '5657 Green Corners\nTimothymouth, MO 39130',
#   'mail': 'hillelizabeth@yahoo.com',
#   'jobs': ['Nurse, learning disability',
#    'Chief of Staff',
#    'Financial planner'],
#   'id': 136726},
#  {'username': 'anna17',
#   'name': 'Colleen Scott',
#   'sex': 'F',
#   'address': '0510 Anderson Orchard\nNelsonstad, KY 92537',
#   'mail': 'james20@hotmail.com',
#   'jobs': ['Child psychotherapist', 'Seismic interpreter', 'Retail manager'],
#   'id': 37026},
#  {'username': 'waltonhannah',
#   'name': 'William Bernard',
#   'sex': 'M',
#   'address': 'PSC 2462, Box 5852\nAPO AA 43271',
#   'mail': 'millergail@yahoo.com',
#   'jobs': ['Logistics and distribution manager',
#    'Merchant navy officer',
#    'Microbiologist'],
#   'id': 77146},
#  {'username': 'jamesmckenzie',
#   'name': 'Howard Blankenship',
#   'sex': 'M',
#   'address': 'PSC 1853, Box 6104\nAPO AE 61953',
#   'mail': 'huntsarah@gmail.com',
#   'jobs': ['Professor Emeritus',
#    'Librarian, public',
#    'Learning mentor',
#    'Education officer, community'],
#   'id': 407338},
#  {'username': 'michael28',
#   'name': 'Dr. Charles Jones',
#   'sex': 'M',
#   'address': '03999 Mckinney Stream\nWilliamsland, VT 98324',
#   'mail': 'annachristian@gmail.com',
#   'jobs': ['Fitness centre manager',
#    'Gaffer',
#    'Theatre director',
#    'Music therapist',
#    'Aeronautical engineer'],
#   'id': 83093},
#  {'username': 'christina19',
#   'name': 'Melanie Hess',
#   'sex': 'F',
#   'address': '7650 Megan Forges Apt. 648\nElizabethton, NE 19614',
#   'mail': 'dturner@hotmail.com',
#   'jobs': ['Geologist, wellsite',
#    'Accountant, chartered',
#    'Customer service manager',
#    'Research officer, government'],
#   'id': 153866},
#  {'username': 'helenhall',
#   'name': 'Angela Baker',
#   'sex': 'F',
#   'address': '9489 Gregory Union\nJohnville, DE 39395',
#   'mail': 'nancy36@hotmail.com',
#   'jobs': ['Chemist, analytical',
#    'Television camera operator',
#    'Location manager',
#    'Administrator',
#    'Dealer'],
#   'id': 1562},
#  {'username': 'ryanphillips',
#   'name': 'Miguel Cuevas',
#   'sex': 'M',
#   'address': '471 Pittman Shoals\nPort Eric, NC 43612',
#   'mail': 'richardsseth@hotmail.com',
#   'jobs': ['Surveyor, building',
#    'Broadcast presenter',
#    'Patent attorney',
#    'Engineer, manufacturing',
#    'Nurse, mental health'],
#   'id': 188744},
#  {'username': 'harrissandra',
#   'name': 'Thomas Cisneros',
#   'sex': 'M',
#   'address': '08137 Robert Hollow\nHallfort, ND 02186',
#   'mail': 'amybrown@yahoo.com',
#   'jobs': ['Curator', 'Aid worker', 'Press sub'],
#   'id': 679759},
#  {'username': 'kimberlybrock',
#   'name': 'Tim Parker',
#   'sex': 'M',
#   'address': '40794 Hill Stream\nBryanberg, KS 12602',
#   'mail': 'cassandra35@yahoo.com',
#   'jobs': ['Conservation officer, historic buildings',
#    'Insurance account manager',
#    'Public relations officer'],
#   'id': 1003473},
#  {'username': 'trujilloashley',
#   'name': 'Charles Butler',
#   'sex': 'M',
#   'address': '515 Harrison Lake Apt. 800\nTammyside, NE 99899',
#   'mail': 'leewilliam@yahoo.com',
#   'jobs': ['Teaching laboratory technician',
#    'Air traffic controller',
#    'Designer, exhibition/display',
#    'Professor Emeritus'],
#   'id': 94996},
#  {'username': 'alexanderkelly',
#   'name': 'Lucas Lowe',
#   'sex': 'M',
#   'address': '23908 Angela Ways\nTiffanyview, NY 07087',
#   'mail': 'rebeccamcfarland@yahoo.com',
#   'jobs': ['Occupational hygienist', 'Surgeon', 'Civil engineer, consulting'],
#   'id': 97901},
#  {'username': 'privera',
#   'name': 'Stephanie Noble',
#   'sex': 'F',
#   'address': '6753 Bell Hill\nFlemingchester, MA 29669',
#   'mail': 'jacob65@yahoo.com',
#   'jobs': ['Insurance broker', 'Magazine journalist', 'Chartered accountant'],
#   'id': 516406},
#  {'username': 'nancy12',
#   'name': 'Jesus Thomas',
#   'sex': 'M',
#   'address': '200 Thomas Gateway Suite 323\nDebraland, MI 79080',
#   'mail': 'crichardson@gmail.com',
#   'jobs': ['Counsellor',
#    'Newspaper journalist',
#    'Engineer, site',
#    'Surveyor, rural practice',
#    'Occupational therapist'],
#   'id': 90628},
#  {'username': 'robertrichardson',
#   'name': 'Mary Cooper',
#   'sex': 'F',
#   'address': '75146 Nathan Plaza\nMichaelville, PA 55349',
#   'mail': 'samuel01@gmail.com',
#   'jobs': ['Educational psychologist',
#    'Retail buyer',
#    'Management consultant'],
#   'id': 288146},
#  {'username': 'teresaballard',
#   'name': 'Ronald Ortega',
#   'sex': 'M',
#   'address': '301 Amanda Square Apt. 088\nAnthonyton, MD 57214',
#   'mail': 'meganferguson@hotmail.com',
#   'jobs': ['Mining engineer',
#    'Sports development officer',
#    'Investment banker, corporate',
#    'Journalist, magazine'],
#   'id': 8688},
#  {'username': 'prattjoseph',
#   'name': 'Karen Smith',
#   'sex': 'F',
#   'address': '59347 Stacey Mountain Suite 888\nPort Richard, NM 55056',
#   'mail': 'michelleparker@gmail.com',
#   'jobs': ['Child psychotherapist',
#    'Graphic designer',
#    'Medical sales representative',
#    'Sports administrator'],
#   'id': 61388},
#  {'username': 'stokescheryl',
#   'name': 'Peter Wilson',
#   'sex': 'M',
#   'address': '77204 Salinas Mountain Apt. 045\nKeytown, IA 55371',
#   'mail': 'wendy82@gmail.com',
#   'jobs': ['Engineer, broadcasting (operations)',
#    'Stage manager',
#    'Broadcast journalist',
#    'Development worker, community',
#    'Rural practice surveyor'],
#   'id': 235468},
#  {'username': 'richardwhite',
#   'name': 'Charles Martin',
#   'sex': 'M',
#   'address': '021 Nichole Forge\nSusanstad, CT 70685',
#   'mail': 'hcamacho@hotmail.com',
#   'jobs': ['Cabin crew',
#    'Surveyor, hydrographic',
#    'Customer service manager',
#    'Estate agent'],
#   'id': 898589},
#  {'username': 'mistyzavala',
#   'name': 'Mary Flynn',
#   'sex': 'F',
#   'address': '85359 Taylor Square Apt. 022\nEast Kenneth, HI 15693',
#   'mail': 'kristenreyes@hotmail.com',
#   'jobs': ['Scientist, physiological',
#    'Event organiser',
#    'Public relations officer',
#    'Housing manager/officer'],
#   'id': 4439},
#  {'username': 'marissa26',
#   'name': 'Lisa Lopez',
#   'sex': 'F',
#   'address': '3290 Johnson Island Apt. 180\nEast Suzanneton, OR 42494',
#   'mail': 'kmccullough@hotmail.com',
#   'jobs': ['Sports development officer',
#    'Lawyer',
#    'Chief Operating Officer',
#    'Systems developer',
#    'Dance movement psychotherapist'],
#   'id': 482933},
#  {'username': 'xzamora',
#   'name': 'Henry Alvarez',
#   'sex': 'M',
#   'address': '9866 Henry Mill Apt. 882\nNorth Jonathon, AZ 19201',
#   'mail': 'shanerobinson@yahoo.com',
#   'jobs': ['Engineer, aeronautical',
#    'Exhibition designer',
#    'Brewing technologist'],
#   'id': 10649},
#  {'username': 'jessecowan',
#   'name': 'Margaret Turner',
#   'sex': 'F',
#   'address': '5140 Smith Mountains\nWest Glennstad, WV 56346',
#   'mail': 'johnathansavage@gmail.com',
#   'jobs': ['Television production assistant',
#    'Embryologist, clinical',
#    'Trading standards officer'],
#   'id': 813515},
#  {'username': 'michaelriddle',
#   'name': 'Chloe Wagner',
#   'sex': 'F',
#   'address': '297 Melissa Way\nBlakeshire, TN 16412',
#   'mail': 'maurice76@hotmail.com',
#   'jobs': ['Actuary',
#    'Restaurant manager, fast food',
#    'Market researcher',
#    'Quality manager'],
#   'id': 37779},
#  {'username': 'cassandra63',
#   'name': 'Christopher Byrd',
#   'sex': 'M',
#   'address': '74243 Harris Rue Apt. 569\nRamirezfort, IA 44390',
#   'mail': 'allisonsanchez@gmail.com',
#   'jobs': ['International aid/development worker',
#    "Politician's assistant",
#    'Environmental consultant'],
#   'id': 461834},
#  {'username': 'andrew58',
#   'name': 'Jesse Ortiz',
#   'sex': 'M',
#   'address': '64119 Matthew Pines\nShanefort, NY 31686',
#   'mail': 'andrea91@gmail.com',
#   'jobs': ['Sports therapist',
#    'Engineer, energy',
#    'Biochemist, clinical',
#    'Microbiologist'],
#   'id': 121686},
#  {'username': 'zflores',
#   'name': 'Jessica Watson',
#   'sex': 'F',
#   'address': 'PSC 9514, Box 2974\nAPO AE 57694',
#   'mail': 'mnelson@yahoo.com',
#   'jobs': ['Newspaper journalist', 'Biomedical engineer', 'Sports coach'],
#   'id': 262200},
#  {'username': 'karenhuang',
#   'name': 'Patrick Hawkins',
#   'sex': 'M',
#   'address': '55740 Gutierrez Plains Suite 123\nNew Jeffreyhaven, WA 78759',
#   'mail': 'zsimpson@hotmail.com',
#   'jobs': ['Airline pilot',
#    'Engineer, structural',
#    'Health and safety inspector',
#    'Cytogeneticist'],
#   'id': 20754},
#  {'username': 'johnnystrickland',
#   'name': 'Robert Robinson',
#   'sex': 'M',
#   'address': 'Unit 4104 Box 6047\nDPO AE 77206',
#   'mail': 'renee82@hotmail.com',
#   'jobs': ['Furniture designer',
#    'Paediatric nurse',
#    'Osteopath',
#    'Engineer, civil (consulting)',
#    'Journalist, magazine'],
#   'id': 575052},
#  {'username': 'edward61',
#   'name': 'Jennifer Stewart',
#   'sex': 'F',
#   'address': '73943 Anthony Park Suite 424\nNguyenport, VA 30960',
#   'mail': 'earellano@gmail.com',
#   'jobs': ['Sports therapist', 'Tax inspector', 'Scientist, forensic'],
#   'id': 882465},
#  {'username': 'stacey31',
#   'name': 'Anthony Ramirez',
#   'sex': 'M',
#   'address': '320 Raymond Shoal Suite 059\nHollowayhaven, KY 52769',
#   'mail': 'stephen22@hotmail.com',
#   'jobs': ['Bookseller',
#    'English as a foreign language teacher',
#    'Set designer',
#    'Counsellor',
#    'Meteorologist'],
#   'id': 39547},
#  {'username': 'millervincent',
#   'name': 'Jonathan Callahan',
#   'sex': 'M',
#   'address': '90193 Barnes Cliffs\nFranklinside, GA 25602',
#   'mail': 'andrew10@gmail.com',
#   'jobs': ['Community development worker',
#    'Television camera operator',
#    'Control and instrumentation engineer'],
#   'id': 964093},
#  {'username': 'christine57',
#   'name': 'Angel Williams',
#   'sex': 'F',
#   'address': '581 Garcia Roads Apt. 477\nSouth Holly, RI 91473',
#   'mail': 'marylozano@gmail.com',
#   'jobs': ['Producer, television/film/video',
#    'Broadcast engineer',
#    'Charity officer',
#    'Haematologist',
#    'Historic buildings inspector/conservation officer'],
#   'id': 630984},
#  {'username': 'wdavis',
#   'name': 'April Howard',
#   'sex': 'F',
#   'address': '19892 Tran Course Apt. 775\nLake Karenstad, AK 69688',
#   'mail': 'keithamanda@hotmail.com',
#   'jobs': ['Lighting technician, broadcasting/film/video',
#    'Surveyor, planning and development',
#    'Teaching laboratory technician'],
#   'id': 50509},
#  {'username': 'smithkatherine',
#   'name': 'Alexander Smith',
#   'sex': 'M',
#   'address': '6060 Barry Dale\nChristopherside, OH 92094',
#   'mail': 'laura62@yahoo.com',
#   'jobs': ['Careers adviser',
#    'Careers adviser',
#    'Product manager',
#    'Research scientist (life sciences)',
#    'Designer, multimedia'],
#   'id': 672534},
#  {'username': 'abrown',
#   'name': 'Kimberly Simmons',
#   'sex': 'F',
#   'address': '16634 David Freeway Suite 821\nPort Edward, DE 92982',
#   'mail': 'brandon84@gmail.com',
#   'jobs': ['Licensed conveyancer', 'Archivist', 'Ship broker'],
#   'id': 214991},
#  {'username': 'edwin87',
#   'name': 'Anthony Thompson',
#   'sex': 'M',
#   'address': '8165 Martinez Lodge\nWest Anthonyburgh, TN 18279',
#   'mail': 'mgarcia@gmail.com',
#   'jobs': ['Copywriter, advertising',
#    'Surveyor, commercial/residential',
#    'Hydrogeologist'],
#   'id': 1360982},
#  {'username': 'robert24',
#   'name': 'David Kelley',
#   'sex': 'M',
#   'address': '262 Michelle Streets Apt. 670\nChristinestad, OH 72142',
#   'mail': 'tdoyle@gmail.com',
#   'jobs': ['Risk analyst', 'Hydrographic surveyor', 'Financial controller'],
#   'id': 278639},
#  {'username': 'rhodesmary',
#   'name': 'Jacob Harvey',
#   'sex': 'M',
#   'address': 'PSC 8379, Box 6667\nAPO AA 18327',
#   'mail': 'whiteheadsherry@gmail.com',
#   'jobs': ['Fashion designer',
#    'Cartographer',
#    'Scientist, water quality',
#    'Graphic designer'],
#   'id': 537937},
#  {'username': 'andradecourtney',
#   'name': 'Scott Alvarado',
#   'sex': 'M',
#   'address': '60827 Michael Parkways Suite 266\nBrandonstad, NM 88527',
#   'mail': 'natalietaylor@yahoo.com',
#   'jobs': ['Furniture conservator/restorer',
#    'Public relations account executive',
#    'Research officer, trade union'],
#   'id': 461283},
#  {'username': 'wellsjesse',
#   'name': 'Jamie Tran',
#   'sex': 'F',
#   'address': '3032 Johnson Points\nChristinamouth, NE 78248',
#   'mail': 'johnsonderrick@yahoo.com',
#   'jobs': ['Surveyor, hydrographic',
#    'Museum/gallery curator',
#    'Manufacturing systems engineer',
#    'Print production planner'],
#   'id': 811431},
#  {'username': 'gilljohn',
#   'name': 'Sara Hickman',
#   'sex': 'F',
#   'address': '706 Parker Locks\nLongborough, NE 06076',
#   'mail': 'jacobcrawford@hotmail.com',
#   'jobs': ['Public relations account executive',
#    'Musician',
#    'Insurance account manager'],
#   'id': 932620},
#  {'username': 'tramsey',
#   'name': 'Candace Wong',
#   'sex': 'F',
#   'address': '8207 Hunt Fall\nPort Gregory, TN 78905',
#   'mail': 'hodgecrystal@gmail.com',
#   'jobs': ['Child psychotherapist',
#    'Education officer, museum',
#    'Psychologist, prison and probation services',
#    'Commercial art gallery manager'],
#   'id': 10113},
#  {'username': 'rstanley',
#   'name': 'Sandra Hill',
#   'sex': 'F',
#   'address': '6652 Roy Way Suite 642\nEast Sheilaville, OR 50681',
#   'mail': 'jeremy89@gmail.com',
#   'jobs': ['Energy manager',
#    'Building control surveyor',
#    'Games developer',
#    'IT trainer',
#    'Rural practice surveyor'],
#   'id': 428885},
#  {'username': 'ievans',
#   'name': 'Ethan Morales',
#   'sex': 'M',
#   'address': '9300 Phillips Way Apt. 948\nNew Aliceburgh, GA 70575',
#   'mail': 'markmarks@yahoo.com',
#   'jobs': ['Counselling psychologist',
#    'Surveyor, commercial/residential',
#    'Event organiser',
#    'Logistics and distribution manager',
#    'Museum/gallery conservator'],
#   'id': 1329782},
#  {'username': 'rickyvaughn',
#   'name': 'Nicole Johnston',
#   'sex': 'F',
#   'address': '137 Cisneros Path Apt. 601\nChaneyland, NJ 95831',
#   'mail': 'whunter@hotmail.com',
#   'jobs': ['Environmental manager',
#    'Marketing executive',
#    'Production designer, theatre/television/film',
#    'Translator'],
#   'id': 80353},
#  {'username': 'bakerlisa',
#   'name': 'Walter Wallace',
#   'sex': 'M',
#   'address': '3319 Craig Bridge\nWest Courtney, ME 20802',
#   'mail': 'allisonheather@hotmail.com',
#   'jobs': ['Chief Financial Officer',
#    'Claims inspector/assessor',
#    'Radio broadcast assistant'],
#   'id': 1891},
#  {'username': 'walkerpaul',
#   'name': 'Matthew Hinton',
#   'sex': 'M',
#   'address': '562 Carter Road Apt. 110\nWest Michaelview, KY 87911',
#   'mail': 'amygraham@yahoo.com',
#   'jobs': ['Insurance risk surveyor',
#    'Seismic interpreter',
#    'Secretary/administrator',
#    'Magazine journalist'],
#   'id': 242729},
#  {'username': 'amorales',
#   'name': 'Matthew Shepherd',
#   'sex': 'M',
#   'address': '928 Kimberly Rapids\nWilliamstad, ME 98726',
#   'mail': 'scottbrown@gmail.com',
#   'jobs': ['Curator',
#    'Government social research officer',
#    'Special educational needs teacher',
#    'Horticultural consultant',
#    'Biochemist, clinical'],
#   'id': 2549237},
#  {'username': 'harrismegan',
#   'name': 'Teresa Torres',
#   'sex': 'F',
#   'address': '4083 Smith Gateway Suite 857\nNorth Michaelville, FL 47530',
#   'mail': 'devonlloyd@hotmail.com',
#   'jobs': ['Copywriter, advertising',
#    'Scientist, audiological',
#    'Administrator, arts',
#    'Legal secretary'],
#   'id': 262129},
#  {'username': 'edwardsaustin',
#   'name': 'Gregory Huffman',
#   'sex': 'M',
#   'address': '54989 Madeline Mill Suite 534\nNorth Rebecca, MO 71519',
#   'mail': 'andrewrowland@gmail.com',
#   'jobs': ['Aid worker',
#    'Chemist, analytical',
#    'Corporate treasurer',
#    'Charity officer',
#    'Ship broker'],
#   'id': 567959},
#  {'username': 'nicholas86',
#   'name': 'Amber Jacobs',
#   'sex': 'F',
#   'address': '147 Little Spur\nJordanfurt, UT 51171',
#   'mail': 'brucethomas@yahoo.com',
#   'jobs': ['Occupational psychologist',
#    'Legal executive',
#    'Therapist, drama',
#    'Insurance risk surveyor',
#    'Investment banker, operational'],
#   'id': 47858},
#  {'username': 'ortizsteven',
#   'name': 'Brittney Lee',
#   'sex': 'F',
#   'address': '05048 Young Key Apt. 245\nWest Heidimouth, AK 81874',
#   'mail': 'tgarcia@yahoo.com',
#   'jobs': ['Advertising account planner',
#    'Nurse, mental health',
#    'Higher education careers adviser',
#    'Marketing executive'],
#   'id': 465056},
#  {'username': 'miguelwolf',
#   'name': 'Sharon Walsh',
#   'sex': 'F',
#   'address': '559 Jeremiah Mills Apt. 488\nKnighttown, NM 07761',
#   'mail': 'vanessa10@hotmail.com',
#   'jobs': ['Scientist, product/process development',
#    'Housing manager/officer',
#    'Audiological scientist',
#    'Government social research officer'],
#   'id': 144205},
#  {'username': 'penningtonalicia',
#   'name': 'Vicki Short',
#   'sex': 'F',
#   'address': '05267 Miles Mall Apt. 769\nVictoriamouth, DC 17554',
#   'mail': 'timothy26@hotmail.com',
#   'jobs': ['Risk analyst',
#    'Diagnostic radiographer',
#    'Scientific laboratory technician',
#    'Psychotherapist, dance movement',
#    'Teacher, special educational needs'],
#   'id': 213139},
#  {'username': 'douglas33',
#   'name': 'Theresa Wilson',
#   'sex': 'F',
#   'address': 'PSC 7664, Box 1154\nAPO AA 24551',
#   'mail': 'salazarwilliam@yahoo.com',
#   'jobs': ['Clinical psychologist',
#    'Engineer, petroleum',
#    'Lexicographer',
#    'Psychologist, counselling',
#    'Accountant, chartered'],
#   'id': 177443},
#  {'username': 'cmolina',
#   'name': 'Travis Wallace',
#   'sex': 'M',
#   'address': '6205 Brandy Unions Apt. 432\nMichaelberg, NJ 91136',
#   'mail': 'reginarobinson@gmail.com',
#   'jobs': ['Proofreader',
#    'Clinical scientist, histocompatibility and immunogenetics',
#    'Network engineer'],
#   'id': 2200921},
#  {'username': 'huntterri',
#   'name': 'Austin Ward',
#   'sex': 'M',
#   'address': '53485 Robert Parks\nWademouth, WI 12513',
#   'mail': 'jdavis@hotmail.com',
#   'jobs': ['Psychotherapist',
#    'Horticultural therapist',
#    'Animal technologist',
#    'Psychotherapist',
#    'Insurance risk surveyor'],
#   'id': 437294},
#  {'username': 'toconnor',
#   'name': 'Travis Martin',
#   'sex': 'M',
#   'address': '096 Murphy Locks Apt. 192\nNorth Louis, VA 55432',
#   'mail': 'hunterjacob@gmail.com',
#   'jobs': ['Company secretary',
#    'Retail banker',
#    'Animal nutritionist',
#    'Senior tax professional/tax inspector',
#    'Producer, radio'],
#   'id': 143318},
#  {'username': 'tanderson',
#   'name': 'Sarah Stevenson',
#   'sex': 'F',
#   'address': '8790 Powell Mission\nDeniseburgh, CO 82821',
#   'mail': 'sheltonstacey@hotmail.com',
#   'jobs': ['Retail merchandiser',
#    'Psychiatric nurse',
#    'Learning disability nurse',
#    'Designer, graphic',
#    'Tourism officer'],
#   'id': 116740},
#  {'username': 'sawyerjames',
#   'name': 'Kendra Cook',
#   'sex': 'F',
#   'address': '4652 Rodriguez Courts\nSouth Robert, OK 57460',
#   'mail': 'uanderson@yahoo.com',
#   'jobs': ['Scientist, physiological',
#    "Barrister's clerk",
#    'Education officer, museum'],
#   'id': 323731},
#  {'username': 'hensleybrittney',
#   'name': 'Robin Lambert',
#   'sex': 'F',
#   'address': '21418 Wallace Inlet Suite 018\nPort Calvinland, OH 99864',
#   'mail': 'fwoods@hotmail.com',
#   'jobs': ['Research officer, political party',
#    'Heritage manager',
#    'Engineer, manufacturing'],
#   'id': 804550},
#  {'username': 'beankatelyn',
#   'name': 'Anne Miller',
#   'sex': 'F',
#   'address': '412 Reid Lakes\nPort Jerome, ME 55491',
#   'mail': 'clarkkirsten@yahoo.com',
#   'jobs': ['Conservation officer, historic buildings',
#    'Consulting civil engineer',
#    'Conservator, furniture',
#    'Software engineer',
#    'Nurse, adult'],
#   'id': 125356},
#  {'username': 'barbaramacias',
#   'name': 'Julia Flores',
#   'sex': 'F',
#   'address': 'PSC 7729, Box 9222\nAPO AE 75822',
#   'mail': 'jimmygeorge@yahoo.com',
#   'jobs': ['Dietitian',
#    'Outdoor activities/education manager',
#    'Clothing/textile technologist',
#    'Industrial buyer'],
#   'id': 865936},
#  {'username': 'qwade',
#   'name': 'Caitlin Benton',
#   'sex': 'F',
#   'address': '355 William Underpass\nNew Crystalview, WA 80512',
#   'mail': 'lauren72@yahoo.com',
#   'jobs': ['Location manager',
#    'Newspaper journalist',
#    'Surveyor, rural practice',
#    'Outdoor activities/education manager'],
#   'id': 440869},
#  {'username': 'raymond30',
#   'name': 'Lynn Diaz MD',
#   'sex': 'F',
#   'address': '62592 Todd Groves Apt. 433\nWest Grace, NJ 78278',
#   'mail': 'awilliams@yahoo.com',
#   'jobs': ['Exhibition designer',
#    'Fashion designer',
#    'Health physicist',
#    'Proofreader',
#    'Programmer, multimedia'],
#   'id': 464080},
#  {'username': 'btownsend',
#   'name': 'Robert Mcconnell',
#   'sex': 'M',
#   'address': '1397 Perez Corner\nNew Brandishire, AZ 28855',
#   'mail': 'cwilkerson@hotmail.com',
#   'jobs': ['Producer, radio',
#    'Secondary school teacher',
#    'Operations geologist'],
#   'id': 52282},
#  {'username': 'dmoore',
#   'name': 'Diana Martin',
#   'sex': 'F',
#   'address': '67428 Timothy Path\nPort Mary, MN 59354',
#   'mail': 'kyle80@hotmail.com',
#   'jobs': ['Scientist, research (medical)',
#    'Conservator, museum/gallery',
#    'Occupational hygienist'],
#   'id': 335718},
#  {'username': 'kelsey73',
#   'name': 'Robert Brown',
#   'sex': 'M',
#   'address': '069 Rivera Mall Suite 975\nCopelandfurt, CT 71574',
#   'mail': 'rcook@yahoo.com',
#   'jobs': ['Health service manager',
#    'Garment/textile technologist',
#    'Engineer, biomedical',
#    'Agricultural engineer',
#    'Soil scientist'],
#   'id': 311003},
#  {'username': 'shawnrobinson',
#   'name': 'Jennifer Myers',
#   'sex': 'F',
#   'address': '4169 Anna Fall Apt. 611\nPhillipsmouth, AK 32472',
#   'mail': 'brittany57@yahoo.com',
#   'jobs': ['Merchandiser, retail', 'Clinical cytogeneticist', 'Advice worker'],
#   'id': 542159},
#  {'username': 'angelasmith',
#   'name': 'Lisa Yoder',
#   'sex': 'F',
#   'address': '938 Amber Tunnel Suite 546\nAngelachester, TX 20390',
#   'mail': 'charris@yahoo.com',
#   'jobs': ['Engineer, electronics',
#    'Secondary school teacher',
#    'Transport planner',
#    'Secretary, company',
#    'Maintenance engineer'],
#   'id': 730126},
#  {'username': 'wilsonjonathan',
#   'name': 'Christopher Anderson',
#   'sex': 'M',
#   'address': '62887 White Ferry\nJordanstad, MN 65726',
#   'mail': 'hallkeith@hotmail.com',
#   'jobs': ['Scientific laboratory technician',
#    'Agricultural engineer',
#    'Advice worker',
#    'Geologist, wellsite',
#    'Wellsite geologist'],
#   'id': 124614},
#  {'username': 'pbaird',
#   'name': 'Kevin Schwartz',
#   'sex': 'M',
#   'address': '5423 Johnson Squares Apt. 927\nNicoletown, ME 73397',
#   'mail': 'carolyn77@gmail.com',
#   'jobs': ['Conference centre manager',
#    'Nutritional therapist',
#    'Fast food restaurant manager',
#    'Warehouse manager'],
#   'id': 48263},
#  {'username': 'moraleshayley',
#   'name': 'Michael Graham',
#   'sex': 'M',
#   'address': '09936 Sabrina Centers\nWest Brianhaven, OK 80507',
#   'mail': 'heidi60@gmail.com',
#   'jobs': ['Copywriter, advertising',
#    'Management consultant',
#    'Equality and diversity officer',
#    'Public house manager',
#    'Designer, graphic'],
#   'id': 505183},
#  {'username': 'staceynguyen',
#   'name': 'Terry Hunt',
#   'sex': 'M',
#   'address': 'Unit 3162 Box 2350\nDPO AP 79305',
#   'mail': 'wdavis@gmail.com',
#   'jobs': ['Scientist, marine',
#    'Therapist, horticultural',
#    'Engineer, structural',
#    'Merchant navy officer',
#    'Commissioning editor'],
#   'id': 321078},
#  {'username': 'martincrystal',
#   'name': 'Andre Gilbert',
#   'sex': 'M',
#   'address': '822 Lopez Plain\nWest Kelly, WV 13180',
#   'mail': 'andrewsingh@hotmail.com',
#   'jobs': ['Clinical research associate',
#    'Immunologist',
#    'Personnel officer',
#    'Bonds trader',
#    'Chiropractor'],
#   'id': 1108700},
#  {'username': 'dmartinez',
#   'name': 'Sergio Stewart',
#   'sex': 'M',
#   'address': '2676 Brian Pines Apt. 514\nNorth Amanda, AZ 53317',
#   'mail': 'mharris@gmail.com',
#   'jobs': ['Information systems manager',
#    'Location manager',
#    'Artist',
#    'Medical secretary',
#    'Media buyer'],
#   'id': 422893},
#  {'username': 'kreynolds',
#   'name': 'Maria Williamson',
#   'sex': 'F',
#   'address': '574 Rhonda Lodge Apt. 382\nAnthonyside, ME 08310',
#   'mail': 'murraymichael@gmail.com',
#   'jobs': ['Health physicist',
#    'Engineer, chemical',
#    'Public affairs consultant',
#    'Civil engineer, consulting'],
#   'id': 121690},
#  {'username': 'lindawhite',
#   'name': 'Eric Novak',
#   'sex': 'M',
#   'address': '56090 Julie Inlet Suite 641\nWest Leslie, AL 46584',
#   'mail': 'jonestroy@yahoo.com',
#   'jobs': ['Retail buyer',
#    'Graphic designer',
#    'Engineer, biomedical',
#    'Administrator, charities/voluntary organisations'],
#   'id': 283251},
#  {'username': 'danielamanda',
#   'name': 'Jessica Gutierrez',
#   'sex': 'F',
#   'address': 'USNS Alexander\nFPO AE 29331',
#   'mail': 'rhonda90@gmail.com',
#   'jobs': ['Armed forces operational officer',
#    'Clinical molecular geneticist',
#    'Best boy',
#    'Geographical information systems officer',
#    'Insurance risk surveyor'],
#   'id': 515278},
#  {'username': 'walterwilliams',
#   'name': 'Carrie Mccall',
#   'sex': 'F',
#   'address': '097 Christina Course Apt. 518\nThompsonburgh, LA 83538',
#   'mail': 'lisa82@yahoo.com',
#   'jobs': ['Consulting civil engineer',
#    'Production designer, theatre/television/film',
#    'Learning mentor'],
#   'id': 211184},
#  {'username': 'frankerin',
#   'name': 'Christopher Perez',
#   'sex': 'M',
#   'address': '95310 David Spring\nAllenmouth, NJ 81978',
#   'mail': 'stephenssusan@gmail.com',
#   'jobs': ['Ophthalmologist',
#    'Administrator, sports',
#    'Clinical cytogeneticist',
#    'Counselling psychologist'],
#   'id': 526666},
#  {'username': 'william18',
#   'name': 'Troy Barker',
#   'sex': 'M',
#   'address': '139 Lindsay Lock Apt. 967\nSharonberg, CA 47097',
#   'mail': 'matthew87@yahoo.com',
#   'jobs': ['Pathologist', 'Chief of Staff', 'Engineering geologist'],
#   'id': 386585},
#  {'username': 'perezmichael',
#   'name': 'Cynthia Grant',
#   'sex': 'F',
#   'address': '44772 Kara Inlet Suite 000\nWhitakerborough, DE 79229',
#   'mail': 'epaul@gmail.com',
#   'jobs': ['Tour manager',
#    'Air cabin crew',
#    'Retail banker',
#    'Further education lecturer'],
#   'id': 356062},
#  {'username': 'christopherdyer',
#   'name': 'Mary Hubbard',
#   'sex': 'F',
#   'address': '157 Jennifer Trail Suite 955\nWest Victoria, MI 04238',
#   'mail': 'ritterclaire@yahoo.com',
#   'jobs': ['Claims inspector/assessor', 'Minerals surveyor', 'Firefighter'],
#   'id': 327115},
#  {'username': 'hlee',
#   'name': 'Wanda Bradley',
#   'sex': 'F',
#   'address': '519 Lane Bridge\nEast William, HI 23530',
#   'mail': 'markpark@yahoo.com',
#   'jobs': ['Actuary',
#    'Surveyor, rural practice',
#    'Education officer, museum',
#    'Buyer, retail'],
#   'id': 171790},
#  {'username': 'barbara76',
#   'name': 'Jacqueline Hunter',
#   'sex': 'F',
#   'address': '3796 Carson Mews Apt. 928\nWarnerfurt, OK 50490',
#   'mail': 'ltyler@gmail.com',
#   'jobs': ['Warehouse manager',
#    'Information officer',
#    'Chief Operating Officer'],
#   'id': 247473},
#  {'username': 'gabriel80',
#   'name': 'Susan Conner',
#   'sex': 'F',
#   'address': '21575 Catherine Centers Suite 892\nVincenthaven, DE 21289',
#   'mail': 'kevinpetersen@gmail.com',
#   'jobs': ['Research scientist (life sciences)',
#    'Physiological scientist',
#    'Historic buildings inspector/conservation officer'],
#   'id': 145352},
#  {'username': 'qaustin',
#   'name': 'Julie Wagner',
#   'sex': 'F',
#   'address': '7075 Reynolds Port\nJoseside, NY 92892',
#   'mail': 'cruzolivia@yahoo.com',
#   'jobs': ['Video editor',
#    'Building control surveyor',
#    'Scientist, research (medical)',
#    'Minerals surveyor',
#    'Chief Marketing Officer'],
#   'id': 573325},
#  {'username': 'amygray',
#   'name': 'Mark Gregory',
#   'sex': 'M',
#   'address': '88099 Yolanda Highway Suite 090\nCookborough, MN 37304',
#   'mail': 'cheryl35@gmail.com',
#   'jobs': ['Legal executive',
#    'Secondary school teacher',
#    'Engineering geologist',
#    'Human resources officer'],
#   'id': 222139},
#  {'username': 'evanswanson',
#   'name': 'Taylor Fisher',
#   'sex': 'F',
#   'address': '2904 Johnson Summit\nNew Brianaside, NY 18948',
#   'mail': 'jessicawilson@hotmail.com',
#   'jobs': ['Biochemist, clinical',
#    'Air broker',
#    'Investment banker, corporate'],
#   'id': 1925885},
#  {'username': 'katherine59',
#   'name': 'Kenneth Burns',
#   'sex': 'M',
#   'address': '944 Woodard Plaza Apt. 360\nPort Amandaton, SD 67613',
#   'mail': 'pstevens@hotmail.com',
#   'jobs': ['Therapist, drama',
#    'Psychotherapist, child',
#    'Television production assistant'],
#   'id': 1364641},
#  {'username': 'bridgetjones',
#   'name': 'David Mccarty',
#   'sex': 'M',
#   'address': '142 Jessica Ports Suite 519\nEast Josephburgh, NH 28541',
#   'mail': 'barbaraparker@hotmail.com',
#   'jobs': ['Theatre stage manager',
#    'Engineering geologist',
#    'Embryologist, clinical'],
#   'id': 121684},
#  {'username': 'amanda04',
#   'name': 'Elizabeth Wolfe',
#   'sex': 'F',
#   'address': 'USS Banks\nFPO AE 64420',
#   'mail': 'leachrachael@hotmail.com',
#   'jobs': ['Surveyor, building', 'Mining engineer', 'Mudlogger'],
#   'id': 292175},
#  {'username': 'williamsdawn',
#   'name': 'Tammy Rodriguez',
#   'sex': 'F',
#   'address': '9675 Lawrence Heights\nNorth Patrickburgh, MS 11282',
#   'mail': 'ewebb@yahoo.com',
#   'jobs': ['Retail merchandiser',
#    'Civil Service fast streamer',
#    'Youth worker',
#    'IT trainer'],
#   'id': 685866},
#  {'username': 'rhood',
#   'name': 'Denise Brown',
#   'sex': 'F',
#   'address': '2344 Randall Mews\nRobinland, WI 07389',
#   'mail': 'fmitchell@hotmail.com',
#   'jobs': ['Editor, film/video', 'Arboriculturist', 'Statistician'],
#   'id': 64780},
#  {'username': 'michael68',
#   'name': 'Michael Figueroa',
#   'sex': 'M',
#   'address': '48891 Anthony Dale\nPort Jeff, MN 54280',
#   'mail': 'alicia11@hotmail.com',
#   'jobs': ['Chartered management accountant',
#    'Video editor',
#    'Engineer, electronics',
#    'Engineer, maintenance'],
#   'id': 47510},
#  {'username': 'rosssusan',
# ...
#   'id': 97825},
#  {'username': 'hornsherry',
#   'name': 'Mr. Bryan Freeman',
#   'sex': 'M',
#   'address': '9125 Craig Dam\nWest Stevenside, ID 18249',
#   'mail': 'aaronwagner@yahoo.com',
#   'jobs': ['Forensic scientist',
#    'Sales executive',
#    'Chartered legal executive (England and Wales)',
#    'Engineer, production',
#    'Financial risk analyst'],
#   'id': 204116},
#  {'username': 'stewartmichael',
#   'name': 'Thomas Conway',
#   'sex': 'M',
#   'address': '4582 Steele Radial Apt. 107\nAntoniofort, OR 08464',
#   'mail': 'earias@hotmail.com',
#   'jobs': ['Local government officer',
#    'Visual merchandiser',
#    'Clinical cytogeneticist',
#    'Midwife'],
#   'id': 28460},
#  {'username': 'shannonmiller',
#   'name': 'Charles Hill',
#   'sex': 'M',
#   'address': '27932 Cameron Meadow Suite 830\nLake Michaelborough, MD 02004',
#   'mail': 'yharris@gmail.com',
#   'jobs': ['Horticultural consultant',
#    'Historic buildings inspector/conservation officer',
#    'Agricultural consultant'],
#   'id': 956207},
#  {'username': 'nashwilliam',
#   'name': 'Richard Perkins',
#   'sex': 'M',
#   'address': '1017 Jimmy Inlet Suite 225\nGonzalesfort, DC 75744',
#   'mail': 'csmith@hotmail.com',
#   'jobs': ['Production engineer',
#    'Social worker',
#    'Records manager',
#    'Bonds trader',
#    'Engineer, maintenance (IT)'],
#   'id': 1271506},
#  {'username': 'wendy88',
#   'name': 'Rachel Moore',
#   'sex': 'F',
#   'address': '12875 Powell Rest\nEast John, NM 96032',
#   'mail': 'mclaughlinkathryn@yahoo.com',
#   'jobs': ['Tourist information centre manager',
#    'Physicist, medical',
#    'Glass blower/designer'],
#   'id': 55392},
#  {'username': 'vazquezmitchell',
#   'name': 'Daniel Jacobs',
#   'sex': 'M',
#   'address': 'PSC 3016, Box 1659\nAPO AA 81027',
#   'mail': 'erika73@gmail.com',
#   'jobs': ['Senior tax professional/tax inspector',
#    'Teacher, primary school',
#    'Careers adviser',
#    'Trade mark attorney',
#    'Programmer, multimedia'],
#   'id': 164368},
#  {'username': 'simmonslisa',
#   'name': 'Stephen Gonzales',
#   'sex': 'M',
#   'address': '92960 Carter Ford Apt. 028\nLynnfurt, ID 50908',
#   'mail': 'christina55@gmail.com',
#   'jobs': ['Site engineer',
#    'Geographical information systems officer',
#    'Health visitor'],
#   'id': 255057},
#  {'username': 'joshua29',
#   'name': 'James Hernandez',
#   'sex': 'M',
#   'address': '822 Stephenson Creek Suite 112\nJeffreyside, TN 00698',
#   'mail': 'kellie32@gmail.com',
#   'jobs': ['Medical technical officer',
#    'Teacher, English as a foreign language',
#    'Community development worker'],
#   'id': 832773},
#  {'username': 'daniellemcguire',
#   'name': 'Laurie Johnson',
#   'sex': 'F',
#   'address': '05197 Hartman Loop\nAmyville, ME 69883',
#   'mail': 'kevin47@yahoo.com',
#   'jobs': ['Set designer',
#    'Therapist, sports',
#    'Economist',
#    'Theatre stage manager'],
#   'id': 29229},
#  {'username': 'walkerjulie',
#   'name': 'Jeremy Cortez',
#   'sex': 'M',
#   'address': 'USS Burns\nFPO AE 66947',
#   'mail': 'meghanparker@yahoo.com',
#   'jobs': ['Manufacturing engineer',
#    'Engineer, civil (consulting)',
#    'Psychologist, clinical',
#    'Surveyor, hydrographic',
#    'Video editor'],
#   'id': 382464},
#  {'username': 'amorrison',
#   'name': 'Lauren Ramirez',
#   'sex': 'F',
#   'address': '21206 Brian Gardens Suite 254\nEast Kennethside, NV 18092',
#   'mail': 'jacksonlarry@yahoo.com',
#   'jobs': ['Office manager',
#    'Pharmacist, community',
#    'Chiropodist',
#    'Speech and language therapist'],
#   'id': 335614},
#  {'username': 'juanhall',
#   'name': 'Lorraine Martinez',
#   'sex': 'F',
#   'address': '70904 Gonzalez Rue\nScottmouth, DE 96694',
#   'mail': 'mmontoya@hotmail.com',
#   'jobs': ['Private music teacher',
#    'Field trials officer',
#    'Engineer, water',
#    'Film/video editor'],
#   'id': 391008},
#  {'username': 'danielle79',
#   'name': 'Alex Medina',
#   'sex': 'M',
#   'address': '46558 Adams Light\nGomezport, NC 96906',
#   'mail': 'schmidtcarolyn@hotmail.com',
#   'jobs': ['English as a second language teacher',
#    'Surveyor, hydrographic',
#    'Surveyor, building control',
#    'Sports therapist',
#    'Manufacturing systems engineer'],
#   'id': 65573},
#  {'username': 'jamiegreen',
#   'name': 'Amber Rivera',
#   'sex': 'F',
#   'address': '734 Welch Bypass\nNew James, NH 31687',
#   'mail': 'barnettjimmy@yahoo.com',
#   'jobs': ['Operational investment banker',
#    'Psychologist, prison and probation services',
#    'Nurse, learning disability',
#    'Psychotherapist, dance movement'],
#   'id': 121786},
#  {'username': 'feliciadominguez',
#   'name': 'Kathryn Deleon',
#   'sex': 'F',
#   'address': '8996 Sanders Drive Apt. 625\nEast Savannahshire, OK 05047',
#   'mail': 'scottchristopher@gmail.com',
#   'jobs': ['Therapist, sports',
#    'Designer, graphic',
#    'Advice worker',
#    'Energy manager',
#    'Secretary/administrator'],
#   'id': 90611},
#  {'username': 'nlee',
#   'name': 'Gail Caldwell',
#   'sex': 'F',
#   'address': '9878 David Highway Apt. 456\nNicolefurt, ID 03190',
#   'mail': 'udennis@gmail.com',
#   'jobs': ['Engineer, maintenance (IT)',
#    'Health service manager',
#    'Conservator, museum/gallery'],
#   'id': 111911},
#  {'username': 'jwilcox',
#   'name': 'Kristi Garcia',
#   'sex': 'F',
#   'address': '06752 Williams Drive\nNorth Julieville, AR 05337',
#   'mail': 'johnsonmichael@yahoo.com',
#   'jobs': ['Tax inspector',
#    'Corporate investment banker',
#    'Administrator, sports'],
#   'id': 196198},
#  {'username': 'walterreynolds',
#   'name': 'Martin Long',
#   'sex': 'M',
#   'address': '801 Matthew Mall Suite 732\nMarkhaven, CT 59330',
#   'mail': 'latoya35@yahoo.com',
#   'jobs': ['Site engineer',
#    'Sport and exercise psychologist',
#    'Research officer, trade union'],
#   'id': 69927},
#  {'username': 'bradley58',
#   'name': 'Laura Cline',
#   'sex': 'F',
#   'address': '370 Ashley Alley\nBarbarashire, RI 46983',
#   'mail': 'antoniowebb@yahoo.com',
#   'jobs': ['Therapist, horticultural',
#    'Development worker, community',
#    'Solicitor, Scotland',
#    'Pilot, airline'],
#   'id': 282737},
#  {'username': 'kgallegos',
#   'name': 'Mark Johnson',
#   'sex': 'M',
#   'address': '2606 Christina Wells\nMichaelshire, IN 30625',
#   'mail': 'uharrell@hotmail.com',
#   'jobs': ['Trade mark attorney',
#    'Pathologist',
#    'Higher education lecturer',
#    'Fashion designer',
#    'Teacher, secondary school'],
#   'id': 416409},
#  {'username': 'sharontucker',
#   'name': 'Anthony Matthews',
#   'sex': 'M',
#   'address': '303 Fuentes Lights Suite 838\nHarrisfurt, NM 70169',
#   'mail': 'lisasmith@hotmail.com',
#   'jobs': ['Chemist, analytical', 'Designer, television/film set', 'Actuary'],
#   'id': 221851},
#  {'username': 'fhall',
#   'name': 'Jasmine Byrd',
#   'sex': 'F',
#   'address': '0733 Lee Meadows Suite 916\nBriannaborough, NH 11902',
#   'mail': 'buckleykyle@hotmail.com',
#   'jobs': ['Research scientist (physical sciences)',
#    'Education officer, community',
#    'Product/process development scientist'],
#   'id': 86947},
#  {'username': 'victoriazamora',
#   'name': 'Brendan Leblanc',
#   'sex': 'M',
#   'address': 'Unit 1426 Box 3643\nDPO AP 35115',
#   'mail': 'rhopkins@hotmail.com',
#   'jobs': ['Sports administrator', 'Quarry manager', 'Psychologist, forensic'],
#   'id': 34280},
#  {'username': 'travis57',
#   'name': 'Angela Sandoval',
#   'sex': 'F',
#   'address': '2122 Webb Summit\nRichberg, KS 30110',
#   'mail': 'laura07@gmail.com',
#   'jobs': ['Textile designer',
#    'Insurance claims handler',
#    'Community arts worker',
#    'Theatre stage manager',
#    'Research scientist (life sciences)'],
#   'id': 438558},
#  {'username': 'mlopez',
#   'name': 'Melanie Torres',
#   'sex': 'F',
#   'address': '338 Alan Ferry\nWest Kimberlyland, AK 53455',
#   'mail': 'hchaney@hotmail.com',
#   'jobs': ['Software engineer',
#    'Occupational hygienist',
#    'Engineer, chemical'],
#   'id': 481494},
#  {'username': 'snyderandrew',
#   'name': 'Julie Murphy',
#   'sex': 'F',
#   'address': '804 Herrera Via\nEast James, NM 89957',
#   'mail': 'gibsonalyssa@gmail.com',
#   'jobs': ['Therapist, occupational',
#    'Chiropodist',
#    'Scientist, biomedical',
#    'Engineer, mining',
#    'Network engineer'],
#   'id': 63128},
#  {'username': 'colleendean',
#   'name': 'Sharon Lin',
#   'sex': 'F',
#   'address': '98571 White Manor\nReneeburgh, OK 86887',
#   'mail': 'jefferybell@yahoo.com',
#   'jobs': ['Event organiser',
#    'Medical illustrator',
#    'Surveyor, building control'],
#   'id': 511821},
#  {'username': 'coleandrea',
#   'name': 'Andrea Vasquez',
#   'sex': 'F',
#   'address': '291 Donna Fords\nNew Stacy, KS 03407',
#   'mail': 'annvaughn@gmail.com',
#   'jobs': ['Occupational psychologist',
#    'Development worker, international aid',
#    'Accountant, chartered certified'],
#   'id': 15572},
#  {'username': 'desiree85',
#   'name': 'Joseph Wade',
#   'sex': 'M',
#   'address': 'Unit 5375 Box 7243\nDPO AP 27470',
#   'mail': 'ojohnson@gmail.com',
#   'jobs': ['Public librarian',
#    'Therapist, speech and language',
#    'Surveyor, building'],
#   'id': 1123793},
#  {'username': 'ocollier',
#   'name': 'Joan Bailey',
#   'sex': 'F',
#   'address': 'USS Mercado\nFPO AE 61628',
#   'mail': 'jeff06@hotmail.com',
#   'jobs': ['Research officer, government',
#    'Equality and diversity officer',
#    'Surveyor, quantity',
#    'Futures trader'],
#   'id': 1687037},
#  {'username': 'buckleyrebecca',
#   'name': 'Katherine Dean',
#   'sex': 'F',
#   'address': 'USS Lowe\nFPO AA 29825',
#   'mail': 'suzannerussell@gmail.com',
#   'jobs': ['Nature conservation officer',
#    'Film/video editor',
#    'Ambulance person'],
#   'id': 235751},
#  {'username': 'peter97',
#   'name': 'Daniel Rodriguez',
#   'sex': 'M',
#   'address': '61242 Boyer Hill\nPort Robert, SC 02062',
#   'mail': 'amiller@gmail.com',
#   'jobs': ['Equality and diversity officer',
#    'Commercial/residential surveyor',
#    'Medical secretary',
#    'Probation officer'],
#   'id': 251499},
#  {'username': 'tsalas',
#   'name': 'Luke Hood',
#   'sex': 'M',
#   'address': '93027 Moore Vista\nNew Kaylaland, WY 76111',
#   'mail': 'claire15@gmail.com',
#   'jobs': ['Market researcher',
#    'Curator',
#    'Engineer, biomedical',
#    'Engineer, communications'],
#   'id': 168896},
#  {'username': 'stephaniesnyder',
#   'name': 'Jasmine Campbell',
#   'sex': 'F',
#   'address': '50923 Madeline Brook Suite 349\nWest Samanthafort, MO 05061',
#   'mail': 'carterjoseph@hotmail.com',
#   'jobs': ['Administrator, education',
#    'Careers information officer',
#    'Engineer, drilling'],
#   'id': 790231},
#  {'username': 'michelle21',
#   'name': 'Shawn Hale',
#   'sex': 'M',
#   'address': '87173 Brent Junctions Apt. 643\nWest Jacob, SC 24140',
#   'mail': 'dsanchez@hotmail.com',
#   'jobs': ['Aid worker',
#    'Operational investment banker',
#    'Accounting technician',
#    'Hotel manager',
#    'Nutritional therapist'],
#   'id': 192581},
#  {'username': 'jesus56',
#   'name': 'Jason White',
#   'sex': 'M',
#   'address': '37540 Nicholson Summit\nNew Brittany, NJ 17338',
#   'mail': 'zachary18@yahoo.com',
#   'jobs': ['Data processing manager',
#    'Research scientist (life sciences)',
#    'Best boy',
#    'Learning disability nurse'],
#   'id': 51664},
#  {'username': 'oliveraaron',
#   'name': 'Melissa Brown',
#   'sex': 'F',
#   'address': '412 Bird Spurs\nMichaelside, CA 10173',
#   'mail': 'amanda92@gmail.com',
#   'jobs': ['Water quality scientist',
#    'Financial risk analyst',
#    'Engineer, production'],
#   'id': 1129847},
#  {'username': 'vtaylor',
#   'name': 'Tara Kelly',
#   'sex': 'F',
#   'address': '2049 Schultz Terrace\nWilliamsland, SC 62184',
#   'mail': 'jeffreymccarthy@yahoo.com',
#   'jobs': ['Community pharmacist', 'Media buyer', 'IT sales professional'],
#   'id': 356222},
#  {'username': 'iwatkins',
#   'name': 'John Nelson',
#   'sex': 'M',
#   'address': '51164 Wu Ranch Apt. 320\nNorth Julie, NV 38976',
#   'mail': 'pattonmark@hotmail.com',
#   'jobs': ['Administrator, Civil Service',
#    'Production engineer',
#    'Journalist, magazine'],
#   'id': 91392},
#  {'username': 'fstanley',
#   'name': 'Victoria Russell',
#   'sex': 'F',
#   'address': '757 Martin Camp\nWest Christieview, TX 07318',
#   'mail': 'jonesmichele@hotmail.com',
#   'jobs': ['Hospital doctor',
#    'Volunteer coordinator',
#    'Engineer, electronics',
#    'Psychotherapist, child'],
#   'id': 876253},
#  {'username': 'bryan04',
#   'name': 'Jordan Burke',
#   'sex': 'M',
#   'address': '0626 Samuel Park\nNorth Mario, KS 16728',
#   'mail': 'patriciaross@hotmail.com',
#   'jobs': ['IT consultant', "Politician's assistant", 'Warden/ranger'],
#   'id': 65190},
#  {'username': 'robinsongordon',
#   'name': 'Susan Gardner',
#   'sex': 'F',
#   'address': 'Unit 3877 Box 4781\nDPO AE 57419',
#   'mail': 'cforbes@yahoo.com',
#   'jobs': ['Air traffic controller',
#    'Surveyor, quantity',
#    'Tourist information centre manager',
#    'Lobbyist',
#    'Pensions consultant'],
#   'id': 229137},
#  {'username': 'tayloraustin',
#   'name': 'Kirk Hicks',
#   'sex': 'M',
#   'address': '38851 Michelle Forges Apt. 231\nLake Sharichester, MI 30959',
#   'mail': 'jean83@yahoo.com',
#   'jobs': ['Air traffic controller',
#    'Television production assistant',
#    'Office manager'],
#   'id': 164913},
#  {'username': 'scott92',
#   'name': 'Anthony Reeves',
#   'sex': 'M',
#   'address': '099 Cuevas Hill Suite 438\nEdwardsfurt, DE 88265',
#   'mail': 'xharris@yahoo.com',
#   'jobs': ['Academic librarian',
#    'Public affairs consultant',
#    'Conservation officer, nature',
#    'Surveyor, mining'],
#   'id': 1445094},
#  {'username': 'wellsfrancisco',
#   'name': 'Sean Bennett',
#   'sex': 'M',
#   'address': '37777 William Trace Suite 348\nSouth Ronaldfurt, WV 78706',
#   'mail': 'cannoncameron@hotmail.com',
#   'jobs': ['Psychiatric nurse',
#    'Naval architect',
#    'Homeopath',
#    'Landscape architect'],
#   'id': 62997},
#  {'username': 'ogonzalez',
#   'name': 'Anthony Webb',
#   'sex': 'M',
#   'address': '3893 Elizabeth Row\nWrightville, DC 03541',
#   'mail': 'kathryn96@hotmail.com',
#   'jobs': ['Museum/gallery conservator',
#    'Chief Technology Officer',
#    'Mudlogger'],
#   'id': 470211},
#  {'username': 'ygordon',
#   'name': 'Aaron Taylor',
#   'sex': 'M',
#   'address': '674 Pamela Square Apt. 345\nNorth Julia, NV 46252',
#   'mail': 'brent59@yahoo.com',
#   'jobs': ['Editor, film/video',
#    'Telecommunications researcher',
#    'Furniture designer',
#    'Control and instrumentation engineer',
#    'Buyer, industrial'],
#   'id': 1655837},
#  {'username': 'elewis',
#   'name': 'Valerie Lee',
#   'sex': 'F',
#   'address': '235 Julie Summit Suite 460\nJadeport, MT 49806',
#   'mail': 'christinanguyen@hotmail.com',
#   'jobs': ['Loss adjuster, chartered',
#    'Scientist, product/process development',
#    'Engineer, water'],
#   'id': 90086},
#  {'username': 'jmiller',
#   'name': 'April Jones',
#   'sex': 'F',
#   'address': '191 Melanie Underpass Suite 350\nDorisshire, SC 61721',
#   'mail': 'garciaderek@yahoo.com',
#   'jobs': ['Communications engineer',
#    'Translator',
#    'Teacher, music',
#    'Journalist, newspaper'],
#   'id': 48902},
#  {'username': 'michaelhartman',
#   'name': 'Sarah Castaneda',
#   'sex': 'F',
#   'address': '4364 Jackson Locks Suite 991\nNorth Andrew, ND 68515',
#   'mail': 'justin28@hotmail.com',
#   'jobs': ['Geochemist',
#    'Loss adjuster, chartered',
#    'Herbalist',
#    'Advice worker'],
#   'id': 109353},
#  {'username': 'lopezderek',
#   'name': 'Tracy Brown',
#   'sex': 'F',
#   'address': '805 Taylor Roads\nMaryville, MS 32255',
#   'mail': 'james65@yahoo.com',
#   'jobs': ['Charity officer',
#    'Adult guidance worker',
#    'Leisure centre manager'],
#   'id': 1142473},
#  {'username': 'fzuniga',
#   'name': 'John Martinez',
#   'sex': 'M',
#   'address': '28262 Nancy Freeway\nStaffordton, MS 34983',
#   'mail': 'bruce58@yahoo.com',
#   'jobs': ['Television floor manager',
#    'Therapist, drama',
#    'Licensed conveyancer'],
#   'id': 54827},
#  {'username': 'amysmith',
#   'name': 'Jimmy Hendrix',
#   'sex': 'M',
#   'address': '399 Barry Wall\nPort Barbara, AZ 64144',
#   'mail': 'jenningswilliam@hotmail.com',
#   'jobs': ['Control and instrumentation engineer',
#    'Insurance risk surveyor',
#    'Theatre manager'],
#   'id': 1409727},
#  {'username': 'loweanthony',
#   'name': 'Tyler Wilson',
#   'sex': 'M',
#   'address': '527 Janet Ports Apt. 602\nNew Mathewville, MD 52703',
#   'mail': 'johnsondavid@yahoo.com',
#   'jobs': ['Exercise physiologist',
#    "Barrister's clerk",
#    'Scientist, water quality',
#    'Acupuncturist',
#    'Producer, television/film/video'],
#   'id': 64625},
#  ...]

# %%
jobs = []
for person in contributors_sample:
    jobs += person['jobs']   
jobs = np.unique(jobs)
jobs
# Out:
# array(['Academic librarian', 'Accommodation manager',
#        'Accountant, chartered', 'Accountant, chartered certified',
#        'Accountant, chartered management',
#        'Accountant, chartered public finance', 'Accounting technician',
#        'Actor', 'Actuary', 'Acupuncturist', 'Administrator',
#        'Administrator, Civil Service', 'Administrator, arts',
#        'Administrator, charities/voluntary organisations',
#        'Administrator, education', 'Administrator, local government',
#        'Administrator, sports', 'Adult guidance worker', 'Adult nurse',
#        'Advertising account executive', 'Advertising account planner',
#        'Advertising art director', 'Advertising copywriter',
#        'Advice worker', 'Aeronautical engineer',
#        'Agricultural consultant', 'Agricultural engineer', 'Aid worker',
#        'Air broker', 'Air cabin crew', 'Air traffic controller',
#        'Airline pilot', 'Ambulance person', 'Amenity horticulturist',
#        'Analytical chemist', 'Animal nutritionist', 'Animal technologist',
#        'Animator', 'Applications developer', 'Arboriculturist',
#        'Archaeologist', 'Architect', 'Architectural technologist',
#        'Archivist',
#        'Armed forces logistics/support/administrative officer',
#        'Armed forces operational officer',
#        'Armed forces technical officer',
#        'Armed forces training and education officer',
#        'Art gallery manager', 'Art therapist', 'Artist',
#        'Arts administrator', 'Arts development officer',
#        'Associate Professor', 'Astronomer', 'Audiological scientist',
#        'Automotive engineer', 'Banker', 'Barista', 'Barrister',
#        "Barrister's clerk", 'Best boy', 'Biochemist, clinical',
#        'Biomedical engineer', 'Biomedical scientist', 'Bonds trader',
#        'Bookseller', 'Brewing technologist', 'Broadcast engineer',
#        'Broadcast journalist', 'Broadcast presenter',
#        'Building control surveyor', 'Building services engineer',
#        'Building surveyor', 'Buyer, industrial', 'Buyer, retail',
#        'Cabin crew', 'Call centre manager', 'Camera operator',
#        'Careers adviser', 'Careers information officer', 'Cartographer',
#        'Catering manager', 'Ceramics designer', 'Charity fundraiser',
#        'Charity officer', 'Chartered accountant',
#        'Chartered certified accountant',
#        'Chartered legal executive (England and Wales)',
#        'Chartered loss adjuster', 'Chartered management accountant',
#        'Chartered public finance accountant', 'Chemical engineer',
#        'Chemist, analytical', 'Chief Executive Officer',
#        'Chief Financial Officer', 'Chief Marketing Officer',
#        'Chief Operating Officer', 'Chief Strategy Officer',
#        'Chief Technology Officer', 'Chief of Staff',
#        'Child psychotherapist', 'Chiropodist', 'Chiropractor',
#        'Civil Service administrator', 'Civil Service fast streamer',
#        'Civil engineer, consulting', 'Civil engineer, contracting',
#        'Claims inspector/assessor', 'Clinical biochemist',
#        'Clinical cytogeneticist', 'Clinical embryologist',
#        'Clinical molecular geneticist', 'Clinical psychologist',
#        'Clinical research associate',
#        'Clinical scientist, histocompatibility and immunogenetics',
#        'Clothing/textile technologist', 'Colour technologist',
#        'Commercial art gallery manager', 'Commercial horticulturist',
#        'Commercial/residential surveyor', 'Commissioning editor',
#        'Communications engineer', 'Community arts worker',
#        'Community development worker', 'Community education officer',
#        'Community pharmacist', 'Company secretary', 'Comptroller',
#        'Computer games developer', 'Conference centre manager',
#        'Conservation officer, historic buildings',
#        'Conservation officer, nature', 'Conservator, furniture',
#        'Conservator, museum/gallery', 'Consulting civil engineer',
#        'Contracting civil engineer', 'Contractor',
#        'Control and instrumentation engineer', 'Copy',
#        'Copywriter, advertising', 'Corporate investment banker',
#        'Corporate treasurer', 'Counselling psychologist', 'Counsellor',
#        'Curator', 'Customer service manager', 'Cytogeneticist',
#        'Dance movement psychotherapist', 'Dancer',
#        'Data processing manager', 'Data scientist',
#        'Database administrator', 'Dealer', 'Dentist',
#        'Designer, blown glass/stained glass',
#        'Designer, ceramics/pottery', 'Designer, exhibition/display',
#        'Designer, fashion/clothing', 'Designer, furniture',
#        'Designer, graphic', 'Designer, industrial/product',
#        'Designer, interior/spatial', 'Designer, jewellery',
#        'Designer, multimedia', 'Designer, television/film set',
#        'Designer, textile', 'Development worker, community',
#        'Development worker, international aid', 'Diagnostic radiographer',
#        'Dietitian', 'Diplomatic Services operational officer',
#        'Dispensing optician', 'Doctor, general practice',
#        'Doctor, hospital', 'Dramatherapist', 'Drilling engineer',
#        'Early years teacher', 'Ecologist', 'Economist',
#        'Editor, commissioning', 'Editor, film/video',
#        'Editor, magazine features', 'Editorial assistant',
#        'Education administrator', 'Education officer, community',
#        'Education officer, environmental', 'Education officer, museum',
#        'Educational psychologist', 'Electrical engineer',
#        'Electronics engineer', 'Embryologist, clinical',
#        'Emergency planning/management officer', 'Energy engineer',
#        'Energy manager', 'Engineer, aeronautical',
#        'Engineer, agricultural', 'Engineer, automotive',
#        'Engineer, biomedical', 'Engineer, broadcasting (operations)',
#        'Engineer, building services', 'Engineer, chemical',
#        'Engineer, civil (consulting)', 'Engineer, civil (contracting)',
#        'Engineer, communications',
#        'Engineer, control and instrumentation', 'Engineer, drilling',
#        'Engineer, electrical', 'Engineer, electronics',
#        'Engineer, energy', 'Engineer, land', 'Engineer, maintenance',
#        'Engineer, maintenance (IT)', 'Engineer, manufacturing',
#        'Engineer, manufacturing systems', 'Engineer, materials',
#        'Engineer, mining', 'Engineer, petroleum', 'Engineer, production',
#        'Engineer, site', 'Engineer, structural',
#        'Engineer, technical sales', 'Engineer, water',
#        'Engineering geologist', 'English as a foreign language teacher',
#        'English as a second language teacher', 'Environmental consultant',
#        'Environmental education officer',
#        'Environmental health practitioner', 'Environmental manager',
#        'Equality and diversity officer', 'Equities trader', 'Ergonomist',
#        'Estate agent', 'Estate manager/land agent', 'Event organiser',
#        'Exercise physiologist', 'Exhibition designer',
#        'Exhibitions officer, museum/gallery', 'Facilities manager',
#        'Farm manager', 'Fashion designer', 'Fast food restaurant manager',
#        'Field seismologist', 'Field trials officer', 'Film/video editor',
#        'Financial adviser', 'Financial controller', 'Financial manager',
#        'Financial planner', 'Financial risk analyst', 'Financial trader',
#        'Fine artist', 'Firefighter', 'Fish farm manager',
#        'Fisheries officer', 'Fitness centre manager', 'Food technologist',
#        'Forensic psychologist', 'Forensic scientist',
#        'Forest/woodland manager', 'Freight forwarder',
#        'Furniture conservator/restorer', 'Furniture designer',
#        'Further education lecturer', 'Futures trader', 'Gaffer',
#        'Games developer', 'Garment/textile technologist',
#        'General practice doctor', 'Geneticist, molecular', 'Geochemist',
#        'Geographical information systems officer',
#        'Geologist, engineering', 'Geologist, wellsite',
#        'Geophysical data processor', 'Geophysicist/field seismologist',
#        'Geoscientist', 'Glass blower/designer',
#        'Government social research officer', 'Graphic designer',
#        'Haematologist', 'Health and safety adviser',
#        'Health and safety inspector', 'Health physicist',
#        'Health promotion specialist', 'Health service manager',
#        'Health visitor', 'Herbalist', 'Heritage manager', 'Herpetologist',
#        'Higher education careers adviser', 'Higher education lecturer',
#        'Historic buildings inspector/conservation officer',
#        'Holiday representative', 'Homeopath', 'Horticultural consultant',
#        'Horticultural therapist', 'Horticulturist, amenity',
#        'Horticulturist, commercial', 'Hospital doctor',
#        'Hospital pharmacist', 'Hotel manager', 'Housing manager/officer',
#        'Human resources officer', 'Hydrogeologist',
#        'Hydrographic surveyor', 'Hydrologist', 'IT consultant',
#        'IT sales professional', 'IT technical support officer',
#        'IT trainer', 'Illustrator', 'Immigration officer', 'Immunologist',
#        'Industrial buyer', 'Industrial/product designer',
#        'Information officer', 'Information systems manager',
#        'Insurance account manager', 'Insurance broker',
#        'Insurance claims handler', 'Insurance risk surveyor',
#        'Insurance underwriter', 'Intelligence analyst',
#        'Interior and spatial designer',
#        'International aid/development worker', 'Interpreter',
#        'Investment analyst', 'Investment banker, corporate',
#        'Investment banker, operational', 'Jewellery designer',
#        'Journalist, broadcasting', 'Journalist, magazine',
#        'Journalist, newspaper', 'Land', 'Land/geomatics surveyor',
#        'Landscape architect', 'Lawyer', 'Learning disability nurse',
#        'Learning mentor', 'Lecturer, further education',
#        'Lecturer, higher education', 'Legal executive', 'Legal secretary',
#        'Leisure centre manager', 'Lexicographer', 'Librarian, academic',
#        'Librarian, public', 'Licensed conveyancer',
#        'Lighting technician, broadcasting/film/video', 'Lobbyist',
#        'Local government officer', 'Location manager',
#        'Logistics and distribution manager', 'Loss adjuster, chartered',
#        'Magazine features editor', 'Magazine journalist',
#        'Maintenance engineer', 'Make', 'Management consultant',
#        'Manufacturing engineer', 'Manufacturing systems engineer',
#        'Marine scientist', 'Market researcher', 'Marketing executive',
#        'Materials engineer', 'Mechanical engineer', 'Media buyer',
#        'Media planner', 'Medical illustrator',
#        'Medical laboratory scientific officer', 'Medical physicist',
#        'Medical sales representative', 'Medical secretary',
#        'Medical technical officer', 'Mental health nurse',
#        'Merchandiser, retail', 'Merchant navy officer', 'Metallurgist',
#        'Meteorologist', 'Microbiologist', 'Midwife', 'Minerals surveyor',
#        'Mining engineer', 'Mudlogger', 'Multimedia programmer',
#        'Multimedia specialist', 'Museum education officer',
#        'Museum/gallery conservator', 'Museum/gallery curator',
#        'Museum/gallery exhibitions officer', 'Music therapist',
#        'Music tutor', 'Musician', 'Nature conservation officer',
#        'Naval architect', 'Network engineer', 'Neurosurgeon',
#        'Newspaper journalist', 'Nurse, adult', "Nurse, children's",
#        'Nurse, learning disability', 'Nurse, mental health',
#        'Nutritional therapist', 'Occupational hygienist',
#        'Occupational psychologist', 'Occupational therapist',
#        'Oceanographer', 'Office manager', 'Oncologist',
#        'Operational investment banker', 'Operational researcher',
#        'Operations geologist', 'Ophthalmologist', 'Optician, dispensing',
#        'Optometrist', 'Orthoptist', 'Osteopath',
#        'Outdoor activities/education manager', 'Paediatric nurse',
#        'Paramedic', 'Passenger transport manager', 'Patent attorney',
#        'Patent examiner', 'Pathologist', 'Pension scheme manager',
#        'Pensions consultant', 'Personal assistant', 'Personnel officer',
#        'Petroleum engineer', 'Pharmacist, community',
#        'Pharmacist, hospital', 'Pharmacologist', 'Photographer',
#        'Physicist, medical', 'Physiological scientist', 'Physiotherapist',
#        'Phytotherapist', 'Pilot, airline',
#        'Planning and development surveyor', 'Plant breeder/geneticist',
#        'Podiatrist', 'Police officer', "Politician's assistant",
#        'Presenter, broadcasting', 'Press photographer', 'Press sub',
#        'Primary school teacher', 'Print production planner', 'Printmaker',
#        'Prison officer', 'Private music teacher', 'Probation officer',
#        'Producer, radio', 'Producer, television/film/video',
#        'Product designer', 'Product manager',
#        'Product/process development scientist',
#        'Production assistant, radio', 'Production assistant, television',
#        'Production designer, theatre/television/film',
#        'Production engineer', 'Production manager', 'Professor Emeritus',
#        'Programme researcher, broadcasting/film/video',
#        'Programmer, applications', 'Programmer, multimedia',
#        'Programmer, systems', 'Proofreader', 'Psychiatric nurse',
#        'Psychiatrist', 'Psychologist, clinical',
#        'Psychologist, counselling', 'Psychologist, educational',
#        'Psychologist, forensic', 'Psychologist, occupational',
#        'Psychologist, prison and probation services',
#        'Psychologist, sport and exercise', 'Psychotherapist',
#        'Psychotherapist, child', 'Psychotherapist, dance movement',
#        'Public affairs consultant', 'Public house manager',
#        'Public librarian', 'Public relations account executive',
#        'Public relations officer', 'Publishing copy',
#        'Publishing rights manager', 'Purchasing manager',
#        'Quality manager', 'Quantity surveyor', 'Quarry manager',
#        'Race relations officer', 'Radiation protection practitioner',
#        'Radio broadcast assistant', 'Radio producer',
#        'Radiographer, diagnostic', 'Radiographer, therapeutic',
#        'Ranger/warden', 'Records manager', 'Recruitment consultant',
#        'Recycling officer', 'Regulatory affairs officer',
#        'Research officer, government',
#        'Research officer, political party',
#        'Research officer, trade union',
#        'Research scientist (life sciences)', 'Research scientist (maths)',
#        'Research scientist (medical)',
#        'Research scientist (physical sciences)', 'Restaurant manager',
#        'Restaurant manager, fast food', 'Retail banker', 'Retail buyer',
#        'Retail manager', 'Retail merchandiser', 'Risk analyst',
#        'Risk manager', 'Runner, broadcasting/film/video',
#        'Rural practice surveyor', 'Sales executive',
#        'Sales professional, IT', 'Sales promotion account executive',
#        'Science writer', 'Scientific laboratory technician',
#        'Scientist, audiological', 'Scientist, biomedical',
#        'Scientist, clinical (histocompatibility and immunogenetics)',
#        'Scientist, forensic', 'Scientist, marine',
#        'Scientist, physiological',
#        'Scientist, product/process development',
#        'Scientist, research (life sciences)',
#        'Scientist, research (maths)', 'Scientist, research (medical)',
#        'Scientist, research (physical sciences)',
#        'Scientist, water quality', 'Secondary school teacher',
#        'Secretary, company', 'Secretary/administrator',
#        'Seismic interpreter', 'Senior tax professional/tax inspector',
#        'Set designer', 'Ship broker', 'Site engineer',
#        'Social research officer, government', 'Social researcher',
#        'Social worker', 'Software engineer', 'Soil scientist',
#        'Solicitor', 'Solicitor, Scotland',
#        'Sound technician, broadcasting/film/video',
#        'Special educational needs teacher', 'Special effects artist',
#        'Speech and language therapist', 'Sport and exercise psychologist',
#        'Sports administrator', 'Sports coach',
#        'Sports development officer', 'Sports therapist', 'Stage manager',
#        'Statistician', 'Structural engineer', 'Sub', 'Surgeon',
#        'Surveyor, building', 'Surveyor, building control',
#        'Surveyor, commercial/residential', 'Surveyor, hydrographic',
#        'Surveyor, insurance', 'Surveyor, land/geomatics',
#        'Surveyor, minerals', 'Surveyor, mining',
#        'Surveyor, planning and development', 'Surveyor, quantity',
#        'Surveyor, rural practice', 'Systems analyst', 'Systems developer',
#        'TEFL teacher', 'Tax adviser', 'Tax inspector',
#        'Teacher, English as a foreign language',
#        'Teacher, adult education', 'Teacher, early years/pre',
#        'Teacher, music', 'Teacher, primary school',
#        'Teacher, secondary school', 'Teacher, special educational needs',
#        'Teaching laboratory technician', 'Technical author',
#        'Technical brewer', 'Technical sales engineer',
#        'Telecommunications researcher', 'Television camera operator',
#        'Television floor manager', 'Television production assistant',
#        'Television/film/video producer', 'Textile designer',
#        'Theatre director', 'Theatre manager', 'Theatre stage manager',
#        'Theme park manager', 'Therapeutic radiographer', 'Therapist, art',
#        'Therapist, drama', 'Therapist, horticultural', 'Therapist, music',
#        'Therapist, nutritional', 'Therapist, occupational',
#        'Therapist, speech and language', 'Therapist, sports',
#        'Tour manager', 'Tourism officer',
#        'Tourist information centre manager', 'Town planner',
#        'Toxicologist', 'Trade mark attorney',
#        'Trade union research officer', 'Trading standards officer',
#        'Training and development officer', 'Translator',
#        'Transport planner', 'Travel agency manager', 'Tree surgeon',
#        'Veterinary surgeon', 'Video editor', 'Visual merchandiser',
#        'Volunteer coordinator', 'Warden/ranger', 'Warehouse manager',
#        'Waste management officer', 'Water engineer',
#        'Water quality scientist', 'Web designer', 'Wellsite geologist',
#        'Writer', 'Youth worker'], dtype='<U59')

# %%
job_people = dict.fromkeys(jobs)

for job in jobs:
    job_people[job] = []
    for person in contributors_sample:
        if job in person['jobs']:
            job_people[job].append(person['name'])
job_people
# Out:
# {'Academic librarian': ['Amy Durham',
#   'Tim Hayes',
#   'Mary Ellis',
#   'Kristina Wang',
#   'Anthony Reeves',
#   'Gabriel Moore',
#   'Nichole Cross',
#   'Jim Wells',
#   'Gregory Gregory',
#   'Katelyn Smith',
#   'Megan Adams',
#   'Angela Kennedy',
#   'Chris Villanueva',
#   'Christopher Morales',
#   'John Sullivan',
#   'Christina Kane',
#   'Lisa Ruiz',
#   'Patricia Smith'],
#  'Accommodation manager': ['Leslie Padilla',
#   'Scott Ramos',
#   'Kristopher Clarke',
#   'Nancy Watkins',
#   'Danielle Hardin',
#   'Tamara Stevens',
#   'Kimberly Garcia',
#   'Mikayla Elliott',
#   'Catherine Hart',
#   'Nathan Walters',
#   'Jason Thompson',
#   'Derek Gates',
#   'Jordan Walker MD',
#   'Scott Brooks',
#   'Anthony Sosa',
#   'Sheila Saunders',
#   'Justin Moore',
#   'Karen Pineda',
#   'Jason Gutierrez',
#   'Megan Vasquez',
#   'Alexis Payne',
#   'Kathryn Boyd',
#   'Wanda King',
#   'Kevin Yang'],
#  'Accountant, chartered': ['Brooke Higgins',
#   'Melanie Hess',
#   'Theresa Wilson',
#   'Jesse Armstrong',
#   'Michael Lynch',
#   'Donna Anderson',
#   'Laura Henry',
#   'Crystal Wright',
#   'Jon Harmon',
#   'Regina Hughes',
#   'Mark Morris',
#   'Thomas Crosby',
#   'Pamela Gregory',
#   'Lauren Ward',
#   'Elizabeth Mcdonald',
#   'Jacob Acosta',
#   'Raymond Mcclure',
#   'Cameron Mooney',
#   'Stanley Faulkner',
#   'Wanda Rodriguez',
#   'Adrian Harding',
#   'Laura Jenkins',
#   'Bernard Goodman',
#   'Jeffrey Wolf',
#   'Corey Ponce',
#   'Lisa Ruiz',
#   'Kristen Chan',
#   'Jamie Chang',
#   'Jenna Reyes',
#   'Jesse Cantrell'],
#  'Accountant, chartered certified': ['Amy Myers',
#   'Christopher Reed',
#   'John Edwards',
#   'Jennifer Hensley',
#   'Wesley Butler',
#   'Andrea Vasquez',
#   'William Cooper',
#   'Matthew Guerrero',
#   'Mrs. Lisa Thomas',
#   'Roy Brown',
#   'Amanda Scott',
#   'Jill Torres',
#   'Melissa Peterson',
#   'Andrew Jimenez',
#   'Wayne Haynes',
#   'Matthew Cruz',
#   'Arthur Schultz',
#   'Melvin Taylor',
#   'Christina Thompson',
#   'Kim Hughes',
#   'Amy Daniel',
#   'Cynthia Chase',
#   'Shaun Benson',
#   'Tyler Williamson',
#   'Laura Cervantes',
#   'Duane Pittman'],
#  'Accountant, chartered management': ['Patrick Johnson',
#   'Ashley Grant',
#   'Michael Lynch',
#   'Juan Long',
#   'Mr. Michael Day MD',
#   'Melissa Anderson',
#   'Rose Nguyen',
#   'Melissa Williams',
#   'Lisa Lyons',
#   'Gregory Gilbert',
#   'Jennifer Brennan',
#   'Timothy Smith',
#   'Jessica Whitehead',
#   'Kevin Mooney',
#   'Amanda Lewis',
#   'Sarah Greene',
#   'Katrina Thomas',
#   'Kristin Campbell',
#   'Stephanie Taylor',
#   'Amy Taylor MD',
#   'Gary James',
#   'Kathryn Boyd',
#   'Mary Berry',
#   'Steven Snow'],
#  'Accountant, chartered public finance': ['Christopher Boyd',
#   'Robert Woods',
#   'Mason Thompson',
#   'Tony Davis',
#   'Stephanie Richards',
#   'Gavin Brown',
#   'Lauren Santana',
#   'Alexander Sparks',
#   'Erin Rose',
#   'Susan Moore',
#   'Andrew Cruz',
#   'Phillip Zimmerman',
#   'Thomas Howard',
#   'Nathaniel Sherman MD',
#   'Vanessa White',
#   'Harry Cortez',
#   'Jaime Hartman',
#   'Christopher Knight',
#   'Jerry Curry',
#   'Emily Vaughn',
#   'Pamela Moore'],
#  'Accounting technician': ['Jose Briggs',
#   'Daniel Nunez',
#   'Shawn Hale',
#   'Kyle Alvarado',
#   'Carrie Harris',
#   'Mary Russell',
#   'Ryan Anderson',
#   'Kenneth Morris',
#   'Tonya Evans',
#   'Victoria Mcneil',
#   'Joseph Roth',
#   'Felicia Rivera',
#   'Tina Hanson',
#   'Christopher Holder',
#   'Dr. Nicole Salazar',
#   'Jessica Rodriguez',
#   'Margaret Gross',
#   'Kaitlyn English MD',
#   'Alice Brooks',
#   'Tony Green',
#   'Benjamin Ryan',
#   'Bryan Adams',
#   'Donna Petty',
#   'Lucas Finley',
#   'Charlene Matthews',
#   'Richard White'],
#  'Actor': ['Cathy Marsh',
#   'Ashley Chaney',
#   'Adrienne Bowman',
#   'Cynthia Fritz',
#   'Michael Page',
#   'Luis Bennett',
#   'Denise Kennedy',
#   'Kenneth Levy',
#   'Jessica Bell DDS',
#   'Bryce Anderson',
#   'Wendy Harris',
#   'Ashley Stanley',
#   'Charles Nelson',
#   'George Miller',
#   'Ashley Flores',
#   'Anthony Tate',
#   'Rodney Davis',
#   'Eric Smith',
#   'Marcia Schwartz',
#   'Frederick Baldwin',
#   'Robert Mcguire',
#   'Laura Manning',
#   'Jordan Brown',
#   'Angela Butler',
#   'Anthony Spencer'],
#  'Actuary': ['Chloe Wagner',
#   'Wanda Bradley',
#   'John Gonzalez',
#   'Anthony Matthews',
#   'Charles Allen',
#   'Ashley Martin',
#   'Theresa King MD',
#   'William Gonzalez',
#   'Dennis Jones',
#   'Justin Murphy',
#   'Victor Thompson',
#   'Michael Johnson',
#   'Zachary Pitts',
#   'Karen Anthony',
#   'Barbara Lopez',
#   'Sarah Jensen',
#   'David Snyder',
#   'Susan Hernandez',
#   'Larry Roberts',
#   'Jason Jones',
#   'Melissa Roberts',
#   'Edward Herman',
#   'Rebecca Gonzalez',
#   'Cynthia Malone',
#   'Michael Parsons',
#   'Jessica Ward',
#   'Robert Hurst',
#   'Michael Casey',
#   'James Williams',
#   'Deanna Burke',
#   'Rebecca Ramirez',
#   'Michael Wise',
#   'John Williams'],
#  'Acupuncturist': ['Manuel Bell',
#   'Nathan Thompson',
#   'Peggy Young',
#   'Lisa Buck',
#   'Andrea Roberts',
#   'George Harris',
#   'Tyler Wilson',
#   'Kelly Duncan',
#   'Sonya Salinas',
#   'Joseph Gutierrez',
#   'Ashley Jacobson',
#   'Kristi Cook',
#   'Jessica Martin',
#   'Melvin Dixon',
#   'James Dominguez',
#   'Brooke Bates',
#   'Alexandra Griffin',
#   'Michael Olson',
#   'Stephanie Wallace',
#   'David Miller',
#   'Devin David',
#   'Troy Dunlap',
#   'Dr. George Flores Jr.'],
#  'Administrator': ['Angela Baker',
#   'Terry Martin',
#   'Blake Thompson',
#   'Sara Poole',
#   'Adam Williams',
#   'Michelle Francis',
#   'Amanda Lopez',
#   'Kelly Tucker',
#   'Amanda Perez',
#   'Peter Cantrell',
#   'Morgan Garcia',
#   'Maria Frost',
#   'Alex Young',
#   'Jessica Peterson',
#   'Clayton Snow'],
#  'Administrator, Civil Service': ['Sharon Baker',
#   'Michael Hanson',
#   'Matthew Rivera',
#   'John Nelson',
#   'Luke Stone MD',
#   'Jeffrey Krueger',
#   'Jose Ferguson',
#   'Katelyn Nelson',
#   'Richard Collins',
#   'Robert Castro',
#   'Jose Wilson',
#   'Kevin Alexander',
#   'Eric Johnson',
#   'Sean Cox',
#   'Alexis West',
#   'Stacey Goodman',
#   'George Conner',
#   'Taylor Scott',
#   'Robert Nguyen',
#   'Sean Russell'],
#  'Administrator, arts': ['Teresa Torres',
#   'Brian Valdez',
#   'Grant Miller',
#   'Sheila Price',
#   'Sheila Hill',
#   'Nathan Chavez',
#   'Mark Morris',
#   'Tyler Valencia',
#   'Misty Phelps',
#   'Mrs. Amy Jackson DVM',
#   'Gail Williams',
#   'Kara Dixon',
#   'Jamie Martinez',
#   'Christopher Anderson',
#   'Jesse Hull',
#   'Holly Ramos',
#   'Samuel Davis',
#   'Randall Green',
#   'Sierra Reyes',
#   'Michael Nguyen',
#   'Jeremy Wilson',
#   'Amy Friedman',
#   'Tara Anderson',
#   'Alexis Dawson',
#   'Peggy Reynolds',
#   'James Peck',
#   'Pamela Moore'],
#  'Administrator, charities/voluntary organisations': ['Eric Novak',
#   'Leslie Padilla',
#   'Vicki Smith',
#   'Nicholas Thompson',
#   'Erin Baker',
#   'Teresa Jones',
#   'Carrie Harris',
#   'Kenneth Johnston',
#   'Shelly Holder',
#   'Justin Wilson',
#   'Shannon Hardy',
#   'Tina Green',
#   'William Sampson',
#   'John Powell',
#   'Scott Griffin',
#   'Thomas Lewis',
#   'Bryan Yates',
#   'Todd Walton',
#   'Melanie Jones',
#   'Dustin Chan',
#   'Michael Garcia',
#   'James Thomas',
#   'Tracy Johnson',
#   'Hayden Evans'],
#  'Administrator, education': ['Christopher Decker',
#   'Jeffrey Smith',
#   'Kaitlyn Guerra',
#   'Erin Parks',
#   'Gabriela Eaton',
#   'Anthony Hughes',
#   'Jasmine Campbell',
#   'Daniel Wall',
#   'Jeremy Obrien',
#   'Jill Riley',
#   'Sarah Aguirre',
#   'Tonya Evans',
#   'Emily Blair',
#   'Sheri Cox',
#   'Melanie Schwartz',
#   'Yesenia Orr',
#   'Mrs. Emily Harrison MD',
#   'Louis Hart',
#   'Todd Garcia',
#   'Stephanie Myers',
#   'Laurie Calhoun',
#   'Laura Parker',
#   'Jacob Horton',
#   'Jacob King',
#   'Kayla Castaneda',
#   'Jill Wells',
#   'Nicole Charles',
#   'Brittany Dunn',
#   'Luis Morrison'],
#  'Administrator, local government': ['Alan Mccoy',
#   'Kelly Boyle',
#   'Deborah Griffith',
#   'Colleen Rose',
#   'Victoria Mccann',
#   'Jessica Garcia PhD',
#   'Abigail Miller',
#   'Steven Bailey',
#   'Joanna Tucker',
#   'Derek Richardson',
#   'James Frost',
#   'Debra Green',
#   'William Gallagher',
#   'Linda Vega',
#   'Mike Santos',
#   'Lisa Salazar',
#   'Michael Whitehead',
#   'Christian Lewis',
#   'Jose Wiggins',
#   'Debbie Mejia',
#   'Wayne Day',
#   'Yvette Jones',
#   'Michelle Bradley',
#   'William Martin',
#   'Anna Schaefer'],
#  'Administrator, sports': ['Christopher Perez',
#   'Teresa Johnson',
#   'Megan Rodriguez',
#   'Wayne Reed',
#   'William Kerr',
#   'Kristi Garcia',
#   'Jessica Gonzalez',
#   'Brenda Austin',
#   'Steven Webb',
#   'Brittany Jackson',
#   'Lisa Love',
#   'Christian Jensen',
#   'Linda Miller',
#   'Desiree Brown',
#   'Jessica Young',
#   'Anne Mills',
#   'Ashley Rivera',
#   'Alisha Martinez',
#   'Amanda Hartman',
#   'Christine Moreno',
#   'Jonathan Gallagher',
#   'Jessica Rodriguez',
#   'Karen Richardson',
#   'Margaret Hess',
#   'Ashley Flores',
#   'Michael Harris',
#   'Susan Bradley',
#   'Ann Parker',
#   'Jamie Chang',
#   'Ricky Oneill'],
#  'Adult guidance worker': ['Jose Morris',
#   'George Martin',
#   'Michael Daniel',
#   'Ann Lloyd',
#   'Juan West',
#   'Katelyn Poole',
#   'Tracy Brown',
#   'Joshua Beasley',
#   'James Lyons',
#   'Tamara Palmer',
#   'Robert Long',
#   'Clayton York',
#   'Victoria Powell',
#   'Anita Dominguez',
#   'James Thomas',
#   'Jason Kelly',
#   'Tim Watkins',
#   'Debra Dalton',
#   'Misty Martinez',
#   'Michael Wells',
#   'Eric Mendoza',
#   'Jacob King',
#   'Anne Reyes',
#   'Melissa Ruiz',
#   'Mary Garcia',
#   'Patrick Fuentes'],
#  'Adult nurse': ['Jennifer Hicks',
#   'Bryce Armstrong',
#   'Donald Hamilton',
#   'Debra Schmidt',
#   'Molly Tyler',
#   'Laura King',
#   'Lisa Pittman',
#   'Daniel Johnson',
#   'Denise Kennedy',
#   'Jennifer Villarreal',
#   'Susan Cline',
#   'Marcus Mcneil',
#   'Ashlee Robinson',
#   'Tina Wilson',
#   'George Hatfield',
#   'Terry Rush',
#   'Jason Thompson',
#   'Andrew Williams',
#   'Aaron Glenn',
#   'Christopher Nichols',
#   'Natalie Jones',
#   'Lauren Johnson',
#   'James Hardin',
#   'Stephanie Lewis',
#   'Mariah Rivas',
#   'Diane Cox',
#   'Debra Hunter',
#   'Natalie Baker',
#   'Erik Smith',
#   'Douglas Stokes',
#   'Leslie Knight',
#   'Andrew Wells',
#   'Timothy Liu',
#   'Jessica Mitchell'],
#  'Advertising account executive': ['Holly Bautista',
#   'Lawrence Cortez',
#   'Ashley Kennedy',
#   'Jeffrey Cooper',
#   'Kevin Spencer',
#   'Karen Hebert',
#   'Kevin Levine',
#   'Melissa Anderson',
#   'Laurie Decker',
#   'Wendy Peters',
#   'Joy Thomas',
#   'Elizabeth Holland',
#   'Kara Dixon',
#   'Shannon Price',
#   'Matthew Gillespie',
#   'Jessica Madden',
#   'Christopher Young',
#   'William Gonzalez',
#   'Victor Thompson',
#   'Monique Wallace',
#   'James Heath',
#   'Brandi Barron',
#   'Jessica Carpenter',
#   'Faith Wallace',
#   'Courtney Green'],
#  'Advertising account planner': ['Brittney Lee',
#   'Sharon Harrison',
#   'Charles Barton',
#   'Jeffrey Smith',
#   'Brian Smith',
#   'Erin Hernandez',
#   'Shawn Miller',
#   'Taylor Bailey',
#   'Jacqueline Anderson',
#   'Duane Marsh',
#   'Jordan Smith',
#   'Melanie Schwartz',
#   'Frank Silva',
#   'Melissa Harris',
#   'William Sandoval',
#   'Kristin Walters',
#   'Tracy Rodgers',
#   'Vincent Wright',
#   'Terri Eaton',
#   'Candace Bauer',
#   'Gerald Allen',
#   'Louis Gibbs',
#   'Cindy Roberts',
#   'Elizabeth Davenport',
#   'Melanie Hensley'],
#  'Advertising art director': ['Rachel Bullock',
#   'Taylor Frye',
#   'Jennifer Banks',
#   'Jennifer Barrett',
#   'Eric Mclaughlin',
#   'William Baker',
#   'James Haley',
#   'Jason West',
#   'Bridget Gutierrez',
#   'Penny Hernandez',
#   'Michael Watson',
#   'Mary Pope DVM',
#   'Diane Cox',
#   'Jesus Strong',
#   'Kathleen Aguilar',
#   'Curtis Munoz',
#   'Jennifer Landry',
#   'Elizabeth Wright',
#   'Brenda Nelson'],
#  'Advertising copywriter': ['Lisa Owens',
#   'Robert Woods',
#   'Courtney Murray',
#   'Christina Stone',
#   'David Harris',
#   'Cathy Perry',
#   'Peter Perez',
#   'Jermaine Clark',
#   'Mandy Walter',
#   'Margaret Price',
#   'Evelyn Brock',
#   'Theresa King MD',
#   'John Jones',
#   'Jason Joyce',
#   'Julie Santos',
#   'Stephanie Graham',
#   'Julia Price',
#   'Kevin Carter',
#   'Allison Hill',
#   'Amanda Hodge',
#   'Stephanie Cortez',
#   'Benjamin Williams',
#   'Katherine Johnson',
#   'Cheryl Spencer',
#   'Lisa Ruiz',
#   'Maria Peters',
#   'Jill Wells',
#   'Jessica Scott'],
#  'Advice worker': ['Heather Larson',
#   'Jennifer Myers',
#   'Christopher Anderson',
#   'Jack Arnold',
#   'Robert Lucas',
#   'Corey Garcia',
#   'Jason Mcdowell',
#   'Michael Williams',
#   'Kimberly Wilkins',
#   'Kathryn Deleon',
#   'Sarah Castaneda',
#   'Aaron Crosby',
#   'Daniel Wall',
#   'Brad Alvarez',
#   'Dr. Kevin Ferguson',
#   'Michael Watson',
#   'Anthony Miller',
#   'Jordan Stein',
#   'Michele Howard',
#   'Michael Harris',
#   'Luis Parker',
#   'Jeremy Robertson',
#   'Edward Anderson',
#   'Christopher Morales',
#   'Stephanie Hicks',
#   'Christopher Baker',
#   'Kristen Parrish',
#   'Laura Taylor'],
#  'Aeronautical engineer': ['Dr. Charles Jones',
#   'Joseph Goodman',
#   'Joshua Fuentes',
#   'Sherri Arnold',
#   'Brad Nunez',
#   'Jill Williamson',
#   'Brittany Johnson',
#   'Dennis Hansen',
#   'Jennifer Weaver DVM',
#   'William Myers',
#   'Kenneth French',
#   'Cynthia Rollins',
#   'Michelle King',
#   'Abigail Miller',
#   'April Alvarez',
#   'Richard Phillips',
#   'Lisa Noble',
#   'Donna Best',
#   'Kevin Rodriguez',
#   'Debbie Hubbard',
#   'Cory Davis',
#   'John Pearson',
#   'Scott Griffin',
#   'Dennis Aguirre',
#   'Shirley Johnson',
#   'Jennifer Herrera',
#   'Toni Avery',
#   'Dr. Timothy Zimmerman',
#   'Terry Hudson',
#   'Rebecca Brown',
#   'Bruce Perkins',
#   'Julia Green',
#   'Cheryl Ochoa',
#   'Mary Berry',
#   'Daniel Martin',
#   'Jennifer Crawford'],
#  'Agricultural consultant': ['Maria Nelson',
#   'David Richardson',
#   'Alicia Garcia MD',
#   'Debra Schmidt',
#   'Ashley Palmer',
#   'Matthew Owen',
#   'Charles Hill',
#   'Theodore Wagner',
#   'April Garner',
#   'Christian Martinez',
#   'Michelle Ellison',
#   'Mitchell Arnold',
#   'Jessica Hunter',
#   'Taylor Gray',
#   'Matthew Lane',
#   'Monica Schmitt',
#   'Susan Moore',
#   'James Thomas',
#   'David Cruz',
#   'Emma Salazar',
#   'Jessica Murphy',
#   'Anthony Manning',
#   'Paul Campbell',
#   'Joseph Miller',
#   'Michael Green',
#   'Todd Peters',
#   'James Mills',
#   'Kelly Glover',
#   'Brian Hunt',
#   'Erik Smith',
#   'Kimberly Montes',
#   'Kevin Richards',
#   'Richard Jones'],
#  'Agricultural engineer': ['Robert Brown',
#   'Christopher Anderson',
#   'Cynthia Bryant',
#   'Lori Roth',
#   'Rachel Brooks',
#   'George Harris',
#   'Ann Lloyd',
#   'Jermaine Clark',
#   'Tonya Todd',
#   'James Flores',
#   'Melissa Brown',
#   'Edwin Walker',
#   'Crystal Chandler',
#   'Mary Long',
#   'Eduardo Carter',
#   'Eric Sanchez',
#   'Anne Adkins',
#   'Joseph Mann',
#   'Kristina Thompson',
#   'Michael Robles',
#   'Marcia Schwartz',
#   'Angela Kennedy',
#   'Amanda Watson',
#   'Valerie Scott',
#   'Joseph Riddle'],
#  'Aid worker': ['Thomas Cisneros',
#   'Gregory Huffman',
#   'Victoria Kane',
#   'Michael Rodriguez',
#   'Donna Torres',
#   'John Ferguson',
#   'James Morales',
#   'Shawn Hale',
#   'Megan Shaffer',
#   'Carrie Carrillo',
#   'Lisa Sanchez',
#   'James Williams',
#   'Julie Morgan',
#   'Andrew Fox',
#   'David Jones',
#   'Timothy Smith',
#   'Derrick Stone',
#   'Andrew Davis',
#   'Sarah Alexander',
#   'Eric Santiago',
#   'Diane King',
#   'April Mccann',
#   'Tonya Kelley',
#   'Eric Miller',
#   'Jordan Lewis',
#   'Angela Douglas',
#   'Jennifer Galvan',
#   'Ann Christensen',
#   'Pamela Wilson',
#   'Donna Henry',
#   'Susan Lynch',
#   'Laura Tate'],
#  'Air broker': ['Nicole Smith',
#   'Taylor Fisher',
#   'Tim Hayes',
#   'Thomas Moore',
#   'Janice Jenkins',
#   'Joseph Anderson',
#   'Tara Zimmerman',
#   'Amy Jordan',
#   'Christina Johnson',
#   'Beverly Harris',
#   'William Glover',
#   'Alicia Cross',
#   'Barbara Rosario',
#   'Danielle Rodriguez',
#   'Dr. Nicole Salazar',
#   'Donna Best',
#   'Heather Lane',
#   'Rebecca Brown',
#   'Cynthia Cain',
#   'Zoe Wallace',
#   'Wyatt Barker',
#   'Christina Wilson'],
#  'Air cabin crew': ['Cynthia Grant',
#   'Melissa Jackson',
#   'Erin Parks',
#   'James Garcia',
#   'Karen Sloan',
#   'Hannah Reyes',
#   'Wendy Peters',
#   'Joseph Webb',
#   'Kenneth Schwartz',
#   'Mr. Frank Jones',
#   'Barbara Robinson',
#   'Jill Brown',
#   'Sarah Brown',
#   'Heather Steele',
#   'Robert Cuevas',
#   'Kevin Fletcher',
#   'Alicia Hernandez',
#   'Amy Friedman',
#   'Kristin Reynolds',
#   'Karen King',
#   'Shelly Thompson',
#   'Mary Berry',
#   'Jonathan Gallegos'],
#  'Air traffic controller': ['Charles Butler',
#   'Chelsea Lam',
#   'Amanda Taylor',
#   'Sherry Cook',
#   'Wesley Butler',
#   'Susan Gardner',
#   'Kirk Hicks',
#   'Howard Hill',
#   'Barbara Mendoza',
#   'Kristin Gonzales',
#   'Sarah Aguirre',
#   'Dennis Merritt',
#   'Steven Yoder',
#   'Christina Hale',
#   'Christopher Shaw',
#   'David Curtis',
#   'Charles Allen',
#   'John Pineda',
#   'Melvin Taylor',
#   'Christine Cooper'],
#  'Airline pilot': ['Patrick Hawkins',
#   'Courtney Strong',
#   'Edward Montgomery',
#   'Sharon Harrison',
#   'Douglas Rich',
#   'Kayla Marshall',
#   'Shawn Miller',
#   'Sarah Brown',
#   'Gina Johnson',
#   'Morgan Freeman',
#   'Jessica Williams',
#   'Dr. Kevin Ferguson',
#   'Sherry Campbell',
#   'Katherine Adams',
#   'Stacy Gonzalez',
#   'Anita Dominguez',
#   'Victor Perez',
#   'Katherine Colon',
#   'Douglas Stephenson',
#   'Andrew Farmer',
#   'Grant Barrett',
#   'Thomas Lewis',
#   'Linda Mayo',
#   'Tim Watkins',
#   'Laura Mcmillan',
#   'Antonio Oneill',
#   'Daniel Kelly',
#   'John Tyler',
#   'Jamie Howard',
#   'Michael Sampson'],
#  'Ambulance person': ['Stephanie Garcia',
#   'Kyle Montgomery',
#   'Samantha Gilbert',
#   'Brett Wheeler',
#   'Kimberly Kelly',
#   'Katherine Dean',
#   'Mr. Matthew White DDS',
#   'Dr. Penny Hogan',
#   'Emily Martin DDS',
#   'Teresa Novak',
#   'Angela Smith',
#   'Cynthia Jones',
#   'Spencer Williams',
#   'Patrick Alvarez',
#   'Elizabeth Thompson',
#   'Matthew Butler',
#   'Wayne Christensen',
#   'Evan Booth',
#   'Susan Reed',
#   'Gregory Chen',
#   'Keith Robinson',
#   'Tina Stone',
#   'Emily Williams',
#   'Elizabeth Marsh',
#   'Alyssa Ritter',
#   'Susan Tucker',
#   'Michael Porter',
#   'Jane Torres',
#   'Victoria Jackson',
#   'Tiffany Snyder'],
#  'Amenity horticulturist': ['Robert Chapman',
#   'Donna Torres',
#   'Joshua Estes',
#   'Kathryn Torres',
#   'Julian Baker',
#   'Kristin Gonzales',
#   'Cynthia Garcia',
#   'Angel Lopez',
#   'Brenda Thompson',
#   'Elizabeth Anderson',
#   'Thomas Morris',
#   'Caitlyn Smith',
#   'Steven Yoder',
#   'Brandy Brown',
#   'Bernard Goodman',
#   'Priscilla Kennedy',
#   'Karen Dalton',
#   'Heather Hurst',
#   'Andrew Castro',
#   'James Edwards',
#   'Nancy Rosario'],
#  'Analytical chemist': ['Michael Kelly',
#   'Karina Miller',
#   'Megan Underwood',
#   'Shane Lewis',
#   'Antonio Brown',
#   'Jason Silva',
#   'Abigail Jenkins',
#   'Stephanie Hensley',
#   'David May',
#   'Gavin Brown',
#   'Sierra Brandt',
#   'Marissa Jensen',
#   'David Bryan',
#   'Carolyn Johnson',
#   'Mr. Andrew Ramirez',
#   'Dr. Leslie Nelson DVM',
#   'Tamara Hendrix',
#   'Wayne Christensen',
#   'Jeffrey Greene',
#   'Crystal Davis',
#   'Daniel Taylor',
#   'Jessica Sawyer',
#   'Haley Sheppard',
#   'Jeffrey Padilla',
#   'Steve Vasquez',
#   'Natalie Wilson',
#   'Mike Perez'],
#  'Animal nutritionist': ['Jennifer Hicks',
#   'Travis Martin',
#   'Brian Valdez',
#   'Dana Evans',
#   'Stephanie Moon',
#   'Christian Mitchell',
#   'Tina Lopez',
#   'Chase Aguilar',
#   'Michelle Cook MD',
#   'Robert Henderson',
#   'Shari Ward',
#   'Kyle Lane',
#   'Stephanie Richards',
#   'Daniel Long',
#   'Janet Murray',
#   'Melanie Schwartz',
#   'Nathaniel Sanchez',
#   'Natalie Mcdaniel',
#   'Vanessa White',
#   'Virginia Gomez',
#   'Caroline Richards',
#   'Maria Chan',
#   'Teresa Bush',
#   'Bryan Galvan',
#   'Robert Carter',
#   'Keith Peterson',
#   'Thomas Graham',
#   'Edward Berger',
#   'Cole Walsh',
#   'Brandon Petersen',
#   'Danny Robbins',
#   'Jessica Armstrong',
#   'Laura Tate'],
#  'Animal technologist': ['Austin Ward',
#   'Lynn Ball',
#   'Cheryl Rodriguez',
#   'Amy Hodges',
#   'Andrea Roberts',
#   'Dana Ellis',
#   'Jill Lloyd',
#   'Luis Bean',
#   'Zachary Ramirez',
#   'Shelly Orozco',
#   'Casey Macdonald',
#   'Heather Griffith',
#   'Danielle Taylor',
#   'Patrick Andrews',
#   'Jacqueline Taylor',
#   'Mark Young',
#   'John Robinson',
#   'Eric Wilkins',
#   'Regina Andrade'],
#  'Animator': ['John Gonzalez',
#   'Amanda Barry',
#   'Cory Pennington',
#   'Kristen Rodriguez',
#   'Phillip Gonzales',
#   'Tyler Wong',
#   'Kenneth Johnston',
#   'Stephanie Richards',
#   'Shelly Holder',
#   'Ian Davis',
#   'Melanie Schwartz',
#   'Billy Cruz',
#   'Denise Acevedo',
#   'Vincent Wright',
#   'Kathryn Wright DDS',
#   'Sarah Wright',
#   'Chelsey Mitchell',
#   'Shannon Lucas',
#   'Cynthia Malone',
#   'Joan French',
#   'Keith Tran',
#   'Christopher Wilson',
#   'Heather Daniels',
#   'Daniel Barnes',
#   'Andrea Wallace'],
#  'Applications developer': ['Brad Nunez',
#   'Kelly Boyle',
#   'Mr. Daniel Williams',
#   'John Nguyen',
#   'Tracy Carlson',
#   'Catherine Frazier',
#   'Nicole Reeves',
#   'Donna Clements',
#   'Elizabeth Mann',
#   'Melissa Ross',
#   'Karen Anthony',
#   'Ashley Evans',
#   'Robert Leblanc',
#   'Carl Allen',
#   'Jennifer Williams',
#   'Timothy Mueller',
#   'Angela Simon',
#   'Keith Robinson',
#   'Robert Collins',
#   'Shane Gutierrez',
#   'Wyatt Barker',
#   'Carmen Moon',
#   'Michael Murphy',
#   'Ann Parker',
#   'Sarah Aguirre',
#   'Derek Davis'],
#  'Arboriculturist': ['John Bender',
#   'Denise Brown',
#   'Ivan Davis',
#   'Lynn Ball',
#   'Kelly Olsen',
#   'Brian Williams',
#   'Michael Campos',
#   'Amy Foster',
#   'Howard Hill',
#   'Rebecca Alvarez',
#   'Brian Kim',
#   'Anna Richards',
#   'William Gonzalez',
#   'Jordan Johnson',
#   'Erin Knight',
#   'Lynn Williams',
#   'Andrew Miller',
#   'Erik Barnett',
#   'James Dominguez',
#   'David Ortiz',
#   'Thomas Anderson',
#   'Wendy Mcmillan',
#   'Elijah Williams',
#   'Philip Payne',
#   'Raymond Miller'],
#  'Archaeologist': ['Brooke Higgins',
#   'Karina Miller',
#   'Anthony King',
#   'Michael Watson',
#   'Christine Grimes',
#   'Harold Chase',
#   'Kristen Myers',
#   'Matthew Robinson',
#   'Beth Gutierrez',
#   'Daniel Johnson',
#   'Gabriel Moore',
#   'Michele Vargas',
#   'John Martinez',
#   'Megan Robertson',
#   'Wanda Sanders',
#   'Sharon Grant',
#   'Keith Howell',
#   'Mary Sheppard',
#   'Gregory Jimenez',
#   'Jessica Bell DDS',
#   'Joseph Roth',
#   'Amanda Carson',
#   'Jennifer Bridges',
#   'Jeremy Thomas',
#   'Mike Santos',
#   'Scott Smith',
#   'James Ruiz',
#   'Dana Zimmerman',
#   'Elizabeth Hodges',
#   'Kendra Newman DVM'],
#  'Architect': ['Karina Miller',
#   'Albert Richards',
#   'Ashley Grant',
#   'Ashley Patterson',
#   'Anna Oliver',
#   'Sabrina Coleman',
#   'John Meyer',
#   'Renee Martinez',
#   'Lindsey Coleman',
#   'Matthew Taylor',
#   'Katrina Baker',
#   'Victoria Butler',
#   'Richard Martinez',
#   'Grace Day',
#   'Maureen Cross',
#   'Bryan Yates',
#   'Anthony Kent',
#   'Elizabeth Huber',
#   'Mary Mccormick',
#   'Christina Kane',
#   'Angela Klein',
#   'Daniel Potts',
#   'Samantha Harrison'],
#  'Architectural technologist': ['Ryan Wilkins',
#   'Jennifer Turner',
#   'Gregory Williams',
#   'Anna Yu',
#   'James Harris',
#   'Ethan Weiss',
#   'Erica Camacho',
#   'Jose Ferguson',
#   'Peter Cantrell',
#   'Stacy Gonzalez',
#   'Jonathan Gallagher',
#   'Rebecca Williams',
#   'Carlos Rodriguez',
#   'Morgan Pratt',
#   'Dr. Keith Jackson',
#   'Karen Brennan',
#   'Edward Herman',
#   'Kevin Bell',
#   'Timothy Tucker',
#   'Alicia Hogan',
#   'Rachel Henry',
#   'Judy Pena MD',
#   'Brenda Nelson',
#   'Steven Luna',
#   'Jason Reed',
#   'Sarah Jackson',
#   'Samantha Glover'],
#  'Archivist': ['Kimberly Simmons',
#   'Tina Richards',
#   'Leslie Strong',
#   'Robert Brown',
#   'Raymond Raymond',
#   'Susan Schultz',
#   'Amanda Cook',
#   'Lisa Reynolds',
#   'Sarah Thompson',
#   'Lori Cunningham',
#   'Gina Nelson',
#   'Caitlyn Green',
#   'Elizabeth Walker',
#   'Zachary Madden',
#   'Bethany Harrell',
#   'Steven Yoder',
#   'Meghan Davis',
#   'Thomas Foster',
#   'Judy Mack',
#   'Cynthia Thompson',
#   'Alicia Atkinson',
#   'Matthew Moore',
#   'Debra Hunter',
#   'Connor Barr',
#   'Vanessa Baker'],
#  'Armed forces logistics/support/administrative officer': ['Kathryn Walsh',
#   'Robert Chapman',
#   'Isabella Dunn',
#   'Mrs. Stephanie Brown',
#   'Susan Bird',
#   'James Mendoza',
#   'Matthew Combs',
#   'William Gonzalez',
#   'Danielle Clark',
#   'Leslie Smith',
#   'Megan James',
#   'Mike Santos',
#   'Tanya Price DDS',
#   'Ashley Flores',
#   'Matthew Cruz',
#   'Kayla Jones',
#   'Jason Gutierrez',
#   'Elizabeth Smith',
#   'Nicole Burch',
#   'Antonio Levy'],
#  'Armed forces operational officer': ['Jessica Gutierrez',
#   'Yolanda Ferrell',
#   'Courtney Strong',
#   'Kelly Boyle',
#   'Anthony Estes',
#   'Kelly Mcmahon',
#   'Rodney Fritz',
#   'Patricia Vega',
#   'Jeff Williams',
#   'Crystal Pope',
#   'Kenneth French',
#   'Jerry Lam',
#   'Melissa Norris',
#   'Jessica Walters',
#   'Andrew Fox',
#   'Laura Carter',
#   'Kyle Beltran',
#   'Veronica Nelson',
#   'Penny Hernandez',
#   'Nathaniel Sanchez',
#   'Jason Walker',
#   'Kyle Sparks',
#   'Ashley Davis',
#   'Cynthia Bell',
#   'Mark Oconnor',
#   'Misty Martinez',
#   'Alexis West',
#   'Julie Johnson',
#   'Lisa Harris',
#   'Felicia Day',
#   'Anna Schaefer'],
#  'Armed forces technical officer': ['Jack Knight',
#   'Kenneth French',
#   'Phillip Gonzales',
#   'Robert Long',
#   'Amber Miller',
#   'Thomas Smith',
#   'Garrett Moore',
#   'Kevin Alvarado',
#   'Rodney Allen',
#   'Meagan Nguyen',
#   'Alexandra Black',
#   'Matthew Richardson',
#   'John Davis',
#   'Melanie Ward',
#   'Julie Roman',
#   'Morgan Pratt',
#   'Brandon Evans',
#   'Amy Maxwell',
#   'Travis Rogers',
#   'Larry Good',
#   'Angel Nichols',
#   'Erik Smith',
#   'Kimberly Montes',
#   'David Strong',
#   'Sara Bird',
#   'Mary Berry',
#   'Jessica Washington',
#   'Brian Mason',
#   'Elizabeth Sandoval',
#   'Steven Snow',
#   'Gary Ashley'],
#  'Armed forces training and education officer': ['Kelly Atkins',
#   'Jennifer Andersen',
#   'Walter Fuller',
#   'Teresa Miller',
#   'Michael Chapman',
#   'Melissa Lynch',
#   'Lauren Jones',
#   'Joseph Serrano',
#   'Matthew Cox',
#   'Gregory Pennington',
#   'Sierra Brandt',
#   'Michael Briggs',
#   'Alex Tucker',
#   'Robert Chapman',
#   'Traci Collins',
#   'John Watson',
#   'Lorraine Williams',
#   'Dr. Kenneth Taylor',
#   'Alexandra Black',
#   'Nicole Davis',
#   'Patricia Lewis',
#   'Valerie Pope',
#   'Elizabeth Brown',
#   'Jessica Lee',
#   'Cindy Miller',
#   'Sarah Roth',
#   'Sharon Pollard',
#   'Charles Ramirez',
#   'Tracy Cardenas',
#   'Brian Lopez',
#   'Cindy Jones'],
#  'Art gallery manager': ['Judy Shaw',
#   'Mr. Matthew Santos',
#   'Molly Tyler',
#   'Scott Cardenas',
#   'Wayne Reed',
#   'Theodore Wagner',
#   'Tara Davis',
#   'Joshua Conley',
#   'Kimberly Jones',
#   'Micheal Ramirez',
#   'Lisa Anderson',
#   'Jessica Murray',
#   'Jo Miller',
#   'Jason Johnson',
#   'Olivia Kennedy',
#   'Thomas Anderson',
#   'Amanda Lewis',
#   'Jose Lam',
#   'Darrell Wagner',
#   'Nathaniel Sherman MD',
#   'Holly Ramos',
#   'Brandy Adams',
#   'Christopher Reed',
#   'Philip Payne',
#   'Alicia Hernandez',
#   'Jose Rodriguez',
#   'Jennifer Jones',
#   'Ronald Bridges',
#   'Robert Graham',
#   'Jordan Brown',
#   'Douglas White'],
#  'Art therapist': ['Jennifer Banks',
#   'Shannon Swanson',
#   'Robert Parker',
#   'John Brewer',
#   'James White',
#   'Crystal Hill',
#   'Adrian Mason',
#   'Jennifer Harris',
#   'Shannon Hardy',
#   'Denise Sutton',
#   'Sharon Moreno',
#   'Cory Jones',
#   'Janet Harris',
#   'Megan Sullivan',
#   'Larry Roberts',
#   'Justin Macias',
#   'Sandra Delacruz',
#   'Jessica Barker',
#   'Steve Vasquez',
#   'John Hood',
#   'Ashley Sandoval',
#   'Thomas Walker',
#   'David Powell',
#   'Brittany Dunn',
#   'Rebecca Murphy'],
#  'Artist': ['Sergio Stewart',
#   'Gina Acosta',
#   'Patricia Floyd',
#   'Joseph Gardner',
#   'Karen Walker',
#   'Molly Tyler',
#   'James Weaver',
#   'Kathryn Torres',
#   'Aaron King',
#   'Christina Harris',
#   'Heather Ryan',
#   'Tami Lawrence',
#   'Brandy Olson',
#   'Taylor Gray',
#   'Roberta Olson',
#   'Penny Hernandez',
#   'Katherine Tucker',
#   'Karen Richardson',
#   'Paula Harris',
#   'Crystal Smith',
#   'Stephanie Lewis',
#   'Michelle Wilkerson',
#   'Jeffrey Acosta',
#   'Robert Cuevas',
#   'Elizabeth Smith',
#   'Rebecca Jones',
#   'Jennifer Crawford'],
#  'Arts administrator': ['Kristin Rosario',
#   'Stephanie Williams',
#   'Luke Martinez',
#   'Heather Murphy',
#   'Rebecca Marshall',
#   'Erica Johns',
#   'Joseph Davis',
#   'Jaime Mahoney',
#   'Andrew Fox',
#   'Robert Miller',
#   'Rodney Allen',
#   'Gerald Thomas',
#   'Joshua Finley',
#   'Alexa Buck',
#   'Alyssa Ritter',
#   'Jeffrey Jackson',
#   'Gina Maldonado'],
#  'Arts development officer': ['Molly Mooney',
#   'Jesse Armstrong',
#   'Erin Reed',
#   'Douglas Becker',
#   'Jennifer Owens',
#   'Jessica Russo',
#   'Kaitlyn Sanders',
#   'Kristen Taylor',
#   'Andrea Martinez',
#   'Katherine Mcbride',
#   'Hailey Roberts',
#   'Kelly Bowen',
#   'Sandra Goodman',
#   'Alyssa Martinez',
#   'Parker Fisher',
#   'John Lee',
#   'Stephanie Newton',
#   'Charles Nelson',
#   'Eduardo Carter',
#   'Ashlee Tate',
#   'Kevin Mooney',
#   'Sharon Moreno',
#   'Cory Davis',
#   'Calvin Lee',
#   'Kevin Boyle',
#   'Louis Mitchell',
#   'Jessica Bridges',
#   'Willie Payne',
#   'Steven Kelly',
#   'Chad Mclaughlin',
#   'Eduardo Levy MD',
#   'Dylan Pierce',
#   'Brian Hampton'],
#  'Associate Professor': ['Mary Lewis',
#   'Mary Caldwell',
#   'Theresa Morgan',
#   'Laurie Decker',
#   'Kathy Neal',
#   'Diana Adams',
#   'Michelle Ellison',
#   'Amanda Hartman',
#   'Samantha Jenkins',
#   'Todd Compton',
#   'Jacob Rodriguez',
#   'Aaron Herrera',
#   'James Heath',
#   'Anthony Nelson',
#   'Elizabeth Campbell',
#   'Tony Green',
#   'Benjamin Ryan',
#   'Kim Hughes',
#   'Katie Parsons',
#   'Brandon Allison',
#   'Sandra Johnson'],
#  'Astronomer': ['Stacy Wood',
#   'David Kirk',
#   'Ryan Campos',
#   'Lisa Jones',
#   'Charles James',
#   'Martha Robinson PhD',
#   'Gina Weaver',
#   'Dawn Hernandez',
#   'Teresa Mora',
#   'Brett Garcia',
#   'Brenda Thompson',
#   'Ryan Bennett',
#   'John Mcconnell',
#   'Linda Mayo',
#   'Desiree Butler',
#   'Larry Garcia',
#   'Jonathan Rangel',
#   'Jose Rodriguez',
#   'Brittany Heath',
#   'Caroline Henry',
#   'Meghan Wilson DVM',
#   'Keith Tran',
#   'Nicole Dickson',
#   'Paul Molina',
#   'Michelle Morrison'],
#  'Audiological scientist': ['Laura Trujillo',
#   'Sharon Walsh',
#   'Gregory Jones',
#   'Kristopher Clarke',
#   'David Richardson',
#   'Sara Le',
#   'Amber Miller',
#   'Robert Evans',
#   'Cindy Black',
#   'Jaime Mahoney',
#   'Lauren Santana',
#   'Christian Jensen',
#   'Chelsea Patterson',
#   'Vanessa Frazier',
#   'Jason Ramos',
#   'Zoe Moore',
#   'Tommy Rodriguez',
#   'Christian Lewis',
#   'Chad Garcia',
#   'Douglas Savage',
#   'Taylor Scott',
#   'Clayton Snow',
#   'Kevin Sanchez',
#   'Roger Stark',
#   'Wesley Johnson',
#   'Paul Maldonado'],
#  'Automotive engineer': ['Roger Lewis',
#   'Gilbert Cobb',
#   'Kelly Boyle',
#   'Dylan Cox',
#   'Sabrina Zhang',
#   'Robert Crane',
#   'Michelle Pena',
#   'Mark Clay',
#   'Sara Mendez',
#   'Donna Anderson',
#   'Jose Wilson',
#   'Kristina Lopez',
#   'Alisha Martinez',
#   'John Powell',
#   'Paula Olson',
#   'Tonya Robinson',
#   'David Kaiser',
#   'Angel Knapp',
#   'Christopher Greer',
#   'Stephen Reid',
#   'Meghan Wilson DVM',
#   'Jessica Murphy',
#   'Cindy Jones',
#   'Holly Daniels',
#   'Miss Samantha Adams',
#   'Jose Johnson'],
#  'Banker': ['Lisa Carter',
#   'Brandon Ellis',
#   'Holly Bautista',
#   'Jaime Hernandez',
#   'Darrell Richardson',
#   'Renee Perry',
#   'Cathy Lopez',
#   'Hannah Price',
#   'Olivia Morales',
#   'Nicole Yang',
#   'Dr. Joseph King',
#   'Todd Garcia',
#   'Jacqueline Little',
#   'Ashley Dorsey',
#   'Michael Conway',
#   'Cory Jones',
#   'Andrea Rivera',
#   'Jason Smith',
#   'Carlos Chang',
#   'Gary James',
#   'Dawn Carpenter',
#   'Michele Brown',
#   'Christian Hicks',
#   'Sharon Cortez'],
#  'Barista': ['Spencer Leon',
#   'Ryan Wilkins',
#   'James Garcia',
#   'Ethan Weiss',
#   'Victor Flores',
#   'Emily Hines',
#   'Thomas Murphy',
#   'Jennifer Harris',
#   'Bruce Day',
#   'Monica Perez',
#   'Heidi Holloway',
#   'Matthew Cole',
#   'Chad Austin',
#   'Dr. Kenneth Taylor',
#   'Richard Martinez',
#   'Teresa Hernandez',
#   'Chelsey Mitchell',
#   'Christina Walker',
#   'Jerry Stephens',
#   'Eric Guerrero',
#   'Katherine Hunter',
#   'Sharon Macdonald',
#   'Michael Wise',
#   'Alexis Alvarez',
#   'David Rodriguez'],
#  'Barrister': ['Gina Stevens',
#   'William Smith',
#   'Cheryl Carpenter',
#   'Holly Thompson',
#   'Andrea Browning',
#   'Gavin Weiss',
#   'Rebecca Best',
#   'Bradley Holder',
#   'Shari Ward',
#   'Robert Long',
#   'Jennifer Hayes',
#   'John Meyer',
#   'Jennifer Garcia',
#   'Amanda Thompson',
#   'Chelsea Patterson',
#   'Alicia Black',
#   'Kimberly West',
#   'Jimmy Bell',
#   'Nicole Neal',
#   'Lawrence Santana',
#   'Michael Watson',
#   'Steven Yoder',
#   'Emily Guerra',
#   'Sandra Delacruz',
#   'Jane Duran',
#   'Angel Knapp',
#   'Kenneth Mendez',
#   'Julie Johnson',
#   'Carrie Johnston',
#   'Andrew Jackson',
#   'William Schultz',
#   'Alexandria Cameron',
#   'Karen Marshall',
#   'Megan Hoover',
#   'Michael Higgins'],
#  "Barrister's clerk": ['Kendra Cook',
#   'Michael Watson',
#   'Javier Zhang',
#   'Elizabeth Browning',
#   'Tyler Wilson',
#   'Crystal Hill',
#   'Kelly Murphy',
#   'William Castillo',
#   'Nicholas Massey',
#   'Melinda Marsh',
#   'Adrienne Thompson',
#   'Aaron Green',
#   'Jodi Welch',
#   'Selena Henderson',
#   'Thomas Howard',
#   'Karen Morton',
#   'Donna Carter',
#   'Eric Williams',
#   'Maria Nichols',
#   'Tammy Hoffman',
#   'Mallory Johnston',
#   'Cathy Alexander',
#   'Maria Peters',
#   'Andrew Mccann',
#   'Brenda Hall',
#   'Tony Williams'],
#  'Best boy': ['Jessica Gutierrez',
#   'Erin Reed',
#   'John Perry',
#   'Kelly Tapia',
#   'Jason White',
#   'Xavier Ponce',
#   'Melissa Sullivan',
#   'James Elliott',
#   'Gavin Brown',
#   'Ann Salas',
#   'Justin Blanchard',
#   'Paula Odom',
#   'Karen Robinson',
#   'Tina Green',
#   'Bryce Martinez',
#   'Stephanie Douglas',
#   'Johnathan Soto',
#   'Maria Frost',
#   'David Dudley',
#   'Lawrence Santana',
#   'Robert Aguilar',
#   'Kevin Boyle',
#   'Richard Haynes',
#   'Blake Khan',
#   'Cynthia Ruiz',
#   'Emily West',
#   'Shawn Pearson'],
#  'Biochemist, clinical': ['Jesse Ortiz',
#   'Matthew Shepherd',
#   'Taylor Fisher',
#   'Victoria Kane',
#   'Vicki Smith',
#   'Julia Perez',
#   'Lisa Cunningham',
#   'Samuel May',
#   'Megan Brewer',
#   'Adrienne Thompson',
#   'Michele Garcia',
#   'Kevin Alexander',
#   'Jessica Davis',
#   'Kayla Bruce',
#   'Cindy Smith',
#   'Stanley Faulkner',
#   'Derek Wilson',
#   'Joshua Davis',
#   'Rachel Barrett',
#   'Randy Murphy',
#   'Philip Payne',
#   'Tyler Washington',
#   'Bradley Hayes',
#   'Penny Fields',
#   'Michelle Thomas',
#   'Stephanie Hicks',
#   'Mary Johnson',
#   'Keith Griffith'],
#  'Biomedical engineer': ['Olivia Johnson',
#   'Jessica Watson',
#   'Daniel Fox',
#   'John Wilson',
#   'Gary Ramirez',
#   'Donald Henderson',
#   'Wanda Sanders',
#   'Mark Carr',
#   'Christopher Brown',
#   'Christopher Spencer',
#   'Hannah Johnson',
#   'Katherine Tucker',
#   'Benjamin Mccormick',
#   'Steve George',
#   'Samantha Contreras',
#   'Troy Mcdaniel',
#   'Mark Coleman',
#   'Shelby Patton',
#   'Kristina Adams',
#   'Samantha Watkins',
#   'Charles Simpson',
#   'Kristen Chan',
#   'Erin Williams'],
#  'Biomedical scientist': ['Lindsey Nguyen',
#   'Andrea Lawson',
#   'Diana Potter',
#   'Brent Johnson',
#   'Andre Dawson',
#   'Peter Mullins',
#   'Cindy Perez',
#   'Roger Hall',
#   'Andrew Perry',
#   'Kristy Reyes',
#   'Jennifer Castro',
#   'David Little',
#   'Eric Le',
#   'Dustin Sandoval',
#   'Gerald Thomas',
#   'Sydney Kane',
#   'Virginia Ortiz',
#   'Patricia Franklin',
#   'Alexander Rogers',
#   'Kara Owens',
#   'Jason Warren',
#   'Jennifer Crawford',
#   'Rebecca James'],
#  'Bonds trader': ['Jerry Salazar',
#   'Andre Gilbert',
#   'Scott Stone',
#   'Rodney Bradshaw',
#   'Alexander Russo',
#   'Richard Perkins',
#   'Ryan Lawrence',
#   'Christian Martinez',
#   'Claire Simpson',
#   'Paula Odom',
#   'Mark Medina',
#   'Lance Moore',
#   'Donna Anderson',
#   'Marissa Jensen',
#   'Jose Thomas',
#   'Michele Garcia',
#   'Jessica Williams',
#   'Lynn Patterson',
#   'Diane King',
#   'Mark Baker',
#   'Aaron Bradford',
#   'Johnny Gutierrez',
#   'Joseph Brown',
#   'Eric Smith',
#   'Steven Fuentes',
#   'David Richmond',
#   'Sharon Pollard',
#   'Stephen Gomez',
#   'Brittney Sherman',
#   'Alexandria Cameron',
#   'Wanda King',
#   'Andrew Mccann',
#   'Tony Williams'],
#  'Bookseller': ['Anthony Ramirez',
#   'Joseph James',
#   'Jennifer Wu',
#   'Robert Martin',
#   'Brittany Brown',
#   'Travis Torres',
#   'Laurie Miller',
#   'Ann Smith',
#   'Danny Cox',
#   'Monica Bruce',
#   'Edward Mullins',
#   'Nicole Washington',
#   'Derek Johnson',
#   'Tonya Evans',
#   'Tracy Oconnor',
#   'Shane Richards',
#   'Sean Larson',
#   'Cynthia Jones',
#   'Ruben Lewis',
#   'Michael Haynes',
#   'Lisa Flores',
#   'Johnny Gutierrez',
#   'Jesse Arellano',
#   'Joshua Keller',
#   'Jessica Murphy',
#   'Derek Gates',
#   'Andrew Schwartz',
#   'Catherine Wyatt',
#   'Alyssa Nelson',
#   'Katherine Pollard',
#   'Debra Dalton',
#   'Sydney Kane',
#   'Melissa Roberts',
#   'Patricia Moreno',
#   'Carla Warner',
#   'Sarah Lee',
#   'Andrew Jackson',
#   'Bernard Ochoa',
#   'Regina Glass',
#   'Stephanie Kennedy',
#   'Samantha Jackson'],
#  'Brewing technologist': ['Henry Alvarez',
#   'Natalie Higgins',
#   'Stephanie Moon',
#   'Gina Acosta',
#   'Colleen Jensen',
#   'Kaitlyn Berry',
#   'Melanie Johnson',
#   'Mason Cole',
#   'Susan Schultz',
#   'Megan Robertson',
#   'Raymond Richardson',
#   'Bryce Anderson',
#   'Dylan Boyd',
#   'Tim Gonzales',
#   'Sarah Thompson',
#   'Donald Reese',
#   'Michael Porter',
#   'Chad Austin',
#   'Rebecca Clark',
#   'Theresa Barry',
#   'Elizabeth Brown',
#   'Latoya Lyons',
#   'Holly Fitzpatrick',
#   'Ernest Marshall',
#   'Terry Phillips',
#   'Melissa Gay',
#   'Jonathan Davis',
#   'Laura Taylor',
#   'Patricia Smith'],
#  'Broadcast engineer': ['Justin Barron',
#   'Angel Williams',
#   'Brandy Nguyen',
#   'Kelly Wallace',
#   'Robert Sanchez',
#   'Sara Davenport',
#   'Ashley Taylor',
#   'Thomas Huang',
#   'Matthew Wong',
#   'Curtis Barker',
#   'Mr. Andrew Ramirez',
#   'Debra Garcia',
#   'Joanna Tucker',
#   'Sandra Cherry',
#   'Maria Frost',
#   'Lawrence Santana',
#   'Julie Roman',
#   'Joshua Leonard',
#   'Jeremy Miller',
#   'Larry Campbell',
#   'Daniel Martinez',
#   'Caroline Vaughn',
#   'Emily Bell',
#   'Mark Shepherd',
#   'Ashley Snyder',
#   'Heather Daniels'],
#  'Broadcast journalist': ['Peter Wilson',
#   'Kenneth Cooper',
#   'Mark Mcdowell',
#   'Christina Harrison',
#   'Juan Simpson',
#   'Steve Farrell',
#   'Joseph Gutierrez',
#   'Julian Baker',
#   'Christopher Garcia',
#   'Virginia Carlson',
#   'Adrienne Vance',
#   'Steven Stevenson',
#   'Michael Briggs',
#   'Erika Coleman',
#   'Mrs. Jennifer Brown DDS',
#   'Andrew Jimenez',
#   'Michael Chambers',
#   'Colton Evans',
#   'Kayla Davila',
#   'Matthew Pennington',
#   'Larry Beck',
#   'Amanda Hoffman',
#   'Adriana Garza',
#   'Jane Duran',
#   'Catherine Chambers',
#   'David Burns',
#   'Jasmine Shaw',
#   'Anna Reyes',
#   'Tracy Cardenas',
#   'Danny Robbins',
#   'John Jackson',
#   'Gabriel Turner',
#   'Rhonda Young',
#   'Kristen Parrish'],
#  'Broadcast presenter': ['Miguel Cuevas',
#   'Stephanie Herrera',
#   'Sarah Williams',
#   'John Anderson',
#   'Megan Rodriguez',
#   'Kelly Tapia',
#   'Holly Richards',
#   'Hannah Griffin',
#   'Frances Benton',
#   'Gregory Richard',
#   'Jessica Bell DDS',
#   'Kristina Matthews',
#   'Richard Barrett',
#   'Lisa Smith',
#   'Jennifer Bridges',
#   'Cheyenne Rich',
#   'John Spencer',
#   'Kevin Gonzalez',
#   'Mr. Bruce Yang MD',
#   'Heather Alexander',
#   'Kurt Pollard',
#   'Sharon Patterson',
#   'Makayla Rivera',
#   'Valerie Scott',
#   'Joshua Smith',
#   'Jaime Watkins',
#   'Deborah Young',
#   'Samantha Harrison'],
#  'Building control surveyor': ['Kenneth Wright',
#   'Sandra Hill',
#   'Julie Wagner',
#   'Sandra Zamora',
#   'Rodney Lee',
#   'Christine Grimes',
#   'Luke Martinez',
#   'Tamara Stevens',
#   'Diana Moreno',
#   'Mark Carr',
#   'Sarah Christian',
#   'David Figueroa',
#   'Lindsey Coleman',
#   'Matthew Curtis',
#   'Danielle Brown',
#   'Anthony Smith',
#   'Timothy Fernandez',
#   'Michael Watson',
#   'Donna Deleon',
#   'Norma Mclaughlin',
#   'Ashley Brewer',
#   'Julie Garcia',
#   'Melissa Fleming',
#   'Angelica Bright',
#   'Jessica Armstrong',
#   'Timothy Rodriguez',
#   'Kimberly Anderson',
#   'Felicia Day',
#   'Sarah Robinson',
#   'David Powell',
#   'Samantha Harrison'],
#  'Building services engineer': ['Casey Foster',
#   'Cheryl Rodriguez',
#   'Joseph Franklin',
#   'Gregory Harrison',
#   'Karen Walker',
#   'Patricia Clements',
#   'Nicole Olson',
#   'Ann Smith',
#   'Nathan Chavez',
#   'Frank Williams',
#   'Melissa Jacobs',
#   'Joe Clark',
#   'Amy Williams',
#   'Alexa Frey',
#   'Jessica Hurst',
#   'Juan Mcneil',
#   'Emily Guerra',
#   'Eric Williams',
#   'Dr. Richard Wang',
#   'Cynthia Fields',
#   'Brittany Dunn'],
#  'Building surveyor': ['Jennifer Rivera',
#   'Matthew Rivera',
#   'Ellen Mccullough',
#   'James Elliott',
#   'Sean Barton',
#   'Kenneth Bailey Jr.',
#   'William Gutierrez',
#   'Miss Jacqueline Johnson',
#   'Rodney Allen',
#   'Jason Joyce',
#   'Rebekah Hamilton',
#   'Michelle Jensen',
#   'Steven Long',
#   'Sarah Brown',
#   'Dr. Paul Johnston Jr.',
#   'Anne Hicks',
#   'Samuel Davis',
#   'Valerie Jones',
#   'Robin Bell',
#   'Chelsea Coleman',
#   'Jeffrey Mason'],
#  'Buyer, industrial': ['Richard Brown',
#   'Rebecca Ayers',
#   'Amy Woods',
#   'Patrick Shaw',
#   'James Salazar',
#   'Brian Garcia',
#   'Aaron Taylor',
#   'Tracy Morris',
#   'Colleen Rose',
#   'Kelly Tucker',
#   'Shane Richards',
#   'Samuel Gibson',
#   'Christine Kaufman',
#   'Katherine Adams',
#   'Susan Moore',
#   'Matthew Marquez',
#   'Kristy Day',
#   'Jordan Edwards',
#   'Katherine Clark',
#   'Kristen Wright',
#   'David Thornton',
#   'Jeremy Wilson',
#   'Jose Wiggins',
#   'Eric Cuevas'],
#  'Buyer, retail': ['Wanda Bradley',
#   'Maria Campbell',
#   'John Rose',
#   'Sherry Cook',
#   'Wesley Davenport',
#   'Eileen Ramirez',
#   'Gwendolyn Young',
#   'Linda Hubbard',
#   'Matthew Combs',
#   'William Werner',
#   'Richard Oneal',
#   'Justin Blanchard',
#   'Kristin Gonzales',
#   'Erika Kramer',
#   'Scott Simpson',
#   'Benjamin Parker',
#   'Timothy Fernandez',
#   'Rose Flores',
#   'Jacob White',
#   'Kristina Thompson',
#   'Laura Mcmillan',
#   'Jennifer Johnson',
#   'Robert Mccann',
#   'Robert Hurst'],
#  'Cabin crew': ['Kenneth Love',
#   'Sydney Cisneros',
#   'Charles Martin',
#   'Steven Fox',
#   'Rodney Fritz',
#   'Shari Pena',
#   'Russell Alexander',
#   'Elizabeth Flores',
#   'Dustin George',
#   'Jessica Young',
#   'Nathan Thompson',
#   'Lindsey Coleman',
#   'Justin Gibson',
#   'Jeffrey Kim',
#   'Kathleen Bell',
#   'Benjamin Bullock',
#   'Eric Miller',
#   'Aaron Rodriguez',
#   'Sierra Reyes',
#   'Peter Johnson',
#   'Anita Dunn',
#   'Julia Green',
#   'Gail Whitney'],
#  'Call centre manager': ['Dylan Rodriguez',
#   'Nicole Hernandez',
#   'Adrian Gonzalez',
#   'Meredith Orr',
#   'Matthew Robinson',
#   'Kelly Duncan',
#   'Brett Lawson',
#   'Sonya Salinas',
#   'Scott Gomez',
#   'Brandi Rose',
#   'Mary Long',
#   'Anna Brown',
#   'Ashley Davis',
#   'Angela Simon',
#   'Kimberly Allen',
#   'Christina Parker',
#   'Christopher Greer',
#   'Penny Fields',
#   'Kimberly Montes',
#   'William Schultz',
#   'Cindy Stanley',
#   'Tracy Hughes'],
#  'Camera operator': ['Thomas Moore',
#   'Kristi Mckenzie',
#   'Christy Allen',
#   'Melissa Wilson',
#   'Mr. Daniel Williams',
#   'Darrell Ferguson',
#   'Wesley Whitaker',
#   'Pamela Alexander',
#   'Brett Garcia',
#   'Steven Bailey',
#   'Mrs. Sheryl Long',
#   'Heidi Holloway',
#   'Andrew Williams',
#   'Joshua Morgan',
#   'Anthony Lopez',
#   'Brandon Martinez',
#   'Heather Orr MD',
#   'Steven Thomas',
#   'Jeremy Wilson',
#   'Jack Berger',
#   'William Guzman',
#   'Jessica Ayala',
#   'Charles Gentry',
#   'Adam Nunez',
#   'Michelle Morrison',
#   'Tina Morales'],
#  'Careers adviser': ['Alexander Smith',
#   'Courtney Murray',
#   'Jason Zavala',
#   'Cameron Kane',
#   'Donna Torres',
#   'Patricia Vega',
#   'Kelly Tapia',
#   'Kristen Rodriguez',
#   'Daniel Jacobs',
#   'Gabrielle Mcdonald',
#   'Anthony King',
#   'Timothy Lewis',
#   'Maria Lopez',
#   'Angela Atkinson',
#   'Patrick Jacobson',
#   'Justin Thomas',
#   'Kathy Copeland',
#   'Brandy Brown',
#   'Heather Steele',
#   'Daniel White',
#   'Amanda Hodge',
#   'Mark Miller',
#   'Peter Simmons',
#   'Katie Livingston',
#   'Timothy Stark',
#   'Daniel Rodriguez',
#   'Luis Morrison',
#   'Nancy Harrison'],
#  'Careers information officer': ['Christopher Mcclain',
#   'Rebecca Best',
#   'Jasmine Campbell',
#   'Carla Lamb',
#   'Bradley Austin',
#   'Luis Bennett',
#   'Cynthia Webster',
#   'Tammy Rodriguez',
#   'Melanie Vargas',
#   'Julie Harrison',
#   'Vincent Warren',
#   'Sarah Greene',
#   'Regina Hanna',
#   'David Miller',
#   'Michelle Thomas',
#   'Barbara Williams',
#   'Terry Phillips',
#   'Melanie Hensley',
#   'Kenneth Greer',
#   'Deanna Burke',
#   'Monica Lopez',
#   'Brian Lee'],
#  'Cartographer': ['Jacob Harvey',
#   'Nicholas Phelps',
#   'Jenna Arnold',
#   'Olivia Marshall',
#   'Melissa Garcia',
#   'John Lewis',
#   'Teresa Martin',
#   'Glenn Jones',
#   'Jason Hartman',
#   'Nicole Berry',
#   'Caitlyn Carey',
#   'Jamie Martinez',
#   'Gina Nelson',
#   'Nathaniel Sherman MD',
#   'Derek Gates',
#   'Jordan Booth',
#   'Heather Steele',
#   'Rebecca Smith',
#   'Cheyenne Harris',
#   'Amber Smith',
#   'Joshua Smith',
#   'Michael Montgomery',
#   'John Reed',
#   'John Miller',
#   'Victoria Anderson',
#   'Donald Garcia',
#   'Debbie Glass'],
#  'Catering manager': ['Susan Phillips',
#   'Lisa Jones',
#   'Joseph James',
#   'Robert Woods',
#   'Austin Jackson',
#   'Maria Nelson',
#   'Matthew Combs',
#   'Isaiah Gillespie',
#   'Erin Mcclain',
#   'Mrs. Christine Logan',
#   'Kelly Duncan',
#   'Teresa Mora',
#   'Wendy Harris',
#   'Sandra Cherry',
#   'Eric Chase',
#   'Ebony Harrison',
#   'Charles Garrett',
#   'Alicia Davis',
#   'Christopher Harvey',
#   'Omar Green',
#   'Melvin Taylor',
#   'John Hood'],
#  'Ceramics designer': ['John Morton',
#   'Teresa Johnson',
#   'Daniel Fox',
#   'Judy Downs',
#   'Lisa Buck',
#   'Mitchell Nelson',
#   'Kyle Hendricks',
#   'Julian Baker',
#   'Patrick Montgomery',
#   'Adam Pratt',
#   'Brian Bright',
#   'Mr. Brian Lang',
#   'Elizabeth Fletcher',
#   'Gerald Hanson',
#   'Samantha Fletcher',
#   'John Spencer',
#   'Misty Martinez',
#   'Jenny Crane',
#   'Ryan Walker',
#   'Julie Schultz',
#   'Heather Alexander',
#   'Whitney Russell',
#   'Tracy Cardenas',
#   'Tracy Diaz',
#   'Jasmine Long'],
#  'Charity fundraiser': ['Mr. Matthew Robinson',
#   'Stacy Wood',
#   'Lori Lewis',
#   'Nicholas Smith',
#   'Caitlin Mccarty',
#   'Brian Rich',
#   'John Johnson',
#   'Scott Cardenas',
#   'Linda Hubbard',
#   'Brent Johnson',
#   'Melissa Lynch',
#   'Angela Scott',
#   'James Dominguez',
#   'Lisa Love',
#   'Christopher Yang',
#   'Sydney Bridges',
#   'Tammy Wise',
#   'Christine Nielsen',
#   'David Smith',
#   'Michelle Zamora',
#   'Angela Butler',
#   'Susan Bradley',
#   'Ashley Sandoval',
#   'Michael Porter',
#   'Ian Hill',
#   'William Martin'],
#  'Charity officer': ['Angel Williams',
#   'Gregory Huffman',
#   'Ashley Shields',
#   'Philip Carlson',
#   'Tina Fischer',
#   'Tracy Brown',
#   'Christopher Burton',
#   'Valerie Smith',
#   'Melissa Sullivan',
#   'Teresa Martin',
#   'David Figueroa',
#   'Pamela Reynolds',
#   'Anne Mills',
#   'Cassandra Larson',
#   'Andrew Williams',
#   'Kevin Rodriguez',
#   'John Davis',
#   'Wendy Thomas',
#   'Valerie Coffey',
#   'Caroline Richards',
#   'Jerry Welch',
#   'Nathan Williams',
#   'Heather Gomez',
#   'Timothy Mack',
#   'Julia Green',
#   'Melanie Moore'],
#  'Chartered accountant': ['Stephanie Noble',
#   'Nathan Thompson',
#   'Christine Solis',
#   'Daniel Brown',
#   'David Willis',
#   'Marvin Holmes',
#   'Scott Gomez',
#   'Michael Kent',
#   'Jack Scott',
#   'Stephanie Horton',
#   'Kristin Walters',
#   'Lisa Salazar',
#   'Monica Barnes',
#   'Anna Adkins',
#   'Jason Jones',
#   'Jeffrey Wolf',
#   'Jennifer Moreno',
#   'Robert Woodward',
#   'Wesley Johnson',
#   'Kenneth Greer'],
#  'Chartered certified accountant': ['Kimberly Smith',
#   'Kristopher Clarke',
#   'Gabrielle Garcia',
#   'Alan Rose',
#   'Tina Fischer',
#   'Heather Barton',
#   'Patricia Jones',
#   'Pamela Harrell',
#   'Robert Miller',
#   'Stacey Maynard',
#   'Clayton York',
#   'Melissa Harris',
#   'Benjamin Mccormick',
#   'Antonio Oneill',
#   'Jeffrey Brown',
#   'Christian Mcdaniel',
#   'Ronald Baker',
#   'Tiffany Snyder'],
#  'Chartered legal executive (England and Wales)': ['Sheryl Phillips',
#   'Steven Lopez',
#   'Kaitlyn Berry',
#   'Crystal Wright',
#   'Mr. Bryan Freeman',
#   'James Williams',
#   'Leslie Smith',
#   'Shelley Sanchez',
#   'Melissa Dixon',
#   'Daniel Smith',
#   'James Stark',
#   'Debra Dalton',
#   'Katherine Pena',
#   'Emily Rose',
#   'Matthew Moore',
#   'Elizabeth Chavez',
#   'Katherine Meyer',
#   'Timothy Stark',
#   'Tammy Boone',
#   'Steven Gilbert'],
#  'Chartered loss adjuster': ['Amy Woods',
#   'Nicholas Benson',
#   'Tina Lopez',
#   'Jessica Hernandez',
#   'Darrell Richardson',
#   'Devin Hughes PhD',
#   'Sara Miller',
#   'Steven Johnson',
#   'Richard Collins',
#   'James Haley',
#   'Fernando Leach',
#   'Sarah Douglas',
#   'Tina Green',
#   'Jeffrey Wilson',
#   'Heather Payne',
#   'James Herrera',
#   'Sarah Edwards',
#   'Cody Gross MD',
#   'Megan Williams',
#   'Jeffrey Davies',
#   'Jonathan Taylor',
#   'Bruce Perkins',
#   'Debbie Mejia',
#   'Paul Diaz',
#   'Nancy Howard',
#   'Andrew Mccann',
#   'Brian Carter'],
#  'Chartered management accountant': ['Michael Figueroa',
#   'Mrs. Jacqueline Trevino',
#   'Michael Nelson',
#   'Beth Gutierrez',
#   'Michael Fox',
#   'Bryan Hahn',
#   'Lindsay Leon',
#   'Sergio Delgado',
#   'Christopher Garcia',
#   'Cindy Black',
#   'Charles Smith',
#   'Riley Franklin',
#   'Kyle Waters',
#   'Briana Richardson',
#   'Megan Williams',
#   'Jason Jones',
#   'David Lewis',
#   'Devin David',
#   'Ann Christensen',
#   'Steven Rhodes',
#   'Nicolas Melton'],
#  'Chartered public finance accountant': ['Jose Anderson',
#   'Jose Morris',
#   'Scott Ramos',
#   'Jimmy Day',
#   'Lisa Brown',
#   'Jessica Hernandez',
#   'Michael Page',
#   'Lisa White',
#   'Robert Howell',
#   'Jon Harmon',
#   'John Henson',
#   'Colin George',
#   'Thomas Riley',
#   'Timothy Gonzalez',
#   'Beverly Harris',
#   'Sydney Bridges',
#   'Jeffrey Smith',
#   'Trevor Brown',
# ...
#   'Parker Howe',
#   'Caitlyn Carey',
#   'Kevin Rodriguez',
#   'Susan Hernandez',
#   'Charles Woodward',
#   'Jerry Hall',
#   'Maureen Cross',
#   'Scott Cooper Jr.',
#   'Sarah Roth',
#   'Daniel Martinez',
#   'Candace Bauer',
#   'Gabriel Horton',
#   'Karen Waller',
#   'Heather Hurst',
#   'John Reed',
#   'Jonathan Gallegos',
#   'Brandy Campbell',
#   'Eric Hernandez',
#   'Timothy Esparza',
#   'Brandon Farrell'],
#  'Therapist, nutritional': ['Cathy Perry',
#   'Kristin Rosario',
#   'Edgar Long',
#   'Scott Watkins',
#   'Robert Henderson',
#   'Robert Howell',
#   'Andrea Dougherty',
#   'Scott Bush',
#   'Eric Hill',
#   'Matthew Cole',
#   'Deborah Robinson',
#   'Valerie Pope',
#   'Joseph Perkins',
#   'Lauren Johnson',
#   'Elizabeth Guerrero',
#   'Elizabeth Lawson',
#   'Joshua Martin II',
#   'Margaret Warren',
#   'Joshua Dean'],
#  'Therapist, occupational': ['Kimberly Kelly',
#   'Julie Murphy',
#   'Courtney Carlson',
#   'Mike Kemp PhD',
#   'Pamela Franco',
#   'Lynn Patterson',
#   'Nathan Knox',
#   'Molly Sanford',
#   'David Curtis',
#   'Michelle Wilkerson',
#   'Timothy Chambers',
#   'Bethany Brown',
#   'Kathleen Hanna',
#   'George Conner',
#   'Alexis Payne',
#   'Susan Tucker',
#   'Matthew Simpson',
#   'Joseph Thompson',
#   'Margaret Warren'],
#  'Therapist, speech and language': ['Benjamin Garcia',
#   'Colin Jefferson',
#   'Jenna Hernandez',
#   'Joseph Wade',
#   'Michelle Pena',
#   'Shane Bryant',
#   'Jonathan Johnson',
#   'Lindsey Clay',
#   'Thomas Nunez',
#   'Brad Alvarez',
#   'Matthew Obrien',
#   'Karen Robinson',
#   'Alexandra Bolton',
#   'Walter Mosley',
#   'Peter Howard',
#   'Vernon Bradley',
#   'Rachel Barrett',
#   'Dennis Collins',
#   'Dawn Lewis',
#   'Joseph Rivas',
#   'Joseph Hamilton',
#   'Ashlee Price',
#   'Steven Church'],
#  'Therapist, sports': ['Carla Miller',
#   'Sarah Bennett',
#   'Mario Trevino',
#   'Jack Knight',
#   'Brandon Shelton',
#   'Russell Montoya',
#   'Laurie Johnson',
#   'Kathryn Deleon',
#   'Nathan Lewis',
#   'Elizabeth Stone',
#   'Emily Hines',
#   'Erica Johns',
#   'Susan Davidson',
#   'Linda Rogers',
#   'Kimberly Anderson',
#   'Jason Ramos',
#   'Michael Blankenship',
#   'Jonathan King',
#   'Felicia Conley',
#   'Christopher Riggs',
#   'Kimberly Holloway',
#   'Andrea Clarke',
#   'Timothy Liu',
#   'Brandon Allison',
#   'Joseph Thompson'],
#  'Tour manager': ['Cynthia Grant',
#   'Jennifer Banks',
#   'Paul Washington',
#   'Mr. Jeffrey Ballard',
#   'Billy Jennings',
#   'Phillip Knox',
#   'Derrick Stone',
#   'Judy Garcia',
#   'David Benson',
#   'Austin Rivers',
#   'Valerie Coffey',
#   'Pamela Cochran',
#   'Dylan Blackburn',
#   'Jill Brown',
#   'Dr. Amy Brown DDS',
#   'Julie Johnson',
#   'Linda Rios',
#   'Crystal Walton',
#   'Erica Harper'],
#  'Tourism officer': ['Sarah Stevenson',
#   'Autumn Parker',
#   'Patricia Clements',
#   'Ashley Chaney',
#   'Gabrielle Mcdonald',
#   'Luis Bennett',
#   'Denise Kennedy',
#   'Elizabeth Rodriguez',
#   'Jennifer Stephenson',
#   'Summer Johnson',
#   'Mary Thomas',
#   'Mark Wright',
#   'Roy Jones',
#   'Sandra Goodman',
#   'Jessica Walters',
#   'Tammy Rodriguez',
#   'Christian Jensen',
#   'Curtis Evans',
#   'Michele Smith',
#   'Sabrina Krause',
#   'Brian Mayer',
#   'Stephanie Newton',
#   'Ashley Jacobson',
#   'Kimberly West',
#   'Jason Alvarez',
#   'Kevin Rowe',
#   'Jared Weaver',
#   'Shannon Lopez DVM',
#   'Jennifer Jackson',
#   'Edward Berger',
#   'James Bailey',
#   'Susan Bradley',
#   'Kevin Smith'],
#  'Tourist information centre manager': ['Carlos Evans',
#   'Mr. Mathew Huffman DDS',
#   'Rachel Moore',
#   'Susan Gardner',
#   'Anna Ross',
#   'Christine Hale',
#   'Robert Martin',
#   'Emily Cole',
#   'Taylor Bailey',
#   'Laura Young',
#   'Andrew Rodriguez',
#   'Yolanda Lindsey',
#   'Richard Bradley',
#   'Joshua Thompson',
#   'Joshua Barker',
#   'Michael Porter',
#   'Julia Price',
#   'Karen Long',
#   'Chelsea Wade',
#   'Nathan Burgess',
#   'Mary Mccormick',
#   'Jimmy Garcia',
#   'Jessica Garner',
#   'Kristina Brown',
#   'Hunter Hill',
#   'Laura Harrison'],
#  'Town planner': ['Ricardo Shelton',
#   'Russell Payne',
#   'John Gonzalez',
#   'Kevin Sawyer',
#   'Richard Jordan',
#   'Anthony Hughes',
#   'Larry Bryant',
#   'Allison Williams',
#   'Brittany Jackson',
#   'Gail Williams',
#   'Sheryl Henry',
#   'Linda Green',
#   'Robin Love',
#   'Traci Collins',
#   'Jennifer Mitchell',
#   'Caitlyn Smith',
#   'Jacqueline Hoffman',
#   'Emily Guerra',
#   'Dylan Berger',
#   'Nicole Lopez',
#   'Elizabeth Lawson',
#   'Julie Johnson',
#   'Stephanie Hernandez',
#   'Clinton Hall',
#   'Ashley Snyder',
#   'Brent Barnes'],
#  'Toxicologist': ['Heather Larson',
#   'Jonathan Lester',
#   'Roberto Johnson',
#   'Adrian Gonzalez',
#   'James Salazar',
#   'Louis Bonilla',
#   'Hailey Roberts',
#   'Matthew Waller',
#   'James Bennett',
#   'Dennis Bailey',
#   'Andrew Miller',
#   'Kayla Snyder',
#   'Brent Booker',
#   'Daniel Smith',
#   'Meghan Davis',
#   'Katherine Pena',
#   'Erik Hernandez',
#   'Kayla Castaneda',
#   'Carmen Cortez',
#   'Adam Nunez',
#   'Amanda Perry'],
#  'Trade mark attorney': ['Jerry Salazar',
#   'Vincent Conner',
#   'Wendy Parker',
#   'Kevin Spencer',
#   'Daniel Jacobs',
#   'Mark Johnson',
#   'Natalie Donaldson',
#   'James Hughes',
#   'Jennifer Martin',
#   'Collin Stanton',
#   'Amy Jordan',
#   'Randall Bentley',
#   'Ryan Collins',
#   'Laura Sheppard',
#   'Jeffrey Ingram',
#   'Charles Smith',
#   'Jennifer King',
#   'Dr. Renee Gardner',
#   'Timothy Bryant',
#   'Bethany Harrell',
#   'Christopher Young',
#   'Andrea Lewis',
#   'Jeffrey White',
#   'Allison Roth',
#   'Valerie Howard',
#   'Grace Lee',
#   'Nicole Phillips',
#   'Jasmine Shaw',
#   'Kathleen Gonzalez',
#   'Melissa Velasquez',
#   'Sherri Allison',
#   'Lisa Fry',
#   'David Page',
#   'Michael Osborne',
#   'Laura Reyes',
#   'Mary Johnson',
#   'Jeffery Wright',
#   'Sarah Jackson'],
#  'Trade union research officer': ['Wesley Butler',
#   'Susan Holland',
#   'Ernest Ballard',
#   'Jeremy Sanders',
#   'Carrie Bauer',
#   'Jeffrey Krueger',
#   'Amanda Cook',
#   'Brian Bright',
#   'Michelle Hayden',
#   'Michael Chambers',
#   'Rebecca Clark',
#   'Kristin Thompson',
#   'Lisa Richards',
#   'James Wright',
#   'Darrell Robles',
#   'Edward Berger',
#   'Bethany Silva',
#   'Pamela Kidd',
#   'Holly Daniels',
#   'Daniel Potts'],
#  'Trading standards officer': ['Margaret Turner',
#   'Kayla Marshall',
#   'Patricia Vega',
#   'Christy Allen',
#   'Jessica Hernandez',
#   'Isaiah Gillespie',
#   'James Lyons',
#   'Juan Simpson',
#   'Joseph Garcia',
#   'Nicole Hubbard',
#   'Sandra Goodman',
#   'Timothy Lewis',
#   'Christopher Brown',
#   'Amy Randall',
#   'Kim Weaver',
#   'Yvette Salinas',
#   'John Ross',
#   'Kelly Miller',
#   'Linda Vega',
#   'Kari Lam',
#   'Alyssa Nelson',
#   'Pamela Crawford',
#   'Patrick Perez',
#   'Donna Thomas',
#   'Christina Kane',
#   'Karen Brown',
#   'Dr. George Flores Jr.'],
#  'Training and development officer': ['Dr. Brian Santiago',
#   'Cory Ross',
#   'John Anderson',
#   'Eric Dennis',
#   'Kyle Alvarado',
#   'Evan Smith',
#   'Matthew Guerrero',
#   'Randall Bentley',
#   'Melissa Wilson',
#   'Lynn Jennings',
#   'Kathleen Henderson',
#   'Jose Wilson',
#   'Brandy Olson',
#   'Patrick Orr',
#   'William Rhodes',
#   'Mrs. Diane Jackson',
#   'Melissa Summers',
#   'William Knight',
#   'Tasha Moore',
#   'Jessica Sawyer',
#   'Frank Carroll',
#   'Brian Lee',
#   'Jessica Barker',
#   'Brett Green',
#   'Stephen Wagner',
#   'Kara Owens',
#   'Andrew Wells',
#   'Peggy Reynolds'],
#  'Translator': ['Nicole Johnston',
#   'Teresa Jimenez',
#   'Sherry Cook',
#   'Robert Lucas',
#   'Mrs. Lisa Lewis',
#   'Kimberly Wilkins',
#   'April Jones',
#   'Rebecca Perry',
#   'John Patterson',
#   'Mark Clay',
#   'Amber Brown',
#   'Alisha Barnes',
#   'Stacy Jones',
#   'Hannah Johnson',
#   'Lorraine Williams',
#   'Teresa Johnson',
#   'Patricia Hoover',
#   'Erin Warner',
#   'Rose Miranda',
#   'Jordan Hayden',
#   'Caroline Richards',
#   'Laura Collins',
#   'Michael Olson',
#   'Julie Garcia',
#   'Linda Phillips',
#   'Patricia Franklin',
#   'Chelsea Allen',
#   'Brett Davis',
#   'Jodi Lee',
#   'Luke Mejia',
#   'Marisa Evans'],
#  'Transport planner': ['Carla Miller',
#   'Lisa Yoder',
#   'Jennifer Perry',
#   'Julie Smith',
#   'John Edwards',
#   'John Carey',
#   'Robert Howell',
#   'Brenda Austin',
#   'Mike Kemp PhD',
#   'Kelly Villanueva',
#   'Cassidy Robinson',
#   'Robert Johnson',
#   'Jim Wells',
#   'Matthew Cox',
#   'Stacy Bush',
#   'Joshua Brooks DVM',
#   'Robin Love',
#   'Anne Mills',
#   'Barbara Robinson',
#   'Eric Garcia',
#   'Amber Rodriguez',
#   'Mr. Bruce Yang MD',
#   'Christian Hicks',
#   'Jessica Ayala',
#   'Tammy Boone',
#   'Jonathan Davis',
#   'Joseph Gonzalez',
#   'Corey Johnson',
#   'Mike Perez',
#   'Linda Frank'],
#  'Travel agency manager': ['Danny Rivera',
#   'Melissa Jackson',
#   'Brian Kelley',
#   'Gregory Williams',
#   'Anna Cook',
#   'Amanda Barry',
#   'Timothy Nunez',
#   'Bruce Reyes',
#   'Julia Steele',
#   'Emily Blair',
#   'Allison Rush',
#   'Connor White',
#   'Nicholas Bartlett',
#   'Catherine Wyatt',
#   'Sarah Lee',
#   'Natalie Baker',
#   'Carmen Cortez'],
#  'Tree surgeon': ['Andrea Lawson',
#   'Joseph Franklin',
#   'Jasmine Morgan',
#   'Kari Hebert',
#   'Lori Vega',
#   'Frances Benton',
#   'John Lewis',
#   'Michael Hernandez',
#   'Sheryl Henry',
#   'Stephanie Green',
#   'Joy Thomas',
#   'Tamara Scott',
#   'Tracy Walker',
#   'Tanya Price DDS',
#   'Tiffany Huff',
#   'Erin Warner',
#   'Jessica Wolf',
#   'Cesar Lopez',
#   'Elizabeth Guerrero',
#   'Douglas Mata',
#   'Mark Gonzalez',
#   'Joseph Walker',
#   'Michael Nguyen',
#   'Peter Simmons',
#   'Jessica Murphy',
#   'Christina Wilson',
#   'Jamie Howard',
#   'Sarah Horne',
#   'Adrian Brown',
#   'Jason Warren'],
#  'Veterinary surgeon': ['Kristina Lang',
#   'Shari Matthews',
#   'Kelly Johnson',
#   'Dean Flores',
#   'Andrew Williams',
#   'Lisa Brown',
#   'Daniel Lowe',
#   'Adam Roberts',
#   'Brent Anderson',
#   'Frank Williams',
#   'Jonathan Rodriguez',
#   'Brittany White',
#   'Diane Brown',
#   'Richard Brown',
#   'Cheyenne Rich',
#   'Joseph Hernandez',
#   'Amanda Meyer',
#   'Craig Goodman',
#   'Kenneth Mendez',
#   'Tracy Johnson',
#   'Ashley Kirk',
#   'Pamela Miller',
#   'Charlene Matthews'],
#  'Video editor': ['Julie Wagner',
#   'Michael Figueroa',
#   'Albert King',
#   'Elizabeth Haynes',
#   'Donald Hamilton',
#   'Donna Torres',
#   'Kimberly Pearson',
#   'Manuel Evans',
#   'Jeremy Cortez',
#   'Christina Harrison',
#   'Matthew Waller',
#   'Wayne Hernandez',
#   'Katelyn Nelson',
#   'Lance Phillips',
#   'Regina Brown',
#   'Donald Welch',
#   'Curtis Barker',
#   'Dr. Renee Gardner',
#   'Betty Stanley',
#   'Joseph Webb',
#   'Mr. Eddie Mitchell',
#   'Antonio Oneill',
#   'Deanna Beck',
#   'Mark Gonzalez',
#   'Crystal Davis',
#   'Bradley Thomas',
#   'John Sullivan',
#   'Dana Zimmerman',
#   'Laura Harrell',
#   'Matthew Johnson',
#   'Eric Wilkins',
#   'Brenda Walker DDS',
#   'Brandon Deleon'],
#  'Visual merchandiser': ['Casey Harper',
#   'Matthew Jones',
#   'Sara Bowman',
#   'Joshua Estes',
#   'Mrs. Andrea Floyd',
#   'Kayla Graham',
#   'Thomas Conway',
#   'Renee Perry',
#   'Jennifer Stephenson',
#   'Emily Johnson',
#   'Joshua Thomas',
#   'Jeffrey Webb',
#   'Richard Bradley',
#   'John Rhodes',
#   'Felicia Yoder',
#   'Mrs. Emily Harrison MD',
#   'Nicole Davis',
#   'Rose Miranda',
#   'Jennifer Dunlap',
#   'Stephen George',
#   'Sarah Harris',
#   'Mark Coleman',
#   'Robert Rodriguez',
#   'Taylor Rhodes',
#   'Steven Rhodes',
#   'Rebecca Ramirez',
#   'Alexander Taylor',
#   'Kristen Torres',
#   'Richard White'],
#  'Volunteer coordinator': ['Cheryl Lewis',
#   'Kevin Sawyer',
#   'Mary Caldwell',
#   'Hannah Rogers',
#   'Jenna Arnold',
#   'Michelle Cook MD',
#   'Victoria Russell',
#   'Tom Clark',
#   'Justin Carroll',
#   'Michael Kent',
#   'Christian Jensen',
#   'Louis Mitchell',
#   'Nicole Perez',
#   'Heather Gomez',
#   'Amanda Foster',
#   'Laura Foster',
#   'Cindy Jones',
#   'Olivia Williams'],
#  'Warden/ranger': ['Austin Jackson',
#   'Zachary Moreno',
#   'Brent Anderson',
#   'Jordan Burke',
#   'Abigail Carlson',
#   'Kelly Duncan',
#   'Renee Levine',
#   'Dale Vaughn',
#   'Amy Randall',
#   'Justin Peterson',
#   'Sarah Jensen',
#   'Carlos Rodriguez',
#   'Trevor Stewart',
#   'Dr. Amy Brown DDS',
#   'Christopher Reed',
#   'Bethany Brown',
#   'Theresa Williams',
#   'Devin Wilson',
#   'Christine Smith',
#   'Daniel Randall',
#   'Stephanie Pratt',
#   'Mark Weiss'],
#  'Warehouse manager': ['Jordan Pittman',
#   'Kevin Schwartz',
#   'Jacqueline Hunter',
#   'Jacob Barton',
#   'Christine Grimes',
#   'Pamela Jones',
#   'Lisa Cunningham',
#   'Gabriela Eaton',
#   'Kimberly Miller',
#   'Antonio Roberts',
#   'Renee Martinez',
#   'Lydia Clark',
#   'Joseph Webb',
#   'Anne Cooper',
#   'Samantha Fletcher',
#   'Jason Kelly',
#   'Emma Velasquez',
#   'Joel Mcintyre',
#   'Madeline Stokes',
#   'Veronica Sutton',
#   'Stephanie Jimenez',
#   'Rebecca Porter',
#   'Mrs. Ann Duncan',
#   'Devin Wilson',
#   'William Dawson',
#   'Sarah Haney'],
#  'Waste management officer': ['Scott Stone',
#   'Cheryl Rodriguez',
#   'Rodney Lee',
#   'Heather Wells',
#   'Susan Carter',
#   'John Martinez',
#   'Robert Martin',
#   'Robert Miller',
#   'Douglas Weeks',
#   'Matthew Ramirez',
#   'Michelle Gutierrez',
#   'Danielle Cruz',
#   'Kimberly Lawrence',
#   'James Wright',
#   'Jessica Martinez',
#   'Heather Griffith',
#   'Michael Harris',
#   'Max Simpson',
#   'Jeremy Robertson',
#   'Lisa Melton',
#   'Dominic Parker',
#   'Rebecca Porter',
#   'Scott Velazquez',
#   'Diane Cox',
#   'Brian Lopez',
#   'Brian Nicholson'],
#  'Water engineer': ['Kenneth Love',
#   'Andrea Lawson',
#   'Sarah Evans',
#   'John Franklin',
#   'Bradley Nielsen',
#   'Brian Suarez',
#   'Mr. Jeffrey Ballard',
#   'Larry Mack',
#   'Robert Crane',
#   'Linda Rogers',
#   'Kimberly Rodriguez',
#   'Ashley Miller',
#   'Derek Coleman',
#   'Michelle Hayden',
#   'Heather Lee',
#   'Rachel Oliver',
#   'James Frost',
#   'James Bush',
#   'Jeffrey Garcia',
#   'Christina Bennett',
#   'Teresa Johnson',
#   'Melanie Ward',
#   'Sara Hensley',
#   'Paula Olson',
#   'Kristina Miller',
#   'Amber Rodriguez',
#   'Joshua Finley',
#   'Shannon Lucas',
#   'Katherine Pena',
#   'Eric Davis',
#   'Laura Diaz',
#   'Rachel Henry',
#   'Dawn Carpenter',
#   'William Guzman',
#   'Wendy Strickland',
#   'Jacqueline Henry'],
#  'Water quality scientist': ['Rebecca Casey',
#   'Sara Bowman',
#   'Nicole Olson',
#   'William Myers',
#   'Melissa Brown',
#   'Jamie Morris',
#   'Andrea Contreras',
#   'Joanna Webster',
#   'Joseph Garcia',
#   'Hannah Lynn',
#   'Lauren Thomas',
#   'Gregory Pennington',
#   'Thomas Smith',
#   'David Jones',
#   'Dustin Roman',
#   'Justin Valencia',
#   'Peter Roy',
#   'Randy Russell',
#   'Benjamin Webster',
#   'Sue Montgomery',
#   'Todd Compton',
#   'Eileen Mcgee',
#   'Anthony Wilson',
#   'Heather Steele',
#   'Michael Wells',
#   'Jessica Kemp',
#   'Cynthia Bolton',
#   'Daniel Martin',
#   'Brian Johnson',
#   'Christopher Lewis'],
#  'Web designer': ['Christian Mathews',
#   'Walter Fuller',
#   'Brandon Hill',
#   'Mr. Matthew White DDS',
#   'Joe Clark',
#   'Lisa Morales',
#   'Megan Kramer',
#   'Scott Bush',
#   'Pamela Franco',
#   'Stephen Robinson',
#   'Andrea Williams',
#   'Kristy Day',
#   'Kimberly Kane',
#   'Jeffrey Greene',
#   'Michael Lin',
#   'Martha Evans',
#   'Phillip Miles',
#   'Lynn Barrett',
#   'Keith Tran',
#   'Emily Bell',
#   'James Quinn',
#   'Faith Wallace',
#   'Sarah Hood',
#   'Samantha Jackson'],
#  'Wellsite geologist': ['Christopher Anderson',
#   'Joseph James',
#   'Jill Williamson',
#   'Brooke Scott',
#   'Destiny Elliott',
#   'Gary Ortiz',
#   'Dennis Macdonald',
#   'Gregory Gilbert',
#   'Kenneth Peck',
#   'Wayne Haynes',
#   'Christopher Price',
#   'Tonya Kelley',
#   'Jordan Hayden',
#   'Yesenia Mills',
#   'Jessica Carpenter',
#   'Jacqueline Waters',
#   'James Walker',
#   'Jennifer Moreno',
#   'Erin Ruiz',
#   'Anita Dunn',
#   'Daniel Moore'],
#  'Writer': ['Michael Lynch',
#   'Tracy Allen',
#   'James Morales',
#   'Megan Robertson',
#   'Erin Hernandez',
#   'Michelle Francis',
#   'John Baker',
#   'Lee Burns',
#   'Beverly Harris',
#   'Linda Brown',
#   'Shirley Johnson',
#   'William Moody',
#   'Angelica Rodriguez',
#   'Blake Khan',
#   'Valerie Jones',
#   'Janet Ellison',
#   'Marvin Morales',
#   'Jeanne Hooper',
#   'Matthew Young'],
#  'Youth worker': ['Nicholas Harrington',
#   'Tammy Rodriguez',
#   'Christina Stone',
#   'Christopher Long',
#   'Brian Floyd',
#   'Robert Wallace',
#   'Jeffrey Smith',
#   'James Curtis',
#   'John Gray',
#   'Victor Watson',
#   'Shannon Lewis',
#   'Edward Mullins',
#   'John Gallagher',
#   'Pamela Alexander',
#   'Jody Johnson',
#   'Kayla Snyder',
#   'Mark Miller',
#   'Claudia Hernandez',
#   'Kevin Cain',
#   'David Snyder',
#   'Bryan Yates',
#   'Randy Murphy',
#   'Blake Olsen',
#   'Emily West',
#   'Angela Simpson',
#   'Kimberly Anderson',
#   'Lisa Nguyen',
#   'Mallory Johnston',
#   'Janet Walker',
#   'Ian Hill',
#   'Steven Williams',
#   'John Williams',
#   'Terry Dunn']}

# %% [markdown]
# 2.2 Сохраните результаты в файл `job_people.pickle` и в файл `job_people.json` с использованием форматов pickle и JSON соответственно. Сравните объемы получившихся файлов. При сохранении в JSON укажите аргумент `indent`.

# %%
#import pickle

# %%
#with open('job_people.pickle', 'wb') as file:
#    pickle.dump(job_people, file)

# %%
#with open('job_people.json', 'w', encoding='utf-8') as file:
#    json.dump(job_people, file, indent = 4)

# %% [markdown]
# 2.3 Считайте файл `job_people.pickle` и продемонстрируйте, что данные считались корректно.

# %%
#with open('job_people.pickle', 'rb') as f:
#    job_people_pickle = pickle.load(f)
    
#job_people_pickle

# %% [markdown]
# ### XML

# %% [markdown]
# 3.1 По данным файла `steps_sample.xml` сформируйте словарь с шагами по каждому рецепту вида `{id_рецепта: ["шаг1", "шаг2"]}`. Сохраните этот словарь в файл `steps_sample.json`

# %%
with open('steps_sample.xml') as fp:
    steps_sample = BeautifulSoup(fp, 'xml')
    
steps_sample.recipe
# Out:
# <recipe>
# <id>44123</id>
# <steps>
# <step has_minutes="1">in 1 / 4 cup butter , saute carrots , onion , celery and broccoli stems for 5 minutes</step>
# <step>add thyme , oregano and basil</step>
# <step has_minutes="1">saute 5 minutes more</step>
# <step>add wine and deglaze pan</step>
# <step>add hot chicken stock and reduce by one-third</step>
# <step>add worcestershire sauce , tabasco , smoked chicken , beans and broccoli florets</step>
# <step has_minutes="1">simmer 5 minutes</step>
# <step has_minutes="1">add cream , simmer 5 minutes more and season to taste</step>
# <step>drop in remaining butter , piece by piece , stirring until melted and serve immediately</step>
# <step>smoked chicken: on a covered grill , slightly smoke boneless chicken , cooking to medium rare</step>
# <step>chef meskan uses applewood chips and does not allow the grill to become too hot</step>
# </steps>
# </recipe>

# %%
recipe_steps_dict = {}

for recipe in steps_sample.find_all('recipe'):
    recipe_steps_dict[recipe.id.next] = []
    for step in recipe.steps.find_all('step'):
        recipe_steps_dict[recipe.id.next].append(step.next)

recipe_steps_dict
# Out:
# {'44123': ['in 1 / 4 cup butter , saute carrots , onion , celery and broccoli stems for 5 minutes',
#   'add thyme , oregano and basil',
#   'saute 5 minutes more',
#   'add wine and deglaze pan',
#   'add hot chicken stock and reduce by one-third',
#   'add worcestershire sauce , tabasco , smoked chicken , beans and broccoli florets',
#   'simmer 5 minutes',
#   'add cream , simmer 5 minutes more and season to taste',
#   'drop in remaining butter , piece by piece , stirring until melted and serve immediately',
#   'smoked chicken: on a covered grill , slightly smoke boneless chicken , cooking to medium rare',
#   'chef meskan uses applewood chips and does not allow the grill to become too hot'],
#  '67664': ['mix all the ingredients using a blender',
#   'pour into popsicle molds',
#   'freeze and enjoy !'],
#  '38798': ['combine all ingredients in a large bowl and mix well',
#   'shape into one-inch balls',
#   'cover and refrigerate or freeze until ready to bake',
#   'preheat oven to 350 degrees',
#   'place on ungreased baking sheet and bake until light brown'],
#  '35173': ['lay out sandwich rolls on jelly roll pans / cookie sheets',
#   'melt butter , mix in italian dressing mix',
#   'using a pastry or bbq brush , graciously apply seasoned butter to the top of the"bottom bun" and the top of the top bun',
#   "don't miss this step , i don't know why , but it does make a difference !",
#   'here is where i create an assembly line w / the bottoms of the buns',
#   'layer each bun w / ham , then swiss cheese , turkey , then cheddar cheese , pepperoni , then mozzerella cheese',
#   'place"lids" on buns and place in 425 degree oven for approximly 12-15 minutes , or until you see the tops start to turn golden brown'],
#  '84797': ['honey mustard sauce: whisk all the ingredients together serve warm or cold',
#   'easy bbq sauce: combine all ingredients in a pot& cook over low heat until the sugar is dissolved',
#   'serve warm or cold',
#   'garlic dill sauce: mix all the ingredients and chill until ready to serve'],
#  '44045': ['combine eggs , flour , baking powder , salt& pepper with the corn',
#   'mix thoroughly',
#   'add cream to mixture',
#   'melt fat in frying pan& drop corn mixture by spoonfuls into the hot fat',
#   'brown on both sides',
#   'serve w / syrup'],
#  '107229': ['cook pasta in salted water until al dente',
#   'drain',
#   'steam broccoli , set aside',
#   'whisk next 6 ingredients together in large serving bowl',
#   'add hot pasta',
#   'stir in onions , broccoli , and chicken',
#   'toss in cilantro',
#   'sprinkle on sesame seeds'],
#  '95926': ['spread a tablespoon on one side of each slice on bread',
#   'peel and cut the bananas into 1 / 4-inch round slices',
#   'lay the slices on two of the slices of bread and then top with the other half',
#   'enjoy !'],
#  '453467': ['pre-heat oven the 350 degrees f',
#   'in a mixing bowl , sift together the flours and baking powder',
#   'set aside',
#   'in another mixing bowl , blend together the sugars , margarine , and salt until light and fluffy',
#   'add the eggs , water , and vanilla to the margarine / sugar mixture and mix together until well combined',
#   'add in the flour mixture to the wet ingredients and blend until combined',
#   'scrape down the sides of the bowl and add the chocolate chips',
#   'mix until combined',
#   'scrape down the sides to the bowl again',
#   'using an ice cream scoop , scoop evenly rounded balls of dough and place of cookie sheet about 1 - 2 inches apart to allow for spreading during baking',
#   'bake for 10 - 15 minutes or until golden brown on the outside and soft & chewy in the center',
#   'serve hot and enjoy !'],
#  '306168': ['preheat oven to 350 degrees',
#   'spray a 2 quart baking dish with cooking spray , set aside',
#   'in a large bowl mix together broccoli , soup , one cup of cheese , garlic powder , pepper , salt , milk , 1 cup of french onions , and soy sauce',
#   'pour into baking dish , sprinkle remaining cheese over top',
#   'bake for 25 minutes or until cheese is lightly browned',
#   'sprinkle with rest of french fried onions and bake until onions are browned and cheese is bubbly , about 10 more minutes'],
#  '50662': ['coat the meat with 1 / 2 c of flour and the paprika',
#   'brown in vegetable oil',
#   'transfer to a casserole dish',
#   'add can of onions',
#   'combine one can of the chicken soup and one can water',
#   'pour over meat and onions',
#   'bake at 350 for 45 minutes',
#   'while the meat is baking-- combine 2 c flour , the baking powder , salt , poultry seasoning , celery seed , onion flakes and poppy seeds',
#   'mix well , and add 1 / 4 c oil and 1 c milk',
#   'drop tablespoons of dough into breadcrumbs which you have mixed with melted butter',
#   'put dumplings on top of the meat',
#   'increase heat to 425 and bake for another 20 minutes',
#   'make sauce',
#   'combine one can of cream of chicken soup and sour cream',
#   'heat sauce and serve over meat and dumplings'],
#  '118843': ['mix all ingredients together just until blended',
#   'spoon large tbspfuls onto a baking sheet',
#   'bake at 350 for 10-14 minutes'],
#  '69190': ['cook potatoes , onions , celery , and carrots in water until tender',
#   'meanwhile , in other pan , put in milk , butter , cream of chicken , cream of celery , and bullion cubes on low heat',
#   'when potatoes and the vegetables are tender , pour in the milk , butter , the cream of chicken and cream of celery , with the bullion cubes into the pan with the potatoes',
#   'put on medium heat and stir in potato flakes occasionally',
#   'enjoy !'],
#  '503475': ['beat the eggs lightly and add the milk',
#   'combine the flour , sugar and salt',
#   'stir the flour mixture into the egg mixture , stirring in the cup of cream as you mix',
#   'fry the apple slices in butter in a skillet',
#   'preheat oven to 500 degree',
#   'cover the bottom of an oven-proof baking dish , or heavy skillet , with apples',
#   'pour the batter over slices and bake in a preheated 500 oven',
#   'when nearly done , remove from oven and sprinkle here and there with a mixture of sugar and cinnamon to taste',
#   'place dabs of butter on the pancake and return to oven until browned',
#   'just before serving , sprinkle with lemon juice , and cut into triangles'],
#  '149593': ['set oven to 400 degrees',
#   'set oven rack to second-lowest position',
#   'grease 12 regular size muffin tins or line with paper muffin liners',
#   'in a bowl sift together flour , 1 / 2 cup plus 2 tablespoons sugar , baking powder , baking soda and salt',
#   'in another bowl whisk together melted butter with sour cream , egg and vanilla or almond extract',
#   'stir in the butter mixture into the flour mixture',
#   'stir with a wooden spoon just until combined',
#   'divide the batter between each muffin tin',
#   'if you want you can sprinkle with a topping',
#   'bake for about 20 minutes or until muffins test done'],
#  '200148': ['for crust:',
#   'melt margarine and blend well with graham cracker cumbs and sweetener',
#   'press well into bottom of spring-form pan or round cake pan',
#   'bake at 350f for 10 minutes',
#   'let cool',
#   'filling:',
#   'mash tofu with vegan cream cheese',
#   'add all other ingredients to tofu mixture and whip with hand mixer until well blended and very creamy',
#   'try to get all tofu lumps out',
#   'pour into crust and bake at 350f for 45-50 minutes',
#   'turn off oven and leave in for 15 minutes more to help set center',
#   'when done edges should be golden and starting to pull away from sides of pan , center should be soft set',
#   'cool about an hour then refrigerate another 3 hours to set center',
#   'keep refrigerated',
#   'helpful hints: draining the tofu well is important',
#   "too much liquid and the center won't set well",
#   'after slicing the cake place a paper towel in the cut out section before returning it to the frige',
#   'this will absorb any fluid that will condense on the plate or in the pan and keep the bottom of the cake from getting too soggy'],
#  '310570': ['first - let me explain the feta',
#   'we have an italian market that sells fresh fruits and veggies etc',
#   'and they have a fresh cheese section',
#   'i always buy a block of french feta cheese',
#   'i use half for this recipe and the rest for omelets etc',
#   "you can use the prepacked feta but if you want the full experience you'll need a lot",
#   'also , you may use other variety of feta the french is very salty which is why i add cottage cheese',
#   'it kind of balances out the saltiness abit',
#   'you just need 1 package of phyllo',
#   'mine says 32 oz , buy the long box not the country',
#   'preheat oven to 350f',
#   'in large mixing bowl beat eggs , add 2 cups milk and mix well',
#   'take your block of feta and cut in half',
#   'use one 1 / 2 and refrigerate the other',
#   'crumble the feta into the egg mix and add cottage cheese',
#   'make sure you have nice chunks',
#   'mix well , the mixture should be thick and very lumpy',
#   'if too thick add more milk',
#   'take a large deep baking dish',
#   'sprinkle oil on bottom only',
#   'lay one sheet phyllo and drizzle with oil , continue until you have 4 sheets',
#   'when you add the last sheet place your hand flat on the phyllo sheets and gently gather , without tearing by pulling the sides slightly toward center',
#   ':)',
#   "use 1 full ladle of the egg / feta mixture onto the layer , you don't need to cover all the phyllo just don't leave the feta in one spot distribute",
#   'layer another phyllo sheet and sprinkle with oil',
#   'layer another sheet of phyllo and again crumple the center then sprinkle the oil',
#   'one ladle of the egg / feta mix',
#   'continue in this pattern',
#   'if you see that you have alot of the egg / feta mix left you can start to add more than the 1 ladle',
#   'your last layer should be 3-4 layers of phyllo',
#   "don't sprinkle with oil yet",
#   'take a soup spoon and with the handle , tuck in the sides',
#   'now sprinkle with oil',
#   'bake for about 30-40 minutes or until the top is puffed and nicely browned',
#   'your kitchen with smell wonderful',
#   'the burek will puff high off the top of the pan but once cooled will drop',
#   'you must cool completely or you will nto be able to cut with out it falling apart',
#   "it's moist and a bit salty and goes great with a nice cold beer ! you can serve as main meal with salad or as appetizer"],
#  '95534': ['preheat oven to 325f',
#   'sprinkle the roast with garlic powder , oregano and pepper , then cook roast , uncovered , in a shallow roasting pan , about 30 minutes per pound',
#   "roast will be very rare-- don't overcook it !",
#   'let cool slightly , then thinly slice',
#   "add to the roast's pan drippings: the boiling water , bouillon cubes , oregano , thyme , pepper , tabasco sauce , garlic and worcestershire sauce",
#   'simmer for 20 minutes , scraping up the browned bits',
#   'taste for salt and add some if you wish',
#   'add the sliced beef',
#   'cover and marinate in da gravy overnight',
#   'reheat the next day and serve in crusty italian sandwich rolls'],
#  '109818': ['preheat oven to 350f',
#   'cook bacon until crisp',
#   'drain grease and crumble into fine bits',
#   'peel and slice carrots , place into baking dish',
#   'add tomato soup , bacon and sugar and stir well',
#   'bake for 30-45 minutes until bubbly',
#   'eat and enjoy !'],
#  '66932': ['heat 1 tbsp oil in pan and saut mushrooms until browned',
#   'remove from heat',
#   'heat remaining oil in pan and add rice',
#   'add egg and mix until rice is thoroughly coated with egg',
#   'cook for 5-10 minutes on high , or until egg is lightly browned',
#   'combine rice mixture and vegetables in large bowl and stir until vegetables are well mixed',
#   'add soy sauce to taste and serve'],
#  '226001': ['heat water and butter to rolling boil',
#   'stir in flour , stirring vigorously over low heat about 1 minute , or until mixture forms a ball',
#   'remove from heat',
#   'beat in eggs all at one time and continue beating until smooth',
#   'drop dough by scant 1 / 4 cupfuls about 3" apart on ungreased baking sheet',
#   'bake at 400 for 35 to 40 minutes , or until puffed and golden',
#   'cool out of draft',
#   'cut in half horizontally , open , and remove any uncooked filaments of dough',
#   'make dream whip according to package directions',
#   'make pudding with only half the milk it calls for',
#   'quickly add the pudding to the dream whip and mix well',
#   "fill cream puffs , sprinkle with a little powdered sugar and refrigerate until serving -- if you don't eat them first !"],
#  '125195': ['in large bowl , combine mayo , relish , sugar , seas',
#   'salt and mustard',
#   "gently fold in rest of ingredients adding peas last so they don't get broken up and mushy",
#   'chill',
#   'if you like it extra creamy , double the sauce'],
#  '141939': ['in a large bowl whisk the buttermilk , oil , hot pepper sauce , minced garlic , dijon mustard , 1 teaspoon salt and about 1 / 2 teaspoon black pepper',
#   'add in sliced onion and chicken pieces',
#   'turn to coat / mix well',
#   'cover and refrigerate for a minimum of 4 hours or up 24 hours , turning occasionally',
#   'place a cookie rack on a foil-lined 15x10-inch baking sheet',
#   'in a bowl mix together dry breadcrumbs , parmesan cheese , flour , thyme spice , paprika , cayenne pepper , 1-1 / 2 teaspoon seasoned salt salt and garlic powder',
#   'remove the chicken pieces from marinade , allowing any excess marinade to drip off the chicken',
#   'dip the chicken pieces into the breadcrumb mixture and turn to coat completely',
#   'arrange chicken on rack or racks on the baking sheets',
#   'let chicken stand for 30 minutes , no more no less !',
#   'set oven to 425f',
#   'drizzle the melted butter over the chicken pieces',
#   'bake until crisp , golden and cook through about 45 minutes'],
#  '250883': ['beat cream cheese , limeade concentrate and orange juice in medium bowl with electric mixer on medium speed until well blended',
#   'gently stir in cool whip topping',
#   'cover',
#   'refrigerate at least one hour',
#   'serve with cut-up fresh fruit',
#   'to grill fruit:',
#   'peaches , nectarines and plums get a deep caramel-like flavor when cooked on the grill',
#   "here's how to do it",
#   'put pieces of fresh fruit on skewers',
#   "use fruit that's just staring to soften , so that it stays firmly on the skewers",
#   'sprinkle fruit with cinnamon or nutmeg',
#   'place fruit on the grill for a minute to sear',
#   'check the underside',
#   "once it's golden with grill marks , turn it over to finish cooking"],
#  '120297': ['preheat the oven to 200c',
#   'wash the potatoes to remove any dirt , pat dry with paper towels',
#   'prick the potatoes all over with a fork , brush with olive oil and season to taste with salt and pepper',
#   'place the potatoes on a lightly greased baking tray and bake for about an hour or until cooked through',
#   'cool for about 10 minutes',
#   'while the potatoes are roasting , drain the chickpeas , place in a large mixing bowl and mash with a fork',
#   'add the ground coriander , the cumin , the crushed garlic and half the fresh coriander',
#   'cover the bowl with with plastic wrap , and set aside',
#   'once they have cooled , taking care to keep the shells intact , halve the cooked potatoes and scoop out the flesh',
#   'mash the potato flesh until smooth and gently mix with the chickpea mixture',
#   'fold in the yoghurt and tahini , and add a little more of either of these if the mixture seems too dry , season with the pepper and salt , to taste',
#   'place the potato shells on a lightly greased baking tray and fill them with the potato and chickpea mixture',
#   'place the filled potato shells in the oven and bake for 10-15 minutes , or until heated through',
#   'serve the potatoes with the remaining half of the chopped coriander'],
#  '147477': ['mix together and bake until cheese melts',
#   'best when served warm with assorted crackers',
#   'can be used chilled as a spread'],
#  '223349': ['heat oil in a nonstick skillet over medium high heat and add eggplant and cook until almost soft',
#   'bake spaghetti squash at 450f for 1-2 hours until firm to the touch , let cool and then scoop out pulp',
#   'add peppers , onions and oregano to eggplant and saut until tender',
#   'stir in shrimp',
#   'cover and steam , stirring every so often',
#   'add in spaghetti squash and cook for less than a minute',
#   'add olives and parsley: toss again & serve !'],
#  '60938': ['preheat oven to 375f',
#   'cook the diced bacon until crispy , remove from bacon fat and drain on paper towel',
#   'forget everything you were ever taught about peeling potatoes , and peel them with a knife leaving a good bit of potato on the skin',
#   'retain center of potatoes for another recipe , or slice them into wedges and cook in the same manner as the potato skins',
#   'deep fry the potato skins until crispy and golden',
#   'drain thoroughly and salt to taste',
#   'spread the potato skins evenly on a pizza pan',
#   'sprinkle evenly with the green onions , cheese and bacon',
#   'bake for 10-15 minutes until hot and cheddar is melted',
#   'serve hot with sour cream for dipping'],
#  '302399': ['preheat oven to 400 degrees',
#   'lightly grease a cookie sheet',
#   'remove the buiscuits from the can and separate',
#   'place one buiscuit in the center and place the remaining buiscuit around it slightly overlapping',
#   'now flatten them out with your fingers into a 10 inch circle',
#   'brush with the olive oil',
#   'sprinkle with the remaining ingredients',
#   'you can use any kind of cheese you have on hand',
#   'chili powder and monterey jack and some chopped chillies give you a great tex-mex bread',
#   'bake about 15 minute until edges are nice and brown',
#   'pull apart to serve'],
#  '342620': ['preheat oven to 350 degrees',
#   'while oven is preheating , mix in a large bowl all ingredients except for the 1 / 8 cup of bbq sauce',
#   'spray a 2 quart baking dish with the cooking spray',
#   'pour meatloaf into dish , and free form into a loaf shape',
#   'bake for 45 minutes , then drain if needed',
#   'take remaining bbq sauce and spread over top and sides',
#   'return meatloaf to over and bake for 10 to 15 minutes',
#   'let meatloaf "rest " for 10 minutes , serve and enjoy',
#   ':)'],
#  '296983': ['preheat oven to gas mark 8',
#   'cut your potatoes into 1 inch chunks',
#   'toss in a bowl the potatoes in the oil with the rosemary and lemon juice and lemon zest and garlic',
#   'chuck the lot onto a baking tray not forgetting to scrape herbs and oil from the bowl',
#   'bake for twenty minutes while listening to funky tunes and enjoying the yumminess that is to come',
#   'check that potatoes are firm yet "give" with a fork',
#   'squish them a little bit with a fork and put back in oven for another 10 minutes on gas mark 3',
#   'listen to more tunes',
#   'serve with a squirt of fresh lemon and with greek or curry or vegan stuff or just eat out of pan',
#   'i suggest tatskiki',
#   'you can pulverize this into a dip using more olive oil and lemon juice or eat it chunky',
#   'i like chunks',
#   'i reckon this would make an ace potato salad base',
#   "i absolutely hate mayonnaise , so there's no chance of me making that ever ! however you're welcome to try--i'll let you"],
#  '166089': ['for immediate cooking:',
#   'preheat oven to 350f',
#   'combine sauce ingredients and blend until smooth',
#   'toss chicken with sauce and place into a large baking dish',
#   'bake until chicken juices run clear',
#   'for freezing:',
#   'combine sauce ingredients until smooth',
#   'place sauce and chicken into a 1-gallon freezer bag',
#   'shake to coat chicken',
#   'lay flat in freezer',
#   'to thaw and cook:',
#   'thaw completely',
#   'preheat the oven to 350f',
#   'empty the contents of the bag into a large baking dish and bake until the juices run clear'],
#  '129581': ['preheat over to 350f',
#   'put all ingredients for the cake in a bowl',
#   'mix on low for 1 minute to combine',
#   'scrape bowl',
#   'mix on medium high for a full 3 minutes to make it light and fluffy',
#   "spray an angel tube pan or bundt pan with baker's spray",
#   'pour batter in pan and bake for 45 to 50 minutes until done',
#   'let cool in pan and then turn out onto you serving platter',
#   'while cake is cooling , make topping and frosting',
#   'put chopped chocolate in heatproof bowl',
#   'heat cream in a saucepan on medium high until it starts to boil',
#   'as soon as it starts to bubble , pull it off the heat and pour the hot cream over the chocolate',
#   'stir immediately with a whisk to incorporate the cream into the chocolate',
#   'stir until completely melted',
#   'let it cool',
#   'when it gets to spreading consistency you want to coat your cake',
#   'for the topping , combine sugar , cornstarch and salt to a heavy saucepan',
#   'add the coconut milk and cream of coconut',
#   'heat on medium heat and stir until smooth and starts to boil',
#   'stir until it thickens , about 5 - 7 minutes',
#   'keep stirring so that it does not stick to pan',
#   'take the pan off the heat and pour the mixture into a larger bowl and add shredded coconut',
#   'stir to combine',
#   'let this cool completely',
#   'take about a half cup of the topping and stuff it into the middle of the cake',
#   'fill it to the rim and flatten off with a table knife',
#   'then frost cake , the frosting will be smooth and runny so the technique here is to place a dollop of frosting on the top of cake , coax it over to the side with knife so it starts to run down the side',
#   'spread smoothly along the side of cake',
#   'take cake and put it in the refrigerator until the frosting firms up just like the candy bar',
#   'this will take about 30 minutes or so',
#   'after that , take cake out of refrigerator and you are going to mound the remaining half of your coconut topping on the top of the cake',
#   'place back in the refrigerator for about 30 to an hour',
#   'i know that this sounds like a lot of work , but this cake is truly decadent !'],
#  '116741': ['blend well and chill', 'enjoy !'],
#  '325714': ['make sure the eggs are room temperature put parchment paper in the bottom of your cake pan',
#   'mix together the flour , baking powder , baking soda , cinnamon , nutmeg and sugar , salt , set aside',
#   'in another bowl beat the eggs for ~30 sec , add the melted butter , add the shredded carrot',
#   'bake at 350f for 35-40 minutes , then check the cake , it is done when it springs back when lightly pressed in the center and the toothpick comes out clean',
#   'fill and cover with cream cheese frosting',
#   "other recipes i have seen for cream cheese frosting use tons of powdered sugar , i use 2-3 cups maximum , because i don't like it over sweet , but you add as much as you think it needs"],
#  '276594': ['combine beef , eggs , salt , pepper , onion , garlic and breadcrumbs',
#   'shape into 48 meatballs and brown till no longer pink inside',
#   'drain off excess fat on paper towels',
#   'combine vinegar , brown sugar , ketchup , soy sauce , reserved pineapple juice and cornstarch',
#   'simmer till thickened , stirring occasionally',
#   'add meatballs , pineapple and sweet pepper and simmer until thoroughly heated'],
#  '487173': ['1',
#   'cover the top of your pizza stone or , if you dont have one , the inside of a cookie sheet with a good dusting of flour',
#   '2',
#   'pre-heat your oven to 425 degrees f',
#   '3',
#   'pour 3 tablespoons of evoo into a small bowl',
#   '4',
#   'cut out a chunk of your 5-minute bread dough , big enough to be the size somewhere in between a baseball and a softball',
#   '5',
#   'with your fingers flatten the dough to fit on top of your pizza stone or cookie sheet',
#   'from this point on , the crust will remain on the stone or cookie sheet until the pizza is done',
#   '6',
#   'with a pastry brush , cover the top of the flattened dough with a thin layer of the olive oil',
#   '7',
#   'turn the dough over and brush the other side with olive oil',
#   '8',
#   'partially bake the dough for about 7 minutes and take it out of the oven',
#   '9',
#   'using a large spoon or a ladle , spread the pizza sauce on top of the partially-baked crust and cover it as evenly as possible to within one inch of the edges',
#   '10',
#   'distribute the rest of the ingredients all over the top of the pizza sauce',
#   'be creative , my grandchildren like it when i make smiling faces with the pepperoni , black olives and the peppers',
#   '11',
#   'cover the top of the pizza completely with the mozzarella all the way to the edge',
#   '12',
#   'place the pizza stone or cookie sheet in the 425 degree oven and bake for approximately 20 minutes or until the cheese is bubbly and the edges of the crust have turned a dark , golden brown',
#   'if the edges are very light , this may mean that the center of the crust is still raw',
#   '13',
#   'take the pizza out of the oven and place it on a fire-resistant surface',
#   'let it rest for approximately 10 minutes , slice and enjoy !'],
#  '289671': ['in a blender combine coffee with ice cream and chocolate syrup',
#   'blend until smooth',
#   'add in sugar and blend slightly until combined',
#   'place about 1 cup crushed ice in two large tall glasses',
#   'divide the mixture into the glasses',
#   'top with a dollup of whipped cream'],
#  '44050': ['beat cream cheese , sugar , vanilla& salt until fluffy',
#   'fold in cool whip'],
#  '447429': ['in a large skillet , cook bacon',
#   'drain',
#   'crumble',
#   'set aside in a medium bowl',
#   'do not discard grease from skillet',
#   'in same skillet with bacon grease brown beef , onion , celery , garlic powder and pepper',
#   'remove with slotted spoon to bowl with bacon',
#   'be sure to remove all solids from skillet , leaving fat',
#   'add tomatoes to the beef mixture',
#   'peel potatoes and cut into 1 / 2" dice',
#   'when fat in skillet is very hot again , fry potato cubes on all sides until well browned',
#   'drain',
#   'remove to bowl with bacon and beef',
#   'in soup pot , melt butter and add flour',
#   'whisk for 1 minute to cook flour',
#   'add chicken broth and half-and-half',
#   'cook , whisking constantly , until you see the first signs of thickening',
#   'begin adding grated cheeses , a little at a time , whisking constantly , until soup is bubbling , creamy and thick',
#   'remove from heat',
#   'add parsley , mustard and relish',
#   'stir well',
#   'add bowl of bacon and beef mixture and potatoes',
#   'stir',
#   'cover and let stand 5 minutes'],
#  '137701': ['nb: i like to use a fairly strong flavoured , but creamy blue cheese , like gorgonzola , but stilton is also nice',
#   'stock-wise , you may need a little more or less than in the ingredients list',
#   'bring stock up to a simmer',
#   'halve the leeks and remove any gritty bits from inside the rings',
#   'cut the leek into fine strips rather than semi-circles , of approx 1-2 inches in length',
#   'melt half the butter with the olive oil and cook the leeks for approx 10 minutes over a low-medium heat until soft and tinged with brown',
#   'add bacon to pan and cook for about 5 minutes',
#   "stir in garlic and rice , cook for a further minute or two , stirring the rice until it's coated in the butter and oil and starts to go slightly translucent",
#   'add the wine to the pan , turning up the heat to bubble most of it away',
#   'add a ladleful of hot stock to the leek and rice mixture at a time , stirring more or less constantly',
#   'add more stock each time that most of the liquid has been absorbed',
#   'add the fresh sage',
#   'keep doing this for approximately 15 - 25 minutes , until the risotto is creamy , but the rice grains still have a slight bite',
#   "you'll need to start testing the rice after about 15 minutes , but it may take a little longer",
#   'turn off the heat',
#   'stir in the lemon juice , zest , remaining butter , parmesan and blue cheese',
#   'leave the risotto for another 2 minutes until rich , creamy and luscious',
#   'season to taste with black pepper and salt if needed'],
#  '292568': ['add these 3 ingredients to boxed caked mix', 'mix as usual'],
#  '299989': ['cut up chicken and add cumin , taco seasoning salt + pepper , paprika , and adobo , set to the side',
#   'cook rice according to the directions on the box',
#   'in a large saute or frying pan on med-high heat , estimate and add 2 tablespoons extra virgin olive oil',
#   'add chicken',
#   'while chicken is cooking , peel avacados and make guacamole according to package directions',
#   'refrigerate',
#   'open cans of black beans , corn , diced tomatoes with chiles and cilantro and put in small bowls',
#   "if you'd like , you can warm , the can of beans and corn",
#   "don't warm the can of diced tomatoes , unless you like warm salsa / tomato mixture",
#   'once chicken and rice is done , you can start plating',
#   'letting everyone add the toppings of their choice is part of the fun of the meal !',
#   'p',
#   's',
#   'suggestion for plating - put shredded lettuce in bowl or plate first - then add rice , then chicken , then toppings'],
#  '63346': ['heat oven to 350 , grease and flour 13x9 baking pan',
#   'beat eggs , sugar and oil until light and fluffy',
#   'sift together flour , baking powder , baking soda and cinnamon',
#   'add to egg mixture and mix well',
#   'add vanilla , beets and walnuts',
#   'beat for 1 minute on medium speed',
#   'pour into pan , bake for 45 minutes , or until a pick comes out clean'],
#  '342619': ['turn the machine quickly from variable speed 1 to 10 then flip the switch to high',
#   'push the ingredients down into the blades until the entire mixture is blending',
#   'i find it easier to push the food continuously down one corner of the container and eventually it begins to blend',
#   'the apple may require a bit of "pounding" before it begins to mix',
#   'when the mixture is first blending it should be so thick and slushy that it is thick like a thick "slushy"',
#   'if it is too liquid at the beginning , add more ice so it is thick and "slushy"',
#   'this allows you to blend for 1-2 minutes without warming the drink up from the friction of the blades',
#   'it also allows you to break the foods down to the most bioavailable level',
#   'this is a "beginner" green smoothie that 98% of the population will love !'],
#  '383120': ['loosen the yakisoba noodles in a large pan',
#   'in a large saut pan , add the cooking oil , cook in medium heat',
#   'add the fresh garlic , about 10 seconds , add the granulated garlic',
#   'add the noodles right away , then , add the chicken broth',
#   'stir the noodles around to blend with the garlic mix',
#   'add the soy sauce , and then the fish sauce',
#   'stir constantly but be careful not to break the noodles apart',
#   'cook until noodles are smooth and coated',
#   'add the oyster sauce and stir about 5 more minutes',
#   'serve plain or with any of the toppings mentioned above'],
#  '367987': ['in an airtight container , combine vinegar , sugar , salt , mustard , paprika , and garlic',
#   'close container and give it a good shake',
#   'add oil , close container , and shake until evenly blended'],
#  '463219': ['in a medium saucepan , soften the onion in butter',
#   'add flour and stir 1 minute',
#   'add warm milk',
#   'stir until the mixture has thickened',
#   'meanwhile , in a large saucepan , cook pasta in a large quantity of salted boiling water until al dente',
#   'drain pasta and add to the sauce',
#   'add all cheeses , paprika , cayenne pepper and salt',
#   'stir until cheese has melted'],
#  '39172': ['mix the first 5 ingredients together in a large bowl',
#   'in another bowl , combine the eggs , apple sauce , oil and vanilla',
#   'in another bowl mix carrots , apple , pineapple , raisins , walnuts and coconut',
#   'add egg mixture to dry ingredients and mix until partially incorporated , using as few strokes as possible',
#   'add fruit mixture to egg-flour mixture and mix , using as few strokes as possible , until batter is just moistened and fruit is incorporated',
#   "don't over mix if you want light , fluffy muffins",
#   'fill greased muffin cups two-thirds full',
#   'bake at 350 for 20-24 minutes or until toothpick inserted in middle comes out clean'],
#  '216068': ['combine all ingredients except noodles in slow cooker',
#   'cook on low for 6-7 hours , stirring occasionally if you can , until beef is cooked through and vegetables are tender',
#   'add noodles and cook on low for 1 hour , or until soft'],
#  '173730': ['first you need some home-made chicken stock',
#   "don't use store bought powder , it's not hard to make - i promise you this as a former kitchen assassin turned food-lover !",
#   'to make stock:',
#   'bring 3 l of water to a boil in a 4-6 l pot',
#   'add the chicken frames , a good dash of salt and the bay leaves',
#   'you will add more salt later but this helps to extract the maximum flavor from the chicken',
#   'reduce heat to simmer for 1 hour covered , skimming occasionally',
#   'do not simmer for too much longer than this or the bones start to decalcify and make the stock bitter flavoured',
#   'in the meantime:',
#   'clean and rough chop 2',
#   '5 kg of potatos , set aside',
#   'clean and rough chop 1 large leek , set aside',
#   "you're going to puree it all once it's nice and soft from cooking so don't obsess over getting perfect , small diced cubes you just want it chopped up enough so that they'll cook out nicely in the pot",
#   'back to the stock: your hour of simmering is done and voila -- you have stock !',
#   'now remove the chicken frames , set aside',
#   'strain the stock so that you catch any fine bones that may have come loose while simmering',
#   'add the leek',
#   'add the potato',
#   'boil till soft',
#   'once the chicken frames are cool to a temperature you can handle them , chip whatever meat there is off',
#   'set the meat aside',
#   'pluck out the bay leaves',
#   'whiz soup till smooth',
#   'we use a bar mixer personally',
#   'return chicken meat to pot',
#   "add salt and pepper to taste - for those who aren't familiar , this means add a bit , stir it well , let the flavors mingle for a minute or two , spoon a bit out and taste to tell if it suits your preferences",
#   "don't be afraid of the salt -- one of the basic tenants of cheffing is that salt equals flavor",
#   "soup is now ready to eat but if you prefer a thicker soup , allow to simmer uncovered to reduce , till it's as thick as you like"],
#  '287778': ['preheat oven to 375 degrees , grease one baking sheet',
#   'mix pizza crust mix , garlic powder , pepperoni and mozzarella cheese',
#   'add hot water and mix well',
#   'spread parmesan cheese onto greased baking sheet',
#   'drop dough onto parmesan cheese and knead dough into cheese to reduce stickiness',
#   'roll dough out on same pan , to 1 / 2 inch thickness',
#   "using a pizza slicer , cut dough into 1 inch strips , but don't separate",
#   'bake 15-18 minutes and remove from oven',
#   'mix topping ingredients and spread over hot breadsticks'],
#  '437637': ['preheat oven to 350f',
#   'melt the butter in a 9x13 pan',
#   'sift together the flour , baking powder , salt and sugar',
#   'whisk eggs and milk together',
#   'add to dry ingredients and mix by hand till blended',
#   'pour batter evenly over melted butter',
#   'mix sugar and cinnamon together and combine with the peaches',
#   'spoon peaches evenly over the batter , but do not stir it',
#   'bake 60 - 65 minutes , or until light golden brown',
#   'best served warm with whipped cream or vanilla ice cream !'],
#  '123115': ['in frying pan , melt butter',
#   'add teaspoons seasoning and noodles',
#   'saute 2 minutes , stirring',
#   'set aside on paper towel',
#   'in lg',
#   'bowl , combine coleslaw mix , kernels , green onions and red bell pepper',
#   'toss , cover and refrigerate',
#   '30 minutes to 1 hour before serving make dressing:',
#   'in small bowl , whisk rest of ingredients well til syrupy',
#   'pour over salad , stir well , and refrigerate',
#   'just before serving , stir in noodles',
#   'variations:',
#   'sub or add toasted slivered or chopped almonds in place of or in addition to sunflower kernels',
#   'for a complete "one-dish" lunch or meal , stir in 2-3 cups cooked , diced chicken'],
#  '371549': ['in a large bowl , combine the first eight ingredients',
#   'crumble turkey over mixture and mix well',
#   'shape into 6 patties',
#   'coat grill rack with cooking spray before starting the grill',
#   'grill burgers , covered , over medium heat for 2-3 minutes on each side or until no longer pink',
#   'top with cheese',
#   'cover and grill 1-2 minutes longer or until cheese is melted',
#   'serve on rolls with salsa sour cream and lettuce'],
#  '376813': ['put water in a tall pot and heat to a boil',
#   'add the chicken bullion , diced onions , oregano , garlic powder , and pepper',
#   '-slice carrots and add to the boiling water',
#   '- slice celery',
#   '-cut chicken into bite size pieces',
#   'add carrots to the pot and allow them to boil for about 5 minutes before adding the celery , chicken , and about half the package of wide egg noodles and allow to boil until the noodles are tender',
#   "now it's ready to serve",
#   'i love serving it with some buttered dinner rolls on the side',
#   'remember , you can adjust the seasoning and amount of veggies to your taste'],
#  '134085': ['mix first four ingredients',
#   'pour 1 / 4 cup batter for each pancake onto a 300 degree griddle',
#   'flip when pancakes start to bubble',
#   'place warm cheese on meat , sandwich between pancakes'],
#  '390230': ['heat a large stock pot to mediumheat with olive oil',
#   'add onion and peppers',
#   'season with a pinch of salt & pepper',
#   'cook until softened - about 2-3 minutes',
#   'add the chicken',
#   'season with a pinch of salt and pepper',
#   'cook until white , and cooked through',
#   'about 3-4 minutes',
#   'add the tomatoes , beans , garlic , and corn',
#   'season with salt and pepper',
#   'cook for 2-3 minutes',
#   'add all of the spices and the adobo sauce',
#   'add chicken stock',
#   'you may want more or less chicken stock depending on your desired consistency',
#   'i like mine fairly thick',
#   'bring to a boil',
#   'reduce to a rapid simmer',
#   'simmer for about 30-60 minutes -- all up to you -- the longer and lower temperature the better',
#   'add corn meal and cheese to thicken a little at a time',
#   'stir rapidly to avoid lumps',
#   'simmer for another 15 minutes or so',
#   'you may need to add more corn meal and / or cheese to obtain your desired thickness',
#   'check for seasoning -- you may want to add more salt and pepper to fit your taste',
#   'also , add more cayenne or chili powder for heat and depth',
#   'once the desired thickness and seasoning is achieved , the chili is technically ready to serve',
#   'i often like to turn the heat down to low and cook longer -- anywhere from 15 minutes to hours',
#   'this continues to intensify the flavors and thicken the chili',
#   'serve in a bowl with a sprinkle of fresh cilantro , scallions , cheddar cheese , and a spoonful of sour cream',
#   'fresh corn tortillas , cornbread , and garlic-jalapeno focaccia bread go well with this also',
#   "you can vary this in any way - often i'll use shredded rotisserie chicken or different types of beans",
#   'also , you can omit the tomatoes , adobo sauce and red powders all together and use roasted , seeded and peeled green chiles',
#   'if you like more of that east coat / midwestern style chili use ground chicken or turkey and add some tomato paste instead of the cheese / cornmeal to thicken',
#   'you can also omit the meat altogether and add extra beans & vegetables',
#   'this recipe also works well in the crock pot left cooking all day using dried & soaked beans - i like the health benefits of this myself'],
#  '401605': ['preheat oven to 350 degrees',
#   'mash the sweet potatoes',
#   'mix the sugar , melted butter , eggs , milk , vanilla and cinnamon into the sweet potatoes',
#   'spray a baking dish with non-stick cooking spray and pour potato mixture into it',
#   'mix the topping ingredients together in a small bowl',
#   'sprinkle topping over the sweet potato mixture',
#   'bake for approximately 35 minutes , or until the casserole gets brown and bubbly'],
#  '306590': ['combine spices in a bowl',
#   'place potatoes in a pot of cold water , add salt , and cook until potatoes are tender but firm , about 10 minutes',
#   'drain , let cool , and cut each potato lengthwise into 8 slices',
#   'heat grill to high',
#   'brush potatoes w / oil , season w / the spice rub , and grill until golden brown and cooked through , about 3 to 5 minutes'],
#  '303944': ['heat oil in large skillet over medium heat',
#   'cut bacon or pancetta into small dice and cook in the oil until golden brown and fat has rendered',
#   'remove the bacon to paper towels to drain',
#   'cut the peeled shallots in half and slice very thin',
#   'cook them in the rendered drippings until soft , along with the pepper flakes',
#   'add the thawed peas and heat through',
#   'distributing the shallots well',
#   'add in the bacon or pancetta and toss',
#   'serve',
#   'the original recipe called for pancetta which now runs between $20',
#   '00 and 22',
#   '00 per lb',
#   'so i used a good quality thick sliced smoked bacon with great results ! :-)'],
#  '299968': ['soak the beans overnight',
#   'drain beans , place in large saucepan , cover with water , add bay leaves and bring to the boil',
#   'allow to simmer for 1 hour , or until tender',
#   'drain',
#   'finely chop onion and peppers',
#   'saute onion , peppers , garlic and spices until onion browns slightly',
#   'add cooked beans',
#   'stir to mix ingredients',
#   'simmer for 5-10 minutes',
#   'add the tomato and tomato paste',
#   'add salt and sugar to taste',
#   'cook for a further 10-15 minutes on low to allow the flavours to develop',
#   'serve over cooked white or brown rice'],
#  '192542': ['cut chicken breasts into strips',
#   'mix bread crumbs , goldfish crackers and parmesan in a large plastic bag and crush until coarse',
#   'coat chicken with olive oil and roll',
#   'bake at 350 for about 40 minutes'],
#  '147563': ['cut chicken breasts in half and place in large baking dish',
#   'using about 4 tablespoons of the lemon-pepper seasoning , coat breast pieces in seasoning on both sides',
#   'place potatoes over chicken',
#   'in medium bowl , mix butter and lemon juice',
#   'pour butter mixture over potatoes',
#   'sprinkle remaining lemon-pepper seasoning and salt over potatoes',
#   'cover dish with tinfoil and place it in 350 degree oven for 25 minutes',
#   'turn oven to 400 degrees and bake for 15 minutes more or until potatoes are soft',
#   'remove foil and bake for 5 minutes'],
#  '193719': ['yes , 10 lbs',
#   'i stuff the bird and use the rest as a separate casserole',
#   'it all gets eaten',
#   'bake potatoes',
#   'when done and cool enough grate them and put into large bowl',
#   'i use skin and all',
#   'add butter and mix',
#   'do not use margerine',
#   'add other ingredients and mix well',
#   'add salt to taste',
#   'stuff turkey or chicken and roast according to your instructions',
#   'for the rest of it',
#   'butter a casserole dish and put in remaining stuffing',
#   'bake in oven at 350 degrees for about 45 minutes',
#   'baste periodically with turkey / chicken drippings and cook until it has a nice crust on top',
#   'if you want a vegetarian dish use a rich vegetable broth to baste it with'],
#  '38852': ['mix together all the ingredients for the meatballs in large mixing bowl',
#   'shape into balls the size of golf balls',
#   'place meatballs in shallow baking dish',
#   'combine sauce ingredients',
#   'pour over meat',
#   'bake at 350 for 45 minutes to 1 hour',
#   'sauce should be caramelized , but not dry',
#   'meatballs can be made ahead of time and frozen',
#   "i've never done it with this recipe , but the crockpot could be a possibility !"],
#  '250232': ['scrub the potatoes and cut lengthwise into 3 equal slices',
#   'cut each slice into thirds or fourths',
#   'as the potatoes are cut , place them in a dish of ice water',
#   'preheat oven to 425 degrees',
#   'when oven is hot , drain off the water , remove potatoes and pat dry with a paper towel',
#   'return the dried potatoes to the bowl , sprinkle with seasoning and drizzle with oil',
#   'evenly distribute the oil and seasoning with your hands',
#   'place on a cookie sheet or jelly roll pan that has been sprayed with non-stick cooking spray and bake until golden brown and tender',
#   'approximately 30 minutes , turning frequently',
#   'sprinkle with additional seasoning if desired or salt and pepper to taste'],
#  '134787': ['remove pickles from jar and discard juice',
#   'put some dill in bottom of empty pickly jar',
#   'slice pickles into circles and add to jar along with onion and garlic cloves',
#   'top jar with remaining dill',
#   'boil vinegar salt and water and pour over pickles in jar',
#   'replace jar top and let cool',
#   'store in refrigerator'],
#  '437219': ['preheat oven to 250 degrees',
#   'in a saucepan , melt the butter',
#   'whisk in the worscestershire and hot sauce until well blended',
#   'whisk in the garlic powder , seasoned salt , onion powder , cayenne , and celery seed until well blended',
#   'in a large oven safe bowl or roasting pan , add the party mix that you have chosen and begin to dribble the sauce over the mix with a spoon , stirring frequently , until well coated',
#   'bake at 250 degrees for 1 hour and 15 minutes , stirring the mix every 15 minutes',
#   'turn off the oven , stir the mix , and leave the oven door cracked with the mix still inside',
#   'let it sit in oven to cool for 45 to 60 minutes',
#   'store in air tight containers'],
#  '77380': ['mix all ingredients thoroughly',
#   'divide mixture in half and place each half on a sheet of plastic wrap',
#   'draw up the sides of the plastic wrap tightly around each ball and firmly secure',
#   'refrigerate 6-8 hours or until firm',
#   'remove plastic wrap and roll in nuts before serving'],
#  '21357': ['brown chops in oil in a frying pan',
#   'remove to casserole dish',
#   'saute onion and garlic over high heat for 2 minutes',
#   'add sour cream , horseradish , mustard , dressing and wine',
#   'heat for 3 minutes',
#   'pour over chops',
#   'bake in preheated 350f oven for 1 hour or until done'],
#  '198343': ['grease and flour a bundt pan or 2 large loaf pans',
#   'beat the sugar and eggs until creamy',
#   'mix in the oil',
#   'sift the dry ingredients togethr and add to the creamed mixture',
#   'beat in the bananas or mash them and mix in if the are on the less ripe side',
#   'mix in the raisins',
#   'pour this mixture into a bundt pan , and spread out evenly',
#   'bake in a 350 degree oven for 60 minutes or until done',
#   'turn out of the pan when the cake is cool'],
#  '129919': ['cook macaroni in boiling water , per pkg',
#   'directions) drain & set aside',
#   'melt butter in large skillet , add the flour a little at a time & cook over med',
#   'low heat for about 2 minutes stirring constantly',
#   'stir in the milk a little at a time & cook till it gets bubbly & smooth & slightly thick',
#   'stir in the salt , pepper & mustard',
#   'remove from the heat & add the tabasco sauce & cheese',
#   'stir till smooth',
#   'mix very well with the macaroni',
#   'transfer to a 9x13 litely buttered casserole dish , top with the bread crumbs',
#   'bake @ 350 deg',
#   '30-40 mins or till bubbly'],
#  '375376': ['in a medium bowl , sift together the dry ingredients',
#   'in a separate bowl , mix together the liquid ingredients',
#   'gradually beat in the dry ingredients',
#   'beat on high for 2-3 minutes',
#   'pour batter into a greased and floured 9x5 bread pan',
#   'grease one side of a piece of plastic wrap and cover the bread with this side down',
#   'place in a warm area and let rise for 30-50 minutes or doubled in size',
#   'preheat oven to 350 deg f',
#   'remove plastic wrap and place in oven',
#   'bake for 30-40 minutes or until internal temperature reaches 200f',
#   'after first 10 minutes , cover with foil to keep crust from getting too dark'],
#  '152534': ['heat oven 400',
#   'spread dressing over pizza crust using less or more depending on your taste',
#   'spread hamburger on top',
#   'top with the cheese and bacon',
#   'bake about 8 min until cheese is melted',
#   'top with lettuce , pickles , tomatoe , onion , and mustard',
#   'cut into slices and serve immediately',
#   'i cut the pizza right after it comes out of the oven and let everybody top it themselves , with their favorite toppings'],
#  '63131': ['line a 9" x 13" baking dish with foil and coat the foil with nonstick cooking spray',
# ...
#   'drain',
#   'combine raisins , apple , sugar , flour , and cinnamon in bowl',
#   'toss well and set aside',
#   'place 1 phyllo sheet on work surface',
#   'lightly coat with pam',
#   'add remaining sheets on top of each other',
#   'one at a time coating each with pam in between',
#   'cover with plastic wrap , press to seal sheets together , throw away plastic',
#   'spoon apple mixture along 1 long edge of phyllo leaving 2 inches all the way around',
#   'fold over the short edge to cover 2 to 3 inches of filling',
#   'starting at the long end , roll up like a jelly roll',
#   'do not try to roll tightly , the juices need time to expand',
#   'place sturdel , seam side down , on a jelly-roll coated pan sprayed with pam',
#   'cut small slits in top of the dough',
#   'bake at 350 for 35 minutes or until golden',
#   'serve warm with low fat ice cream or yogurt'],
#  '89021': ['mix yogurt and orange peel together for dressing',
#   'pour over remaining ingredients , mixing gently',
#   'chill for 30 minutes'],
#  '330040': ['on the half of a bagel , spread camembert or brie',
#   'if you choose to use fried camembert , search the recipe on recipezaar , if you choose this option add the fried camembert last',
#   'slice the apple into thin slices or however you like it',
#   'place them on the bagel and heat the bagel in the toaster for 3 minutes or until the cheese has melted',
#   'if you choose to use cinnamon , just sprinkle the cinnamon over the toasted bagel',
#   'its ready to eat !'],
#  '452590': ['heat 1 teaspoon water in a skillet over medium high heat',
#   'cook the diced apple until tender , about 3 to 4 minutes',
#   'in a small bowl , mix the cooked apple , cranberries , shallots , feta and a splash of the chicken stock and set aside',
#   'cut a deep horizontal pocket in the side of each chicken breast',
#   'make the pocket as large as you can without piercing the top or bottom of the breast',
#   'place 1 / 4 of the apple mixture in the pocket of each chicken breast',
#   'secure the pocket with toothpicks threading along the side to close',
#   'heat the remaing 1 1 / 2 tablespoons oil in a heavy oven-proof skillet until it begins to smoke',
#   'cook each side of the chicken until golden brown',
#   'add the vinegar and chicken stock and bring to a boil',
#   'lower the heat and gently simmer the chicken for 2 or 3 minutes per side until cooked through',
#   'remove the chicken breasts from the skillet and keep warm',
#   'continue to cook the sauce until it is reduced to a thick syrup',
#   'taste the sauce and season with salt and pepper',
#   'spoon the sauce over each chicken breast to serve'],
#  '403819': ['place dried fruit , sugar , butter , juice and rind in a medium saucepan',
#   'bring to boil stirring occasionally until butter has melted and sugar dissolved',
#   'add apple',
#   'transfer to a large bowl to cool',
#   'grease a 6 cup pudding basin and line base with baking paper',
#   'pour over the golden syrup',
#   'stir the eggs into the fruit mixture and mix well',
#   'fold through the breadcrumbs and flour',
#   'spoon the pudding mixture into prepared basin packing down firmly as you go',
#   'cover the basin with a circle of buttered non-stick baking paper and two circles of foil',
#   'tie securely with kitchen string',
#   'stand pudding on a trivet inside a large saucepan or stockpot',
#   'fill with enough hot water to come 2 / 3 up the side of basin',
#   'cover pot with a lid and simmer for 5 hours , topping up the pot with boiling water as needed',
#   "don't let it boil dry",
#   'cool and store in basin in fridge until christmas',
#   'to reheat , boil pudding using the method above , for 2 hours',
#   'serve with custard , brandy cream or icecream and decorate with berries'],
#  '420689': ['heat oven to 375f',
#   'spray a 13x8 glass baking dish with cooking spray',
#   'cook sausage over med-high heat 5-7 min until no longer pink',
#   'drain',
#   'stir in apple pie filling and chopped apples',
#   'spread mixture evenly in pan and top with 1 cup of shredded cheese',
#   'mix bisquick and milk , salt , pepper and eggs with a whisk until blended',
#   'pour evenly over sausage mixture',
#   'bake 30-37 min or until knife comes out clean',
#   'top with remaining cheese and bake 3-5 min longer',
#   'let stand 5 minutes before serving'],
#  '191150': ['preheat oven to 450 degrees f',
#   'place bread shell on pizza pan',
#   'bake 8 minutes or until hot',
#   'in large skillet cook shallots in hot oil for 3 minutes or until tender',
#   'stir in apples',
#   'cook and stir for 5 minutes or until apples are crisp-tender',
#   'stir in walnuts , 2 tablespoons honey , anise seeds , and dash ground black pepper',
#   'spoon apple mixture evenly over bread shell',
#   'sprinkle with cheese',
#   'bake 5 to 8 minutes more or until cheese is melted',
#   'drizzle with additional honey',
#   'to serve , cut in wedges'],
#  '74520': ['in a large heavy pot , combine fruit , vinegar , raisins , ginger , garlic , salt and hot pepper flakes',
#   'stir well',
#   'over high heat , bring to a boil',
#   'next , turn heat down to low , cover pot and simmer for about 10 minutes , or until you see that the apricots have plumped up',
#   'stir in sugar and return to a simmer',
#   'cook , uncovered and stirring very often , for about 20 minutes',
#   'mixture should appear thickened',
#   'place mixture in a clean pint jar and let cool a bit before screwing on lid',
#   'then keep chutney refrigerated',
#   'serve , cold from fridge , with a pork roast or with chicken , or in a sandwich , or with cream cheese and crackers',
#   'keeps well in fridge for at least 2 weeks--if it lasts that long without being devoured !'],
#  '460292': ['syrup:',
#   'combine cider , 2 tablespoons brown sugar , lemon juice and cornstarch in a small saucepan',
#   'bring to a boil over medium heat , whisking , and cook until thickened , 1 to 2 minutes',
#   'set aside',
#   'pancakes:',
#   'whisk whole-wheat flour , all-purpose flour , baking powder , baking soda and the remaining 1 tablespoon brown sugar in a small bowl',
#   'whisk egg , egg white and buttermilk in a large bowl',
#   'stir in the dry ingredients , apples and bacon until just combined',
#   'brush a large nonstick skillet with 1 / 2 teaspoon oil and place over medium heat until hot',
#   'cooking 4 at a time , use about 1 / 4 cup batter for each pancake and gently spread it to make them about 3 inches in diameter',
#   'cook until the edges are dry and bubbles begin to form , about 2 minutes',
#   'flip the pancakes and cook until golden brown , 1 to 2 minutes more',
#   'repeat with the remaining oil and batter , reducing the heat as necessary to prevent burning',
#   'reheat the cider syrup , if desired , and serve with the pancakes',
#   'make ahead',
#   'reheat on low before serving',
#   'exchanges: 1 1 / 2 starch , 1 / 2 fruit , 1 other carbohydrate , 1 fat'],
#  '130992': ['peel and chop the apples and the bananas',
#   'put all the ingredients in a pan and let cook',
#   'leave simmering over medium heat for about 30 minutes , stirring occasionaly',
#   'check if the jam is ready on a little plate',
#   'put the jam in jars , close the lid and turn them upside down',
#   'leave to cool overnight'],
#  '346687': ['stir sugar and contents of pectin package in a bowl until well blended',
#   'set aside',
#   'combine apples , pomegranate juice and lemon juice in a medium saucepan',
#   'bring to a boil over medium-high heat , stirring occasionally',
#   'cover',
#   'reduce heat and simmer 5 minutes',
#   'crush apples with a potato masher',
#   'allow to cool , about 15 minutes',
#   'add fruit mixture to sugar / pectin mixture , stirring just to combine',
#   'continue stirring for 3 minutes',
#   'using a funnel , ladle jam into five , clean 8 oz plastic freezer jars to fill line',
#   'twist on lids',
#   'let stand until thickened , about 30 minutes',
#   'serve immediately , refrigerate up to three weeks or freeze up to one year'],
#  '169993': ['heat oven to 425',
#   'prepare pie crust as directed on package for one-crust filled pie using 9 inch pie pan',
#   'in large bowl , combine all filling ingredients',
#   'mix well',
#   'set aside',
#   'lightly spoon flour into measuring cup',
#   'level off',
#   'in medium bowl , combine all topping ingredients',
#   'mix with fork until crumbly',
#   'spoon fruit into crust-lined pan',
#   'spoon topping evenly over fruit',
#   'bake at 425 for 50-70 minutes or until apples are tender and edges are bubbly',
#   'cover entire pie loosely with foil after 20 minutes to prevent excessive browning',
#   'cool 2 hours',
#   'serve warm or cold'],
#  '260352': ['melt 1 tablespoon butter in saut pan',
#   'saut apple slices until just turning soft',
#   'beat together eggs , cream or milk , and salt & pepper until blended but not frothy',
#   'melt remaining butter in omelet pan over high heat until foam begins to recede but before beginning to color',
#   'pour in egg mixture and prepare omelet , stirring lightly , but allowing it to set on the bottom',
#   'fill with sauted apples and brie',
#   'fold or roll and slide out of pan onto a heated plate'],
#  '158382': ['core apples and cut into chunks , no need to peel',
#   'place in food processor and chop coarsely',
#   'add cherries , ground almonds and cinnamon',
#   'process to coarsely chop cherries',
#   'transfer to a bowl',
#   'stir in honey to taste and red wine to moisten',
#   'serve at room temperature'],
#  '449725': ['in large bowl , combine the apple , seasoning , salt and pepper',
#   'crumble chicken over mixture and mix well',
#   'shape into 4-6 medium sized patties',
#   'in a large skillet coated with cooking spray , cook patties over medium heat for 6-7 minutes on each side or until a meat thermometer reads 165 and juices run clear',
#   'enjoy !'],
#  '50851': ['heat oven to 375 f',
#   'generously grease muffin pan or line with paper baking cups',
#   'in large bowl combine all-purpose flour , soy flour , sugar , baking powder , salt and cinnamon',
#   'set aside',
#   'in medium bowl , combine eggs , applesauce and oil',
#   'stir liquids into flour mixture just until dry ingredients are moistened',
#   'gently , but quickly , stir in cinnamon candies',
#   'fill muffin cups 2 / 3 to 3 / 4-full',
#   'bake 20 minutes or until toothpick inserted in center comes out clean',
#   'cool on wire rack 5 minutes',
#   'remove muffins from pan to cool completely'],
#  '521251': ['mix every ingredients in bowl',
#   'pour in a mug',
#   'bake in microwave for 2-3 minutes',
#   'mug cake should be smooth and wet',
#   'serve with white yoghurt , cinnamon , chocolate , whiped cream or anything you like'],
#  '205500': ['in a large bowl , mix flour , sugar , baking powder , salt , and cinnamon',
#   'add almond milk and egg replacer mixture and stir just until flour is moistened',
#   'let the batter rest for 5 minutes while the skillet heats',
#   'while the batter is resting , combine all of the "swirl" ingredients , using 2 tablespoons of the prepared batter',
#   'heat a non-stick griddle or skillet over medium heat until a drop of water sizzles',
#   'gently stir the walnuts into the batter',
#   'pour batter by scant 1 / 4 cupfuls onto hot griddle',
#   'immediately drizzle the cinnamon-apple batter over the top of each pancake in a swirl pattern',
#   'cook until tops are bubbly and bubbles burst',
#   'edges will look dry',
#   'with a pancake turner , turn and cook until undersides are golden',
#   'place on a warm platter',
#   'keep warm',
#   'repeat until all batter is used , brushing griddle lightly with canola oil , if necessary , to prevent sticking',
#   'serve pancakes with syrup or other topping as desired'],
#  '331846': ['in a food processor , combine flour , brown sugar , white sugar , cinnamon and cold butter',
#   'pulse until a coarse mixture is formed , and no pieces are larger than a pea , about 12 1-second pulses',
#   'add oats and toss to combine , pressing pieces together with finger',
#   'cover with plastic wrap and refrigerate',
#   'in a dutch oven , combine cranberries with 3 / 4 c sugar , water , and , if using , crystallized ginger and wine',
#   'cook over medium heat about 10 minutes , until cranberries break down and the sauce becomes jammy',
#   'transfer cranberries to a bowl and set aside',
#   'add the apples to the same hot dutch oven',
#   'add remaining 1 / 2 c sugar and dried cranberries',
#   'stir over medium heat 5 minutes , until apples release their juices',
#   'add tapioca and cooked cranberries to dutch oven and stir well to combine',
#   'pour mixture into 9x13" baking dish and spread out evenly',
#   'place dish on a large rimmed baking sheet to catch any bubble-overs',
#   'sprinkle topping evenly over the top of the fruit mixture',
#   'bake in a preheated 400f oven for 30 minutes , until the juices bubble at the edges and the topping is browned',
#   'allow to cool 30 minutes before serving',
#   'serve with vanilla ice cream'],
#  '69045': ['in a mixing bowl , add the first 7 ingredients',
#   'stir to combine',
#   'spread 1 / 4 cup of the mixture on each slice of toasted bread',
#   'sprinkle evenly with walnuts',
#   'top with a slice of cheese',
#   'place tuna melts on a baking sheet',
#   'broil 5 inches away from the heat until the cheese is melted'],
#  '31748': ['place brisket',
#   'onion , garlic and cloves in large dutch oven',
#   'add water to cover',
#   'bring to a boil',
#   'reduce heat , cover and simmer 2 1 / 2 to 3 hours or until tender',
#   'drain brisket , cover and refrigerate up to 24 hours',
#   'to prepare glaze , combine apple jelly , wine , mustard , green onions , salt , peppercorns and curry powder in small saucepan and heat until jelly melts , stirring occasionally',
#   'place brisket in shallow roasting pan',
#   'brush with glaze and roast in preheated 325-degree oven 45 minutes , basting frequently with glaze',
#   'place brisket on heated serving platter and garnish with parsley and tomato roses',
#   'carve brisket into thin slices and serve with remaining glaze',
#   'brisket may also be cooked on charcoal grill for 30 minutes , basting often with glaze'],
#  '20143': ['in medium saucepan , combine brown sugar , cornstarch , 1 / 4 teaspoon caraway seed , and salt',
#   'stir in 11 / 2 cups apple juice and lemon juice',
#   'cook , stirring , over medium heat until thickened',
#   'set aside',
#   'place roast in oven-proof skillet',
#   'insert meat thermometer',
#   'roast at 325 degrees for 1 hour',
#   'brush with 1 / 2 cup apple juice mixture',
#   'roast 2 hours longer',
#   'spoon combined sauerkraut , apples , carrot , and 1 / 2 cup remaining apple juice and 1 / 2 teaspoon caraway seed around pork roast',
#   'spoon remaining apple juice mixture over pork roast and sauerkraut',
#   'cover',
#   'roast 30 to 60 minutes longer , or until meat thermometer registers 155 to 160 degrees',
#   'let roast stand 5 to 10 minutes',
#   'slice to serve'],
#  '524289': ['for stuffing , in a large skillet , cook bacon over medium high heat until crisp',
#   'remove with a slotted spoon and rain on paper towels',
#   'reserve 2 teaspoons drippings in skillet',
#   'cook leeks in reserved drippings for 3 to 4 minutes or until almost tender',
#   'add the wine , thyme , salt , and pepper',
#   'cook and stir until liquid is evaporated',
#   'remove from heat',
#   'stir in cooked bacon',
#   'for glaze , stir together the apple jelly and mustard',
#   'set aside',
#   'trim fat from chops',
#   'make a pocket in each chop by cutting from fat side almost to , but not through , the opposite side',
#   'spoon stuffing into pockets with chops',
#   'if necessary , secure with wooden toothpicks',
#   'sprinkle with additional salt and pepper',
#   'place chops on rack of an uncovered grill directly over medium coals or medium low flame on your gas grill',
#   'grill about 20 minutes or until juices run clear , turning once , and brushing with glaze the last five minutes of grilling',
#   'remove toothpicks before serving'],
#  '203930': ['place bread slices on an ungreased baking sheet',
#   'broil 3-4 inches from the heat for 1-2 minutes or until golden brown',
#   'combine the apple , goat cheese , thyme , oregano and pepper',
#   'sprinkle over bread',
#   'broil 1 minute or until cheese is softened'],
#  ...}

# %%
#with open('recipe_steps.json', 'w') as fp:
#    json.dump(recipe_steps_dict, fp, indent = True)

# %% [markdown]
# 3.2 По данным файла `steps_sample.xml` сформируйте словарь следующего вида: `кол-во_шагов_в_рецепте: [список_id_рецептов]`

# %%
recipe_steps_count_dict = {}

for recipe in steps_sample.find_all('recipe'):
    lenn = len(recipe.steps.find_all('step'))
    if lenn not in recipe_steps_count_dict.keys():
        recipe_steps_count_dict[lenn] = []
    recipe_steps_count_dict[lenn].append(recipe.id.next)

recipe_steps_count_dict
# Out:
# {11: ['44123',
#   '302399',
#   '375376',
#   '140610',
#   '374703',
#   '111198',
#   '257111',
#   '432661',
#   '114204',
#   '63069',
#   '165096',
#   '33947',
#   '250024',
#   '330512',
#   '315233',
#   '25259',
#   '331174',
#   '407621',
#   '263019',
#   '112853',
#   '383729',
#   '13709',
#   '336166',
#   '143286',
#   '387284',
#   '290003',
#   '370746',
#   '34833',
#   '11975',
#   '426211',
#   '373582',
#   '88845',
#   '456968',
#   '14149',
#   '507927',
#   '73602',
#   '91981',
#   '175109',
#   '390933',
#   '193208',
#   '83893',
#   '243008',
#   '259789',
#   '303926',
#   '410920',
#   '446605',
#   '32571',
#   '74419',
#   '308056',
#   '78497',
#   '111963',
#   '361181',
#   '302640',
#   '356655',
#   '53743',
#   '57771',
#   '420689',
#   '74520',
#   '50851',
#   '176277',
#   '266814',
#   '27897',
#   '189207',
#   '138771',
#   '279797',
#   '177831',
#   '32515',
#   '256842',
#   '95295',
#   '383349',
#   '109791',
#   '332641',
#   '116993',
#   '173126',
#   '187872',
#   '177681',
#   '249006',
#   '314834',
#   '283033',
#   '117084',
#   '49202',
#   '284916',
#   '247657',
#   '313162',
#   '424727',
#   '227557',
#   '431305',
#   '263038',
#   '439979',
#   '443041',
#   '241042',
#   '258779',
#   '66965',
#   '200503',
#   '109597',
#   '503121',
#   '290595',
#   '401175',
#   '169146',
#   '282228',
#   '316435',
#   '248582',
#   '504422',
#   '196814',
#   '153793',
#   '36709',
#   '158200',
#   '410513',
#   '191457',
#   '82108',
#   '157276',
#   '28648',
#   '176753',
#   '8565',
#   '300625',
#   '45429',
#   '65897',
#   '102457',
#   '476511',
#   '7036',
#   '449701',
#   '405140',
#   '42526',
#   '360',
#   '224714',
#   '421620',
#   '209347',
#   '110941',
#   '390645',
#   '429589',
#   '295611',
#   '60877',
#   '351891',
#   '137873',
#   '83572',
#   '138305',
#   '204963',
#   '351642',
#   '184280',
#   '52100',
#   '323574',
#   '17782',
#   '208078',
#   '248015',
#   '451177',
#   '60476',
#   '104632',
#   '165769',
#   '434085',
#   '445456',
#   '182234',
#   '159843',
#   '137263',
#   '95284',
#   '137031',
#   '431954',
#   '59257',
#   '1075',
#   '131027',
#   '48378',
#   '422595',
#   '363299',
#   '262605',
#   '320218',
#   '445628',
#   '387882',
#   '211279',
#   '136589',
#   '417786',
#   '407145',
#   '98988',
#   '99034',
#   '262188',
#   '56366',
#   '444125',
#   '8765',
#   '464745',
#   '382880',
#   '214206',
#   '364032',
#   '332582',
#   '310605',
#   '332822',
#   '122527',
#   '515641',
#   '484413',
#   '10869',
#   '189860',
#   '495331',
#   '229779',
#   '201338',
#   '359664',
#   '289766',
#   '179690',
#   '57408',
#   '16407',
#   '206824',
#   '143396',
#   '52089',
#   '205831',
#   '313058',
#   '452758',
#   '231928',
#   '312998',
#   '54945',
#   '29618',
#   '323013',
#   '372807',
#   '217210',
#   '82678',
#   '151210',
#   '287887',
#   '139971',
#   '394247',
#   '414491',
#   '99649',
#   '433349',
#   '352200',
#   '122070',
#   '117238',
#   '98530',
#   '371606',
#   '386601',
#   '211473',
#   '337971',
#   '88060',
#   '71804',
#   '191965',
#   '114023',
#   '134026',
#   '136364',
#   '69389',
#   '272841',
#   '171041',
#   '134263',
#   '87226',
#   '300644',
#   '53757',
#   '332540',
#   '378226',
#   '19664',
#   '71975',
#   '137727',
#   '472794',
#   '295769',
#   '75835',
#   '53445',
#   '253666',
#   '78195',
#   '514138',
#   '62530',
#   '31730',
#   '458694',
#   '481770',
#   '67252',
#   '235218',
#   '40045',
#   '133992',
#   '101752',
#   '113176',
#   '103408',
#   '126610',
#   '311511',
#   '402757',
#   '75066',
#   '195954',
#   '137902',
#   '466342',
#   '16209',
#   '336795',
#   '456864',
#   '476209',
#   '329752',
#   '265167',
#   '45455',
#   '128604',
#   '429328',
#   '73743',
#   '288266',
#   '170339',
#   '194571',
#   '140498',
#   '409348',
#   '134260',
#   '389964',
#   '17602',
#   '40888',
#   '273470',
#   '183829',
#   '65802',
#   '158312',
#   '236879',
#   '383588',
#   '98007',
#   '285076',
#   '193649',
#   '319720',
#   '101036',
#   '132678',
#   '314281',
#   '62166',
#   '380695',
#   '265953',
#   '216859',
#   '335134',
#   '73335',
#   '357845',
#   '359086',
#   '521815',
#   '494677',
#   '54383',
#   '482954',
#   '8444',
#   '245634',
#   '82339',
#   '70274',
#   '417510',
#   '336955',
#   '49511',
#   '450542',
#   '389504',
#   '116299',
#   '31049',
#   '226959',
#   '432667',
#   '351403',
#   '77152',
#   '243335',
#   '79461',
#   '25396',
#   '461136',
#   '12548',
#   '124256',
#   '117192',
#   '99986',
#   '94410',
#   '63564',
#   '399381',
#   '99073',
#   '20482',
#   '26378',
#   '294898',
#   '319962',
#   '240',
#   '19708',
#   '356639',
#   '449638',
#   '316237',
#   '211581',
#   '288142',
#   '497379',
#   '336724',
#   '238679',
#   '391921',
#   '93808',
#   '169662',
#   '138865',
#   '425992',
#   '315293',
#   '229687',
#   '334290',
#   '335434',
#   '221083',
#   '68452',
#   '465971',
#   '48782',
#   '253341',
#   '467385',
#   '161069',
#   '315376',
#   '330114',
#   '125533',
#   '66698',
#   '95609',
#   '279702',
#   '203500',
#   '277319',
#   '74367',
#   '136265',
#   '23689',
#   '296109',
#   '148407',
#   '141419',
#   '283527',
#   '59000',
#   '467705',
#   '357689',
#   '352781',
#   '152573',
#   '364177',
#   '159942',
#   '90444',
#   '239895',
#   '93989',
#   '168981',
#   '139762',
#   '205348',
#   '91775',
#   '161909',
#   '70625',
#   '19783',
#   '199197',
#   '483179',
#   '127187',
#   '118337',
#   '345304',
#   '404889',
#   '4380',
#   '259088',
#   '286105',
#   '81769',
#   '506630',
#   '395749',
#   '337682',
#   '283191',
#   '107955',
#   '437819',
#   '104002',
#   '326620',
#   '410350',
#   '366106',
#   '196802',
#   '392761',
#   '373383',
#   '144258',
#   '369016',
#   '455881',
#   '127017',
#   '51555',
#   '449495',
#   '401462',
#   '443975',
#   '65681',
#   '219237',
#   '385797',
#   '27099',
#   '457353',
#   '104074',
#   '61037',
#   '122139',
#   '416088',
#   '484376',
#   '118256',
#   '235758',
#   '42900',
#   '14835',
#   '38742',
#   '47264',
#   '413633',
#   '467154',
#   '380719',
#   '180837',
#   '54593',
#   '62794',
#   '291683',
#   '447364',
#   '253676',
#   '115221',
#   '127714',
#   '85461',
#   '13800',
#   '58387',
#   '197962',
#   '195298',
#   '180812',
#   '8473',
#   '77452',
#   '154386',
#   '30398',
#   '140352',
#   '312734',
#   '241905',
#   '64005',
#   '30459',
#   '125633',
#   '119560',
#   '292876',
#   '105146',
#   '147357',
#   '384801',
#   '484788',
#   '95798',
#   '460245',
#   '31197',
#   '36950',
#   '204491',
#   '266513',
#   '326977',
#   '266236',
#   '278836',
#   '104492',
#   '256460',
#   '154298',
#   '146874',
#   '142220',
#   '64701',
#   '167854',
#   '191359',
#   '304741',
#   '280949',
#   '230435',
#   '24515',
#   '475468',
#   '251827',
#   '123934',
#   '257308',
#   '197609',
#   '317022',
#   '81065',
#   '64913',
#   '360467',
#   '58587',
#   '329426',
#   '191818',
#   '388695',
#   '263802',
#   '341593',
#   '424577',
#   '95464',
#   '63443',
#   '200378',
#   '98691',
#   '401411',
#   '13565',
#   '325662',
#   '11639',
#   '413552',
#   '340142',
#   '432871',
#   '221773',
#   '194103',
#   '41524',
#   '109068',
#   '439037',
#   '228850',
#   '448503',
#   '392864',
#   '251550',
#   '453396',
#   '133124',
#   '25046',
#   '136815',
#   '12638',
#   '381211',
#   '178218',
#   '117641',
#   '189312',
#   '289466',
#   '59256',
#   '414568',
#   '152237',
#   '98985',
#   '328747',
#   '85874',
#   '198754',
#   '44069',
#   '276136',
#   '88306',
#   '12313',
#   '114199',
#   '308706',
#   '327793',
#   '635',
#   '225660',
#   '157901',
#   '128964',
#   '482034',
#   '220329',
#   '198071',
#   '45709',
#   '41681',
#   '179663',
#   '74703',
#   '164245',
#   '93048',
#   '14637',
#   '83885',
#   '204958',
#   '186466',
#   '465453',
#   '95569',
#   '51801',
#   '265632',
#   '393637',
#   '353660',
#   '326058',
#   '418258',
#   '291158',
#   '513160',
#   '247728',
#   '71154',
#   '439316',
#   '399482',
#   '118383',
#   '356320',
#   '383670',
#   '20176',
#   '176482',
#   '272854',
#   '158353',
#   '360031',
#   '265578',
#   '19070',
#   '70263',
#   '245850',
#   '269030',
#   '240127',
#   '301905',
#   '193972',
#   '402061',
#   '222739',
#   '98061',
#   '465388',
#   '195998',
#   '21197',
#   '68566',
#   '269340',
#   '90804',
#   '83484',
#   '110848',
#   '173635',
#   '195881',
#   '241196',
#   '350933',
#   '36806',
#   '15250',
#   '158322',
#   '106677',
#   '295675',
#   '242821',
#   '229455',
#   '340197',
#   '87801',
#   '266070',
#   '128167',
#   '64704',
#   '78216',
#   '282901',
#   '233781',
#   '94555',
#   '285641',
#   '18201',
#   '192825',
#   '161798',
#   '115713',
#   '397621',
#   '243947',
#   '130768',
#   '113657',
#   '249646',
#   '403928',
#   '163713',
#   '198730',
#   '41295',
#   '502882',
#   '155815',
#   '22240',
#   '252028',
#   '71358',
#   '152368',
#   '224084',
#   '149818',
#   '515670',
#   '587',
#   '244522',
#   '129710',
#   '343486',
#   '65493',
#   '279465',
#   '90884',
#   '86629',
#   '387606',
#   '312689',
#   '298882',
#   '165473',
#   '446432',
#   '460434',
#   '171343',
#   '54345',
#   '30228',
#   '439090',
#   '262327',
#   '243374',
#   '476676',
#   '292204',
#   '238730',
#   '237228',
#   '15905',
#   '85523',
#   '156107',
#   '207998',
#   '278206',
#   '259594',
#   '102041',
#   '363441',
#   '146177',
#   '423800',
#   '80399',
#   '154833',
#   '257177',
#   '134829',
#   '425085',
#   '98330',
#   '209563',
#   '219281',
#   '325414',
#   '325869',
#   '102321',
#   '57995',
#   '68585',
#   '424553',
#   '84919',
#   '57810',
#   '393801',
#   '278868',
#   '65276',
#   '86521',
#   '212683',
#   '68579',
#   '114076',
#   '296315',
#   '70932',
#   '274186',
#   '40093',
#   '201442',
#   '406784',
#   '71244',
#   '186887',
#   '177713',
#   '364099',
#   '170037',
#   '462565',
#   '503830',
#   '327292',
#   '226778',
#   '220655',
#   '68503',
#   '30099',
#   '217552',
#   '137968',
#   '136927',
#   '148503',
#   '99697',
#   '307564',
#   '364326',
#   '70538',
#   '248620',
#   '318257',
#   '109797',
#   '450425',
#   '174666',
#   '180873',
#   '143734',
#   '39375',
#   '372814',
#   '319842',
#   '240671',
#   '56096',
#   '368489',
#   '33191',
#   '177689',
#   '210610',
#   '405675',
#   '95516',
#   '361971',
#   '370000',
#   '122289',
#   '155198',
#   '195666',
#   '64699',
#   '183935',
#   '158356',
#   '461081',
#   '176025',
#   '53879',
#   '187113',
#   '449877',
#   '34063',
#   '85583',
#   '232766',
#   '139904',
#   '48852',
#   '446808',
#   '367834',
#   '84614',
#   '133693',
#   '32059',
#   '482707',
#   '192868',
#   '53272',
#   '47085',
#   '429393',
#   '248717',
#   '423414',
#   '190403',
#   '483225',
#   '469591',
#   '231267',
#   '285113',
#   '294772',
#   '396008',
#   '153610',
#   '95950',
#   '470194',
#   '6848',
#   '239061',
#   '238758',
#   '32771',
#   '509731',
#   '426825',
#   '443215',
#   '132360',
#   '313181',
#   '131922',
#   '58598',
#   '141047',
#   '222659',
#   '207971',
#   '480108',
#   '75242',
#   '358971',
#   '486320',
#   '16227',
#   '79970',
#   '30521',
#   '138282',
#   '210106',
#   '105108',
#   '140969',
#   '61769',
#   '158243',
#   '390087',
#   '52194',
#   '340327',
#   '124810',
#   '197572',
#   '79497',
#   '102151',
#   '506142',
#   '209319',
#   '214400',
#   '58633',
#   '504603',
#   '190277',
#   '419912',
#   '196794',
#   '229942',
#   '484075',
#   '111309',
#   '335471',
#   '254815',
#   '519642',
#   '465392',
#   '230194',
#   '270633',
#   '457203',
#   '473972',
#   '189686',
#   '51799',
#   '17588',
#   '211765',
#   '190872',
#   '472337',
#   '343596',
#   '227921',
#   '186196',
#   '278031',
#   '426903',
#   '147176',
#   '384513',
#   '103583',
#   '387741',
#   '123173',
#   '217915',
#   '369021',
#   '126623',
#   '38617',
#   '482933',
#   '441181',
#   '49543',
#   '110613',
#   '42169',
#   '409064',
#   '106214',
#   '313366',
#   '333907',
#   '324032',
#   '90708',
#   '171769',
#   '256623',
#   '60711',
#   '221838',
#   '495702',
#   '399476',
#   '171728',
#   '218125',
#   '313911',
#   '119804',
#   '194297',
#   '191490',
#   '74512',
#   '382047',
#   '164821',
#   '337879',
#   '76513',
#   '488522',
#   '242990',
#   '34760',
#   '73081',
#   '208451',
#   '235054',
#   '344733',
#   '186780',
#   '102446',
#   '103370',
#   '457620',
#   '318734',
#   '289227',
#   '308893',
#   '246032',
#   '427634',
#   '135924',
#   '21321',
#   '221092',
#   '138680',
#   '4413',
#   '212090',
#   '140579',
#   '125573',
#   '338841',
#   '97905',
#   '62240',
#   '89439',
#   '505610',
#   '251751',
#   '51412',
#   '97572',
#   '298391',
#   '323521',
#   '203686',
#   '104430',
#   '86620',
#   '381018',
#   '327776',
#   '90382',
#   '259198',
#   '358810',
#   '154666',
#   '288003',
#   '142822',
#   '241286',
#   '6913',
#   '226450',
#   '513850',
#   '404918',
#   '394765',
#   '84616',
#   '348505',
#   '61561',
#   '169394',
#   '74890',
#   '24370',
#   '58245',
#   '274121',
#   '56976',
#   '384502',
#   '363341',
#   '227743',
#   '322018',
#   '213436',
#   '12243',
#   '299146',
#   '241714',
#   '200097',
#   '327496',
#   '190185',
#   '146250',
#   '57208',
#   '169175',
#   '149751',
#   '423301',
#   '73911',
#   '82451',
#   '189175',
#   '399380',
#   '256055',
#   '479880',
#   '235909',
#   '333283',
#   '464049',
#   '329809',
#   '79884',
#   '104222',
#   '316695',
#   '455040',
#   '323752',
#   '272941',
#   '295199',
#   '216504',
#   '104098',
#   ...],
#  3: ['67664',
#   '118843',
#   '147477',
#   '367987',
#   '216068',
#   '375362',
#   '367828',
#   '286484',
#   '27060',
#   '121712',
#   '53353',
#   '291409',
#   '160494',
#   '505748',
#   '137187',
#   '111559',
#   '23613',
#   '317681',
#   '223242',
#   '504956',
#   '63907',
#   '246579',
#   '366021',
#   '354751',
#   '460069',
#   '373269',
#   '189127',
#   '240135',
#   '4205',
#   '243909',
#   '202414',
#   '117542',
#   '39189',
#   '314777',
#   '316673',
#   '477848',
#   '256689',
#   '197284',
#   '279302',
#   '245792',
#   '464367',
#   '188540',
#   '125915',
#   '85354',
#   '88978',
#   '264064',
#   '160902',
#   '5197',
#   '227191',
#   '147791',
#   '411505',
#   '79749',
#   '334186',
#   '374277',
#   '355173',
#   '230530',
#   '275663',
#   '272034',
#   '89021',
#   '61297',
#   '260930',
#   '326743',
#   '209058',
#   '154255',
#   '66022',
#   '277459',
#   '288624',
#   '356161',
#   '424837',
#   '174273',
#   '174274',
#   '380641',
#   '7841',
#   '467378',
#   '69539',
#   '176085',
#   '476635',
#   '471921',
#   '187347',
#   '285826',
#   '304396',
#   '480525',
#   '158999',
#   '209879',
#   '484256',
#   '87155',
#   '92096',
#   '174425',
#   '199548',
#   '417578',
#   '326076',
#   '173235',
#   '109866',
#   '425400',
#   '316766',
#   '397529',
#   '273854',
#   '429284',
#   '405042',
#   '256036',
#   '48279',
#   '2866',
#   '247330',
#   '117230',
#   '24572',
#   '156441',
#   '140648',
#   '5006',
#   '61779',
#   '7397',
#   '286813',
#   '195336',
#   '514820',
#   '89453',
#   '228169',
#   '35199',
#   '109267',
#   '347092',
#   '374964',
#   '369209',
#   '184910',
#   '349456',
#   '12276',
#   '142258',
#   '420640',
#   '175723',
#   '391030',
#   '253665',
#   '211806',
#   '128013',
#   '62902',
#   '37056',
#   '420610',
#   '105811',
#   '134206',
#   '360201',
#   '175958',
#   '219761',
#   '375050',
#   '10005',
#   '102185',
#   '79233',
#   '40999',
#   '102815',
#   '36315',
#   '241052',
#   '171380',
#   '304615',
#   '376363',
#   '239498',
#   '384789',
#   '255144',
#   '188823',
#   '109123',
#   '249336',
#   '36256',
#   '445597',
#   '27928',
#   '248337',
#   '57924',
#   '396461',
#   '245066',
#   '184921',
#   '101968',
#   '9177',
#   '114588',
#   '182723',
#   '66',
#   '41090',
#   '294082',
#   '33847',
#   '15601',
#   '470641',
#   '24970',
#   '169574',
#   '364945',
#   '166022',
#   '402871',
#   '281101',
#   '386195',
#   '259627',
#   '237000',
#   '317938',
#   '132359',
#   '176027',
#   '460892',
#   '50307',
#   '139049',
#   '59614',
#   '65204',
#   '49602',
#   '118248',
#   '454111',
#   '93449',
#   '77702',
#   '19529',
#   '28365',
#   '88938',
#   '42750',
#   '265432',
#   '94269',
#   '114168',
#   '239613',
#   '462875',
#   '45008',
#   '253526',
#   '183133',
#   '210321',
#   '220537',
#   '201591',
#   '44289',
#   '308163',
#   '77413',
#   '288410',
#   '50676',
#   '276622',
#   '175364',
#   '430486',
#   '288565',
#   '430334',
#   '322729',
#   '293134',
#   '34557',
#   '208675',
#   '284296',
#   '331627',
#   '54269',
#   '159961',
#   '256026',
#   '36754',
#   '475008',
#   '149217',
#   '233189',
#   '171391',
#   '231995',
#   '72895',
#   '52665',
#   '426504',
#   '21618',
#   '504766',
#   '232770',
#   '36744',
#   '395838',
#   '44935',
#   '9520',
#   '245728',
#   '292945',
#   '266082',
#   '202021',
#   '81937',
#   '264214',
#   '167917',
#   '95453',
#   '481894',
#   '48463',
#   '221387',
#   '501188',
#   '417004',
#   '361978',
#   '108471',
#   '329624',
#   '351829',
#   '26732',
#   '90567',
#   '109718',
#   '81360',
#   '233314',
#   '265442',
#   '255511',
#   '143616',
#   '445132',
#   '259382',
#   '308140',
#   '232848',
#   '213506',
#   '21024',
#   '124189',
#   '206981',
#   '192281',
#   '383870',
#   '205779',
#   '195066',
#   '276832',
#   '383058',
#   '87903',
#   '140586',
#   '411250',
#   '150642',
#   '123889',
#   '262070',
#   '214040',
#   '138972',
#   '172858',
#   '304092',
#   '152781',
#   '193704',
#   '231367',
#   '361143',
#   '135753',
#   '337857',
#   '121019',
#   '471606',
#   '326554',
#   '439418',
#   '333403',
#   '307608',
#   '62236',
#   '308156',
#   '376022',
#   '211242',
#   '459764',
#   '53633',
#   '288854',
#   '407907',
#   '30215',
#   '129533',
#   '171832',
#   '200577',
#   '194278',
#   '241058',
#   '264043',
#   '301544',
#   '504480',
#   '65994',
#   '47251',
#   '464145',
#   '279904',
#   '147397',
#   '67660',
#   '284495',
#   '77640',
#   '311758',
#   '379059',
#   '8791',
#   '44124',
#   '424128',
#   '395533',
#   '315822',
#   '322924',
#   '258307',
#   '383',
#   '263381',
#   '505534',
#   '188719',
#   '228995',
#   '302151',
#   '129063',
#   '99843',
#   '152327',
#   '130012',
#   '400873',
#   '391413',
#   '48799',
#   '44205',
#   '394897',
#   '397330',
#   '504718',
#   '268671',
#   '139619',
#   '427081',
#   '456796',
#   '24415',
#   '39025',
#   '229012',
#   '358188',
#   '222037',
#   '75988',
#   '94042',
#   '467299',
#   '198950',
#   '171610',
#   '307217',
#   '87049',
#   '383412',
#   '136659',
#   '110178',
#   '389682',
#   '126995',
#   '381946',
#   '222156',
#   '223303',
#   '72474',
#   '56009',
#   '27678',
#   '13890',
#   '87521',
#   '234891',
#   '309276',
#   '397772',
#   '291170',
#   '126969',
#   '108030',
#   '305214',
#   '419219',
#   '216112',
#   '324738',
#   '99278',
#   '401574',
#   '190948',
#   '438046',
#   '26216',
#   '149282',
#   '481317',
#   '50988',
#   '386538',
#   '69162',
#   '415829',
#   '182648',
#   '113333',
#   '282711',
#   '236730',
#   '408771',
#   '209891',
#   '220661',
#   '73263',
#   '42719',
#   '147952',
#   '211383',
#   '191538',
#   '75800',
#   '184846',
#   '43677',
#   '351219',
#   '124818',
#   '474848',
#   '95575',
#   '218664',
#   '281936',
#   '79626',
#   '2405',
#   '460436',
#   '79074',
#   '54517',
#   '172798',
#   '280812',
#   '193078',
#   '318829',
#   '7542',
#   '4098',
#   '427790',
#   '420194',
#   '110483',
#   '315107',
#   '22097',
#   '422820',
#   '455496',
#   '143816',
#   '458710',
#   '489800',
#   '153952',
#   '304991',
#   '126423',
#   '175149',
#   '32931',
#   '243370',
#   '4724',
#   '154685',
#   '20305',
#   '153979',
#   '142655',
#   '114766',
#   '222979',
#   '191772',
#   '103837',
#   '161408',
#   '244211',
#   '106992',
#   '49896',
#   '281673',
#   '44241',
#   '108527',
#   '109318',
#   '107068',
#   '51774',
#   '89071',
#   '421884',
#   '140482',
#   '24105',
#   '280219',
#   '485745',
#   '130687',
#   '44794',
#   '3158',
#   '137667',
#   '258464',
#   '306454',
#   '402469',
#   '181201',
#   '274976',
#   '48133',
#   '52141',
#   '116244',
#   '355982',
#   '294442',
#   '184443',
#   '405195',
#   '123476',
#   '418909',
#   '320502',
#   '48364',
#   '115289',
#   '318927',
#   '50927',
#   '314819',
#   '312034',
#   '145824',
#   '424920',
#   '45550',
#   '127354',
#   '245080',
#   '428549',
#   '374760',
#   '229508',
#   '32286',
#   '154179',
#   '339046',
#   '217162',
#   '10853',
#   '34744',
#   '437654',
#   '295426',
#   '269910',
#   '143925',
#   '267369',
#   '266884',
#   '226159',
#   '106565',
#   '26198',
#   '444430',
#   '475719',
#   '290479',
#   '27609',
#   '481325',
#   '362641',
#   '199216',
#   '298851',
#   '273863',
#   '17088',
#   '39224',
#   '261183',
#   '470964',
#   '501007',
#   '82277',
#   '386816',
#   '138224',
#   '70655',
#   '294154',
#   '307405',
#   '110923',
#   '195387',
#   '68038',
#   '166735',
#   '52572',
#   '3271',
#   '252928',
#   '273190',
#   '121235',
#   '458915',
#   '377978',
#   '341808',
#   '278998',
#   '25290',
#   '317066',
#   '230532',
#   '52236',
#   '59364',
#   '364643',
#   '189329',
#   '11941',
#   '35105',
#   '49295',
#   '135084',
#   '224097',
#   '23439',
#   '472571',
#   '277781',
#   '442235',
#   '364168',
#   '253229',
#   '281726',
#   '254508',
#   '120679',
#   '156169',
#   '60624',
#   '65206',
#   '101117',
#   '508443',
#   '502613',
#   '423992',
#   '114821',
#   '220267',
#   '191758',
#   '164212',
#   '260668',
#   '443461',
#   '342762',
#   '422601',
#   '24906',
#   '35399',
#   '16559',
#   '125183',
#   '138050',
#   '209310',
#   '222839',
#   '20365',
#   '428768',
#   '41202',
#   '87905',
#   '204740',
#   '228455',
#   '206762',
#   '87174',
#   '319012',
#   '107387',
#   '70096',
#   '194647',
#   '22728',
#   '401110',
#   '143873',
#   '252076',
#   '171543',
#   '241651',
#   '53092',
#   '279981',
#   '159409',
#   '104368',
#   '129894',
#   '462145',
#   '208328',
#   '262408',
#   '440371',
#   '463903',
#   '365943',
#   '360644',
#   '168136',
#   '52953',
#   '36409',
#   '232119',
#   '513886',
#   '120400',
#   '182477',
#   '66258',
#   '227485',
#   '389738',
#   '28140',
#   '311141',
#   '92803',
#   '330156',
#   '146979',
#   '51265',
#   '492483',
#   '74977',
#   '368078',
#   '487741',
#   '347763',
#   '295104',
#   '273841',
#   '121415',
#   '107886',
#   '7786',
#   '105296',
#   '100955',
#   '267105',
#   '88138',
#   '68336',
#   '81765',
#   '5245',
#   '427563',
#   '166274',
#   '98358',
#   '444483',
#   '361116',
#   '6665',
#   '186674',
#   '322972',
#   '317323',
#   '257905',
#   '139032',
#   '49206',
#   '60853',
#   '186204',
#   '49197',
#   '67741',
#   '30726',
#   '134534',
#   '136483',
#   '232859',
#   '79003',
#   '365796',
#   '105671',
#   '426851',
#   '34837',
#   '216028',
#   '451071',
#   '100733',
#   '1878',
#   '442923',
#   '330865',
#   '459458',
#   '83222',
#   '61610',
#   '291695',
#   '83498',
#   '293002',
#   '45804',
#   '323547',
#   '82770',
#   '307634',
#   '437982',
#   '40209',
#   '315908',
#   '41337',
#   '97765',
#   '60689',
#   '368871',
#   '387932',
#   '51126',
#   '111982',
#   '376642',
#   '500258',
#   '390218',
#   '341514',
#   '238867',
#   '238865',
#   '75883',
#   '73201',
#   '203480',
#   '321787',
#   '199634',
#   '151574',
#   '345459',
#   '204187',
#   '89207',
#   '213600',
#   '214123',
#   '215653',
#   '393666',
#   '470687',
#   '144869',
#   '317656',
#   '171514',
#   '436682',
#   '98626',
#   '39497',
#   '419326',
#   '102812',
#   '384077',
#   '369967',
#   '270295',
#   '5454',
#   '154362',
#   '40125',
#   '44742',
#   '171898',
#   '40972',
#   '239993',
#   '370779',
#   '243071',
#   '1590',
#   '70146',
#   '55669',
#   '65804',
#   '340485',
#   '91419',
#   '216061',
#   '271384',
#   '184139',
#   '322902',
#   '477707',
#   '97921',
#   '93339',
#   '213975',
#   '54245',
#   '473508',
#   '274329',
#   '123922',
#   '126570',
#   '511787',
#   '480482',
#   '319060',
#   '228449',
#   '395265',
#   '65193',
#   '286380',
#   '109146',
#   '359626',
#   '317408',
#   '52276',
#   '335978',
#   '37989',
#   '277194',
#   '21835',
#   '31259',
#   '4530',
#   '99643',
#   '486171',
#   '504548',
#   '87265',
#   '109978',
#   '95907',
#   '253661',
#   '122725',
#   '196443',
#   '64632',
#   '408025',
#   '239942',
#   '267637',
#   '52732',
#   '139129',
#   '375148',
#   '28732',
#   '249800',
#   '168223',
#   '69205',
#   '235769',
#   '188336',
#   '337526',
#   '12469',
#   '494131',
#   '251980',
#   '251057',
#   '100568',
#   '37252',
#   '53503',
#   '443050',
#   '89074',
#   '68320',
#   '171731',
#   '205429',
#   '209666',
#   '293373',
#   '154514',
#   '427706',
#   '157542',
#   '429438',
#   '427892',
#   '452871',
#   '84465',
#   '272286',
#   '277390',
#   '107044',
#   '145220',
#   '292631',
#   '28297',
#   '199757',
#   '125021',
#   '113971',
#   '460107',
#   '108784',
#   '232506',
#   '232903',
#   '188060',
#   '327788',
#   '57733',
#   '293675',
#   '466197',
#   '471153',
#   '314012',
#   '175181',
#   '204913',
#   '226456',
#   '221102',
#   '213421',
#   '170147',
#   '278872',
#   '418875',
#   '134234',
#   '346757',
#   '267755',
#   '258852',
#   '136079',
#   '37897',
#   '112866',
#   '100388',
#   '110818',
#   '243900',
#   '221120',
#   '415599',
#   '483719',
#   '65591',
#   '493140',
#   '48851',
#   '293318',
#   '302769',
#   '35721',
#   '225006',
#   '155847',
#   '146601',
#   '323886',
#   '186480',
#   '50692',
#   '445457',
#   '342163',
#   '396360',
#   '34277',
#   '19298',
#   '67113',
#   '163847',
#   '177127',
#   '234962',
#   '470504',
#   '386886',
#   '378972',
#   '232162',
#   '259779',
#   '464622',
#   '223798',
#   '131122',
#   '280367',
#   '372130',
#   '214134',
#   '118438',
#   '55034',
#   '327903',
#   '51879',
#   '216412',
#   '80860',
#   '69706',
#   '15616',
#   '213529',
#   '332766',
#   '156322',
#   '99876',
#   '179248',
#   '119828',
#   '271016',
#   '300803',
#   '140092',
#   '298675',
#   '225681',
#   '105170',
#   '191949',
#   '397218',
#   '309496',
#   '394908',
#   '10698',
#   '153785',
#   '235279',
#   '337017',
#   '348292',
#   '231059',
#   '314337',
#   '152733',
#   '224730',
#   '172543',
#   '121245',
#   '353331',
#   '330263',
#   '410880',
#   '79834',
#   '12561',
#   '46901',
#   '57968',
#   '41238',
#   '227007',
#   '17920',
#   '168181',
#   '32846',
#   '435537',
#   '54570',
#   '26650',
#   '169948',
#   '100227',
#   '73233',
#   '149843',
#   '101781',
#   '211220',
#   '321853',
#   '26039',
#   '309958',
#   '262625',
#   '340608',
#   '263600',
#   '199859',
#   '401488',
#   '321124',
#   '187765',
#   '301070',
#   '286635',
#   '306851',
#   '347526',
#   '458903',
#   '56149',
#   '288279',
#   '330564',
#   '363391',
#   '333688',
#   '325742',
#   '3620',
#   '179001',
#   '410078',
#   '415249',
#   '47603',
#   '441070',
#   '178573',
#   '178445',
#   '188705',
#   '62705',
#   '366852',
#   '21905',
#   ...],
#  5: ['38798',
#   '69190',
#   '125195',
#   '306590',
#   '77380',
#   '378067',
#   '218671',
#   '453243',
#   '101260',
#   '416599',
#   '274469',
#   '79826',
#   '234120',
#   '394191',
#   '448832',
#   '15541',
#   '21629',
#   '50854',
#   '486851',
#   '298089',
#   '149966',
#   '22567',
#   '446600',
#   '243425',
#   '14873',
#   '377658',
#   '392262',
#   '21360',
#   '300355',
#   '398090',
#   '25020',
#   '320973',
#   '493636',
#   '301164',
#   '301365',
#   '21302',
#   '425294',
#   '181765',
#   '462351',
#   '123758',
#   '238000',
#   '186631',
#   '379357',
#   '383147',
#   '160696',
#   '15086',
#   '335876',
#   '15869',
#   '12441',
#   '190394',
#   '49648',
#   '248926',
#   '180696',
#   '357968',
#   '32550',
#   '179128',
#   '407377',
#   '37152',
#   '40858',
#   '247103',
#   '123753',
#   '187678',
#   '65729',
#   '25947',
#   '343461',
#   '293713',
#   '434512',
#   '39398',
#   '246286',
#   '168017',
#   '130409',
#   '213724',
#   '94187',
#   '154964',
#   '382269',
#   '55718',
#   '484942',
#   '171628',
#   '40478',
#   '378468',
#   '449725',
#   '521251',
#   '203930',
#   '87202',
#   '22949',
#   '95211',
#   '176730',
#   '493256',
#   '206772',
#   '425118',
#   '88039',
#   '480684',
#   '406507',
#   '431875',
#   '233971',
#   '136720',
#   '479203',
#   '43123',
#   '175009',
#   '313101',
#   '80418',
#   '428016',
#   '359058',
#   '387542',
#   '372621',
#   '471259',
#   '210250',
#   '160251',
#   '222066',
#   '35874',
#   '210978',
#   '290294',
#   '390089',
#   '93775',
#   '235297',
#   '319864',
#   '378143',
#   '276454',
#   '364119',
#   '301593',
#   '327398',
#   '303491',
#   '183673',
#   '383425',
#   '127099',
#   '302737',
#   '24950',
#   '79633',
#   '289255',
#   '263232',
#   '340656',
#   '11382',
#   '41474',
#   '133631',
#   '47444',
#   '169147',
#   '303938',
#   '392356',
#   '84822',
#   '81021',
#   '468398',
#   '34244',
#   '427745',
#   '2056',
#   '189716',
#   '169364',
#   '456051',
#   '211299',
#   '504083',
#   '108227',
#   '194303',
#   '59727',
#   '18324',
#   '39059',
#   '39370',
#   '114011',
#   '70115',
#   '102171',
#   '477587',
#   '148365',
#   '29731',
#   '412061',
#   '471658',
#   '220408',
#   '336690',
#   '313351',
#   '442276',
#   '49860',
#   '249976',
#   '53204',
#   '422466',
#   '14228',
#   '393533',
#   '372390',
#   '352',
#   '9978',
#   '204780',
#   '399315',
#   '97494',
#   '396396',
#   '201463',
#   '31446',
#   '381746',
#   '43452',
#   '96127',
#   '34484',
#   '141421',
#   '167513',
#   '160570',
#   '62193',
#   '111535',
#   '185611',
#   '30118',
#   '218674',
#   '25415',
#   '245022',
#   '11705',
#   '484315',
#   '436590',
#   '122887',
#   '266316',
#   '276874',
#   '38672',
#   '356742',
#   '256822',
#   '248007',
#   '53404',
#   '206266',
#   '138017',
#   '8151',
#   '111477',
#   '202413',
#   '204578',
#   '151739',
#   '416979',
#   '55095',
#   '398304',
#   '56761',
#   '223621',
#   '424513',
#   '316232',
#   '321147',
#   '30773',
#   '77965',
#   '441933',
#   '155998',
#   '152411',
#   '178954',
#   '286110',
#   '163014',
#   '64820',
#   '424632',
#   '455376',
#   '272413',
#   '17853',
#   '131261',
#   '374312',
#   '156332',
#   '412992',
#   '516952',
#   '236834',
#   '95122',
#   '59407',
#   '323195',
#   '205758',
#   '453425',
#   '107308',
#   '177386',
#   '157807',
#   '299478',
#   '62303',
#   '379482',
#   '167118',
#   '21131',
#   '147564',
#   '164317',
#   '312054',
#   '306629',
#   '181596',
#   '216365',
#   '245744',
#   '353181',
#   '104062',
#   '107515',
#   '91164',
#   '299149',
#   '269705',
#   '83141',
#   '160147',
#   '235666',
#   '300279',
#   '54526',
#   '396623',
#   '113229',
#   '168737',
#   '109801',
#   '287331',
#   '251821',
#   '176875',
#   '379044',
#   '413270',
#   '151163',
#   '322599',
#   '48492',
#   '229065',
#   '220558',
#   '434495',
#   '124388',
#   '150028',
#   '136466',
#   '24039',
#   '47755',
#   '22850',
#   '84707',
#   '57051',
#   '152029',
#   '340432',
#   '167906',
#   '465121',
#   '146942',
#   '151072',
#   '272456',
#   '339569',
#   '47064',
#   '87147',
#   '170929',
#   '40279',
#   '216575',
#   '317072',
#   '92022',
#   '23696',
#   '128588',
#   '88503',
#   '397154',
#   '192293',
#   '130178',
#   '503295',
#   '213941',
#   '249499',
#   '374643',
#   '153569',
#   '452256',
#   '307684',
#   '479461',
#   '373728',
#   '373369',
#   '111469',
#   '466159',
#   '208099',
#   '522311',
#   '39718',
#   '211648',
#   '60741',
#   '357041',
#   '351913',
#   '318807',
#   '159378',
#   '176306',
#   '324740',
#   '287380',
#   '258985',
#   '255327',
#   '177600',
#   '340941',
#   '93557',
#   '469055',
#   '318295',
#   '383502',
#   '169856',
#   '27978',
#   '35668',
#   '87548',
#   '178603',
#   '434140',
#   '185025',
#   '338767',
#   '333243',
#   '433836',
#   '225056',
#   '128440',
#   '79414',
#   '281473',
#   '372858',
#   '146481',
#   '60846',
#   '503298',
#   '149176',
#   '316299',
#   '272468',
#   '433417',
#   '164660',
#   '415430',
#   '24911',
#   '138971',
#   '263659',
#   '225717',
#   '189741',
#   '110805',
#   '24740',
#   '286991',
#   '208798',
#   '179280',
#   '44507',
#   '33284',
#   '20587',
#   '334927',
#   '45180',
#   '29028',
#   '83526',
#   '161799',
#   '259941',
#   '11717',
#   '227387',
#   '51530',
#   '458158',
#   '55512',
#   '43136',
#   '199785',
#   '393609',
#   '20513',
#   '371990',
#   '420713',
#   '462621',
#   '25516',
#   '291577',
#   '197686',
#   '279967',
#   '205915',
#   '217854',
#   '77804',
#   '341952',
#   '232842',
#   '233475',
#   '215887',
#   '336463',
#   '257014',
#   '253885',
#   '122758',
#   '220645',
#   '23380',
#   '224221',
#   '186687',
#   '103259',
#   '161118',
#   '144042',
#   '326296',
#   '196763',
#   '147095',
#   '222106',
#   '500819',
#   '24094',
#   '102591',
#   '369110',
#   '82503',
#   '333820',
#   '471484',
#   '287544',
#   '21224',
#   '223680',
#   '19518',
#   '154254',
#   '12782',
#   '24306',
#   '428423',
#   '93442',
#   '191561',
#   '460231',
#   '332056',
#   '445244',
#   '498562',
#   '56830',
#   '92973',
#   '166896',
#   '137839',
#   '187987',
#   '302923',
#   '410719',
#   '300958',
#   '508714',
#   '91887',
#   '98566',
#   '18070',
#   '456782',
#   '249684',
#   '57056',
#   '336796',
#   '37968',
#   '18540',
#   '252134',
#   '189788',
#   '259191',
#   '193877',
#   '257319',
#   '417848',
#   '374107',
#   '12830',
#   '319477',
#   '244483',
#   '190935',
#   '119055',
#   '367592',
#   '367004',
#   '98037',
#   '121306',
#   '166556',
#   '35038',
#   '89081',
#   '85678',
#   '264143',
#   '214639',
#   '10932',
#   '43905',
#   '406062',
#   '50596',
#   '71896',
#   '54615',
#   '387',
#   '91925',
#   '321256',
#   '154820',
#   '245671',
#   '82646',
#   '36890',
#   '251093',
#   '389592',
#   '115057',
#   '71620',
#   '47548',
#   '347833',
#   '218616',
#   '65951',
#   '318336',
#   '282490',
#   '42453',
#   '217173',
#   '241809',
#   '275739',
#   '120981',
#   '167295',
#   '16380',
#   '13177',
#   '342759',
#   '76215',
#   '489962',
#   '80419',
#   '27426',
#   '350099',
#   '328556',
#   '464587',
#   '379355',
#   '517878',
#   '195442',
#   '399702',
#   '226274',
#   '50125',
#   '449302',
#   '333246',
#   '24565',
#   '263709',
#   '167608',
#   '218924',
#   '38319',
#   '56922',
#   '11879',
#   '315921',
#   '330463',
#   '15003',
#   '152660',
#   '152300',
#   '89769',
#   '367184',
#   '72844',
#   '247306',
#   '160210',
#   '61461',
#   '43824',
#   '165312',
#   '50103',
#   '157952',
#   '205230',
#   '163967',
#   '276764',
#   '172219',
#   '28225',
#   '278847',
#   '68197',
#   '33886',
#   '315377',
#   '68599',
#   '148409',
#   '467039',
#   '248077',
#   '67017',
#   '340895',
#   '246308',
#   '153948',
#   '133320',
#   '422172',
#   '202461',
#   '442463',
#   '22201',
#   '216322',
#   '112187',
#   '166560',
#   '57908',
#   '234444',
#   '393286',
#   '15148',
#   '39173',
#   '49125',
#   '23264',
#   '50718',
#   '304402',
#   '261047',
#   '479380',
#   '243871',
#   '489959',
#   '227753',
#   '17118',
#   '200872',
#   '413711',
#   '236579',
#   '141636',
#   '27063',
#   '174857',
#   '255425',
#   '75621',
#   '17941',
#   '55739',
#   '58286',
#   '104165',
#   '280223',
#   '29268',
#   '100967',
#   '203153',
#   '47662',
#   '263453',
#   '342357',
#   '78788',
#   '104422',
#   '211829',
#   '190910',
#   '171137',
#   '140056',
#   '232399',
#   '118116',
#   '192019',
#   '48067',
#   '85042',
#   '238050',
#   '425183',
#   '281075',
#   '349166',
#   '225164',
#   '34903',
#   '70180',
#   '242700',
#   '189802',
#   '83609',
#   '66060',
#   '113385',
#   '84997',
#   '262889',
#   '11407',
#   '236365',
#   '199138',
#   '104070',
#   '298696',
#   '46116',
#   '204569',
#   '127128',
#   '145779',
#   '362346',
#   '173869',
#   '415808',
#   '56805',
#   '250840',
#   '4691',
#   '225239',
#   '221324',
#   '443943',
#   '468228',
#   '28111',
#   '154562',
#   '119357',
#   '366688',
#   '248771',
#   '222435',
#   '39734',
#   '458326',
#   '89272',
#   '301754',
#   '473459',
#   '279757',
#   '322948',
#   '151483',
#   '76994',
#   '98305',
#   '240443',
#   '198521',
#   '150399',
#   '125971',
#   '363286',
#   '244608',
#   '16531',
#   '15836',
#   '32958',
#   '520656',
#   '283945',
#   '188462',
#   '252852',
#   '218489',
#   '99588',
#   '517313',
#   '24420',
#   '17131',
#   '118018',
#   '311307',
#   '264739',
#   '101516',
#   '289922',
#   '179826',
#   '324212',
#   '360132',
#   '444593',
#   '509140',
#   '263253',
#   '345915',
#   '112451',
#   '8928',
#   '14293',
#   '369453',
#   '220520',
#   '319044',
#   '506665',
#   '18964',
#   '516384',
#   '391104',
#   '97401',
#   '355495',
#   '33715',
#   '68218',
#   '250053',
#   '377646',
#   '324518',
#   '353741',
#   '26461',
#   '116144',
#   '36488',
#   '47427',
#   '264517',
#   '82179',
#   '119848',
#   '68450',
#   '330915',
#   '144541',
#   '461205',
#   '271297',
#   '64209',
#   '297222',
#   '268200',
#   '91977',
#   '153730',
#   '328567',
#   '304340',
#   '136123',
#   '32576',
#   '12845',
#   '458528',
#   '166290',
#   '240321',
#   '102916',
#   '453488',
#   '471226',
#   '111925',
#   '57763',
#   '109091',
#   '120015',
#   '34194',
#   '98680',
#   '392727',
#   '411844',
#   '508912',
#   '278429',
#   '199778',
#   '296783',
#   '193559',
#   '438608',
#   '277747',
#   '272778',
#   '230379',
#   '1662',
#   '114409',
#   '118197',
#   '25034',
#   '219867',
#   '313604',
#   '453561',
#   '317638',
#   '485836',
#   '21166',
#   '213980',
#   '69809',
#   '90692',
#   '64771',
#   '84749',
#   '511805',
#   '449347',
#   '225670',
#   '33571',
#   '15075',
#   '301204',
#   '214987',
#   '242396',
#   '88338',
#   '384272',
#   '469496',
#   '259008',
#   '51382',
#   '243222',
#   '227787',
#   '104012',
#   '469036',
#   '51055',
#   '375848',
#   '364626',
#   '148188',
#   '428818',
#   '112277',
#   '173481',
#   '125586',
#   '95891',
#   '76038',
#   '106157',
#   '109834',
#   '117657',
#   '63088',
#   '487501',
#   '360431',
#   '214234',
#   '133150',
#   '229852',
#   '139603',
#   '85805',
#   '471535',
#   '41938',
#   '194464',
#   '80390',
#   '311584',
#   '472454',
#   '280393',
#   '164545',
#   '413510',
#   '219159',
#   '265318',
#   '32684',
#   '56765',
#   '165311',
#   '395880',
#   '260053',
#   '65816',
#   '424437',
#   '174932',
#   '297901',
#   '172801',
#   '281920',
#   '10487',
#   '217013',
#   '187834',
#   '391101',
#   '98511',
#   '142981',
#   '328837',
#   '127038',
#   '73495',
#   '92048',
#   '324561',
#   '373426',
#   '266239',
#   '85323',
#   '32544',
#   '30234',
#   '258312',
#   '162919',
#   '185525',
#   '83030',
#   '79865',
#   '192848',
#   '45584',
#   '305020',
#   '221832',
#   '44199',
#   '54000',
#   '412915',
#   '367624',
#   '14533',
#   '71265',
#   '357274',
#   '498083',
#   '289675',
#   '13610',
#   '172536',
#   '102851',
#   '144185',
#   '269710',
#   '306248',
#   '415398',
#   '276549',
#   '36200',
#   '71653',
#   '93900',
#   '239976',
#   '376802',
#   '87955',
#   '492243',
#   '7120',
#   '472497',
#   '469380',
#   '173552',
#   '286405',
#   '25157',
#   '280107',
#   '383346',
#   '37439',
#   '204142',
#   '124671',
#   '362090',
#   '229483',
#   '436329',
#   '115446',
#   '68451',
#   '429138',
#   '32586',
#   '424386',
#   '489589',
#   '489590',
#   '125535',
#   '310637',
#   '528002',
#   '294059',
#   '174337',
#   '51862',
#   '368762',
#   '135339',
#   '119969',
#   '116953',
#   '176150',
#   '171485',
#   '328711',
#   '45992',
#   '132476',
#   '396259',
#   '400271',
#   '318572',
#   '376910',
#   '165014',
#   '424023',
#   '254718',
#   '38435',
#   '69526',
#   '101953',
#   '69499',
#   '130559',
#   '347911',
#   '206086',
#   '29365',
#   '19009',
#   '279696',
#   '93124',
#   '161055',
#   '338489',
#   '27889',
#   '284450',
#   '363059',
#   '320664',
#   '481925',
#   '297988',
#   '179605',
#   '461329',
#   '25060',
#   '19544',
#   '41599',
#   '224458',
#   '415374',
#   '31987',
#   '20551',
#   '73003',
#   '314112',
#   '287041',
#   '31003',
#   '138105',
#   '122884',
#   '285984',
#   '22088',
#   '177230',
#   '324237',
#   '160507',
#   '33260',
#   '243612',
#   '242235',
#   '183232',
#   '85884',
#   '145126',
#   '38913',
#   '497505',
#   '349190',
#   '203507',
#   '367134',
#   '354311',
#   '129997',
#   '263203',
#   '295376',
#   '325321',
#   '362842',
#   '353899',
#   '218701',
#   '373358',
#   '340411',
#   '493838',
#   '1975',
#   ...],
#  7: ['35173',
#   '109818',
#   '66932',
#   '223349',
#   '63346',
#   '401605',
#   '134787',
#   '21357',
#   '401283',
#   '221429',
#   '256464',
#   '123408',
#   '311959',
#   '141164',
#   '99798',
#   '276601',
#   '88125',
#   '28641',
#   '407747',
#   '58045',
#   '313613',
#   '263109',
#   '437455',
#   '115776',
#   '79312',
#   '230004',
#   '40050',
#   '277562',
#   '244294',
#   '172783',
#   '141617',
#   '102525',
#   '174606',
#   '50337',
#   '60058',
#   '97699',
#   '501197',
#   '414085',
#   '412091',
#   '36009',
#   '174645',
#   '55510',
#   '476489',
#   '14613',
#   '265955',
#   '412006',
#   '136514',
#   '29448',
#   '396740',
#   '455028',
#   '306676',
#   '302106',
#   '354791',
#   '222953',
#   '198137',
#   '102336',
#   '184166',
#   '378968',
#   '260335',
#   '284208',
#   '244742',
#   '97490',
#   '26325',
#   '69776',
#   '103379',
#   '59687',
#   '164072',
#   '455452',
#   '445734',
#   '33321',
#   '71046',
#   '41166',
#   '97140',
#   '102214',
#   '107233',
#   '403593',
#   '422794',
#   '147765',
#   '15543',
#   '362501',
#   '329285',
#   '377722',
#   '264476',
#   '60893',
#   '476461',
#   '214023',
#   '49349',
#   '260352',
#   '158382',
#   '69045',
#   '62080',
#   '414036',
#   '62556',
#   '83213',
#   '135227',
#   '135777',
#   '91395',
#   '259983',
#   '322492',
#   '366402',
#   '123449',
#   '478189',
#   '156650',
#   '95389',
#   '471470',
#   '461147',
#   '449854',
#   '246489',
#   '280297',
#   '24447',
#   '219042',
#   '259154',
#   '279705',
#   '281503',
#   '43401',
#   '216631',
#   '478829',
#   '7210',
#   '362466',
#   '450247',
#   '82600',
#   '342130',
#   '360752',
#   '414890',
#   '410251',
#   '116105',
#   '179427',
#   '54994',
#   '142388',
#   '204418',
#   '311508',
#   '349392',
#   '250136',
#   '192313',
#   '90193',
#   '71866',
#   '117668',
#   '296597',
#   '44095',
#   '440046',
#   '155403',
#   '269152',
#   '36678',
#   '310392',
#   '393778',
#   '267270',
#   '19168',
#   '225329',
#   '417265',
#   '40419',
#   '239451',
#   '168629',
#   '489986',
#   '296921',
#   '268352',
#   '495338',
#   '300068',
#   '208058',
#   '120273',
#   '91514',
#   '323527',
#   '1557',
#   '22889',
#   '215567',
#   '259570',
#   '286882',
#   '306736',
#   '178823',
#   '392655',
#   '49139',
#   '129621',
#   '486312',
#   '97048',
#   '4765',
#   '435575',
#   '160705',
#   '175540',
#   '32579',
#   '122860',
#   '11761',
#   '515586',
#   '32865',
#   '152233',
#   '189821',
#   '159336',
#   '15302',
#   '218750',
#   '137233',
#   '280310',
#   '134000',
#   '327960',
#   '111584',
#   '245429',
#   '286381',
#   '127498',
#   '520230',
#   '333393',
#   '222933',
#   '229434',
#   '203366',
#   '263617',
#   '86929',
#   '457660',
#   '95376',
#   '322270',
#   '167585',
#   '953',
#   '46009',
#   '377082',
#   '473022',
#   '353967',
#   '487985',
#   '158520',
#   '110683',
#   '274369',
#   '31209',
#   '56479',
#   '441824',
#   '457400',
#   '360234',
#   '418256',
#   '255260',
#   '16752',
#   '151675',
#   '284365',
#   '240668',
#   '196089',
#   '23490',
#   '383532',
#   '94307',
#   '33812',
#   '469462',
#   '508579',
#   '128288',
#   '78900',
#   '114249',
#   '399202',
#   '262921',
#   '426351',
#   '285572',
#   '240865',
#   '18187',
#   '47384',
#   '383269',
#   '125090',
#   '22415',
#   '125329',
#   '76275',
#   '404754',
#   '154673',
#   '217287',
#   '211064',
#   '448669',
#   '251211',
#   '459408',
#   '383941',
#   '229204',
#   '78878',
#   '104882',
#   '320030',
#   '191310',
#   '137270',
#   '475310',
#   '128505',
#   '193604',
#   '286317',
#   '313697',
#   '200449',
#   '261244',
#   '411697',
#   '162050',
#   '267403',
#   '159169',
#   '71784',
#   '351782',
#   '28758',
#   '203145',
#   '24871',
#   '120865',
#   '213352',
#   '176478',
#   '215933',
#   '149012',
#   '377380',
#   '316390',
#   '84479',
#   '384400',
#   '25759',
#   '51214',
#   '280318',
#   '78733',
#   '271682',
#   '229772',
#   '19260',
#   '408973',
#   '147360',
#   '408969',
#   '131408',
#   '48885',
#   '338459',
#   '72912',
#   '212958',
#   '15060',
#   '63825',
#   '226550',
#   '249833',
#   '388401',
#   '43913',
#   '22090',
#   '89047',
#   '119160',
#   '290330',
#   '94987',
#   '8404',
#   '30317',
#   '275584',
#   '236281',
#   '243704',
#   '446947',
#   '406420',
#   '114001',
#   '196070',
#   '93520',
#   '62662',
#   '11162',
#   '441847',
#   '73076',
#   '65264',
#   '263488',
#   '334738',
#   '175096',
#   '159958',
#   '109156',
#   '99352',
#   '534393',
#   '392692',
#   '148656',
#   '355882',
#   '425348',
#   '375466',
#   '340394',
#   '138783',
#   '297889',
#   '396266',
#   '23632',
#   '6934',
#   '93634',
#   '305279',
#   '141286',
#   '78563',
#   '182625',
#   '28969',
#   '139208',
#   '291234',
#   '285271',
#   '395885',
#   '228329',
#   '58173',
#   '33799',
#   '59599',
#   '49989',
#   '113582',
#   '165424',
#   '307626',
#   '2902',
#   '92154',
#   '109283',
#   '151928',
#   '178299',
#   '26984',
#   '241877',
#   '422231',
#   '70304',
#   '330318',
#   '139992',
#   '95489',
#   '110481',
#   '450756',
#   '292166',
#   '305855',
#   '320541',
#   '194747',
#   '184897',
#   '351765',
#   '414297',
#   '11420',
#   '98314',
#   '139834',
#   '362862',
#   '265838',
#   '362080',
#   '270950',
#   '193968',
#   '248366',
#   '142481',
#   '68179',
#   '275943',
#   '285441',
#   '91700',
#   '167334',
#   '109173',
#   '152914',
#   '152540',
#   '201675',
#   '40826',
#   '357070',
#   '43637',
#   '277916',
#   '43254',
#   '51578',
#   '223560',
#   '215037',
#   '132278',
#   '109575',
#   '45188',
#   '308872',
#   '418479',
#   '157458',
#   '302548',
#   '244695',
#   '9982',
#   '311299',
#   '34685',
#   '135564',
#   '250665',
#   '33833',
#   '164058',
#   '44258',
#   '58705',
#   '218466',
#   '454397',
#   '247983',
#   '99110',
#   '54241',
#   '188709',
#   '372354',
#   '193147',
#   '191179',
#   '360022',
#   '262670',
#   '286057',
#   '107058',
#   '74778',
#   '83279',
#   '305476',
#   '104923',
#   '188927',
#   '71936',
#   '35197',
#   '4464',
#   '139843',
#   '140771',
#   '100977',
#   '214198',
#   '21168',
#   '259502',
#   '494865',
#   '94580',
#   '112664',
#   '473126',
#   '371026',
#   '249826',
#   '126616',
#   '133905',
#   '220111',
#   '84745',
#   '187021',
#   '13349',
#   '67422',
#   '209723',
#   '124695',
#   '319548',
#   '105731',
#   '499586',
#   '465027',
#   '138924',
#   '140652',
#   '28703',
#   '462647',
#   '364069',
#   '450283',
#   '326338',
#   '13374',
#   '230232',
#   '274321',
#   '107203',
#   '304305',
#   '132675',
#   '190141',
#   '235299',
#   '137486',
#   '420304',
#   '32847',
#   '319324',
#   '54979',
#   '270094',
#   '80361',
#   '472612',
#   '188121',
#   '358826',
#   '111599',
#   '14296',
#   '44261',
#   '505936',
#   '4893',
#   '181816',
#   '92061',
#   '339530',
#   '87102',
#   '99524',
#   '372135',
#   '236851',
#   '25079',
#   '132083',
#   '251404',
#   '108284',
#   '321218',
#   '464226',
#   '484910',
#   '446060',
#   '240581',
#   '82205',
#   '247722',
#   '243721',
#   '218287',
#   '305675',
#   '441821',
#   '126581',
#   '52942',
#   '205260',
#   '170550',
#   '23235',
#   '180797',
#   '198801',
#   '211808',
#   '361470',
#   '276236',
#   '171834',
#   '114397',
#   '414049',
#   '355415',
#   '12883',
#   '156247',
#   '76225',
#   '481852',
#   '52159',
#   '276573',
#   '144129',
#   '329542',
#   '460515',
#   '74021',
#   '220137',
#   '142335',
#   '362757',
#   '304289',
#   '423659',
#   '116074',
#   '221582',
#   '80540',
#   '455086',
#   '180119',
#   '14578',
#   '84793',
#   '14011',
#   '70029',
#   '354578',
#   '119271',
#   '147715',
#   '421990',
#   '13320',
#   '105706',
#   '14896',
#   '316685',
#   '25059',
#   '451019',
#   '411827',
#   '76625',
#   '149202',
#   '307316',
#   '11682',
#   '98485',
#   '49667',
#   '345481',
#   '413256',
#   '378778',
#   '461065',
#   '199591',
#   '32873',
#   '110057',
#   '9192',
#   '417144',
#   '21869',
#   '65064',
#   '69382',
#   '133211',
#   '493851',
#   '19442',
#   '199298',
#   '350436',
#   '281056',
#   '338892',
#   '35416',
#   '194893',
#   '125133',
#   '50869',
#   '4740',
#   '509461',
#   '167270',
#   '322287',
#   '136986',
#   '103243',
#   '416172',
#   '191866',
#   '399533',
#   '272253',
#   '78949',
#   '26160',
#   '187228',
#   '269516',
#   '475423',
#   '302670',
#   '96780',
#   '226775',
#   '381503',
#   '189896',
#   '234060',
#   '21597',
#   '349642',
#   '405601',
#   '179049',
#   '218882',
#   '173130',
#   '340028',
#   '320534',
#   '198798',
#   '461996',
#   '321652',
#   '344433',
#   '49578',
#   '302891',
#   '15553',
#   '224739',
#   '19725',
#   '32743',
#   '412285',
#   '380638',
#   '101173',
#   '351572',
#   '304548',
#   '186461',
#   '117475',
#   '111188',
#   '214674',
#   '499383',
#   '289957',
#   '254702',
#   '221236',
#   '264666',
#   '109432',
#   '52168',
#   '239832',
#   '265492',
#   '81173',
#   '115583',
#   '78014',
#   '66340',
#   '211650',
#   '36684',
#   '159579',
#   '61615',
#   '425309',
#   '421737',
#   '353805',
#   '3439',
#   '70216',
#   '47716',
#   '144190',
#   '16362',
#   '4902',
#   '26504',
#   '82985',
#   '180226',
#   '146428',
#   '94207',
#   '116821',
#   '513947',
#   '271812',
#   '278257',
#   '88753',
#   '238236',
#   '42461',
#   '178935',
#   '478110',
#   '154823',
#   '340438',
#   '477144',
#   '232888',
#   '16343',
#   '192859',
#   '227771',
#   '428568',
#   '207976',
#   '295727',
#   '70126',
#   '91304',
#   '116143',
#   '393791',
#   '70239',
#   '109883',
#   '88404',
#   '114356',
#   '50015',
#   '277163',
#   '273071',
#   '17477',
#   '394250',
#   '107549',
#   '79268',
#   '209931',
#   '416325',
#   '113747',
#   '164389',
#   '126066',
#   '358837',
#   '452607',
#   '50782',
#   '349530',
#   '21752',
#   '219524',
#   '154110',
#   '182259',
#   '508702',
#   '516665',
#   '149808',
#   '423905',
#   '71218',
#   '140552',
#   '106654',
#   '249470',
#   '355962',
#   '285461',
#   '140199',
#   '414422',
#   '81286',
#   '71322',
#   '86993',
#   '129685',
#   '406688',
#   '287938',
#   '56619',
#   '100371',
#   '283724',
#   '116661',
#   '53685',
#   '348070',
#   '194000',
#   '373724',
#   '353886',
#   '235660',
#   '503991',
#   '11100',
#   '96668',
#   '325903',
#   '19697',
#   '161178',
#   '131721',
#   '442092',
#   '359641',
#   '8351',
#   '463766',
#   '104242',
#   '113257',
#   '375043',
#   '405857',
#   '416329',
#   '300801',
#   '253137',
#   '284596',
#   '318613',
#   '445096',
#   '69364',
#   '98936',
#   '165944',
#   '477382',
#   '204938',
#   '268603',
#   '186256',
#   '71369',
#   '117723',
#   '381596',
#   '94790',
#   '105736',
#   '330919',
#   '147820',
#   '23310',
#   '267920',
#   '43706',
#   '206157',
#   '359558',
#   '368533',
#   '54041',
#   '280907',
#   '244044',
#   '236483',
#   '32910',
#   '372874',
#   '373092',
#   '279232',
#   '228146',
#   '329923',
#   '230226',
#   '486173',
#   '11124',
#   '413410',
#   '336869',
#   '381412',
#   '87927',
#   '164218',
#   '167481',
#   '201700',
#   '14379',
#   '215308',
#   '228799',
#   '348970',
#   '29094',
#   '149492',
#   '139722',
#   '320251',
#   '28216',
#   '78263',
#   '136258',
#   '135210',
#   '335810',
#   '101207',
#   '110672',
#   '26890',
#   '200857',
#   '239596',
#   '133136',
#   '159829',
#   '74909',
#   '57539',
#   '417659',
#   '382315',
#   '219131',
#   '190401',
#   '261793',
#   '72145',
#   '115880',
#   '266079',
#   '32617',
#   '275114',
#   '357993',
#   '48490',
#   '148100',
#   '18829',
#   '335702',
#   '91449',
#   '48839',
#   '225727',
#   '238049',
#   '495991',
#   '223690',
#   '242575',
#   '180593',
#   '286906',
#   '418975',
#   '46468',
#   '192651',
#   '460022',
#   '232589',
#   '79683',
#   '465574',
#   '191423',
#   '245016',
#   '3002',
#   '305551',
#   '76540',
#   '269136',
#   '404180',
#   '76654',
#   '68118',
#   '88839',
#   '156906',
#   '365664',
#   '20822',
#   '270949',
#   '28444',
#   '147023',
#   '187149',
#   '53257',
#   '356347',
#   '199743',
#   '39423',
#   '115554',
#   '34846',
#   '9409',
#   '252445',
#   '158575',
#   '214744',
#   '130293',
#   '4127',
#   '76005',
#   '474629',
#   '28795',
#   '87028',
#   '181883',
#   '40572',
#   '381310',
#   '347216',
#   '69824',
#   '334373',
#   '357199',
#   '63717',
#   '65460',
#   '185013',
#   '379818',
#   '72299',
#   '266424',
#   '434012',
#   '195717',
#   '41168',
#   '483168',
#   '218484',
#   '216016',
#   '9234',
#   '124372',
#   '311946',
#   '35589',
#   '229832',
#   '390614',
#   '335436',
#   '231595',
#   '527902',
#   '147471',
#   '17877',
#   '201093',
#   '345215',
#   '392341',
#   '16384',
#   '71849',
#   '51085',
#   '148326',
#   '212564',
#   '196324',
#   '64556',
#   '169865',
#   '147201',
#   '138110',
#   '232757',
#   '308520',
#   '205867',
#   '174351',
#   '262325',
#   '177521',
#   '290943',
#   '497653',
#   '339045',
#   '419796',
#   '230013',
#   '123425',
#   '431115',
#   '294858',
#   '64199',
#   '252131',
#   '86497',
#   '312518',
#   '331376',
#   '169345',
#   '133318',
#   '56246',
#   '396305',
#   '160421',
#   '89470',
#   '426119',
#   '103157',
#   '324983',
#   '137433',
#   '120560',
#   '233122',
#   '461607',
#   '97510',
#   '280291',
#   '31531',
#   '8213',
#   '424172',
#   '73236',
#   '32504',
#   '198902',
#   '49270',
#   '188918',
#   '203207',
#   '323822',
#   '257110',
#   '247449',
#   '155973',
#   '274408',
#   '95710',
#   '327305',
#   '458880',
#   ...],
#  4: ['84797',
#   '95926',
#   '134085',
#   '192542',
#   '100837',
#   '11361',
#   '428566',
#   '235003',
#   '140172',
#   '140173',
#   '296654',
#   '67686',
#   '241276',
#   '297671',
#   '163148',
#   '209459',
#   '361446',
#   '504948',
#   '174129',
#   '229252',
#   '447967',
#   '171809',
#   '354615',
#   '249318',
#   '232548',
#   '303710',
#   '413783',
#   '380243',
#   '33565',
#   '369241',
#   '330954',
#   '198585',
#   '247025',
#   '99570',
#   '308383',
#   '23964',
#   '90641',
#   '441761',
#   '284273',
#   '229406',
#   '291555',
#   '234952',
#   '51982',
#   '205649',
#   '318312',
#   '100649',
#   '302957',
#   '107153',
#   '395585',
#   '23163',
#   '45643',
#   '315847',
#   '494482',
#   '198350',
#   '279229',
#   '145893',
#   '65597',
#   '398095',
#   '461508',
#   '399189',
#   '489651',
#   '385243',
#   '315983',
#   '201746',
#   '22358',
#   '108473',
#   '179738',
#   '307835',
#   '183778',
#   '376844',
#   '487059',
#   '335812',
#   '12997',
#   '299916',
#   '81479',
#   '424917',
#   '96968',
#   '383039',
#   '40008',
#   '89719',
#   '49027',
#   '355413',
#   '55345',
#   '180536',
#   '184531',
#   '133951',
#   '209818',
#   '328233',
#   '179424',
#   '370757',
#   '179462',
#   '241948',
#   '330552',
#   '10301',
#   '144958',
# ...
#   '27663',
#   '69532',
#   '231925',
#   '19446',
#   '394936',
#   '155744',
#   '334814',
#   '190538',
#   '120565',
#   '127504',
#   '55350',
#   '293170',
#   '333598',
#   '402049',
#   '176927',
#   '397334',
#   '221275',
#   '350414',
#   '319676',
#   '51797',
#   '251486',
#   '57943',
#   '215278',
#   '131096',
#   '120366',
#   '93131',
#   '65163',
#   '30553',
#   '331436',
#   '228903',
#   '414038',
#   '291623',
#   '207944',
#   '508040',
#   '501464',
#   '350077',
#   '14815',
#   '499341',
#   '447439',
#   '215207',
#   '404368',
#   '86821',
#   '475517',
#   '386283',
#   '301220',
#   '50901',
#   '362099',
#   '333380',
#   '3304',
#   '64574',
#   '229538',
#   '148776',
#   '160256',
#   '234068',
#   '15283',
#   '116396',
#   '295664',
#   '438879',
#   '263837',
#   '112057',
#   '349002',
#   '363418',
#   '58503',
#   '235009',
#   '188133',
#   '88594',
#   '408123',
#   '267571',
#   '348296',
#   '189973',
#   '316691',
#   '253818',
#   '197840',
#   '29334',
#   '279523',
#   '216658',
#   '164474',
#   '36489',
#   '16685',
#   '105425',
#   '113177',
#   '198886',
#   '72198',
#   '313809',
#   '455868',
#   '135764',
#   '396237',
#   '340998',
#   '110447',
#   '111777',
#   '360804',
#   '507155',
#   '238131',
#   '270478',
#   '516545',
#   '383912',
#   '489145',
#   '64764',
#   '385314',
#   '381962',
#   '269391',
#   '219954',
#   '244453',
#   '215209',
#   '147966',
#   '270951',
#   '165434',
#   '301116',
#   '340108',
#   '141356',
#   '251117',
#   '108170',
#   '178086',
#   '363034',
#   '16903',
#   '282880',
#   '335947',
#   '153153',
#   '488258',
#   '95586',
#   '209270',
#   '435138',
#   '187794',
#   '3941',
#   '161622',
#   '305229',
#   '435214',
#   '446848',
#   '215236',
#   '273754',
#   '15676',
#   '263023',
#   '78086',
#   '268814',
#   '276263',
#   '281479',
#   '85425',
#   '107293',
#   '26030',
#   '57323',
#   '443207',
#   '369488',
#   '316970',
#   '288633',
#   '210247',
#   '354052',
#   '81731',
#   '497654',
#   '140507',
#   '98536',
#   '272006',
#   '158043',
#   '112617',
#   '503292',
#   '503387',
#   '263674',
#   '262585',
#   '374946',
#   '51243',
#   '414908',
#   '24937',
#   '329288',
#   '247870',
#   '43975',
#   '217988',
#   '140973',
#   '141044',
#   '51694',
#   '275718',
#   '36759',
#   '55794',
#   '404222',
#   '452397',
#   '328559',
#   '146709',
#   '255452',
#   '27323',
#   '340409',
#   '198013',
#   '390297',
#   '250110',
#   '157871',
#   '156118',
#   '471028',
#   '199868',
#   '115819',
#   '4699',
#   '210358',
#   '286127',
#   '135350',
#   '361878',
#   '452578',
#   '98950',
#   '117633',
#   '224213',
#   '151614',
#   '502864',
#   '113278',
#   '411799',
#   '232929',
#   '388830',
#   '234207',
#   '165695',
#   '27667',
#   '6929',
#   '413691',
#   '36920',
#   '337644',
#   '107445',
#   '90984',
#   '421197',
#   '320714',
#   '356095',
#   '161755',
#   '245796',
#   '414292',
#   '408825',
#   '407740',
#   '158862',
#   '367655',
#   '11383',
#   '479327',
#   '81009',
#   '252577',
#   '119098',
#   '480241',
#   '64730',
#   '416962',
#   '140866',
#   '304679',
#   '305416',
#   '147412',
#   '325218',
#   '37548',
#   '54824',
#   '448175',
#   '315173',
#   '214655',
#   '126306',
#   '434353',
#   '367547',
#   '126997',
#   '510563',
#   '390728',
#   '116373',
#   '24440',
#   '98342',
#   '79560',
#   '7022',
#   '173969',
#   '504555',
#   '214511',
#   '262987',
#   '40398',
#   '373124',
#   '120255',
#   '161401',
#   '417719',
#   '248344',
#   '430476',
#   '333444',
#   '390036',
#   '238215',
#   '451134',
#   '169726',
#   '362049',
#   '2691',
#   '423971',
#   '136212',
#   '268493',
#   '132301',
#   '161236',
#   '149519',
#   '102000',
#   '367786',
#   '108440',
#   '507595',
#   '324554',
#   '79586',
#   '93851',
#   '184205',
#   '380075',
#   '406038',
#   '81281',
#   '448531',
#   '452923',
#   '167420',
#   '274022',
#   '39608',
#   '5397',
#   '102337',
#   '311422',
#   '253796',
#   '373785',
#   '191510',
#   '487274',
#   '309995',
#   '82325',
#   '292635',
#   '8425',
#   '47171',
#   '15385',
#   '272251',
#   '336827',
#   '428722',
#   '374043',
#   '130189',
#   '201642',
#   '458496',
#   '145304',
#   '404966',
#   '287510',
#   '536610',
#   '139571',
#   '369274',
#   '23832',
#   '376304',
#   '124492',
#   '89729',
#   '505860',
#   '344367',
#   '222061',
#   '205052',
#   '337156',
#   '360502',
#   '162056',
#   '133671',
#   '394274',
#   '361725',
#   '308212',
#   '66673',
#   '114398',
#   '178102',
#   '144713',
#   '80199',
#   '219151',
#   '323142',
#   '138184',
#   '157161',
#   '361040',
#   '179008',
#   '392135',
#   '351350',
#   '25850',
#   '272899',
#   '271844',
#   '195963',
#   '42784',
#   '443204',
#   '241659',
#   '153508',
#   '151355',
#   '381819',
#   '104748',
#   '204180',
#   '251884',
#   '125912',
#   '512305',
#   '384254',
#   '185446',
#   '407000',
#   '30674',
#   '90361',
#   '292983',
#   '392905',
#   '41029',
#   '101027',
#   '205910',
#   '27363',
#   '490564',
#   '350024',
#   '377312',
#   '354023',
#   '304061',
#   '392263',
#   '159767',
#   '72270',
#   '254484',
#   '502004',
#   '300434',
#   '194141',
#   '180227',
#   '205937',
#   '146694',
#   '427594',
#   '172900',
#   '264192',
#   '395126',
#   '247787',
#   '232088',
#   '208772',
#   '208401',
#   '359679',
#   '305765',
#   '234424',
#   '309978',
#   '170087',
#   '49546',
#   '274951',
#   '451987',
#   '6924',
#   '168581',
#   '100717',
#   '265441',
#   '360333',
#   '252536',
#   '254104',
#   '495187',
#   '334911',
#   '177602',
#   '211112',
#   '98493',
#   '40744',
#   '80229',
#   '136413',
#   '250983',
#   '390150',
#   '181162',
#   '133604',
#   '390158',
#   '141782',
#   '261973',
#   '465404',
#   '161610',
#   '206731',
#   '140690',
#   '159966',
#   '3446',
#   '95911',
#   '346274',
#   '177580',
#   '145282',
#   '276955',
#   '93549',
#   '55733',
#   '361732',
#   '89802',
#   '131275',
#   '186056',
#   '444113',
#   '88032',
#   '451347',
#   '139976',
#   '166543',
#   '92892',
#   '263317',
#   '13492',
#   '165421',
#   '169760',
#   '57558',
#   '216245',
#   '278241',
#   '424554',
#   '257829',
#   '300675',
#   '296029',
#   '243352',
#   '287261',
#   '247987',
#   '420077',
#   '142791',
#   '227619',
#   '475194',
#   '363474',
#   '267948',
#   '325994',
#   '192524',
#   '294560',
#   '120868',
#   '116409',
#   '436635',
#   '449047',
#   '169826',
#   '174947',
#   '184431',
#   '463118',
#   '417596',
#   '127698',
#   '478247',
#   '163442',
#   '341023',
#   '213282',
#   '210718',
#   '378824',
#   '338734',
#   '20985',
#   '81306',
#   '143862',
#   '344669',
#   '17675',
#   '166968',
#   '339050',
#   '364197',
#   '126641',
#   '121732',
#   '145802',
#   '72407',
#   '80913',
#   '141906',
#   '45938',
#   '45222',
#   '178091',
#   '9787',
#   '140255',
#   '244800',
#   '263755',
#   '379185',
#   '4425',
#   '106405',
#   '262400',
#   '271802',
#   '404071',
#   '266514',
#   '63772',
#   '224495',
#   '249988',
#   '391012',
#   '365151',
#   '349700',
#   '383575',
#   '256265',
#   '88071',
#   '111792',
#   '252602',
#   '719',
#   '78412',
#   '417554',
#   '317875',
#   '424742',
#   '42892',
#   '380053',
#   '69401',
#   '232392',
#   '291687',
#   '32636',
#   '268662',
#   '430323',
#   '66113',
#   '341301',
#   '97187',
#   '127134',
#   '335292',
#   '167842',
#   '115263',
#   '175688',
#   '24459'],
#  25: ['104588',
#   '26809',
#   '146096',
#   '364148',
#   '368003',
#   '8674',
#   '161250',
#   '472203',
#   '98749',
#   '457429',
#   '95958',
#   '43487',
#   '268800',
#   '462021',
#   '46993',
#   '50069',
#   '252995',
#   '304912',
#   '133105',
#   '93136',
#   '400524',
#   '483359',
#   '21049',
#   '353917',
#   '502',
#   '170050',
#   '45986',
#   '312377',
#   '464670',
#   '471318',
#   '483812',
#   '503346',
#   '398034',
#   '107677',
#   '304874',
#   '478695',
#   '374867',
#   '22174',
#   '296752',
#   '102060',
#   '276255',
#   '381996',
#   '98643',
#   '323225',
#   '378756',
#   '171694',
#   '456439',
#   '94680',
#   '224292',
#   '156132',
#   '52334',
#   '219737',
#   '214484',
#   '246924',
#   '281791',
#   '344164',
#   '384251',
#   '487221',
#   '201687',
#   '110784',
#   '257703',
#   '281722',
#   '228579',
#   '161348',
#   '22605',
#   '347447',
#   '316699',
#   '121264',
#   '392367',
#   '364415',
#   '518217',
#   '296703',
#   '255165',
#   '438872',
#   '30518',
#   '474393',
#   '27709',
#   '91412',
#   '338736',
#   '68897',
#   '214749',
#   '248162',
#   '216753',
#   '230991',
#   '447121',
#   '172969',
#   '443158',
#   '165959',
#   '491104',
#   '3051',
#   '167741',
#   '329975',
#   '293879',
#   '524675',
#   '190461',
#   '195495',
#   '189995',
#   '404574',
#   '183529',
#   '90817',
#   '117455',
#   '229259',
#   '117245',
#   '151937',
#   '47873',
#   '69947',
#   '58386',
#   '395308',
#   '370340',
#   '244433',
#   '487969',
#   '265549',
#   '401483',
#   '290908',
#   '293786',
#   '298662',
#   '471629',
#   '493901',
#   '286145',
#   '154191',
#   '106764',
#   '257629',
#   '252102',
#   '481175'],
#  45: ['325571', '338907', '187751', '465115', '39387'],
#  21: ['423582',
#   '59386',
#   '230060',
#   '184727',
#   '287008',
#   '108524',
#   '135672',
#   '244363',
#   '145419',
#   '327588',
#   '2994',
#   '69728',
#   '174678',
#   '63127',
#   '524716',
#   '349863',
#   '115832',
#   '424671',
#   '217440',
#   '55609',
#   '506883',
#   '403184',
#   '418508',
#   '297472',
#   '354877',
#   '157946',
#   '244642',
#   '277870',
#   '146475',
#   '20207',
#   '180648',
#   '187035',
#   '181750',
#   '416017',
#   '121049',
#   '78945',
#   '121823',
#   '244982',
#   '404987',
#   '288544',
#   '311478',
#   '323713',
#   '261029',
#   '500788',
#   '518229',
#   '274501',
#   '79894',
#   '454832',
#   '30963',
#   '436982',
#   '131185',
#   '496934',
#   '452159',
#   '172789',
#   '422977',
#   '143176',
#   '100651',
#   '100349',
#   '210132',
#   '388773',
#   '239779',
#   '379463',
#   '115451',
#   '222150',
#   '444930',
#   '406582',
#   '238994',
#   '295899',
#   '457779',
#   '89808',
#   '338927',
#   '413018',
#   '145481',
#   '316600',
#   '497758',
#   '522881',
#   '133155',
#   '424162',
#   '464650',
#   '276235',
#   '494323',
#   '372926',
#   '326702',
#   '44343',
#   '268770',
#   '380944',
#   '108856',
#   '229340',
#   '387138',
#   '292301',
#   '9202',
#   '61827',
#   '273618',
#   '279215',
#   '234405',
#   '416206',
#   '422834',
#   '420384',
#   '421659',
#   '33449',
#   '381069',
#   '285362',
#   '337001',
#   '358439',
#   '457687',
#   '136847',
#   '354080',
#   '421393',
#   '470994',
#   '52735',
#   '405596',
#   '265153',
#   '245761',
#   '215907',
#   '173691',
#   '433214',
#   '177782',
#   '8843',
#   '499875',
#   '133486',
#   '248566',
#   '170895',
#   '187723',
#   '254700',
#   '322348',
#   '491552',
#   '465521',
#   '92402',
#   '380083',
#   '48362',
#   '301288',
#   '306331',
#   '398260',
#   '217030',
#   '170007',
#   '200486',
#   '128515',
#   '50458',
#   '198870',
#   '473466',
#   '409964',
#   '202725',
#   '90367',
#   '253262',
#   '452505',
#   '374302',
#   '9031',
#   '408733',
#   '421336',
#   '186981',
#   '177317',
#   '220514',
#   '392705',
#   '53971',
#   '401507',
#   '277148',
#   '275688',
#   '259648',
#   '501423',
#   '380938',
#   '235642',
#   '363125',
#   '372855',
#   '138641',
#   '443276',
#   '303546',
#   '455393',
#   '311157',
#   '100161',
#   '26256',
#   '177195',
#   '211623',
#   '103573',
#   '405629',
#   '456599',
#   '100415',
#   '388112',
#   '125153',
#   '63927',
#   '138315',
#   '350602',
#   '446582',
#   '173929',
#   '51007',
#   '281730',
#   '191322',
#   '60607',
#   '173067',
#   '310733',
#   '139956',
#   '257879',
#   '153135',
#   '211524',
#   '287657',
#   '298482',
#   '140360',
#   '373250',
#   '480930',
#   '296855',
#   '370341',
#   '29078',
#   '517143',
#   '280595',
#   '24422',
#   '370992',
#   '483847',
#   '510745',
#   '284288',
#   '237676',
#   '101420',
#   '261591',
#   '193469',
#   '77325',
#   '483184',
#   '156085',
#   '90067',
#   '354651',
#   '145163',
#   '324439',
#   '503212',
#   '177595',
#   '348024',
#   '190081',
#   '138276',
#   '297289',
#   '336777',
#   '44177',
#   '46653',
#   '70427',
#   '412518',
#   '167991'],
#  23: ['315346',
#   '487671',
#   '242952',
#   '268036',
#   '121665',
#   '38607',
#   '504168',
#   '400415',
#   '380814',
#   '67898',
#   '403198',
#   '299376',
#   '119688',
#   '384511',
#   '477272',
#   '161111',
#   '380709',
#   '233117',
#   '397909',
#   '507106',
#   '166955',
#   '180274',
#   '298883',
#   '316496',
#   '470412',
#   '137999',
#   '504952',
#   '138876',
#   '313974',
#   '37597',
#   '265481',
#   '91855',
#   '18849',
#   '112496',
#   '139526',
#   '134438',
#   '134093',
#   '472096',
#   '54177',
#   '373087',
#   '197315',
#   '367090',
#   '164029',
#   '4161',
#   '5018',
#   '272075',
#   '100622',
#   '217994',
#   '499389',
#   '107507',
#   '250856',
#   '445956',
#   '292388',
#   '48586',
#   '72532',
#   '121484',
#   '475356',
#   '459822',
#   '141071',
#   '391607',
#   '308048',
#   '316135',
#   '260243',
#   '226871',
#   '241871',
#   '102481',
#   '3662',
#   '446891',
#   '328864',
#   '494631',
#   '130935',
#   '180555',
#   '41660',
#   '469634',
#   '444079',
#   '518033',
#   '88804',
#   '216921',
#   '316718',
#   '504401',
#   '191722',
#   '124316',
#   '88990',
#   '253709',
#   '274354',
#   '271977',
#   '116432',
#   '443465',
#   '81004',
#   '2759',
#   '165364',
#   '260693',
#   '432989',
#   '224579',
#   '184378',
#   '162768',
#   '222876',
#   '45134',
#   '154402',
#   '199123',
#   '13867',
#   '145626',
#   '100600',
#   '309310',
#   '146547',
#   '341093',
#   '176688',
#   '178177',
#   '30491',
#   '471486',
#   '533951',
#   '233139',
#   '56083',
#   '496040',
#   '360824',
#   '406171',
#   '57470',
#   '165104',
#   '324228',
#   '371777',
#   '302023',
#   '46506',
#   '231686',
#   '257244',
#   '290013',
#   '210038',
#   '389459',
#   '407852',
#   '232633',
#   '339110',
#   '115753',
#   '179892',
#   '292518',
#   '403352',
#   '462526',
#   '192940',
#   '420069',
#   '77188',
#   '319298',
#   '137205',
#   '103699',
#   '112090',
#   '432377',
#   '149452',
#   '324696',
#   '146134',
#   '327802',
#   '504709',
#   '214051',
#   '254225',
#   '148889',
#   '187569',
#   '460374',
#   '128178',
#   '198887',
#   '98668',
#   '49357'],
#  31: ['161604',
#   '323218',
#   '26072',
#   '307558',
#   '474057',
#   '35601',
#   '340594',
#   '302405',
#   '295756',
#   '98983',
#   '106891',
#   '39016',
#   '458073',
#   '176120',
#   '185935',
#   '123266',
#   '415109',
#   '215114',
#   '512892',
#   '272423',
#   '530466',
#   '268928',
#   '18353',
#   '387919',
#   '354254',
#   '141098',
#   '118923',
#   '135850',
#   '346423',
#   '508331',
#   '45216',
#   '384676',
#   '503507',
#   '143667'],
#  32: ['344915',
#   '400024',
#   '434903',
#   '461636',
#   '293515',
#   '48',
#   '12179',
#   '232884',
#   '188672',
#   '272414',
#   '245088',
#   '388410',
#   '3045',
#   '320989',
#   '426105',
#   '402303',
#   '114557',
#   '70714',
#   '57062',
#   '124424',
#   '16127',
#   '317934',
#   '290463',
#   '128874',
#   '514180',
#   '272962',
#   '502688',
#   '245820',
#   '405210',
#   '440859',
#   '22003',
#   '95093',
#   '72169',
#   '354031',
#   '265656'],
#  40: ['424845',
#   '42845',
#   '228948',
#   '155194',
#   '224729',
#   '297282',
#   '125499',
#   '154787'],
#  44: ['233539',
#   '354868',
#   '246387',
#   '47467',
#   '343087',
#   '13950',
#   '358726',
#   '235584',
#   '366252',
#   '314409',
#   '56107'],
#  43: ['518120', '37639', '48954', '261193', '192436', '137853', '418779'],
#  36: ['387424',
#   '330133',
#   '408652',
#   '353520',
#   '331929',
#   '484664',
#   '534855',
#   '247539',
#   '449994',
#   '272093',
#   '418912',
#   '82079',
#   '234114',
#   '287542',
#   '218872'],
#  62: ['400101'],
#  27: ['70438',
#   '145034',
#   '211518',
#   '223185',
#   '174435',
#   '414388',
#   '386788',
#   '154842',
#   '301370',
#   '307156',
#   '511255',
#   '93219',
#   '153325',
#   '419301',
#   '396057',
#   '390250',
#   '254057',
#   '114998',
#   '121005',
#   '207592',
#   '233281',
#   '275426',
#   '47069',
#   '60118',
#   '432210',
#   '357108',
#   '342019',
#   '135076',
#   '91240',
#   '55776',
#   '256909',
#   '315235',
#   '262564',
#   '235601',
#   '129286',
#   '309457',
#   '43518',
#   '263265',
#   '199080',
#   '194649',
#   '390431',
#   '249844',
#   '54791',
#   '159366',
#   '266348',
#   '70888',
#   '417485',
#   '164497',
#   '312050',
#   '53444',
#   '221027',
#   '513659',
#   '151952',
#   '431646',
#   '495674',
#   '457412',
#   '103201',
#   '39716',
#   '534064',
#   '411125',
#   '308422',
#   '265777',
#   '155741',
#   '365816',
#   '214959',
#   '479973',
#   '349276',
#   '298187',
#   '187525',
#   '201278',
#   '64944',
#   '433477',
#   '43396',
#   '95006',
#   '406974',
#   '377943',
#   '520867',
#   '171459',
#   '236785',
#   '208379',
#   '375367',
#   '47195',
#   '181743',
#   '395521',
#   '80476'],
#  42: ['159935', '84074', '69628', '239666', '234912'],
#  67: ['448591'],
#  47: ['366685', '200780', '398107', '181411'],
#  37: ['174848',
#   '102771',
#   '257346',
#   '237752',
#   '334023',
#   '458101',
#   '106373',
#   '453239',
#   '88970',
#   '268624',
#   '234306',
#   '65382',
#   '30748',
#   '332745',
#   '288096',
#   '441302',
#   '86410',
#   '338453',
#   '370574'],
#  41: ['111596', '264210', '202753', '95756', '179670', '153130'],
#  39: ['254615',
#   '423704',
#   '267289',
#   '418474',
#   '226102',
#   '486865',
#   '306303',
#   '46098'],
#  60: ['8409'],
#  35: ['398969',
#   '240562',
#   '487119',
#   '53824',
#   '321848',
#   '392229',
#   '348872',
#   '3145',
#   '470106',
#   '34199',
#   '38409',
#   '535691',
#   '342416',
#   '291375',
#   '20568',
#   '373957',
#   '231240',
#   '448525',
#   '6651',
#   '340969'],
#  68: ['389774'],
#  48: ['99823', '107529'],
#  88: ['284729'],
#  70: ['692'],
#  55: ['66524', '263072'],
#  53: ['197341', '196010', '169943'],
#  73: ['536360'],
#  51: ['536747', '435430', '524744'],
#  69: ['373670'],
#  63: ['470251'],
#  46: ['288125'],
#  87: ['337926'],
#  49: ['254347', '498384'],
#  52: ['185860'],
#  65: ['510490'],
#  56: ['509506']}

# %% [markdown]
# 3.3 Получите список рецептов, в этапах выполнения которых есть информация о времени (часы или минуты). Для отбора подходящих рецептов обратите внимание на атрибуты соответствующих тэгов.

# %%
recipes_with_time = []

for recipe in steps_sample.find_all('recipe'):
    if len(recipe.steps.find_all('step', has_minutes = "1")) > 0 or len(recipe.steps.find_all('step', has_hours = "1")) > 0:
        recipes_with_time.append(recipe.id.next)

len(recipes_with_time)
# Out:
# 23469

# %% [markdown]
# 3.4 Загрузите данные из файла `recipes_sample.csv` (__ЛР2__) в таблицу `recipes`. Для строк, которые содержат пропуски в столбце `n_steps`, заполните этот столбец на основе файла  `steps_sample.xml`. Строки, в которых столбец `n_steps` заполнен, оставьте без изменений.

# %%
recipes.head()
# Out:
#                                        name     id  minutes  contributor_id  \
# 0     george s at the cove  black bean soup  44123       90           35193
# 1        healthy for them  yogurt popsicles  67664       10           91970
# 2              i can t believe it s spinach  38798       30            1533
# 3                      italian  gut busters  35173       45           22724
# 4  love is in the air  beef fondue   sauces  84797       25            4470
#
#    submitted  n_steps                                        description  \
# 0 2002-10-25      NaN  an original recipe created by chef scott meska...
# 1 2003-07-26      NaN  my children and their friends ask for my homem...
# 2 2002-08-29      NaN            these were so go, it surprised even me.
# 3 2002-07-27      NaN  my sister-in-law made these for us at a family...
# 4 2004-02-23      4.0  i think a fondue is a very romantic casual din...
#
#    n_ingredients
# 0           18.0
# 1            NaN
# 2            8.0
# 3            NaN
# 4            NaN

# %%
id_steps = {}

for recipe in steps_sample.find_all('recipe'):
    recipe_steps = len(recipe.steps.find_all('step'))
    id_steps[recipe.id.next] = float(recipe_steps)

id_steps
# Out:
# {'44123': 11.0,
#  '67664': 3.0,
#  '38798': 5.0,
#  '35173': 7.0,
#  '84797': 4.0,
#  '44045': 6.0,
#  '107229': 8.0,
#  '95926': 4.0,
#  '453467': 12.0,
#  '306168': 6.0,
#  '50662': 15.0,
#  '118843': 3.0,
#  '69190': 5.0,
#  '503475': 10.0,
#  '149593': 10.0,
#  '200148': 18.0,
#  '310570': 38.0,
#  '95534': 10.0,
#  '109818': 7.0,
#  '66932': 7.0,
#  '226001': 12.0,
#  '125195': 5.0,
#  '141939': 13.0,
#  '250883': 14.0,
#  '120297': 14.0,
#  '147477': 3.0,
#  '223349': 7.0,
#  '60938': 10.0,
#  '302399': 11.0,
#  '342620': 9.0,
#  '296983': 14.0,
#  '166089': 14.0,
#  '129581': 33.0,
#  '116741': 2.0,
#  '325714': 6.0,
#  '276594': 6.0,
#  '487173': 30.0,
#  '289671': 6.0,
#  '44050': 2.0,
#  '447429': 24.0,
#  '137701': 18.0,
#  '292568': 2.0,
#  '299989': 14.0,
#  '63346': 7.0,
#  '342619': 9.0,
#  '383120': 10.0,
#  '367987': 3.0,
#  '463219': 8.0,
#  '39172': 8.0,
#  '216068': 3.0,
#  '173730': 28.0,
#  '287778': 9.0,
#  '437637': 10.0,
#  '123115': 14.0,
#  '371549': 8.0,
#  '376813': 9.0,
#  '134085': 4.0,
#  '390230': 34.0,
#  '401605': 7.0,
#  '306590': 5.0,
#  '303944': 13.0,
#  '299968': 13.0,
#  '192542': 4.0,
#  '147563': 9.0,
#  '193719': 16.0,
#  '38852': 9.0,
#  '250232': 10.0,
#  '134787': 7.0,
#  '437219': 9.0,
#  '77380': 5.0,
#  '21357': 7.0,
#  '198343': 9.0,
#  '129919': 12.0,
#  '375376': 11.0,
#  '152534': 8.0,
#  '63131': 6.0,
#  '24760': 8.0,
#  '327979': 2.0,
#  '375362': 3.0,
#  '217296': 13.0,
#  '121107': 12.0,
#  '435816': 29.0,
#  '198073': 22.0,
#  '202949': 6.0,
#  '26420': 2.0,
#  '367828': 3.0,
#  '140610': 11.0,
#  '392181': 38.0,
#  '468143': 10.0,
#  '374703': 11.0,
#  '100837': 4.0,
#  '286484': 3.0,
#  '176996': 6.0,
#  '290187': 20.0,
#  '11361': 4.0,
#  '459738': 16.0,
#  '111198': 11.0,
#  '164636': 2.0,
#  '33246': 1.0,
#  '302498': 10.0,
#  '378067': 5.0,
#  '165438': 10.0,
#  '267159': 8.0,
#  '401283': 7.0,
#  '428566': 4.0,
#  '533190': 10.0,
#  '478546': 26.0,
#  '40228': 12.0,
#  '255985': 20.0,
#  '402246': 9.0,
#  '180817': 15.0,
#  '133326': 15.0,
#  '513963': 12.0,
#  '213395': 13.0,
#  '27060': 3.0,
#  '334201': 6.0,
#  '482111': 2.0,
#  '126072': 2.0,
#  '292147': 6.0,
#  '221429': 7.0,
#  '218671': 5.0,
#  '121712': 3.0,
#  '235003': 4.0,
#  '43669': 6.0,
#  '449768': 19.0,
#  '257696': 8.0,
#  '53353': 3.0,
#  '115160': 13.0,
#  '140172': 4.0,
#  '392598': 8.0,
#  '356163': 9.0,
#  '140173': 4.0,
#  '289025': 9.0,
#  '291409': 3.0,
#  '282812': 6.0,
#  '489337': 16.0,
#  '250900': 10.0,
#  '160494': 3.0,
#  '245950': 8.0,
#  '388578': 10.0,
#  '360881': 10.0,
#  '453243': 5.0,
#  '101260': 5.0,
#  '256464': 7.0,
#  '122791': 18.0,
#  '214264': 2.0,
#  '416599': 5.0,
#  '162657': 6.0,
#  '166483': 9.0,
#  '385415': 8.0,
#  '120462': 13.0,
#  '128544': 19.0,
#  '257111': 11.0,
#  '274469': 5.0,
#  '432661': 11.0,
#  '388488': 12.0,
#  '353419': 9.0,
#  '296654': 4.0,
#  '114204': 11.0,
#  '430737': 14.0,
#  '166082': 16.0,
#  '36072': 10.0,
#  '123408': 7.0,
#  '79826': 5.0,
#  '63069': 11.0,
#  '112648': 10.0,
#  '317798': 13.0,
#  '468765': 9.0,
#  '505748': 3.0,
#  '258970': 8.0,
#  '128027': 10.0,
#  '165096': 11.0,
#  '33947': 11.0,
#  '122817': 9.0,
#  '423528': 19.0,
#  '210766': 10.0,
#  '234120': 5.0,
#  '311959': 7.0,
#  '324047': 6.0,
#  '313237': 10.0,
#  '394191': 5.0,
#  '448832': 5.0,
#  '137187': 3.0,
#  '311313': 6.0,
#  '157534': 12.0,
#  '82136': 15.0,
#  '281251': 8.0,
#  '234531': 10.0,
#  '100633': 10.0,
#  '3441': 8.0,
#  '141164': 7.0,
#  '329881': 9.0,
#  '64631': 17.0,
#  '333395': 9.0,
#  '99798': 7.0,
#  '276601': 7.0,
#  '67686': 4.0,
#  '104588': 25.0,
#  '400025': 20.0,
#  '15541': 5.0,
#  '57206': 12.0,
#  '241276': 4.0,
#  '148114': 9.0,
#  '192212': 17.0,
#  '62088': 14.0,
#  '88125': 7.0,
#  '57009': 2.0,
#  '15646': 14.0,
#  '141847': 6.0,
#  '382633': 15.0,
#  '33849': 16.0,
#  '35287': 19.0,
#  '21629': 5.0,
#  '325571': 45.0,
#  '116672': 2.0,
#  '395196': 6.0,
#  '345089': 10.0,
#  '14912': 9.0,
#  '50854': 5.0,
#  '297671': 4.0,
#  '228000': 10.0,
#  '28641': 7.0,
#  '486851': 5.0,
#  '385071': 8.0,
#  '87105': 8.0,
#  '407747': 7.0,
#  '265502': 2.0,
#  '151148': 6.0,
#  '111559': 3.0,
#  '151131': 6.0,
#  '163148': 4.0,
#  '473574': 8.0,
#  '58045': 7.0,
#  '13671': 8.0,
#  '250024': 11.0,
#  '140171': 8.0,
#  '209459': 4.0,
#  '313613': 7.0,
#  '100590': 6.0,
#  '136471': 10.0,
#  '496614': 16.0,
#  '23613': 3.0,
#  '263109': 7.0,
#  '330512': 11.0,
#  '331269': 6.0,
#  '387435': 22.0,
#  '450975': 29.0,
#  '174369': 6.0,
#  '365478': 12.0,
#  '411729': 20.0,
#  '106797': 6.0,
#  '18985': 15.0,
#  '387106': 8.0,
#  '298089': 5.0,
#  '317681': 3.0,
#  '315233': 11.0,
#  '25259': 11.0,
#  '223242': 3.0,
#  '361446': 4.0,
#  '331174': 11.0,
#  '55425': 8.0,
#  '429949': 26.0,
#  '254176': 10.0,
#  '407621': 11.0,
#  '504956': 3.0,
#  '90092': 9.0,
#  '412075': 8.0,
#  '504948': 4.0,
#  '125721': 1.0,
#  '429759': 8.0,
#  '139718': 2.0,
#  '149966': 5.0,
#  '128563': 14.0,
#  '494527': 15.0,
#  '437455': 7.0,
#  '63907': 3.0,
#  '315982': 2.0,
#  '103153': 8.0,
#  '423582': 21.0,
#  '59386': 21.0,
#  '22567': 5.0,
#  '246579': 3.0,
#  '123716': 10.0,
#  '240415': 6.0,
#  '115776': 7.0,
#  '140174': 9.0,
#  '446600': 5.0,
#  '518151': 15.0,
#  '213132': 18.0,
#  '213133': 16.0,
#  '174129': 4.0,
#  '438486': 12.0,
#  '335920': 15.0,
#  '56202': 15.0,
#  '155405': 14.0,
#  '19618': 6.0,
#  '263019': 11.0,
#  '324404': 9.0,
#  '243425': 5.0,
#  '23378': 8.0,
#  '281409': 10.0,
#  '79312': 7.0,
#  '14873': 5.0,
#  '366021': 3.0,
#  '377658': 5.0,
#  '329139': 12.0,
#  '331719': 14.0,
#  '463122': 6.0,
#  '354751': 3.0,
#  '8827': 1.0,
#  '460069': 3.0,
#  '223979': 9.0,
#  '112853': 11.0,
#  '392262': 5.0,
#  '309247': 10.0,
#  '437642': 9.0,
#  '222079': 10.0,
#  '363962': 8.0,
#  '532656': 12.0,
#  '234856': 10.0,
#  '115831': 9.0,
#  '227248': 10.0,
#  '277764': 26.0,
#  '67203': 6.0,
#  '206008': 6.0,
#  '392927': 8.0,
#  '59334': 10.0,
#  '330611': 8.0,
#  '76433': 9.0,
#  '102749': 8.0,
#  '452525': 20.0,
#  '383729': 11.0,
#  '13709': 11.0,
#  '229252': 4.0,
#  '29512': 17.0,
#  '230004': 7.0,
#  '40050': 7.0,
#  '277562': 7.0,
#  '69990': 6.0,
#  '267714': 9.0,
#  '21360': 5.0,
#  '191671': 8.0,
#  '234169': 10.0,
#  '244294': 7.0,
#  '113458': 9.0,
#  '435110': 2.0,
#  '206136': 2.0,
#  '300355': 5.0,
#  '281241': 1.0,
#  '351371': 1.0,
#  '98942': 8.0,
#  '57566': 13.0,
#  '377020': 12.0,
#  '373269': 3.0,
#  '131977': 15.0,
#  '230060': 21.0,
#  '189127': 3.0,
#  '482020': 22.0,
#  '241632': 26.0,
#  '172729': 2.0,
#  '398090': 5.0,
#  '169561': 15.0,
#  '428080': 13.0,
#  '455193': 6.0,
#  '172783': 7.0,
#  '229599': 2.0,
#  '172781': 6.0,
#  '292695': 2.0,
#  '173486': 14.0,
#  '455529': 1.0,
#  '25020': 5.0,
#  '141617': 7.0,
#  '130759': 9.0,
#  '170021': 10.0,
#  '336166': 11.0,
#  '184074': 8.0,
#  '141308': 10.0,
#  '177987': 6.0,
#  '143286': 11.0,
#  '504294': 14.0,
#  '183929': 9.0,
#  '170081': 24.0,
#  '336314': 18.0,
#  '240135': 3.0,
#  '485158': 1.0,
#  '320973': 5.0,
#  '387284': 11.0,
#  '151748': 10.0,
#  '493636': 5.0,
#  '301164': 5.0,
#  '301365': 5.0,
#  '447967': 4.0,
#  '307870': 9.0,
#  '171809': 4.0,
#  '354615': 4.0,
#  '102525': 7.0,
#  '336627': 28.0,
#  '21302': 5.0,
#  '281593': 6.0,
#  '403180': 12.0,
#  '503265': 8.0,
#  '204012': 29.0,
#  '425294': 5.0,
#  '290003': 11.0,
#  '60583': 15.0,
#  '174606': 7.0,
#  '76727': 10.0,
#  '44570': 13.0,
#  '403438': 8.0,
#  '249318': 4.0,
#  '181765': 5.0,
#  '316172': 8.0,
#  '313942': 6.0,
#  '120135': 18.0,
#  '462351': 5.0,
#  '242179': 17.0,
#  '232548': 4.0,
#  '244477': 12.0,
#  '455543': 12.0,
#  '171097': 15.0,
#  '175975': 16.0,
#  '409088': 18.0,
#  '50337': 7.0,
#  '276396': 1.0,
#  '105093': 15.0,
#  '98694': 8.0,
#  '179987': 13.0,
#  '303710': 4.0,
#  '184727': 21.0,
#  '509612': 19.0,
#  '144568': 12.0,
#  '356701': 6.0,
#  '159732': 6.0,
#  '319005': 14.0,
#  '4205': 3.0,
#  '229376': 9.0,
#  '60058': 7.0,
#  '97699': 7.0,
#  '243909': 3.0,
#  '3258': 8.0,
#  '370746': 11.0,
#  '385942': 19.0,
#  '387136': 17.0,
#  '501197': 7.0,
#  '361524': 6.0,
#  '125847': 13.0,
#  '97066': 12.0,
#  '48864': 16.0,
#  '123758': 5.0,
#  '34833': 11.0,
#  '316190': 2.0,
#  '101429': 8.0,
#  '414085': 7.0,
#  '231161': 14.0,
#  '37313': 8.0,
#  '238000': 5.0,
#  '315346': 23.0,
#  '202414': 3.0,
#  '435173': 17.0,
#  '289893': 9.0,
#  '489028': 13.0,
#  '117542': 3.0,
#  '67666': 1.0,
#  '412091': 7.0,
#  '19104': 10.0,
#  '186631': 5.0,
#  '295701': 2.0,
#  '379357': 5.0,
#  '36009': 7.0,
#  '11975': 11.0,
#  '11141': 9.0,
#  '174645': 7.0,
#  '55510': 7.0,
#  '190648': 8.0,
#  '14192': 2.0,
#  '413783': 4.0,
#  '380243': 4.0,
#  '474098': 13.0,
#  '39189': 3.0,
#  '426211': 11.0,
#  '497751': 6.0,
#  '287008': 21.0,
#  '373582': 11.0,
#  '383147': 5.0,
#  '436664': 22.0,
#  '160696': 5.0,
#  '200227': 18.0,
#  '339114': 17.0,
#  '22742': 17.0,
#  '88845': 11.0,
#  '143795': 10.0,
#  '33565': 4.0,
#  '388304': 8.0,
#  '15086': 5.0,
#  '44541': 8.0,
#  '369241': 4.0,
#  '370775': 16.0,
#  '402421': 16.0,
#  '330954': 4.0,
#  '476489': 7.0,
#  '314777': 3.0,
#  '490199': 24.0,
#  '143938': 12.0,
#  '335824': 10.0,
#  '316673': 3.0,
#  '359713': 20.0,
#  '198585': 4.0,
#  '204147': 10.0,
#  '211370': 2.0,
#  '14613': 7.0,
#  '265955': 7.0,
#  '22337': 9.0,
#  '386614': 10.0,
#  '487671': 23.0,
#  '179011': 13.0,
#  '502995': 17.0,
#  '47545': 12.0,
#  '519547': 6.0,
#  '335876': 5.0,
#  '179210': 22.0,
#  '370018': 15.0,
#  '412006': 7.0,
#  '136451': 10.0,
#  '57757': 8.0,
#  '160133': 2.0,
#  '284868': 1.0,
#  '456968': 11.0,
#  '136514': 7.0,
#  '429293': 16.0,
#  '213177': 6.0,
#  '339697': 14.0,
#  '247025': 4.0,
#  '15869': 5.0,
#  '14149': 11.0,
#  '80474': 8.0,
#  '401584': 12.0,
#  '482653': 12.0,
#  '41990': 9.0,
#  '26809': 25.0,
#  '118667': 10.0,
#  '183118': 9.0,
#  '115721': 12.0,
#  '148060': 16.0,
#  '407545': 15.0,
#  '201417': 17.0,
#  '370125': 14.0,
#  '15458': 8.0,
#  '403878': 15.0,
#  '402687': 20.0,
#  '160310': 19.0,
#  '270626': 6.0,
#  '29448': 7.0,
#  '438204': 18.0,
#  '106417': 18.0,
#  '124673': 12.0,
#  '477848': 3.0,
#  '291364': 19.0,
#  '217021': 13.0,
#  '99570': 4.0,
#  '12441': 5.0,
#  '137010': 10.0,
#  '161604': 31.0,
#  '228901': 10.0,
#  '308383': 4.0,
#  '393601': 8.0,
#  '190394': 5.0,
#  '37595': 15.0,
#  '303928': 19.0,
#  '66815': 13.0,
#  '108524': 21.0,
#  '149731': 6.0,
#  '130679': 2.0,
#  '39031': 6.0,
#  '333740': 10.0,
#  '118016': 16.0,
#  '130754': 8.0,
#  '112868': 20.0,
#  '507927': 11.0,
#  '73602': 11.0,
#  '485171': 17.0,
#  '121493': 10.0,
#  '105886': 16.0,
#  '510215': 9.0,
#  '396740': 7.0,
#  '394291': 19.0,
#  '49648': 5.0,
#  '70271': 6.0,
#  '455028': 7.0,
#  '229602': 1.0,
#  '91981': 11.0,
#  '306676': 7.0,
#  '405479': 8.0,
#  '465254': 8.0,
#  '242952': 23.0,
#  '344915': 32.0,
#  '424845': 40.0,
#  '101371': 2.0,
#  '302106': 7.0,
#  '225426': 18.0,
#  '248926': 5.0,
#  '354791': 7.0,
#  '155788': 15.0,
#  '452649': 14.0,
#  '357052': 12.0,
#  '222953': 7.0,
#  '423344': 6.0,
#  '180696': 5.0,
#  '162268': 14.0,
#  '256689': 3.0,
#  '473974': 8.0,
#  '197284': 3.0,
#  '26748': 6.0,
#  '342437': 9.0,
#  '323352': 10.0,
#  '23964': 4.0,
#  '146801': 2.0,
#  '198137': 7.0,
#  '266146': 8.0,
#  '249918': 10.0,
#  '102336': 7.0,
#  '90641': 4.0,
#  '184166': 7.0,
#  '294327': 2.0,
#  '456752': 2.0,
#  '175109': 11.0,
#  '378968': 7.0,
#  '316418': 8.0,
#  '255570': 18.0,
#  '260335': 7.0,
#  '392740': 29.0,
#  '314181': 9.0,
#  '124735': 9.0,
#  '291058': 9.0,
#  '243286': 2.0,
#  '388844': 8.0,
#  '357968': 5.0,
#  '490605': 13.0,
#  '441761': 4.0,
#  '386803': 17.0,
#  '83061': 14.0,
#  '284273': 4.0,
#  '338907': 45.0,
#  '53878': 9.0,
#  '21019': 6.0,
#  '214316': 13.0,
#  '283443': 20.0,
#  '390933': 11.0,
#  '229406': 4.0,
#  '83959': 10.0,
#  '291555': 4.0,
#  '279302': 3.0,
#  '106260': 6.0,
#  '395016': 15.0,
#  '32550': 5.0,
#  '69233': 12.0,
#  '287526': 10.0,
#  '304996': 6.0,
#  '7550': 18.0,
#  '323477': 1.0,
#  '97032': 16.0,
#  '334915': 13.0,
#  '179128': 5.0,
#  '107674': 8.0,
#  '234952': 4.0,
#  '284208': 7.0,
#  '33081': 10.0,
#  '233539': 44.0,
#  '119839': 8.0,
#  '51982': 4.0,
#  '153': 19.0,
#  '146096': 25.0,
#  '198234': 10.0,
#  '407377': 5.0,
#  '29977': 8.0,
#  '245792': 3.0,
#  '135672': 21.0,
#  '37152': 5.0,
#  '518120': 43.0,
#  '40858': 5.0,
#  '44063': 10.0,
#  '50755': 8.0,
#  '427188': 2.0,
#  '147802': 16.0,
#  '291228': 9.0,
#  '247103': 5.0,
#  '116798': 2.0,
#  '205649': 4.0,
#  '224037': 12.0,
#  '362623': 12.0,
#  '144411': 16.0,
#  '184458': 12.0,
#  '318312': 4.0,
#  '196426': 6.0,
#  '464367': 3.0,
#  '123753': 5.0,
#  '346944': 20.0,
#  '208190': 2.0,
#  '142233': 6.0,
#  '472418': 14.0,
#  '188540': 3.0,
#  '111955': 9.0,
#  '110887': 14.0,
#  '100649': 4.0,
#  '466175': 10.0,
#  '499403': 8.0,
#  '256775': 6.0,
#  '116061': 10.0,
#  '187678': 5.0,
#  '302957': 4.0,
#  '112725': 1.0,
#  '428980': 6.0,
#  '37161': 10.0,
#  '62012': 8.0,
#  '125915': 3.0,
#  '473291': 9.0,
#  '100156': 8.0,
#  '166813': 12.0,
#  '153430': 8.0,
#  '8448': 19.0,
#  '268036': 23.0,
#  '244742': 7.0,
#  '97490': 7.0,
#  '244363': 21.0,
#  '272003': 17.0,
#  '187946': 13.0,
#  '145419': 21.0,
#  '275046': 1.0,
#  '193208': 11.0,
#  '29537': 12.0,
#  '26325': 7.0,
#  '85354': 3.0,
#  '338711': 6.0,
#  '65729': 5.0,
#  '233728': 13.0,
#  '229143': 10.0,
#  '201036': 8.0,
#  '170342': 14.0,
#  '88978': 3.0,
#  '442149': 18.0,
#  '441938': 18.0,
#  '441945': 15.0,
#  '107153': 4.0,
#  '226753': 6.0,
#  '123689': 2.0,
#  '25947': 5.0,
#  '484063': 10.0,
#  '69776': 7.0,
#  '28545': 6.0,
#  '343461': 5.0,
#  '81945': 15.0,
#  '305163': 8.0,
#  '322281': 9.0,
#  '412424': 17.0,
#  '61879': 8.0,
#  '113306': 9.0,
#  '293713': 5.0,
#  '434512': 5.0,
#  '264064': 3.0,
#  '476007': 15.0,
#  '83893': 11.0,
#  '84849': 16.0,
#  '84840': 9.0,
#  '125381': 13.0,
#  '304543': 12.0,
#  '103379': 7.0,
#  '224122': 10.0,
#  '495369': 6.0,
#  '59687': 7.0,
#  '412171': 6.0,
#  '121156': 2.0,
#  '57786': 8.0,
#  '395585': 4.0,
#  '243008': 11.0,
#  '229727': 10.0,
#  '39398': 5.0,
#  '131531': 2.0,
#  '246286': 5.0,
#  '23163': 4.0,
#  '64952': 8.0,
#  '168017': 5.0,
#  '69168': 10.0,
#  '164072': 7.0,
#  '160902': 3.0,
#  '37428': 6.0,
#  '311630': 16.0,
#  '5197': 3.0,
#  '384056': 12.0,
#  '131965': 13.0,
#  '455452': 7.0,
#  '445734': 7.0,
#  '33321': 7.0,
#  '35014': 6.0,
#  '259789': 11.0,
#  '293253': 12.0,
#  '71046': 7.0,
#  '161307': 9.0,
#  '78108': 10.0,
#  '327588': 21.0,
#  '303926': 11.0,
#  '323576': 2.0,
#  '105454': 2.0,
#  '403981': 24.0,
#  '8327': 19.0,
#  '217453': 17.0,
#  '78442': 18.0,
#  '410920': 11.0,
#  '130409': 5.0,
#  '41166': 7.0,
#  '213724': 5.0,
#  '406854': 17.0,
#  '421824': 10.0,
#  '133465': 10.0,
#  '230428': 9.0,
#  '227191': 3.0,
#  '356277': 6.0,
#  '446605': 11.0,
#  '420119': 13.0,
#  '436791': 10.0,
#  '330876': 19.0,
#  '141762': 19.0,
#  '507760': 10.0,
#  '97140': 7.0,
#  '32571': 11.0,
#  '254578': 6.0,
#  '129786': 14.0,
#  '194654': 18.0,
#  '45643': 4.0,
#  '94187': 5.0,
#  '387424': 36.0,
#  '75123': 6.0,
#  '317060': 8.0,
#  '147791': 3.0,
#  '315847': 4.0,
#  '102889': 6.0,
#  '102214': 7.0,
#  '31777': 16.0,
#  '508642': 19.0,
#  '12780': 6.0,
#  '243010': 10.0,
#  '107233': 7.0,
#  '411505': 3.0,
#  '28745': 9.0,
#  '123900': 6.0,
#  '259986': 12.0,
#  '317573': 12.0,
#  '388864': 12.0,
#  '154964': 5.0,
#  '74419': 11.0,
#  '140873': 6.0,
#  '190637': 12.0,
#  '267631': 9.0,
#  '490291': 2.0,
#  '121123': 6.0,
#  '400101': 62.0,
#  '423999': 6.0,
#  '403593': 7.0,
#  '79749': 3.0,
#  '339225': 2.0,
#  '205094': 9.0,
#  '494482': 4.0,
#  '317235': 8.0,
#  '422794': 7.0,
#  '143226': 9.0,
#  '457603': 15.0,
#  '309809': 17.0,
#  '264075': 2.0,
#  '334186': 3.0,
#  '48738': 6.0,
#  '193400': 14.0,
#  '105209': 12.0,
#  '193732': 6.0,
#  '374277': 3.0,
#  '50078': 12.0,
#  '154372': 13.0,
#  '66416': 8.0,
#  '198570': 12.0,
#  '70438': 27.0,
#  '382269': 5.0,
#  '147765': 7.0,
#  '459131': 8.0,
#  '198350': 4.0,
#  '317351': 13.0,
#  '437715': 10.0,
#  '279229': 4.0,
#  '308056': 11.0,
#  '130727': 2.0,
#  '241413': 15.0,
#  '175166': 18.0,
#  '15543': 7.0,
#  '19209': 13.0,
#  '222408': 18.0,
#  '292280': 8.0,
#  '327392': 15.0,
#  '362501': 7.0,
#  '329285': 7.0,
#  '334017': 6.0,
#  '253057': 20.0,
#  '377722': 7.0,
#  '71821': 12.0,
#  '238257': 16.0,
#  '264476': 7.0,
#  '512016': 1.0,
#  '145893': 4.0,
#  '55718': 5.0,
#  '14479': 13.0,
#  '484942': 5.0,
#  '78497': 11.0,
#  '111963': 11.0,
#  '238404': 9.0,
#  '179478': 12.0,
#  '122949': 14.0,
#  '60893': 7.0,
#  '131206': 14.0,
#  '132633': 9.0,
#  '331337': 16.0,
#  '189327': 8.0,
#  '65597': 4.0,
#  '3776': 9.0,
#  '361181': 11.0,
#  '389070': 13.0,
#  '507578': 9.0,
#  '243292': 12.0,
#  '302640': 11.0,
#  '102728': 6.0,
#  '8134': 14.0,
#  '99029': 8.0,
#  '355173': 3.0,
#  '335405': 12.0,
#  '46041': 8.0,
#  '476461': 7.0,
#  '466380': 10.0,
#  '230530': 3.0,
#  '230146': 20.0,
#  '356655': 11.0,
#  '214023': 7.0,
#  '171628': 5.0,
#  '378409': 17.0,
#  '398095': 4.0,
#  '256456': 8.0,
#  '53743': 11.0,
#  '193375': 20.0,
#  '291363': 10.0,
#  '49349': 7.0,
#  '100295': 18.0,
#  '60527': 17.0,
#  '79682': 9.0,
#  '461508': 4.0,
#  '489534': 12.0,
#  '404419': 1.0,
#  '275663': 3.0,
#  '39402': 2.0,
#  '57771': 11.0,
#  '127637': 12.0,
#  '140850': 6.0,
#  '190858': 10.0,
#  '388465': 9.0,
#  '102670': 20.0,
#  '78210': 14.0,
#  '338725': 16.0,
#  '175891': 16.0,
#  '75960': 6.0,
#  '399189': 4.0,
#  '142852': 6.0,
#  '71833': 2.0,
#  '40478': 5.0,
#  '54095': 13.0,
#  '12672': 6.0,
#  '50936': 14.0,
#  '93365': 8.0,
#  '272034': 3.0,
#  '40589': 12.0,
#  '224452': 6.0,
#  '400912': 12.0,
#  '378468': 5.0,
#  '146444': 13.0,
#  '456852': 10.0,
#  '107851': 18.0,
#  '89021': 3.0,
#  '330040': 6.0,
#  '452590': 15.0,
#  '403819': 18.0,
#  '420689': 11.0,
#  '191150': 12.0,
#  '74520': 11.0,
#  '460292': 17.0,
#  '130992': 6.0,
#  '346687': 14.0,
#  '169993': 15.0,
#  '260352': 7.0,
#  '158382': 7.0,
#  '449725': 5.0,
#  '50851': 11.0,
#  '521251': 5.0,
#  '205500': 15.0,
#  '331846': 17.0,
#  '69045': 7.0,
#  '31748': 12.0,
#  '20143': 15.0,
#  '524289': 18.0,
#  '203930': 5.0,
#  ...}

# %%
id_steps_df = pd.DataFrame.from_dict(id_steps, orient = 'index').reset_index().rename(columns={0:'n_steps','index':'id'})
id_steps_df
# Out:
#            id  n_steps
# 0       44123     11.0
# 1       67664      3.0
# 2       38798      5.0
# 3       35173      7.0
# 4       84797      4.0
# ...       ...      ...
# 29995  267661     16.0
# 29996  386977     22.0
# 29997  103312     10.0
# 29998  486161      7.0
# 29999  298512      9.0
#
# [30000 rows x 2 columns]

# %%
recipes = recipes.combine_first(id_steps_df)
recipes.head()
# Out:
#    contributor_id                                        description     id  \
# 0           35193  an original recipe created by chef scott meska...  44123
# 1           91970  my children and their friends ask for my homem...  67664
# 2            1533            these were so go, it surprised even me.  38798
# 3           22724  my sister-in-law made these for us at a family...  35173
# 4            4470  i think a fondue is a very romantic casual din...  84797
#
#    minutes  n_ingredients  n_steps                                      name  \
# 0       90           18.0     11.0     george s at the cove  black bean soup
# 1       10            NaN      3.0        healthy for them  yogurt popsicles
# 2       30            8.0      5.0              i can t believe it s spinach
# 3       45            NaN      7.0                      italian  gut busters
# 4       25            NaN      4.0  love is in the air  beef fondue   sauces
#
#    submitted
# 0 2002-10-25
# 1 2003-07-26
# 2 2002-08-29
# 3 2002-07-27
# 4 2004-02-23

# %% [markdown]
# 3.5 Проверьте, содержит ли столбец `n_steps` пропуски. Если нет, то преобразуйте его к целочисленному типу и сохраните результаты в файл `recipes_sample_with_filled_nsteps.csv`

# %%
recipes['n_steps'].isna().sum()
# Out:
# 0

# %%
#recipes.to_csv('recipes_sample_with_filled_nsteps.csv', index = False, sep = ',')
