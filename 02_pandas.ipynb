# %% [markdown]
# # Pandas

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Загрузите данные из файла `sp500hst.txt` и обозначьте столбцы в соответствии с содержимым: `"date", "ticker", "open", "high", "low", "close", "volume"`.

# %%
df = pd.read_csv('sp500hst.txt', sep = ',', header = None, names = ["date", "ticker", "open", "high", "low", "close", "volume"] )
df
# Out:
#             date ticker   open     high     low  close  volume
# 0       20090821      A  25.60  25.6100  25.220  25.55   34758
# 1       20090824      A  25.64  25.7400  25.330  25.50   22247
# 2       20090825      A  25.50  25.7000  25.225  25.34   30891
# 3       20090826      A  25.32  25.6425  25.145  25.48   33334
# 4       20090827      A  25.50  25.5700  25.230  25.54   70176
# ...          ...    ...    ...      ...     ...    ...     ...
# 122569  20100813    ZMH  51.72  51.9000  51.380  51.44   14561
# 122570  20100816    ZMH  51.13  51.4700  50.600  51.00   13489
# 122571  20100817    ZMH  51.14  51.6000  50.890  51.21   20498
# 122572  20100819    ZMH  51.63  51.6300  50.170  50.22   18259
# 122573  20100820    ZMH  50.03  50.5500  49.480  49.82   17792
#
# [122574 rows x 7 columns]

# %% [markdown]
# 2. Рассчитайте среднее значение показателей для каждого из столбцов c номерами 3-6.

# %%
df.loc[:,'high':'volume'].mean()
# Out:
# high         43.102243
# low          42.054464
# close        42.601865
# volume    81395.068138
# dtype: float64

# %% [markdown]
# 3. Добавьте столбец, содержащий только число месяца, к которому относится дата.

# %%
df['date'] = pd.to_datetime(df['date'], format = '%Y%m%d')
df['month'] = df['date'].dt.month
df
# Out:
#              date ticker   open     high     low  close  volume  month
# 0      2009-08-21      A  25.60  25.6100  25.220  25.55   34758      8
# 1      2009-08-24      A  25.64  25.7400  25.330  25.50   22247      8
# 2      2009-08-25      A  25.50  25.7000  25.225  25.34   30891      8
# 3      2009-08-26      A  25.32  25.6425  25.145  25.48   33334      8
# 4      2009-08-27      A  25.50  25.5700  25.230  25.54   70176      8
# ...           ...    ...    ...      ...     ...    ...     ...    ...
# 122569 2010-08-13    ZMH  51.72  51.9000  51.380  51.44   14561      8
# 122570 2010-08-16    ZMH  51.13  51.4700  50.600  51.00   13489      8
# 122571 2010-08-17    ZMH  51.14  51.6000  50.890  51.21   20498      8
# 122572 2010-08-19    ZMH  51.63  51.6300  50.170  50.22   18259      8
# 122573 2010-08-20    ZMH  50.03  50.5500  49.480  49.82   17792      8
#
# [122574 rows x 8 columns]

# %% [markdown]
# 4. Рассчитайте суммарный объем торгов для для одинаковых значений тикеров.

# %%
df.groupby('ticker')['volume'].sum()
# Out:
# ticker
# A        8609336
# AA      81898998
# AAPL    52261170
# ABC      9006756
# ABT     18975870
#           ...
# XTO     21297931
# YHOO    56837171
# YUM     10971538
# ZION    15551119
# ZMH      4938916
# Name: volume, Length: 524, dtype: int64

# %% [markdown]
# 5. Загрузите данные из файла sp500hst.txt и обозначьте столбцы в соответствии с содержимым: "date", "ticker", "open", "high", "low", "close", "volume". Добавьте столбец с расшифровкой названия тикера, используя данные из файла `sp_data2.csv` . В случае нехватки данных об именах тикеров корректно обработать их.

# %%
sp = pd.read_csv('sp_data2.csv', sep = ';', header = None, names = ['ticker', 'company', 'log return'])
sp
# Out:
#     ticker          company log return
# 0     AAPL            Apple       3.6%
# 1     AMZN       Amazon.com       3.2%
# 2    GOOGL         Alphabet       3.1%
# 3     GOOG         Alphabet       3.1%
# 4     MSFT        Microsoft       3.0%
# ..     ...              ...        ...
# 500    SCG            SCANA       0.0%
# 501    AIZ         Assurant       0.0%
# 502    AYI    Acuity Brands       0.0%
# 503    HRB        H&R Block       0.0%
# 504    RRC  Range Resources       0.0%
#
# [505 rows x 3 columns]

# %%
df
# Out:
#              date ticker   open     high     low  close  volume  month
# 0      2009-08-21      A  25.60  25.6100  25.220  25.55   34758      8
# 1      2009-08-24      A  25.64  25.7400  25.330  25.50   22247      8
# 2      2009-08-25      A  25.50  25.7000  25.225  25.34   30891      8
# 3      2009-08-26      A  25.32  25.6425  25.145  25.48   33334      8
# 4      2009-08-27      A  25.50  25.5700  25.230  25.54   70176      8
# ...           ...    ...    ...      ...     ...    ...     ...    ...
# 122569 2010-08-13    ZMH  51.72  51.9000  51.380  51.44   14561      8
# 122570 2010-08-16    ZMH  51.13  51.4700  50.600  51.00   13489      8
# 122571 2010-08-17    ZMH  51.14  51.6000  50.890  51.21   20498      8
# 122572 2010-08-19    ZMH  51.63  51.6300  50.170  50.22   18259      8
# 122573 2010-08-20    ZMH  50.03  50.5500  49.480  49.82   17792      8
#
# [122574 rows x 8 columns]

# %%
df = df.merge(sp[['ticker','company']])
df
# Out:
#             date ticker   open     high     low  close  volume  month  \
# 0     2009-08-21      A  25.60  25.6100  25.220  25.55   34758      8
# 1     2009-08-24      A  25.64  25.7400  25.330  25.50   22247      8
# 2     2009-08-25      A  25.50  25.7000  25.225  25.34   30891      8
# 3     2009-08-26      A  25.32  25.6425  25.145  25.48   33334      8
# 4     2009-08-27      A  25.50  25.5700  25.230  25.54   70176      8
# ...          ...    ...    ...      ...     ...    ...     ...    ...
# 82167 2010-08-13   ZION  20.17  20.4300  19.840  19.89   25193      8
# 82168 2010-08-16   ZION  19.81  19.9600  19.600  19.95   25914      8
# 82169 2010-08-17   ZION  20.07  20.4700  19.830  20.31   31717      8
# 82170 2010-08-19   ZION  19.83  20.0000  19.130  19.35   45935      8
# 82171 2010-08-20   ZION  19.15  19.2700  18.810  19.14   37225      8
#
#                     company
# 0      Agilent Technologies
# 1      Agilent Technologies
# 2      Agilent Technologies
# ...

# %% [markdown]
# ## Лабораторная работа №2

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца(ов) с индексами.

# %%
recipes = pd.read_csv('recipes_sample.csv', sep = ',', header = 0, parse_dates = )
reviews = pd.read_csv('reviews_sample.csv', sep = ',', header = 0, parse_dates = , index_col=0)

reviews
# Out:
#             user_id  recipe_id        date  rating  \
# 370476        21752      57993  2003-05-01       5
# 624300       431813     142201  2007-09-16       5
# 187037       400708     252013  2008-01-10       4
# 706134   2001852463     404716  2017-12-11       5
# 312179        95810     129396  2008-03-14       5
# ...             ...        ...         ...     ...
# 1013457     1270706     335534  2009-05-17       4
# 158736      2282344       8701  2012-06-03       0
# 1059834      689540     222001  2008-04-08       5
# 453285   2000242659     354979  2015-06-02       5
# 691207       463435     415599  2010-09-30       5
#
#                                                     review
# 370476   Last week whole sides of frozen salmon fillet ...
# 624300   So simple and so tasty!  I used a yellow capsi...
# 187037   Very nice breakfast HH, easy to make and yummy...
# 706134   These are a favorite for the holidays and so e...
# ...

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
def params(df):
    print('Количество точек данных (строк):', df.shape[0])
    print('Количество столбцов:', df.shape[1])
    print('Тип данных каждого столбца: \n', df.dtypes)
    return ''
    
print('Для рецептов:', '\n')
print(params(recipes), '\n')
print('Для отзывов:', '\n')
print(params(reviews), '\n')
# Out:
# Для рецептов:
#
# Количество точек данных (строк): 30000
# Количество столбцов: 8
# Тип данных каждого столбца:
#  name               object
# id                  int64
# minutes             int64
# contributor_id      int64
# submitted          object
# n_steps           float64
# description        object
# n_ingredients     float64
# dtype: object
#
#
# Для отзывов:
#
# Количество точек данных (строк): 126696
# Количество столбцов: 5
# Тип данных каждого столбца:
#  user_id       int64
# recipe_id     int64
# date         object
# rating        int64
# review       object
# dtype: object

# %%
recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            30000 non-null  object
#  1   id              30000 non-null  int64
#  2   minutes         30000 non-null  int64
#  3   contributor_id  30000 non-null  int64
#  4   submitted       30000 non-null  object
#  5   n_steps         18810 non-null  float64
#  6   description     29377 non-null  object
#  7   n_ingredients   21120 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
recipes.isnull().sum(axis=0)
# Out:
# name                  0
# id                    0
# minutes               0
# contributor_id        0
# submitted             0
# n_steps           11190
# description         623
# n_ingredients      8880
# dtype: int64

# %%
reviews.isnull().sum(axis=0)
# Out:
# user_id       0
# recipe_id     0
# date          0
# rating        0
# review       17
# dtype: int64

# %%
print('Доля строк, содержащих пропуски для файла Рецепты: {:.2%}'.format(sum(recipes.isnull().sum(axis=1) > 0) / recipes.shape[0]))
print('Доля строк, содержащих пропуски для файла Отзывы: {:.2%}'.format(sum(reviews.isnull().sum(axis=1) > 0) / reviews.shape[0]))
# Out:
# Доля строк, содержащих пропуски для файла Рецепты: 56.85%
# Доля строк, содержащих пропуски для файла Отзывы: 0.01%

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
recipes[['minutes', 'n_steps', 'n_ingredients']].mean(axis=0)
# Out:
# minutes          123.358133
# n_steps            9.805582
# n_ingredients      9.008286
# dtype: float64

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
recipes.sample(10)['name']
# Out:
# 10432                          eggplant hummus
# 10357                               egg pakora
# 10884              festival sausage  crock pot
# 25296              spicy artichoke spinach dip
# 14708            italian restaurant baked ziti
# 26838                       swiss mocha cooler
# 21047    polenta gratin with gorgonzola cheese
# 19391                         orange snowdrops
# 9484             dipped chocolate chip cookies
# 24643                    smoky peas   potatoes
# Name: name, dtype: object

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
reviews = reviews.reset_index(drop=True)
reviews
# Out:
#            user_id  recipe_id        date  rating  \
# 0            21752      57993  2003-05-01       5
# 1           431813     142201  2007-09-16       5
# 2           400708     252013  2008-01-10       4
# 3       2001852463     404716  2017-12-11       5
# 4            95810     129396  2008-03-14       5
# ...            ...        ...         ...     ...
# 126691     1270706     335534  2009-05-17       4
# 126692     2282344       8701  2012-06-03       0
# 126693      689540     222001  2008-04-08       5
# 126694  2000242659     354979  2015-06-02       5
# 126695      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# 3       These are a favorite for the holidays and so e...
# 4       Excellent soup!  The tomato flavor is just gre...
# ...

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
recipes[(recipes['minutes'] <= 20) & (recipes['n_ingredients'] <= 5)]
# Out:
#                                                     name      id  minutes  \
# 28                                   quick biscuit bread  302399       20
# 60                         peas  fit for a king or queen  303944       20
# 90                     hawaiian sunrise           mimosa  100837        5
# 91            tasty dish s   banana pudding in 2 minutes  286484        2
# 94                                    1 minute meatballs   11361       13
# ...                                                  ...     ...      ...
# 29873  zip and steam red potatoes with butter and garlic  304922       13
# 29874                          ziplock vanilla ice cream   74250       10
# 29905                      zucchini and corn with cheese  256177       15
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29983                          zucchini with serrano ham  162411       15
#
#        contributor_id   submitted  n_steps  \
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
recipes['submitted'] = pd.to_datetime(recipes['submitted'])
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %%
recipes = pd.read_csv('recipes_sample.csv', sep = ',', header = 0, parse_dates = ['submitted'])
recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            30000 non-null  object
#  1   id              30000 non-null  int64
#  2   minutes         30000 non-null  int64
#  3   contributor_id  30000 non-null  int64
#  4   submitted       30000 non-null  datetime64[ns]
#  5   n_steps         18810 non-null  float64
#  6   description     29377 non-null  object
#  7   n_ingredients   21120 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
recipes[recipes['submitted'].dt.year <= 2010]
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29993                     zuni caf zucchini pickles  316950     2895
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
recipes['description_length'] = recipes['description'].str.len()
recipes.head()
# Out:
#                                        name     id  minutes  contributor_id  \
# 0     george s at the cove  black bean soup  44123       90           35193
# 1        healthy for them  yogurt popsicles  67664       10           91970
# 2              i can t believe it s spinach  38798       30            1533
# 3                      italian  gut busters  35173       45           22724
# 4  love is in the air  beef fondue   sauces  84797       25            4470
#
#    submitted  n_steps                                        description  \
# 0 2002-10-25      NaN  an original recipe created by chef scott meska...
# 1 2003-07-26      NaN  my children and their friends ask for my homem...
# 2 2002-08-29      NaN            these were so go, it surprised even me.
# 3 2002-07-27      NaN  my sister-in-law made these for us at a family...
# 4 2004-02-23      4.0  i think a fondue is a very romantic casual din...
#
#    n_ingredients  description_length
# ...

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipes['name'] = recipes['name'].str.capitalize()
recipes
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами).

# %%
recipes['name_word_count'] = recipes['name'].str.split().str.len()
recipes
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
recipes.groupby('contributor_id')['name'].count().idxmax()
# Out:
# 89831

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы?

# %%
reviews.groupby('recipe_id')['rating'].mean()
# Out:
# recipe_id
# 48        1.000000
# 55        4.750000
# 66        4.944444
# 91        4.750000
# 94        5.000000
#             ...
# 536547    5.000000
# 536610    0.000000
# 536728    4.000000
# 536729    4.750000
# 536747    0.000000
# Name: rating, Length: 28100, dtype: float64

# %%
len(set(recipes['id']).symmetric_difference(set(reviews['recipe_id'])))
# Out:
# 1900

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
recipes.groupby(recipes['submitted'].dt.year)['name'].count()
# Out:
# submitted
# 1999     275
# 2000     104
# 2001     589
# 2002    2644
# 2003    2334
# 2004    2153
# 2005    3130
# 2006    3473
# 2007    4429
# 2008    4029
# 2009    2963
# 2010    1538
# 2011     922
# 2012     659
# 2013     490
# 2014     139
# 2015      42
# 2016      24
# 2017      39
# 2018      24
# Name: name, dtype: int64

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты без отзывов должны отсутствовать в данной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и выведя на экран строку из полученного `DataFrame`, содержащую информацию об этом отзыве.

# %%
reviews = reviews.rename({'recipe_id':'id'}, axis = 1)
dff = reviews.merge(recipes, on = ['id'], how = 'left')[['id', 'name', 'user_id', 'rating']]

# %%
reviews = reviews.rename({'id':'recipe_id'}, axis = 1)

# %%
dff
# Out:
#             id                                               name     user_id  \
# 0        57993                               Salmon with tomatoes       21752
# 1       142201                               Lemon cajun stir fry      431813
# 2       252013        Cottage cheese  honey and cinnamon on toast      400708
# 3       404716                                      Belly buttons  2001852463
# 4       129396                                 Double tomato soup       95810
# ...        ...                                                ...         ...
# 126691  335534                     Melissa s lemon pepper chicken     1270706
# 126692    8701                    Should be illegal oven bbq ribs     2282344
# 126693  222001                                 Cheesy bacon bread      689540
# 126694  354979  Kittencal s pan seared steak  stove top to ove...  2000242659
# 126695  415599                               Montreal steak spice      463435
#
#         rating
# 0            5
# ...

# %%
dff[dff['id'] == tuple(set(recipes['id']).symmetric_difference(set(reviews['recipe_id'])))]
# Out:
# Empty DataFrame
# Columns: [id, name, user_id, rating]
# Index: []

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`. У рецептов, для которых отсутствуют отзывы, в соответствущем столбце должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и выведя на экран строку из полученного `DataFrame`, содержащую информацию об этом отзыве.

# %%
joined = reviews.groupby('recipe_id')['review'].count().to_frame()
recipes = recipes.rename({'id': 'recipe_id'}, axis=1)
spp = recipes[['recipe_id', 'name']].merge(joined, on='recipe_id', how='outer').fillna(0)
spp.head()
# Out:
#    recipe_id                                      name  review
# 0      44123     George s at the cove  black bean soup     3.0
# 1      67664        Healthy for them  yogurt popsicles     8.0
# 2      38798              I can t believe it s spinach     3.0
# 3      35173                      Italian  gut busters     1.0
# 4      84797  Love is in the air  beef fondue   sauces     8.0

# %% [markdown]
# 5.3. Выясните, отзывы, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
mean_rait = reviews.groupby(pd.to_datetime(reviews['date'], format='%Y-%m-%d', errors='ignore').dt.year)[['rating']].mean()
mean_rait.idxmin()[0]
# Out:
# 2017

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
recipes = recipes.sort_values(by = 'name_word_count', ascending = False)
recipes
recipes.to_csv('6.1_new_recipes.csv')
new = pd.read_csv('6.1_new_recipes.csv', sep = ',',index_col=0, header = 0)
new
# Out:
#                                                     name  recipe_id  minutes  \
# 26223  Subru uncle s whole green moong dal i ll be ma...      77188       95
# 28083  Tsr version of t g i  friday s black bean soup...     102274       75
# 26222  Subru uncle s toor ki dal sindhi style  dad  m...      76908       65
# 27876  Top secret recipes version of  i h o p  griddl...     113346       20
# 5734   Chicken curry or  cat s vomit on a bed of magg...     294898       30
# ...                                                  ...        ...      ...
# 3253                                          Blackmoons     323195      430
# 4138                                         Bushwhacker     156521       10
# 2357                                            Basbousa      12957       60
# 15052                                          Josefinas     264859       20
# 4710                                            Caramels     143615       30
#
# ...

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %%
with pd.ExcelWriter('6.2.xlsx') as writer: 
    dff.to_excel(writer, sheet_name='Рецепты с оценками')
    spp.to_excel(writer, sheet_name='Количество отзывов по рецептам')
    writer.save()
